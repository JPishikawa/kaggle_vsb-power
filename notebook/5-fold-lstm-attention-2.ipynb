# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
# Out:
# /home/cwademo123/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        # now, we just add all the features to new_ts and convert it to np.array
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
# 100%|██████████| 1452/1452 [06:38<00:00,  3.65it/s]
#  11%|█         | 162/1452 [00:40<05:30,  3.91it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ec943055693e> in <module>()
#       8         X.append(X_temp)
#       9         y.append(y_temp)
# ---> 10 load_all()
#      11 X = np.concatenate(X)
#      12 y = np.concatenate(y)
#
# <ipython-input-10-ec943055693e> in load_all()
#       5     total_size = len(df_train)
#       6     for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
# ----> 7         X_temp, y_temp = prep_data(ini, end)
#       8         X.append(X_temp)
#       9         y.append(y_temp)
#
# <ipython-input-9-9f3631ebe811> in prep_data(start, end)
#      19                 y.append(target)
#      20             # extract and transform data into sets of features
# ---> 21             X_signal.append(transform_ts(praq_train[str(signal_id)]))
#      22         # concatenate all the 3 phases in one matrix
#      23         X_signal = np.concatenate(X_signal, axis=1)
#
# <ipython-input-8-82a069a7279a> in transform_ts(ts, n_dim, min_max)
#      21         std_bot = mean - std
#      22         # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
# ---> 23         percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100])
#      24         max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
#      25         relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    4289     r, k = _ureduce(a, func=_percentile, q=q, axis=axis, out=out,
#    4290                     overwrite_input=overwrite_input,
# -> 4291                     interpolation=interpolation)
#    4292     if keepdims:
#    4293         return r.reshape(q.shape + k)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    4031         keepdim = (1,) * a.ndim
#    4032
# -> 4033     r = func(a, **kwargs)
#    4034     return r, keepdim
#    4035
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in _percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    4390         weights_above.shape = weights_shape
#    4391
# -> 4392         ap.partition(concatenate((indices_below, indices_above)), axis=axis)
#    4393
#    4394         # ensure axis with qth is first
#
# KeyboardInterrupt:

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
# Out:
# (2904, 160, 57) (2904,)

# %%
X = np.load("./X.npy")
y = np.load("./y.npy")

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(LSTM(128, return_sequences=True))(inp)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64)(x)
    
    x = LeakyReLU(alpha=0.1)(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 27s 12ms/step - loss: 0.3726 - matthews_correlation: 0.0000e+00 - val_loss: 0.2332 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.2276 - matthews_correlation: 0.0000e+00 - val_loss: 0.2263 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.2192 - matthews_correlation: 0.0000e+00 - val_loss: 0.2189 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.2159 - matthews_correlation: 0.1048 - val_loss: 0.2164 - val_matthews_correlation: 0.1923
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.19231, saving model to weights_0.h5
# Epoch 5/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.2111 - matthews_correlation: 0.0997 - val_loss: 0.2120 - val_matthews_correlation: 0.0772
#
# Epoch 00005: val_matthews_correlation did not improve from 0.19231
# Epoch 6/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.2036 - matthews_correlation: 0.1122 - val_loss: 0.2059 - val_matthews_correlation: 0.0772
#
# Epoch 00006: val_matthews_correlation did not improve from 0.19231
# Epoch 7/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1923 - matthews_correlation: 0.1958 - val_loss: 0.1758 - val_matthews_correlation: 0.1930
#
# Epoch 00007: val_matthews_correlation improved from 0.19231 to 0.19302, saving model to weights_0.h5
# Epoch 8/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1632 - matthews_correlation: 0.3256 - val_loss: 0.1200 - val_matthews_correlation: 0.2606
#
# Epoch 00008: val_matthews_correlation improved from 0.19302 to 0.26056, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1245 - matthews_correlation: 0.4492 - val_loss: 0.1016 - val_matthews_correlation: 0.5195
#
# Epoch 00009: val_matthews_correlation improved from 0.26056 to 0.51948, saving model to weights_0.h5
# Epoch 10/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1187 - matthews_correlation: 0.5636 - val_loss: 0.0909 - val_matthews_correlation: 0.7594
#
# Epoch 00010: val_matthews_correlation improved from 0.51948 to 0.75941, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1106 - matthews_correlation: 0.6227 - val_loss: 0.0859 - val_matthews_correlation: 0.7246
#
# Epoch 00011: val_matthews_correlation did not improve from 0.75941
# Epoch 12/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1081 - matthews_correlation: 0.5792 - val_loss: 0.0955 - val_matthews_correlation: 0.7800
#
# Epoch 00012: val_matthews_correlation improved from 0.75941 to 0.77997, saving model to weights_0.h5
# Epoch 13/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1085 - matthews_correlation: 0.5929 - val_loss: 0.1068 - val_matthews_correlation: 0.7319
#
# Epoch 00013: val_matthews_correlation did not improve from 0.77997
# Epoch 14/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1076 - matthews_correlation: 0.6547 - val_loss: 0.0921 - val_matthews_correlation: 0.6592
#
# Epoch 00014: val_matthews_correlation did not improve from 0.77997
# Epoch 15/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1076 - matthews_correlation: 0.6011 - val_loss: 0.0778 - val_matthews_correlation: 0.7097
#
# Epoch 00015: val_matthews_correlation did not improve from 0.77997
# Epoch 16/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1049 - matthews_correlation: 0.6082 - val_loss: 0.0799 - val_matthews_correlation: 0.7877
#
# Epoch 00016: val_matthews_correlation improved from 0.77997 to 0.78766, saving model to weights_0.h5
# Epoch 17/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1074 - matthews_correlation: 0.5676 - val_loss: 0.0822 - val_matthews_correlation: 0.7320
#
# Epoch 00017: val_matthews_correlation did not improve from 0.78766
# Epoch 18/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1021 - matthews_correlation: 0.6138 - val_loss: 0.0983 - val_matthews_correlation: 0.7215
#
# Epoch 00018: val_matthews_correlation did not improve from 0.78766
# Epoch 19/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1033 - matthews_correlation: 0.6246 - val_loss: 0.0766 - val_matthews_correlation: 0.7621
#
# Epoch 00019: val_matthews_correlation did not improve from 0.78766
# Epoch 20/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0980 - matthews_correlation: 0.6389 - val_loss: 0.0856 - val_matthews_correlation: 0.7456
#
# Epoch 00020: val_matthews_correlation did not improve from 0.78766
# Epoch 21/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0977 - matthews_correlation: 0.6122 - val_loss: 0.0882 - val_matthews_correlation: 0.6465
#
# Epoch 00021: val_matthews_correlation did not improve from 0.78766
# Epoch 22/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1026 - matthews_correlation: 0.6299 - val_loss: 0.0856 - val_matthews_correlation: 0.7300
#
# Epoch 00022: val_matthews_correlation did not improve from 0.78766
# Epoch 23/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0978 - matthews_correlation: 0.6271 - val_loss: 0.0943 - val_matthews_correlation: 0.5684
#
# Epoch 00023: val_matthews_correlation did not improve from 0.78766
# Epoch 24/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1054 - matthews_correlation: 0.6001 - val_loss: 0.0789 - val_matthews_correlation: 0.7368
#
# Epoch 00024: val_matthews_correlation did not improve from 0.78766
# Epoch 25/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0972 - matthews_correlation: 0.6232 - val_loss: 0.0844 - val_matthews_correlation: 0.7434
#
# Epoch 00025: val_matthews_correlation did not improve from 0.78766
# Epoch 26/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0932 - matthews_correlation: 0.6930 - val_loss: 0.0958 - val_matthews_correlation: 0.7189
#
# Epoch 00026: val_matthews_correlation did not improve from 0.78766
# Epoch 27/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1001 - matthews_correlation: 0.5693 - val_loss: 0.0822 - val_matthews_correlation: 0.7069
#
# Epoch 00027: val_matthews_correlation did not improve from 0.78766
# Epoch 28/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0981 - matthews_correlation: 0.6377 - val_loss: 0.0779 - val_matthews_correlation: 0.7804
#
# Epoch 00028: val_matthews_correlation did not improve from 0.78766
# Epoch 29/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0945 - matthews_correlation: 0.6747 - val_loss: 0.0816 - val_matthews_correlation: 0.7465
#
# Epoch 00029: val_matthews_correlation did not improve from 0.78766
# Epoch 30/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0874 - matthews_correlation: 0.6987 - val_loss: 0.0722 - val_matthews_correlation: 0.7781
#
# Epoch 00030: val_matthews_correlation did not improve from 0.78766
# Epoch 31/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0892 - matthews_correlation: 0.6781 - val_loss: 0.0768 - val_matthews_correlation: 0.7761
#
# Epoch 00031: val_matthews_correlation did not improve from 0.78766
# Epoch 32/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0891 - matthews_correlation: 0.6960 - val_loss: 0.0744 - val_matthews_correlation: 0.7601
#
# Epoch 00032: val_matthews_correlation did not improve from 0.78766
# Epoch 33/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0899 - matthews_correlation: 0.6627 - val_loss: 0.0937 - val_matthews_correlation: 0.7109
#
# Epoch 00033: val_matthews_correlation did not improve from 0.78766
# Epoch 34/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0907 - matthews_correlation: 0.6918 - val_loss: 0.0810 - val_matthews_correlation: 0.7228
#
# Epoch 00034: val_matthews_correlation did not improve from 0.78766
# Epoch 35/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1026 - matthews_correlation: 0.4868 - val_loss: 0.0992 - val_matthews_correlation: 0.6855
#
# Epoch 00035: val_matthews_correlation did not improve from 0.78766
# Epoch 36/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1002 - matthews_correlation: 0.6802 - val_loss: 0.0799 - val_matthews_correlation: 0.7433
#
# Epoch 00036: val_matthews_correlation did not improve from 0.78766
# Epoch 37/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0904 - matthews_correlation: 0.6867 - val_loss: 0.0946 - val_matthews_correlation: 0.7612
#
# Epoch 00037: val_matthews_correlation did not improve from 0.78766
# Epoch 38/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0881 - matthews_correlation: 0.6899 - val_loss: 0.1045 - val_matthews_correlation: 0.6625
#
# Epoch 00038: val_matthews_correlation did not improve from 0.78766
# Epoch 39/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0834 - matthews_correlation: 0.7088 - val_loss: 0.0730 - val_matthews_correlation: 0.7516
#
# Epoch 00039: val_matthews_correlation did not improve from 0.78766
# Epoch 40/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1171 - matthews_correlation: 0.4719 - val_loss: 0.1095 - val_matthews_correlation: 0.7413
#
# Epoch 00040: val_matthews_correlation did not improve from 0.78766
# Epoch 41/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1091 - matthews_correlation: 0.5728 - val_loss: 0.0828 - val_matthews_correlation: 0.7584
#
# Epoch 00041: val_matthews_correlation did not improve from 0.78766
# Epoch 42/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1032 - matthews_correlation: 0.6275 - val_loss: 0.0832 - val_matthews_correlation: 0.7807
#
# Epoch 00042: val_matthews_correlation did not improve from 0.78766
# Epoch 43/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0983 - matthews_correlation: 0.6606 - val_loss: 0.0819 - val_matthews_correlation: 0.8078
#
# Epoch 00043: val_matthews_correlation improved from 0.78766 to 0.80778, saving model to weights_0.h5
# Epoch 44/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0868 - matthews_correlation: 0.6824 - val_loss: 0.0841 - val_matthews_correlation: 0.8262
#
# Epoch 00044: val_matthews_correlation improved from 0.80778 to 0.82624, saving model to weights_0.h5
# Epoch 45/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0839 - matthews_correlation: 0.6930 - val_loss: 0.0780 - val_matthews_correlation: 0.7949
#
# Epoch 00045: val_matthews_correlation did not improve from 0.82624
# Epoch 46/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0924 - matthews_correlation: 0.6502 - val_loss: 0.0792 - val_matthews_correlation: 0.7331
#
# Epoch 00046: val_matthews_correlation did not improve from 0.82624
# Epoch 47/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0887 - matthews_correlation: 0.6445 - val_loss: 0.0818 - val_matthews_correlation: 0.7659
#
# Epoch 00047: val_matthews_correlation did not improve from 0.82624
# Epoch 48/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0837 - matthews_correlation: 0.6892 - val_loss: 0.0898 - val_matthews_correlation: 0.7272
#
# Epoch 00048: val_matthews_correlation did not improve from 0.82624
# Epoch 49/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0891 - matthews_correlation: 0.6660 - val_loss: 0.0851 - val_matthews_correlation: 0.7646
#
# Epoch 00049: val_matthews_correlation did not improve from 0.82624
# Epoch 50/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0896 - matthews_correlation: 0.6931 - val_loss: 0.0813 - val_matthews_correlation: 0.7535
#
# Epoch 00050: val_matthews_correlation did not improve from 0.82624
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 25s 11ms/step - loss: 0.3630 - matthews_correlation: 0.0000e+00 - val_loss: 0.2408 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2388 - matthews_correlation: 0.0000e+00 - val_loss: 0.2343 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2193 - matthews_correlation: 0.0000e+00 - val_loss: 0.2227 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2093 - matthews_correlation: 0.1078 - val_loss: 0.2248 - val_matthews_correlation: 0.1045
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.10453, saving model to weights_1.h5
# Epoch 5/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2040 - matthews_correlation: 0.0523 - val_loss: 0.2114 - val_matthews_correlation: 0.1045
#
# Epoch 00005: val_matthews_correlation did not improve from 0.10453
# Epoch 6/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1896 - matthews_correlation: 0.3086 - val_loss: 0.1919 - val_matthews_correlation: 0.0640
#
# Epoch 00006: val_matthews_correlation did not improve from 0.10453
# Epoch 7/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1756 - matthews_correlation: 0.2860 - val_loss: 0.1663 - val_matthews_correlation: 0.1534
#
# Epoch 00007: val_matthews_correlation improved from 0.10453 to 0.15343, saving model to weights_1.h5
# Epoch 8/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1608 - matthews_correlation: 0.2583 - val_loss: 0.1501 - val_matthews_correlation: 0.0871
#
# Epoch 00008: val_matthews_correlation did not improve from 0.15343
# Epoch 9/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1369 - matthews_correlation: 0.3215 - val_loss: 0.1248 - val_matthews_correlation: 0.5874
#
# Epoch 00009: val_matthews_correlation improved from 0.15343 to 0.58740, saving model to weights_1.h5
# Epoch 10/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1310 - matthews_correlation: 0.4915 - val_loss: 0.1249 - val_matthews_correlation: 0.6251
#
# Epoch 00010: val_matthews_correlation improved from 0.58740 to 0.62515, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1309 - matthews_correlation: 0.5220 - val_loss: 0.1341 - val_matthews_correlation: 0.2745
#
# Epoch 00011: val_matthews_correlation did not improve from 0.62515
# Epoch 12/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1187 - matthews_correlation: 0.5828 - val_loss: 0.1176 - val_matthews_correlation: 0.6470
#
# Epoch 00012: val_matthews_correlation improved from 0.62515 to 0.64697, saving model to weights_1.h5
# Epoch 13/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1079 - matthews_correlation: 0.6527 - val_loss: 0.1131 - val_matthews_correlation: 0.6554
#
# Epoch 00013: val_matthews_correlation improved from 0.64697 to 0.65537, saving model to weights_1.h5
# Epoch 14/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1034 - matthews_correlation: 0.6140 - val_loss: 0.1156 - val_matthews_correlation: 0.6710
#
# Epoch 00014: val_matthews_correlation improved from 0.65537 to 0.67099, saving model to weights_1.h5
# Epoch 15/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1045 - matthews_correlation: 0.6364 - val_loss: 0.1172 - val_matthews_correlation: 0.6805
#
# Epoch 00015: val_matthews_correlation improved from 0.67099 to 0.68045, saving model to weights_1.h5
# Epoch 16/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1041 - matthews_correlation: 0.6297 - val_loss: 0.1088 - val_matthews_correlation: 0.6877
# Epoch 00016: val_matthews_correlation improved from 0.68045 to 0.68772, saving model to weights_1.h5
# Epoch 17/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1000 - matthews_correlation: 0.6587 - val_loss: 0.1144 - val_matthews_correlation: 0.6729
#
# Epoch 00017: val_matthews_correlation did not improve from 0.68772
# Epoch 18/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1037 - matthews_correlation: 0.6186 - val_loss: 0.1023 - val_matthews_correlation: 0.6953
#
# Epoch 00018: val_matthews_correlation improved from 0.68772 to 0.69527, saving model to weights_1.h5
# Epoch 19/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0948 - matthews_correlation: 0.6593 - val_loss: 0.1064 - val_matthews_correlation: 0.6982
#
# Epoch 00019: val_matthews_correlation improved from 0.69527 to 0.69822, saving model to weights_1.h5
# Epoch 20/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1005 - matthews_correlation: 0.6486 - val_loss: 0.1068 - val_matthews_correlation: 0.6729
#
# Epoch 00020: val_matthews_correlation did not improve from 0.69822
# Epoch 21/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1074 - matthews_correlation: 0.5624 - val_loss: 0.1150 - val_matthews_correlation: 0.6368
#
# Epoch 00021: val_matthews_correlation did not improve from 0.69822
# Epoch 22/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1044 - matthews_correlation: 0.6189 - val_loss: 0.1086 - val_matthews_correlation: 0.6489
#
# Epoch 00022: val_matthews_correlation did not improve from 0.69822
# Epoch 23/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0976 - matthews_correlation: 0.6676 - val_loss: 0.1173 - val_matthews_correlation: 0.5845
#
# Epoch 00023: val_matthews_correlation did not improve from 0.69822
# Epoch 24/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1070 - matthews_correlation: 0.5720 - val_loss: 0.1256 - val_matthews_correlation: 0.6367
#
# Epoch 00024: val_matthews_correlation did not improve from 0.69822
# Epoch 25/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0984 - matthews_correlation: 0.6488 - val_loss: 0.1125 - val_matthews_correlation: 0.6489
#
# Epoch 00025: val_matthews_correlation did not improve from 0.69822
# Epoch 26/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0980 - matthews_correlation: 0.6586 - val_loss: 0.1165 - val_matthews_correlation: 0.5753
#
# Epoch 00026: val_matthews_correlation did not improve from 0.69822
# Epoch 27/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0976 - matthews_correlation: 0.6022 - val_loss: 0.1118 - val_matthews_correlation: 0.6513
#
# Epoch 00027: val_matthews_correlation did not improve from 0.69822
# Epoch 28/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0989 - matthews_correlation: 0.6773 - val_loss: 0.1028 - val_matthews_correlation: 0.6899
#
# Epoch 00028: val_matthews_correlation did not improve from 0.69822
# Epoch 29/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0982 - matthews_correlation: 0.6373 - val_loss: 0.1084 - val_matthews_correlation: 0.6371
#
# Epoch 00029: val_matthews_correlation did not improve from 0.69822
# Epoch 30/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0902 - matthews_correlation: 0.6893 - val_loss: 0.1077 - val_matthews_correlation: 0.6755
#
# Epoch 00030: val_matthews_correlation did not improve from 0.69822
# Epoch 31/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0928 - matthews_correlation: 0.6846 - val_loss: 0.1092 - val_matthews_correlation: 0.6285
#
# Epoch 00031: val_matthews_correlation did not improve from 0.69822
# Epoch 32/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0911 - matthews_correlation: 0.6670 - val_loss: 0.1090 - val_matthews_correlation: 0.6155
#
# Epoch 00032: val_matthews_correlation did not improve from 0.69822
# Epoch 33/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0871 - matthews_correlation: 0.7009 - val_loss: 0.1117 - val_matthews_correlation: 0.6310
#
# Epoch 00033: val_matthews_correlation did not improve from 0.69822
# Epoch 34/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0967 - matthews_correlation: 0.6637 - val_loss: 0.1003 - val_matthews_correlation: 0.6410
#
# Epoch 00034: val_matthews_correlation did not improve from 0.69822
# Epoch 35/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0913 - matthews_correlation: 0.6746 - val_loss: 0.1162 - val_matthews_correlation: 0.6152
#
# Epoch 00035: val_matthews_correlation did not improve from 0.69822
# Epoch 36/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0926 - matthews_correlation: 0.7024 - val_loss: 0.1150 - val_matthews_correlation: 0.6310
#
# Epoch 00036: val_matthews_correlation did not improve from 0.69822
# Epoch 37/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0876 - matthews_correlation: 0.7017 - val_loss: 0.1178 - val_matthews_correlation: 0.6562
#
# Epoch 00037: val_matthews_correlation did not improve from 0.69822
# Epoch 38/50
# 2323/2323 [==============================] - 22s 9ms/step - loss: 0.0862 - matthews_correlation: 0.7235 - val_loss: 0.1054 - val_matthews_correlation: 0.6650
#
# Epoch 00038: val_matthews_correlation did not improve from 0.69822
# Epoch 39/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0852 - matthews_correlation: 0.6820 - val_loss: 0.1203 - val_matthews_correlation: 0.6428
#
# Epoch 00039: val_matthews_correlation did not improve from 0.69822
# Epoch 40/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0860 - matthews_correlation: 0.6708 - val_loss: 0.1001 - val_matthews_correlation: 0.6514
#
# Epoch 00040: val_matthews_correlation did not improve from 0.69822
# Epoch 41/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0932 - matthews_correlation: 0.6617 - val_loss: 0.0997 - val_matthews_correlation: 0.6959
#
# Epoch 00041: val_matthews_correlation did not improve from 0.69822
# Epoch 42/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1749 - matthews_correlation: 0.4879 - val_loss: 0.1412 - val_matthews_correlation: 0.2967
#
# Epoch 00042: val_matthews_correlation did not improve from 0.69822
# Epoch 43/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1406 - matthews_correlation: 0.0494 - val_loss: 0.1284 - val_matthews_correlation: 0.0483
#
# Epoch 00043: val_matthews_correlation did not improve from 0.69822
# Epoch 44/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1131 - matthews_correlation: 0.4898 - val_loss: 0.1178 - val_matthews_correlation: 0.6804
#
# Epoch 00044: val_matthews_correlation did not improve from 0.69822
# Epoch 45/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1047 - matthews_correlation: 0.6037 - val_loss: 0.1367 - val_matthews_correlation: 0.6574
#
# Epoch 00045: val_matthews_correlation did not improve from 0.69822
# Epoch 46/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1099 - matthews_correlation: 0.6598 - val_loss: 0.1115 - val_matthews_correlation: 0.7055
#
# Epoch 00046: val_matthews_correlation improved from 0.69822 to 0.70549, saving model to weights_1.h5
# Epoch 47/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0975 - matthews_correlation: 0.6307 - val_loss: 0.1074 - val_matthews_correlation: 0.6759
#
# Epoch 00047: val_matthews_correlation did not improve from 0.70549
# Epoch 48/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0960 - matthews_correlation: 0.6471 - val_loss: 0.1046 - val_matthews_correlation: 0.6667
#
# Epoch 00048: val_matthews_correlation did not improve from 0.70549
# Epoch 49/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0899 - matthews_correlation: 0.6437 - val_loss: 0.1221 - val_matthews_correlation: 0.6348
#
# Epoch 00049: val_matthews_correlation did not improve from 0.70549
# Epoch 50/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0956 - matthews_correlation: 0.6755 - val_loss: 0.1077 - val_matthews_correlation: 0.5838
# Epoch 00050: val_matthews_correlation did not improve from 0.70549
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 25s 11ms/step - loss: 0.3827 - matthews_correlation: 0.0000e+00 - val_loss: 0.2497 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2362 - matthews_correlation: 0.0000e+00 - val_loss: 0.2164 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2167 - matthews_correlation: 0.0000e+00 - val_loss: 0.2024 - val_matthews_correlation: 0.1717
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.17167, saving model to weights_2.h5
# Epoch 4/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2038 - matthews_correlation: -0.0012 - val_loss: 0.1891 - val_matthews_correlation: 0.3428
#
# Epoch 00004: val_matthews_correlation improved from 0.17167 to 0.34279, saving model to weights_2.h5
# Epoch 5/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1800 - matthews_correlation: 0.0933 - val_loss: 0.1990 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.34279
# Epoch 6/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1682 - matthews_correlation: 0.1804 - val_loss: 0.1448 - val_matthews_correlation: 0.4270
#
# Epoch 00006: val_matthews_correlation improved from 0.34279 to 0.42702, saving model to weights_2.h5
# Epoch 7/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1411 - matthews_correlation: 0.4313 - val_loss: 0.1397 - val_matthews_correlation: 0.3882
#
# Epoch 00007: val_matthews_correlation did not improve from 0.42702
# Epoch 8/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1150 - matthews_correlation: 0.6034 - val_loss: 0.1157 - val_matthews_correlation: 0.5529
#
# Epoch 00008: val_matthews_correlation improved from 0.42702 to 0.55292, saving model to weights_2.h5
# Epoch 9/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1095 - matthews_correlation: 0.6133 - val_loss: 0.1412 - val_matthews_correlation: 0.2445
#
# Epoch 00009: val_matthews_correlation did not improve from 0.55292
# Epoch 10/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1127 - matthews_correlation: 0.5387 - val_loss: 0.1174 - val_matthews_correlation: 0.6740
#
# Epoch 00010: val_matthews_correlation improved from 0.55292 to 0.67401, saving model to weights_2.h5
# Epoch 11/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1057 - matthews_correlation: 0.6305 - val_loss: 0.1135 - val_matthews_correlation: 0.5204
#
# Epoch 00011: val_matthews_correlation did not improve from 0.67401
# Epoch 12/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1015 - matthews_correlation: 0.6611 - val_loss: 0.1143 - val_matthews_correlation: 0.5652
#
# Epoch 00012: val_matthews_correlation did not improve from 0.67401
# Epoch 13/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1021 - matthews_correlation: 0.6638 - val_loss: 0.1177 - val_matthews_correlation: 0.6352
#
# Epoch 00013: val_matthews_correlation did not improve from 0.67401
# Epoch 14/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0970 - matthews_correlation: 0.6360 - val_loss: 0.1109 - val_matthews_correlation: 0.5875
#
# Epoch 00014: val_matthews_correlation did not improve from 0.67401
# Epoch 15/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0952 - matthews_correlation: 0.7071 - val_loss: 0.1177 - val_matthews_correlation: 0.5875
#
# Epoch 00015: val_matthews_correlation did not improve from 0.67401
# Epoch 16/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0958 - matthews_correlation: 0.7361 - val_loss: 0.1152 - val_matthews_correlation: 0.5838
#
# Epoch 00016: val_matthews_correlation did not improve from 0.67401
# Epoch 17/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0993 - matthews_correlation: 0.6229 - val_loss: 0.1179 - val_matthews_correlation: 0.5433
#
# Epoch 00017: val_matthews_correlation did not improve from 0.67401
# Epoch 18/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1001 - matthews_correlation: 0.6616 - val_loss: 0.1129 - val_matthews_correlation: 0.6045
#
# Epoch 00018: val_matthews_correlation did not improve from 0.67401
# Epoch 19/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0978 - matthews_correlation: 0.6679 - val_loss: 0.1159 - val_matthews_correlation: 0.6690
#
# Epoch 00019: val_matthews_correlation did not improve from 0.67401
# Epoch 20/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0955 - matthews_correlation: 0.6787 - val_loss: 0.1107 - val_matthews_correlation: 0.5423
#
# Epoch 00020: val_matthews_correlation did not improve from 0.67401
# Epoch 21/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0996 - matthews_correlation: 0.6969 - val_loss: 0.1124 - val_matthews_correlation: 0.5502
#
# Epoch 00021: val_matthews_correlation did not improve from 0.67401
# Epoch 22/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0891 - matthews_correlation: 0.6813 - val_loss: 0.1190 - val_matthews_correlation: 0.6422
#
# Epoch 00022: val_matthews_correlation did not improve from 0.67401
# Epoch 23/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1012 - matthews_correlation: 0.6707 - val_loss: 0.1129 - val_matthews_correlation: 0.5725
#
# Epoch 00023: val_matthews_correlation did not improve from 0.67401
# Epoch 24/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0992 - matthews_correlation: 0.6945 - val_loss: 0.1098 - val_matthews_correlation: 0.5543
#
# Epoch 00024: val_matthews_correlation did not improve from 0.67401
# Epoch 25/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0888 - matthews_correlation: 0.6576 - val_loss: 0.1190 - val_matthews_correlation: 0.5359
#
# Epoch 00025: val_matthews_correlation did not improve from 0.67401
# Epoch 26/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0857 - matthews_correlation: 0.7350 - val_loss: 0.1238 - val_matthews_correlation: 0.5478
#
# Epoch 00026: val_matthews_correlation did not improve from 0.67401
# Epoch 27/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0925 - matthews_correlation: 0.6822 - val_loss: 0.1128 - val_matthews_correlation: 0.5666
#
# Epoch 00027: val_matthews_correlation did not improve from 0.67401
# Epoch 28/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0858 - matthews_correlation: 0.7331 - val_loss: 0.1147 - val_matthews_correlation: 0.6201
#
# Epoch 00028: val_matthews_correlation did not improve from 0.67401
# Epoch 29/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0900 - matthews_correlation: 0.6846 - val_loss: 0.1084 - val_matthews_correlation: 0.6260
#
# Epoch 00029: val_matthews_correlation did not improve from 0.67401
# Epoch 30/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0906 - matthews_correlation: 0.6624 - val_loss: 0.1078 - val_matthews_correlation: 0.6047
#
# Epoch 00030: val_matthews_correlation did not improve from 0.67401
# Epoch 31/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0867 - matthews_correlation: 0.7266 - val_loss: 0.1115 - val_matthews_correlation: 0.5838
#
# Epoch 00031: val_matthews_correlation did not improve from 0.67401
# Epoch 32/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0865 - matthews_correlation: 0.6864 - val_loss: 0.1071 - val_matthews_correlation: 0.6582
#
# Epoch 00032: val_matthews_correlation did not improve from 0.67401
# Epoch 33/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0902 - matthews_correlation: 0.6906 - val_loss: 0.1070 - val_matthews_correlation: 0.6868
#
# Epoch 00033: val_matthews_correlation improved from 0.67401 to 0.68680, saving model to weights_2.h5
# Epoch 34/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0851 - matthews_correlation: 0.7108 - val_loss: 0.1209 - val_matthews_correlation: 0.5903
#
# Epoch 00034: val_matthews_correlation did not improve from 0.68680
# Epoch 35/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0863 - matthews_correlation: 0.7167 - val_loss: 0.1092 - val_matthews_correlation: 0.6153
#
# Epoch 00035: val_matthews_correlation did not improve from 0.68680
# Epoch 36/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0838 - matthews_correlation: 0.7385 - val_loss: 0.1136 - val_matthews_correlation: 0.5423
#
# Epoch 00036: val_matthews_correlation did not improve from 0.68680
# Epoch 37/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0827 - matthews_correlation: 0.7068 - val_loss: 0.1110 - val_matthews_correlation: 0.6975
#
# Epoch 00037: val_matthews_correlation improved from 0.68680 to 0.69750, saving model to weights_2.h5
# Epoch 38/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0899 - matthews_correlation: 0.6578 - val_loss: 0.1094 - val_matthews_correlation: 0.6159
#
# Epoch 00038: val_matthews_correlation did not improve from 0.69750
# Epoch 39/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0867 - matthews_correlation: 0.7233 - val_loss: 0.1127 - val_matthews_correlation: 0.5423
#
# Epoch 00039: val_matthews_correlation did not improve from 0.69750
# Epoch 40/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0839 - matthews_correlation: 0.6863 - val_loss: 0.1053 - val_matthews_correlation: 0.6329
#
# Epoch 00040: val_matthews_correlation did not improve from 0.69750
# Epoch 41/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0786 - matthews_correlation: 0.7530 - val_loss: 0.1134 - val_matthews_correlation: 0.5607
#
# Epoch 00041: val_matthews_correlation did not improve from 0.69750
# Epoch 42/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0812 - matthews_correlation: 0.7126 - val_loss: 0.1101 - val_matthews_correlation: 0.6237
#
# Epoch 00042: val_matthews_correlation did not improve from 0.69750
# Epoch 43/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0942 - matthews_correlation: 0.6943 - val_loss: 0.1148 - val_matthews_correlation: 0.6712
#
# Epoch 00043: val_matthews_correlation did not improve from 0.69750
# Epoch 44/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0854 - matthews_correlation: 0.6901 - val_loss: 0.1107 - val_matthews_correlation: 0.6337
#
# Epoch 00044: val_matthews_correlation did not improve from 0.69750
# Epoch 45/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0827 - matthews_correlation: 0.7263 - val_loss: 0.1072 - val_matthews_correlation: 0.6295
#
# Epoch 00045: val_matthews_correlation did not improve from 0.69750
# Epoch 46/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0828 - matthews_correlation: 0.7006 - val_loss: 0.1042 - val_matthews_correlation: 0.6977
#
# Epoch 00046: val_matthews_correlation improved from 0.69750 to 0.69773, saving model to weights_2.h5
# Epoch 47/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0854 - matthews_correlation: 0.7137 - val_loss: 0.1252 - val_matthews_correlation: 0.4626
#
# Epoch 00047: val_matthews_correlation did not improve from 0.69773
# Epoch 48/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0861 - matthews_correlation: 0.6887 - val_loss: 0.1119 - val_matthews_correlation: 0.5668
#
# Epoch 00048: val_matthews_correlation did not improve from 0.69773
# Epoch 49/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0779 - matthews_correlation: 0.7277 - val_loss: 0.1108 - val_matthews_correlation: 0.6501
#
# Epoch 00049: val_matthews_correlation did not improve from 0.69773
# Epoch 50/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0782 - matthews_correlation: 0.7511 - val_loss: 0.1120 - val_matthews_correlation: 0.6274
#
# Epoch 00050: val_matthews_correlation did not improve from 0.69773
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 25s 11ms/step - loss: 0.3871 - matthews_correlation: 0.0000e+00 - val_loss: 0.2357 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2339 - matthews_correlation: 0.0000e+00 - val_loss: 0.2171 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2201 - matthews_correlation: 0.0000e+00 - val_loss: 0.2106 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2089 - matthews_correlation: 0.0886 - val_loss: 0.2019 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2006 - matthews_correlation: 0.0818 - val_loss: 0.1759 - val_matthews_correlation: 0.0725
#
# Epoch 00005: val_matthews_correlation improved from 0.00000 to 0.07254, saving model to weights_3.h5
# Epoch 6/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1724 - matthews_correlation: 0.1249 - val_loss: 0.1537 - val_matthews_correlation: 0.0573
#
# Epoch 00006: val_matthews_correlation did not improve from 0.07254
# Epoch 7/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1407 - matthews_correlation: 0.4358 - val_loss: 0.1187 - val_matthews_correlation: 0.5484
#
# Epoch 00007: val_matthews_correlation improved from 0.07254 to 0.54840, saving model to weights_3.h5
# Epoch 8/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1152 - matthews_correlation: 0.6312 - val_loss: 0.1357 - val_matthews_correlation: 0.5935
#
# Epoch 00008: val_matthews_correlation improved from 0.54840 to 0.59352, saving model to weights_3.h5
# Epoch 9/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1265 - matthews_correlation: 0.5385 - val_loss: 0.1442 - val_matthews_correlation: 0.4462
#
# Epoch 00009: val_matthews_correlation did not improve from 0.59352
# Epoch 10/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1038 - matthews_correlation: 0.6404 - val_loss: 0.1170 - val_matthews_correlation: 0.5750
#
# Epoch 00010: val_matthews_correlation did not improve from 0.59352
# Epoch 11/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1033 - matthews_correlation: 0.6241 - val_loss: 0.1101 - val_matthews_correlation: 0.6160
#
# Epoch 00011: val_matthews_correlation improved from 0.59352 to 0.61601, saving model to weights_3.h5
# Epoch 12/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0978 - matthews_correlation: 0.6496 - val_loss: 0.1126 - val_matthews_correlation: 0.6082
#
# Epoch 00012: val_matthews_correlation did not improve from 0.61601
# Epoch 13/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1026 - matthews_correlation: 0.6483 - val_loss: 0.1106 - val_matthews_correlation: 0.4358
#
# Epoch 00013: val_matthews_correlation did not improve from 0.61601
# Epoch 14/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1025 - matthews_correlation: 0.6497 - val_loss: 0.1076 - val_matthews_correlation: 0.6160
#
# Epoch 00014: val_matthews_correlation did not improve from 0.61601
# Epoch 15/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0945 - matthews_correlation: 0.6792 - val_loss: 0.1063 - val_matthews_correlation: 0.5678
#
# Epoch 00015: val_matthews_correlation did not improve from 0.61601
# Epoch 16/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0987 - matthews_correlation: 0.6523 - val_loss: 0.1096 - val_matthews_correlation: 0.6140
#
# Epoch 00016: val_matthews_correlation did not improve from 0.61601
# Epoch 17/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0967 - matthews_correlation: 0.6981 - val_loss: 0.1419 - val_matthews_correlation: 0.4629
#
# Epoch 00017: val_matthews_correlation did not improve from 0.61601
# Epoch 18/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1028 - matthews_correlation: 0.6290 - val_loss: 0.1069 - val_matthews_correlation: 0.6309
#
# Epoch 00018: val_matthews_correlation improved from 0.61601 to 0.63087, saving model to weights_3.h5
# Epoch 19/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0960 - matthews_correlation: 0.6718 - val_loss: 0.1040 - val_matthews_correlation: 0.6223
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63087
# Epoch 20/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0932 - matthews_correlation: 0.6349 - val_loss: 0.1113 - val_matthews_correlation: 0.4847
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63087
# Epoch 21/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0920 - matthews_correlation: 0.6697 - val_loss: 0.1034 - val_matthews_correlation: 0.6248
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63087
# Epoch 22/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0936 - matthews_correlation: 0.6840 - val_loss: 0.1078 - val_matthews_correlation: 0.5743
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63087
# Epoch 23/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0903 - matthews_correlation: 0.6478 - val_loss: 0.1100 - val_matthews_correlation: 0.5528
#
# Epoch 00023: val_matthews_correlation did not improve from 0.63087
# Epoch 24/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0959 - matthews_correlation: 0.6517 - val_loss: 0.1139 - val_matthews_correlation: 0.4819
#
# Epoch 00024: val_matthews_correlation did not improve from 0.63087
# Epoch 25/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0920 - matthews_correlation: 0.6741 - val_loss: 0.1088 - val_matthews_correlation: 0.6470
#
# Epoch 00025: val_matthews_correlation improved from 0.63087 to 0.64698, saving model to weights_3.h5
# Epoch 26/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0940 - matthews_correlation: 0.6105 - val_loss: 0.1096 - val_matthews_correlation: 0.4485
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64698
# Epoch 27/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0959 - matthews_correlation: 0.6693 - val_loss: 0.1032 - val_matthews_correlation: 0.6184
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64698
# Epoch 28/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0898 - matthews_correlation: 0.6797 - val_loss: 0.1089 - val_matthews_correlation: 0.5357
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64698
# Epoch 29/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0921 - matthews_correlation: 0.6429 - val_loss: 0.0978 - val_matthews_correlation: 0.5604
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64698
# Epoch 30/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0926 - matthews_correlation: 0.6799 - val_loss: 0.1010 - val_matthews_correlation: 0.5126
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64698
# Epoch 31/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0889 - matthews_correlation: 0.6885 - val_loss: 0.1074 - val_matthews_correlation: 0.6375
#
# Epoch 00031: val_matthews_correlation did not improve from 0.64698
# Epoch 32/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0926 - matthews_correlation: 0.6781 - val_loss: 0.1091 - val_matthews_correlation: 0.5316
#
# Epoch 00032: val_matthews_correlation did not improve from 0.64698
# Epoch 33/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0885 - matthews_correlation: 0.7100 - val_loss: 0.0977 - val_matthews_correlation: 0.5083
#
# Epoch 00033: val_matthews_correlation did not improve from 0.64698
# Epoch 34/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0911 - matthews_correlation: 0.6892 - val_loss: 0.1032 - val_matthews_correlation: 0.5700
#
# Epoch 00034: val_matthews_correlation did not improve from 0.64698
# Epoch 35/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0874 - matthews_correlation: 0.7106 - val_loss: 0.0983 - val_matthews_correlation: 0.6560
#
# Epoch 00035: val_matthews_correlation improved from 0.64698 to 0.65600, saving model to weights_3.h5
# Epoch 36/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0873 - matthews_correlation: 0.6907 - val_loss: 0.1072 - val_matthews_correlation: 0.4464
#
# Epoch 00036: val_matthews_correlation did not improve from 0.65600
# Epoch 37/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0844 - matthews_correlation: 0.6953 - val_loss: 0.1086 - val_matthews_correlation: 0.6605
#
# Epoch 00037: val_matthews_correlation improved from 0.65600 to 0.66055, saving model to weights_3.h5
# Epoch 38/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0847 - matthews_correlation: 0.7206 - val_loss: 0.1090 - val_matthews_correlation: 0.5019
#
# Epoch 00038: val_matthews_correlation did not improve from 0.66055
# Epoch 39/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0933 - matthews_correlation: 0.7130 - val_loss: 0.0972 - val_matthews_correlation: 0.6703
#
# Epoch 00039: val_matthews_correlation improved from 0.66055 to 0.67027, saving model to weights_3.h5
# Epoch 40/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0821 - matthews_correlation: 0.7172 - val_loss: 0.1070 - val_matthews_correlation: 0.5586
#
# Epoch 00040: val_matthews_correlation did not improve from 0.67027
# Epoch 41/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0869 - matthews_correlation: 0.7177 - val_loss: 0.1078 - val_matthews_correlation: 0.4629
#
# Epoch 00041: val_matthews_correlation did not improve from 0.67027
# Epoch 42/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0857 - matthews_correlation: 0.7072 - val_loss: 0.1020 - val_matthews_correlation: 0.5455
#
# Epoch 00042: val_matthews_correlation did not improve from 0.67027
# Epoch 43/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0890 - matthews_correlation: 0.6608 - val_loss: 0.1172 - val_matthews_correlation: 0.4128
#
# Epoch 00043: val_matthews_correlation did not improve from 0.67027
# Epoch 44/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0847 - matthews_correlation: 0.7541 - val_loss: 0.1010 - val_matthews_correlation: 0.5403
#
# Epoch 00044: val_matthews_correlation did not improve from 0.67027
# Epoch 45/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0810 - matthews_correlation: 0.6897 - val_loss: 0.1007 - val_matthews_correlation: 0.4682
#
# Epoch 00045: val_matthews_correlation did not improve from 0.67027
# Epoch 46/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0850 - matthews_correlation: 0.7290 - val_loss: 0.0950 - val_matthews_correlation: 0.5457
#
# Epoch 00046: val_matthews_correlation did not improve from 0.67027
# Epoch 47/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0864 - matthews_correlation: 0.6978 - val_loss: 0.1056 - val_matthews_correlation: 0.5028
#
# Epoch 00047: val_matthews_correlation did not improve from 0.67027
# Epoch 48/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0829 - matthews_correlation: 0.7011 - val_loss: 0.1000 - val_matthews_correlation: 0.6560
#
# Epoch 00048: val_matthews_correlation did not improve from 0.67027
# Epoch 49/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0899 - matthews_correlation: 0.6904 - val_loss: 0.0998 - val_matthews_correlation: 0.6674
#
# Epoch 00049: val_matthews_correlation did not improve from 0.67027
# Epoch 50/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0806 - matthews_correlation: 0.7404 - val_loss: 0.1136 - val_matthews_correlation: 0.6201
#
# Epoch 00050: val_matthews_correlation did not improve from 0.67027
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 25s 11ms/step - loss: 0.3679 - matthews_correlation: 0.0044 - val_loss: 0.2465 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2324 - matthews_correlation: 0.0000e+00 - val_loss: 0.2138 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2302 - matthews_correlation: 0.0000e+00 - val_loss: 0.2063 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2089 - matthews_correlation: 0.1073 - val_loss: 0.1899 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1822 - matthews_correlation: 0.0000e+00 - val_loss: 0.1751 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1708 - matthews_correlation: 0.0611 - val_loss: 0.1823 - val_matthews_correlation: 0.0673
#
# Epoch 00006: val_matthews_correlation improved from 0.00000 to 0.06727, saving model to weights_4.h5
# Epoch 7/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.1650 - matthews_correlation: 0.0000e+00 - val_loss: 0.1615 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.06727
# Epoch 8/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1510 - matthews_correlation: 0.1226 - val_loss: 0.1486 - val_matthews_correlation: 0.3745
#
# Epoch 00008: val_matthews_correlation improved from 0.06727 to 0.37450, saving model to weights_4.h5
# Epoch 9/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1131 - matthews_correlation: 0.5201 - val_loss: 0.1309 - val_matthews_correlation: 0.5404
#
# Epoch 00009: val_matthews_correlation improved from 0.37450 to 0.54042, saving model to weights_4.h5
# Epoch 10/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1071 - matthews_correlation: 0.6156 - val_loss: 0.1200 - val_matthews_correlation: 0.6428
#
# Epoch 00010: val_matthews_correlation improved from 0.54042 to 0.64283, saving model to weights_4.h5
# Epoch 11/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1017 - matthews_correlation: 0.6608 - val_loss: 0.1519 - val_matthews_correlation: 0.3526
#
# Epoch 00011: val_matthews_correlation did not improve from 0.64283
# Epoch 12/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1121 - matthews_correlation: 0.5339 - val_loss: 0.1196 - val_matthews_correlation: 0.6494
#
# Epoch 00012: val_matthews_correlation improved from 0.64283 to 0.64938, saving model to weights_4.h5
# Epoch 13/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0988 - matthews_correlation: 0.6589 - val_loss: 0.1173 - val_matthews_correlation: 0.5576
#
# Epoch 00013: val_matthews_correlation did not improve from 0.64938
# Epoch 14/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0993 - matthews_correlation: 0.6480 - val_loss: 0.1125 - val_matthews_correlation: 0.6223
#
# Epoch 00014: val_matthews_correlation did not improve from 0.64938
# Epoch 15/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0988 - matthews_correlation: 0.6390 - val_loss: 0.1175 - val_matthews_correlation: 0.5010
#
# Epoch 00015: val_matthews_correlation did not improve from 0.64938
# Epoch 16/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0960 - matthews_correlation: 0.6414 - val_loss: 0.1143 - val_matthews_correlation: 0.5385
#
# Epoch 00016: val_matthews_correlation did not improve from 0.64938
# Epoch 17/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0966 - matthews_correlation: 0.7038 - val_loss: 0.1227 - val_matthews_correlation: 0.5940
#
# Epoch 00017: val_matthews_correlation did not improve from 0.64938
# Epoch 18/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1024 - matthews_correlation: 0.6740 - val_loss: 0.1140 - val_matthews_correlation: 0.5385
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64938
# Epoch 19/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1085 - matthews_correlation: 0.6207 - val_loss: 0.1260 - val_matthews_correlation: 0.4908
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64938
# Epoch 20/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0955 - matthews_correlation: 0.6941 - val_loss: 0.1082 - val_matthews_correlation: 0.6248
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64938
# Epoch 21/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0975 - matthews_correlation: 0.7120 - val_loss: 0.1126 - val_matthews_correlation: 0.6085
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64938
# Epoch 22/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.0957 - matthews_correlation: 0.6817 - val_loss: 0.1129 - val_matthews_correlation: 0.6276
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64938
# Epoch 23/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0969 - matthews_correlation: 0.6551 - val_loss: 0.1165 - val_matthews_correlation: 0.4262
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64938
# Epoch 24/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0960 - matthews_correlation: 0.6878 - val_loss: 0.1239 - val_matthews_correlation: 0.5108
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64938
# Epoch 25/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0966 - matthews_correlation: 0.6515 - val_loss: 0.1243 - val_matthews_correlation: 0.4667
#
# Epoch 00025: val_matthews_correlation did not improve from 0.64938
# Epoch 26/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0961 - matthews_correlation: 0.6486 - val_loss: 0.1082 - val_matthews_correlation: 0.6301
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64938
# Epoch 27/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0902 - matthews_correlation: 0.6695 - val_loss: 0.1180 - val_matthews_correlation: 0.4262
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64938
# Epoch 28/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0996 - matthews_correlation: 0.6581 - val_loss: 0.1074 - val_matthews_correlation: 0.5822
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64938
# Epoch 29/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0938 - matthews_correlation: 0.6487 - val_loss: 0.1133 - val_matthews_correlation: 0.4359
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64938
# Epoch 30/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0879 - matthews_correlation: 0.6706 - val_loss: 0.1150 - val_matthews_correlation: 0.5448
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64938
# Epoch 31/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0873 - matthews_correlation: 0.7039 - val_loss: 0.1077 - val_matthews_correlation: 0.6276
#
# Epoch 00031: val_matthews_correlation did not improve from 0.64938
# Epoch 32/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0873 - matthews_correlation: 0.6879 - val_loss: 0.1034 - val_matthews_correlation: 0.6301
#
# Epoch 00032: val_matthews_correlation did not improve from 0.64938
# Epoch 33/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0884 - matthews_correlation: 0.7240 - val_loss: 0.1035 - val_matthews_correlation: 0.6351
#
# Epoch 00033: val_matthews_correlation did not improve from 0.64938
# Epoch 34/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0843 - matthews_correlation: 0.6971 - val_loss: 0.1171 - val_matthews_correlation: 0.5888
#
# Epoch 00034: val_matthews_correlation did not improve from 0.64938
# Epoch 35/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0902 - matthews_correlation: 0.7120 - val_loss: 0.1094 - val_matthews_correlation: 0.6248
#
# Epoch 00035: val_matthews_correlation did not improve from 0.64938
# Epoch 36/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0887 - matthews_correlation: 0.6483 - val_loss: 0.1060 - val_matthews_correlation: 0.6037
#
# Epoch 00036: val_matthews_correlation did not improve from 0.64938
# Epoch 37/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.0831 - matthews_correlation: 0.7191 - val_loss: 0.1089 - val_matthews_correlation: 0.6289
#
# Epoch 00037: val_matthews_correlation did not improve from 0.64938
# Epoch 38/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0880 - matthews_correlation: 0.6972 - val_loss: 0.1066 - val_matthews_correlation: 0.6249
#
# Epoch 00038: val_matthews_correlation did not improve from 0.64938
# Epoch 39/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0823 - matthews_correlation: 0.7548 - val_loss: 0.1247 - val_matthews_correlation: 0.5588
#
# Epoch 00039: val_matthews_correlation did not improve from 0.64938
# Epoch 40/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0894 - matthews_correlation: 0.6718 - val_loss: 0.1211 - val_matthews_correlation: 0.6133
#
# Epoch 00040: val_matthews_correlation did not improve from 0.64938
# Epoch 41/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0864 - matthews_correlation: 0.6844 - val_loss: 0.1057 - val_matthews_correlation: 0.6357
#
# Epoch 00041: val_matthews_correlation did not improve from 0.64938
# Epoch 42/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0908 - matthews_correlation: 0.7242 - val_loss: 0.1086 - val_matthews_correlation: 0.6092
#
# Epoch 00042: val_matthews_correlation did not improve from 0.64938
# Epoch 43/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0876 - matthews_correlation: 0.7453 - val_loss: 0.1050 - val_matthews_correlation: 0.6131
#
# Epoch 00043: val_matthews_correlation did not improve from 0.64938
# Epoch 44/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0824 - matthews_correlation: 0.7262 - val_loss: 0.1124 - val_matthews_correlation: 0.5908
#
# Epoch 00044: val_matthews_correlation did not improve from 0.64938
# Epoch 45/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0824 - matthews_correlation: 0.7116 - val_loss: 0.1084 - val_matthews_correlation: 0.6240
#
# Epoch 00045: val_matthews_correlation did not improve from 0.64938
# Epoch 46/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0808 - matthews_correlation: 0.7373 - val_loss: 0.1091 - val_matthews_correlation: 0.6187
#
# Epoch 00046: val_matthews_correlation did not improve from 0.64938
# Epoch 47/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0780 - matthews_correlation: 0.7466 - val_loss: 0.1094 - val_matthews_correlation: 0.6188
#
# Epoch 00047: val_matthews_correlation did not improve from 0.64938
# Epoch 48/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0826 - matthews_correlation: 0.7133 - val_loss: 0.1292 - val_matthews_correlation: 0.4438
#
# Epoch 00048: val_matthews_correlation did not improve from 0.64938
# Epoch 49/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0867 - matthews_correlation: 0.7039 - val_loss: 0.1201 - val_matthews_correlation: 0.5978
#
# Epoch 00049: val_matthews_correlation did not improve from 0.64938
# Epoch 50/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0826 - matthews_correlation: 0.7245 - val_loss: 0.1100 - val_matthews_correlation: 0.6579
#
# Epoch 00050: val_matthews_correlation improved from 0.64938 to 0.65795, saving model to weights_4.h5
# ((2904,), (2904,))

# %%
np.save('./tmp/y_val_tmp_2.npy', y_val)
np.save('./tmp/preds_val_tmp_2.npy', preds_val)

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    
    #y_pred = K.cast(y_pred, np.float)
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = np.round(np.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)

    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        #score = matthews_correlation(y_true, (y_proba > threshold).astype(int))
        #score = K.eval(matthews_correlation(y_true, (y_proba > threshold).astype(int)))
        #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        score = matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:00<00:00, 6978.06it/s]

# %%
best_threshold
# Out:
# 0.49

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')
# Out:
# CPU times: user 4.61 ms, sys: 8.35 ms, total: 13 ms
# Wall time: 27.7 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# %%time
# First we daclarete a series of parameters to initiate the loading of the main data
# it is too large, it is impossible to load in one time, so we are doing it in dividing in 10 parts
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [03:01<00:00, 11.34it/s]
# 100%|██████████| 2033/2033 [03:08<00:00, 10.76it/s]
# 100%|██████████| 2033/2033 [03:08<00:00, 10.63it/s]
# 100%|██████████| 2033/2033 [03:07<00:00, 10.82it/s]
# 100%|██████████| 2033/2033 [03:03<00:00, 10.98it/s]
# 100%|██████████| 2033/2033 [03:03<00:00, 10.83it/s]
# 100%|██████████| 2033/2033 [03:04<00:00, 11.22it/s]
# 100%|██████████| 2033/2033 [03:03<00:00, 11.19it/s]
# 100%|██████████| 2033/2033 [03:04<00:00, 10.99it/s]
# 100%|██████████| 2033/2033 [03:04<00:00,  7.64it/s]
# 100%|██████████| 7/7 [00:00<00:00, 10.23it/s]
# CPU times: user 34min 45s, sys: 1min 52s, total: 36min 38s
# Wall time: 32min 22s

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
X_test_input = np.load('./X_test.npy')

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
# Out:
# Beginning fold 1
# Beginning fold 2
# Beginning fold 3
# Beginning fold 4
# Beginning fold 5

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 16s 2ms/step
# 6779/6779 [==============================] - 16s 2ms/step
# 6779/6779 [==============================] - 16s 2ms/step
# 6779/6779 [==============================] - 16s 2ms/step
# 6779/6779 [==============================] - 15s 2ms/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('../output/submission_16.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
lstm_preds = np.squeeze(np.mean(preds_test, axis=0))
np.save("./lstm_preds.npy", lstm_preds)
