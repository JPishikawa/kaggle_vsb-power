# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from scipy.signal import chirp, find_peaks, peak_widths
import pywt

from multiprocessing import Pool
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import warnings

warnings.filterwarnings('ignore')
# Out:
# /home/cwademo123/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
def maddest(d, axis=None):
    """
    Mean Absolute Deviation
    """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

# %%
def denoise_signal( x, wavelet='db4', level=1):
    """
    1. Adapted from waveletSmooth function found here:
    http://connor-johnson.com/2016/01/24/using-pywavelets-to-remove-high-frequency-noise/
    2. Threshold equation and using hard mode in threshold as mentioned
    in section '3.2 denoising based on optimized singular values' from paper by Tomas Vantuch:
    http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    """
    
    # Decompose to get the wavelet coefficients
    coeff = pywt.wavedec( x, wavelet, mode="per", level=level)
    
    # Calculate sigma for threshold as defined in http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    # As noted by @harshit92 MAD referred to in the paper is Mean Absolute Deviation not Median Absolute Deviation
    sigma = (1/0.6745) * maddest( coeff[-level] )

    # Calculte the univeral threshold
    uthresh = sigma * np.sqrt( 2*np.log( len( x ) ) )
    coeff[1:] = ( pywt.threshold( i, value=uthresh, mode='hard' ) for i in coeff[1:] )
    
    # Reconstruct the signal using the thresholded coefficients
    return pywt.waverec( coeff[1:], wavelet, mode='per' )

# %%
def remove_corona(x_dn, maxDistance=10, maxHeightRatio=0.25, maxTicksRemoval=500):
    index = pd.Series(x_dn).loc[np.abs(x_dn)>0].index
    corona_idx = []
    for idx in index:
        for i in range(1,maxDistance+1):
            if idx+i < pd.Series(x_dn).shape[0]:
                if x_dn[idx+i]/(x_dn[idx]+1e-04)<-maxHeightRatio:
                    x_dn[idx:idx+maxTicksRemoval] = 0
                    corona_idx.append(idx)
    return x_dn, corona_idx

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    ts_wave = denoise_signal(ts_std, wavelet='haar', level=1)
    ts_rm, corona_idx = remove_corona(ts_wave)
    
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        ts_rm_range = ts_rm[int(i/2):int(i/2) + int(bucket_size/2)]
        #ts_rm_range = pd.Series(ts_rm_range)
        
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        
        #numpeaks = ts_rm_range[ts_rm_range!=0].count()
        numpeaks = np.sum(ts_rm_range!=0)
        #numpospeaks = ts_rm_range[ts_rm_range>0].count()
        numpospeaks = np.sum(ts_rm_range>0)
        #numnegpeaks = ts_rm_range[ts_rm_range<0].count()
        numnegpeaks = np.sum(ts_rm_range<0)

        #meanamp = np.mean(ts_rm_range)
        #meanamppos = np.mean(ts_rm_range[ts_rm_range>0])
        #meanampneg = np.mean(ts_rm_range[ts_rm_range<0])

        #maxamp = np.max(ts_rm_range)
        #minamp = np.min(ts_rm_range)
        
        #peaks, _ = find_peaks(ts_rm_range)
        #results_full = peak_widths(ts_rm_range, peaks, rel_height=1)
        
        #if len(results_full[0])==0:
        #    maxwidth = 0
        #    minwidth = 0
        #else:
        #    maxwidth = np.max(results_full[0])
        #    minwidth = np.min(results_full[0])
        
        
        
        feat_array = np.asarray([mean, std, std_top, std_bot, max_range])
        feat_array_2 = np.asarray([numpeaks, numpospeaks, numnegpeaks
                                   #, meanamp, meanamppos, meanampneg,
                                 #maxamp, minamp, maxwidth, minwidth
                                  ])
        
        new_ts.append(np.concatenate([feat_array, feat_array_2, percentil_calc, relative_percentile]))
        
    #scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = StandardScaler()
    new_ts = np.asarray(new_ts)
    new_ts[np.isnan(new_ts)] = 0
    
    new_ts = scaler.fit_transform(new_ts)
        
    return new_ts

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
def process_subtrain(arg_tuple):
    start, end, idx = arg_tuple
    X, y = prep_data(start, end)
    return idx, X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
#X = []
#y = []
all_chunks = []

num_cores = 8 
#def load_all():
total_size = len(df_train)
chunk_size = total_size/num_cores

for i in range(8):
    start_idx = int(i * chunk_size)
    end_idx = int(start_idx + chunk_size)
    chunk = (start_idx, end_idx, i)
    all_chunks.append(chunk)

pool = Pool()
results = pool.map(process_subtrain, all_chunks)    
results = sorted(results, key=lambda tup: tup[0])

X = np.concatenate([item[1] for item in results], axis=0)
y = np.concatenate([item[2] for item in results], axis=0)

#load_all()

#X = np.asarray(X)
#y = np.asarray(y)
# Out:
# 100%|██████████| 363/363 [12:49<00:00,  2.71s/it]
# 100%|██████████| 363/363 [13:19<00:00,  2.86s/it]
# 100%|██████████| 363/363 [13:48<00:00,  1.85s/it]
# 100%|██████████| 363/363 [13:50<00:00,  1.80s/it]
# 100%|██████████| 363/363 [14:04<00:00,  1.45it/s]
# 100%|██████████| 363/363 [14:11<00:00,  1.35s/it]
# 100%|██████████| 363/363 [14:15<00:00,  1.02it/s]
# 100%|██████████| 363/363 [14:22<00:00,  1.13s/it]

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# Out:
# (2904, 160, 66) (2904,)

# %%
# save data into file, a numpy specific format
np.save("X_3.npy",X)
np.save("y_3.npy",y)

# %%
X = np.load("./X_3.npy")
y = np.load("./y_3.npy")

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(LSTM(128, return_sequences=True))(inp)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64)(x)
    
    x = LeakyReLU(alpha=0.1)(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 26s 11ms/step - loss: 0.3232 - matthews_correlation: 0.0017 - val_loss: 0.2287 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.2124 - matthews_correlation: 0.0000e+00 - val_loss: 0.1893 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.1587 - matthews_correlation: 0.2937 - val_loss: 0.1363 - val_matthews_correlation: 0.2104
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.21040, saving model to weights_0.h5
# Epoch 4/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1341 - matthews_correlation: 0.4046 - val_loss: 0.1293 - val_matthews_correlation: 0.6329
#
# Epoch 00004: val_matthews_correlation improved from 0.21040 to 0.63291, saving model to weights_0.h5
# Epoch 5/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.1145 - matthews_correlation: 0.5829 - val_loss: 0.1203 - val_matthews_correlation: 0.4685
#
# Epoch 00005: val_matthews_correlation did not improve from 0.63291
# Epoch 6/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.1082 - matthews_correlation: 0.5337 - val_loss: 0.1066 - val_matthews_correlation: 0.6224
#
# Epoch 00006: val_matthews_correlation did not improve from 0.63291
# Epoch 7/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0968 - matthews_correlation: 0.5959 - val_loss: 0.1484 - val_matthews_correlation: 0.4234
#
# Epoch 00007: val_matthews_correlation did not improve from 0.63291
# Epoch 8/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.1012 - matthews_correlation: 0.5804 - val_loss: 0.1157 - val_matthews_correlation: 0.6779
#
# Epoch 00008: val_matthews_correlation improved from 0.63291 to 0.67791, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0931 - matthews_correlation: 0.6338 - val_loss: 0.0892 - val_matthews_correlation: 0.7101
#
# Epoch 00009: val_matthews_correlation improved from 0.67791 to 0.71010, saving model to weights_0.h5
# Epoch 10/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0826 - matthews_correlation: 0.6445 - val_loss: 0.0843 - val_matthews_correlation: 0.7604
#
# Epoch 00010: val_matthews_correlation improved from 0.71010 to 0.76044, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0771 - matthews_correlation: 0.7290 - val_loss: 0.1151 - val_matthews_correlation: 0.6058
#
# Epoch 00011: val_matthews_correlation did not improve from 0.76044
# Epoch 12/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0793 - matthews_correlation: 0.6979 - val_loss: 0.0869 - val_matthews_correlation: 0.7449
#
# Epoch 00012: val_matthews_correlation did not improve from 0.76044
# Epoch 13/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0611 - matthews_correlation: 0.7970 - val_loss: 0.1046 - val_matthews_correlation: 0.6304
#
# Epoch 00013: val_matthews_correlation did not improve from 0.76044
# Epoch 14/50
# 2322/2322 [==============================] - 19s 8ms/step - loss: 0.0578 - matthews_correlation: 0.7612 - val_loss: 0.1145 - val_matthews_correlation: 0.6249
#
# Epoch 00014: val_matthews_correlation did not improve from 0.76044
# Epoch 15/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0522 - matthews_correlation: 0.7930 - val_loss: 0.0893 - val_matthews_correlation: 0.7277
#
# Epoch 00015: val_matthews_correlation did not improve from 0.76044
# Epoch 16/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0490 - matthews_correlation: 0.8210 - val_loss: 0.0871 - val_matthews_correlation: 0.7190
#
# Epoch 00016: val_matthews_correlation did not improve from 0.76044
# Epoch 17/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0440 - matthews_correlation: 0.8506 - val_loss: 0.1215 - val_matthews_correlation: 0.4722
#
# Epoch 00017: val_matthews_correlation did not improve from 0.76044
# Epoch 18/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0571 - matthews_correlation: 0.7912 - val_loss: 0.1189 - val_matthews_correlation: 0.6537
#
# Epoch 00018: val_matthews_correlation did not improve from 0.76044
# Epoch 19/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0642 - matthews_correlation: 0.7680 - val_loss: 0.0785 - val_matthews_correlation: 0.7002
#
# Epoch 00019: val_matthews_correlation did not improve from 0.76044
# Epoch 20/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0479 - matthews_correlation: 0.8553 - val_loss: 0.1177 - val_matthews_correlation: 0.6251
#
# Epoch 00020: val_matthews_correlation did not improve from 0.76044
# Epoch 21/50
# 2322/2322 [==============================] - 19s 8ms/step - loss: 0.0445 - matthews_correlation: 0.8446 - val_loss: 0.1687 - val_matthews_correlation: 0.6541
#
# Epoch 00021: val_matthews_correlation did not improve from 0.76044
# Epoch 22/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0701 - matthews_correlation: 0.7596 - val_loss: 0.0762 - val_matthews_correlation: 0.7464
#
# Epoch 00022: val_matthews_correlation did not improve from 0.76044
# Epoch 23/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0436 - matthews_correlation: 0.8440 - val_loss: 0.1062 - val_matthews_correlation: 0.7088
#
# Epoch 00023: val_matthews_correlation did not improve from 0.76044
# Epoch 24/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0398 - matthews_correlation: 0.8671 - val_loss: 0.0877 - val_matthews_correlation: 0.7456
#
# Epoch 00024: val_matthews_correlation did not improve from 0.76044
# Epoch 25/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0360 - matthews_correlation: 0.8717 - val_loss: 0.0873 - val_matthews_correlation: 0.7389
#
# Epoch 00025: val_matthews_correlation did not improve from 0.76044
# Epoch 26/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0462 - matthews_correlation: 0.8739 - val_loss: 0.0918 - val_matthews_correlation: 0.6385
#
# Epoch 00026: val_matthews_correlation did not improve from 0.76044
# Epoch 27/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0252 - matthews_correlation: 0.9509 - val_loss: 0.1243 - val_matthews_correlation: 0.5477
#
# Epoch 00027: val_matthews_correlation did not improve from 0.76044
# Epoch 28/50
# 2322/2322 [==============================] - 19s 8ms/step - loss: 0.0235 - matthews_correlation: 0.9140 - val_loss: 0.1038 - val_matthews_correlation: 0.6575
#
# Epoch 00028: val_matthews_correlation did not improve from 0.76044
# Epoch 29/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0142 - matthews_correlation: 0.9607 - val_loss: 0.1233 - val_matthews_correlation: 0.6641
#
# Epoch 00029: val_matthews_correlation did not improve from 0.76044
# Epoch 30/50
# 2322/2322 [==============================] - 19s 8ms/step - loss: 0.0680 - matthews_correlation: 0.7297 - val_loss: 0.1255 - val_matthews_correlation: 0.7125
#
# Epoch 00030: val_matthews_correlation did not improve from 0.76044
# Epoch 31/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0351 - matthews_correlation: 0.8933 - val_loss: 0.0947 - val_matthews_correlation: 0.6008
#
# Epoch 00031: val_matthews_correlation did not improve from 0.76044
# Epoch 32/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0257 - matthews_correlation: 0.9278 - val_loss: 0.1184 - val_matthews_correlation: 0.6702
#
# Epoch 00032: val_matthews_correlation did not improve from 0.76044
# Epoch 33/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0138 - matthews_correlation: 0.9718 - val_loss: 0.1069 - val_matthews_correlation: 0.7229
#
# Epoch 00033: val_matthews_correlation did not improve from 0.76044
# Epoch 34/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0189 - matthews_correlation: 0.9475 - val_loss: 0.1261 - val_matthews_correlation: 0.6342
#
# Epoch 00034: val_matthews_correlation did not improve from 0.76044
# Epoch 35/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0201 - matthews_correlation: 0.9390 - val_loss: 0.0867 - val_matthews_correlation: 0.8515
#
# Epoch 00035: val_matthews_correlation improved from 0.76044 to 0.85153, saving model to weights_0.h5
# Epoch 36/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0120 - matthews_correlation: 0.9818 - val_loss: 0.1361 - val_matthews_correlation: 0.5902
#
# Epoch 00036: val_matthews_correlation did not improve from 0.85153
# Epoch 37/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0091 - matthews_correlation: 0.9694 - val_loss: 0.1145 - val_matthews_correlation: 0.7646
#
# Epoch 00037: val_matthews_correlation did not improve from 0.85153
# Epoch 38/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0055 - matthews_correlation: 0.9782 - val_loss: 0.1241 - val_matthews_correlation: 0.7789
#
# Epoch 00038: val_matthews_correlation did not improve from 0.85153
# Epoch 39/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0126 - matthews_correlation: 0.9602 - val_loss: 0.1423 - val_matthews_correlation: 0.6900
#
# Epoch 00039: val_matthews_correlation did not improve from 0.85153
# Epoch 40/50
# 2322/2322 [==============================] - 19s 8ms/step - loss: 0.0114 - matthews_correlation: 0.9683 - val_loss: 0.0938 - val_matthews_correlation: 0.7409
#
# Epoch 00040: val_matthews_correlation did not improve from 0.85153
# Epoch 41/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0363 - matthews_correlation: 0.9206 - val_loss: 0.2490 - val_matthews_correlation: 0.3696
#
# Epoch 00041: val_matthews_correlation did not improve from 0.85153
# Epoch 42/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0553 - matthews_correlation: 0.8350 - val_loss: 0.0829 - val_matthews_correlation: 0.7021
#
# Epoch 00042: val_matthews_correlation did not improve from 0.85153
# Epoch 43/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0354 - matthews_correlation: 0.8925 - val_loss: 0.1085 - val_matthews_correlation: 0.6028
#
# Epoch 00043: val_matthews_correlation did not improve from 0.85153
# Epoch 44/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0207 - matthews_correlation: 0.8719 - val_loss: 0.1050 - val_matthews_correlation: 0.6467
#
# Epoch 00044: val_matthews_correlation did not improve from 0.85153
# Epoch 45/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0105 - matthews_correlation: 0.9633 - val_loss: 0.1041 - val_matthews_correlation: 0.7040
#
# Epoch 00045: val_matthews_correlation did not improve from 0.85153
# Epoch 46/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0055 - matthews_correlation: 0.9748 - val_loss: 0.0994 - val_matthews_correlation: 0.7417
#
# Epoch 00046: val_matthews_correlation did not improve from 0.85153
# Epoch 47/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0035 - matthews_correlation: 0.9835 - val_loss: 0.1093 - val_matthews_correlation: 0.7258
#
# Epoch 00047: val_matthews_correlation did not improve from 0.85153
# Epoch 48/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0020 - matthews_correlation: 0.9970 - val_loss: 0.1083 - val_matthews_correlation: 0.7507
#
# Epoch 00048: val_matthews_correlation did not improve from 0.85153
# Epoch 49/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 0.0014 - matthews_correlation: 0.9957 - val_loss: 0.1183 - val_matthews_correlation: 0.7328
#
# Epoch 00049: val_matthews_correlation did not improve from 0.85153
# Epoch 50/50
# 2322/2322 [==============================] - 20s 8ms/step - loss: 5.8859e-04 - matthews_correlation: 1.0000 - val_loss: 0.1195 - val_matthews_correlation: 0.7328
#
# Epoch 00050: val_matthews_correlation did not improve from 0.85153
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.2714 - matthews_correlation: -0.0035 - val_loss: 0.1962 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1487 - matthews_correlation: 0.2778 - val_loss: 0.1587 - val_matthews_correlation: 0.4841
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.48414, saving model to weights_1.h5
# Epoch 3/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.1280 - matthews_correlation: 0.5476 - val_loss: 0.1420 - val_matthews_correlation: 0.3907
#
# Epoch 00003: val_matthews_correlation did not improve from 0.48414
# Epoch 4/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.1115 - matthews_correlation: 0.6012 - val_loss: 0.1376 - val_matthews_correlation: 0.4940
#
# Epoch 00004: val_matthews_correlation improved from 0.48414 to 0.49398, saving model to weights_1.h5
# Epoch 5/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.1111 - matthews_correlation: 0.6635 - val_loss: 0.1379 - val_matthews_correlation: 0.4746
#
# Epoch 00005: val_matthews_correlation did not improve from 0.49398
# Epoch 6/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0989 - matthews_correlation: 0.6482 - val_loss: 0.1335 - val_matthews_correlation: 0.5267
#
# Epoch 00006: val_matthews_correlation improved from 0.49398 to 0.52671, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0950 - matthews_correlation: 0.6784 - val_loss: 0.1395 - val_matthews_correlation: 0.5105
#
# Epoch 00007: val_matthews_correlation did not improve from 0.52671
# Epoch 8/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0855 - matthews_correlation: 0.6828 - val_loss: 0.1372 - val_matthews_correlation: 0.5328
#
# Epoch 00008: val_matthews_correlation improved from 0.52671 to 0.53276, saving model to weights_1.h5
# Epoch 9/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0909 - matthews_correlation: 0.6966 - val_loss: 0.1269 - val_matthews_correlation: 0.5331
#
# Epoch 00009: val_matthews_correlation improved from 0.53276 to 0.53312, saving model to weights_1.h5
# Epoch 10/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0816 - matthews_correlation: 0.7261 - val_loss: 0.1244 - val_matthews_correlation: 0.5399
#
# Epoch 00010: val_matthews_correlation improved from 0.53312 to 0.53992, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0705 - matthews_correlation: 0.7728 - val_loss: 0.1119 - val_matthews_correlation: 0.5804
#
# Epoch 00011: val_matthews_correlation improved from 0.53992 to 0.58041, saving model to weights_1.h5
# Epoch 12/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0642 - matthews_correlation: 0.8012 - val_loss: 0.1193 - val_matthews_correlation: 0.6300
#
# Epoch 00012: val_matthews_correlation improved from 0.58041 to 0.63000, saving model to weights_1.h5
# Epoch 13/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0651 - matthews_correlation: 0.7649 - val_loss: 0.1100 - val_matthews_correlation: 0.5974
#
# Epoch 00013: val_matthews_correlation did not improve from 0.63000
# Epoch 14/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0567 - matthews_correlation: 0.8218 - val_loss: 0.1095 - val_matthews_correlation: 0.6121
#
# Epoch 00014: val_matthews_correlation did not improve from 0.63000
# Epoch 15/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0384 - matthews_correlation: 0.8800 - val_loss: 0.1309 - val_matthews_correlation: 0.6291
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63000
# Epoch 16/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0331 - matthews_correlation: 0.9054 - val_loss: 0.1441 - val_matthews_correlation: 0.5799
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63000
# Epoch 17/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0474 - matthews_correlation: 0.7872 - val_loss: 0.1418 - val_matthews_correlation: 0.6600
#
# Epoch 00017: val_matthews_correlation improved from 0.63000 to 0.65997, saving model to weights_1.h5
# Epoch 18/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0368 - matthews_correlation: 0.8804 - val_loss: 0.1281 - val_matthews_correlation: 0.6757
#
# Epoch 00018: val_matthews_correlation improved from 0.65997 to 0.67574, saving model to weights_1.h5
# Epoch 19/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0206 - matthews_correlation: 0.9408 - val_loss: 0.1257 - val_matthews_correlation: 0.6850
#
# Epoch 00019: val_matthews_correlation improved from 0.67574 to 0.68500, saving model to weights_1.h5
# Epoch 20/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0173 - matthews_correlation: 0.9352 - val_loss: 0.1506 - val_matthews_correlation: 0.6525
#
# Epoch 00020: val_matthews_correlation did not improve from 0.68500
# Epoch 21/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0104 - matthews_correlation: 0.9710 - val_loss: 0.1579 - val_matthews_correlation: 0.6876
#
# Epoch 00021: val_matthews_correlation improved from 0.68500 to 0.68757, saving model to weights_1.h5
# Epoch 22/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0034 - matthews_correlation: 0.9914 - val_loss: 0.1544 - val_matthews_correlation: 0.6897
#
# Epoch 00022: val_matthews_correlation improved from 0.68757 to 0.68970, saving model to weights_1.h5
# Epoch 23/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0016 - matthews_correlation: 1.0000 - val_loss: 0.1813 - val_matthews_correlation: 0.6665
#
# Epoch 00023: val_matthews_correlation did not improve from 0.68970
# Epoch 24/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0038 - matthews_correlation: 0.9821 - val_loss: 0.1582 - val_matthews_correlation: 0.7095
#
# Epoch 00024: val_matthews_correlation improved from 0.68970 to 0.70950, saving model to weights_1.h5
# Epoch 25/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.0029 - matthews_correlation: 0.9938 - val_loss: 0.1864 - val_matthews_correlation: 0.6922
#
# Epoch 00025: val_matthews_correlation did not improve from 0.70950
# Epoch 26/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0019 - matthews_correlation: 0.9940 - val_loss: 0.2070 - val_matthews_correlation: 0.6609
#
# Epoch 00026: val_matthews_correlation did not improve from 0.70950
# Epoch 27/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0239 - matthews_correlation: 0.9559 - val_loss: 0.1591 - val_matthews_correlation: 0.5862
#
# Epoch 00027: val_matthews_correlation did not improve from 0.70950
# Epoch 28/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0123 - matthews_correlation: 0.9556 - val_loss: 0.1610 - val_matthews_correlation: 0.6414
#
# Epoch 00028: val_matthews_correlation did not improve from 0.70950
# Epoch 29/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0146 - matthews_correlation: 0.9510 - val_loss: 0.2194 - val_matthews_correlation: 0.5791
#
# Epoch 00029: val_matthews_correlation did not improve from 0.70950
# Epoch 30/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0221 - matthews_correlation: 0.9260 - val_loss: 0.1940 - val_matthews_correlation: 0.6015
#
# Epoch 00030: val_matthews_correlation did not improve from 0.70950
# Epoch 31/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0479 - matthews_correlation: 0.8805 - val_loss: 0.1343 - val_matthews_correlation: 0.6590
#
# Epoch 00031: val_matthews_correlation did not improve from 0.70950
# Epoch 32/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0175 - matthews_correlation: 0.9578 - val_loss: 0.1244 - val_matthews_correlation: 0.6620
#
# Epoch 00032: val_matthews_correlation did not improve from 0.70950
# Epoch 33/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0113 - matthews_correlation: 0.9605 - val_loss: 0.1526 - val_matthews_correlation: 0.7080
#
# Epoch 00033: val_matthews_correlation did not improve from 0.70950
# Epoch 34/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0176 - matthews_correlation: 0.9426 - val_loss: 0.1585 - val_matthews_correlation: 0.6266
#
# Epoch 00034: val_matthews_correlation did not improve from 0.70950
# Epoch 35/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0116 - matthews_correlation: 0.9702 - val_loss: 0.1936 - val_matthews_correlation: 0.6610
#
# Epoch 00035: val_matthews_correlation did not improve from 0.70950
# Epoch 36/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0039 - matthews_correlation: 0.9872 - val_loss: 0.1941 - val_matthews_correlation: 0.6002
#
# Epoch 00036: val_matthews_correlation did not improve from 0.70950
# Epoch 37/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0012 - matthews_correlation: 0.9918 - val_loss: 0.1915 - val_matthews_correlation: 0.7322
#
# Epoch 00037: val_matthews_correlation improved from 0.70950 to 0.73217, saving model to weights_1.h5
# Epoch 38/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 4.4480e-04 - matthews_correlation: 1.0000 - val_loss: 0.1879 - val_matthews_correlation: 0.6943
#
# Epoch 00038: val_matthews_correlation did not improve from 0.73217
# Epoch 39/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 2.5739e-04 - matthews_correlation: 1.0000 - val_loss: 0.1932 - val_matthews_correlation: 0.6816
#
# Epoch 00039: val_matthews_correlation did not improve from 0.73217
# Epoch 40/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 2.0330e-04 - matthews_correlation: 1.0000 - val_loss: 0.1958 - val_matthews_correlation: 0.6816
#
# Epoch 00040: val_matthews_correlation did not improve from 0.73217
# Epoch 41/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 1.6614e-04 - matthews_correlation: 1.0000 - val_loss: 0.1986 - val_matthews_correlation: 0.6816
#
# Epoch 00041: val_matthews_correlation did not improve from 0.73217
# Epoch 42/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 1.4239e-04 - matthews_correlation: 0.9918 - val_loss: 0.2005 - val_matthews_correlation: 0.6816
#
# Epoch 00042: val_matthews_correlation did not improve from 0.73217
# Epoch 43/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 1.2639e-04 - matthews_correlation: 1.0000 - val_loss: 0.2028 - val_matthews_correlation: 0.6816
#
# Epoch 00043: val_matthews_correlation did not improve from 0.73217
# Epoch 44/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 1.1359e-04 - matthews_correlation: 0.9918 - val_loss: 0.2051 - val_matthews_correlation: 0.6816
#
# Epoch 00044: val_matthews_correlation did not improve from 0.73217
# Epoch 45/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 1.0240e-04 - matthews_correlation: 0.9918 - val_loss: 0.2074 - val_matthews_correlation: 0.6570
#
# Epoch 00045: val_matthews_correlation did not improve from 0.73217
# Epoch 46/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 9.2971e-05 - matthews_correlation: 1.0000 - val_loss: 0.2091 - val_matthews_correlation: 0.6570
#
# Epoch 00046: val_matthews_correlation did not improve from 0.73217
# Epoch 47/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 8.5360e-05 - matthews_correlation: 1.0000 - val_loss: 0.2106 - val_matthews_correlation: 0.6816
#
# Epoch 00047: val_matthews_correlation did not improve from 0.73217
# Epoch 48/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 7.8485e-05 - matthews_correlation: 1.0000 - val_loss: 0.2123 - val_matthews_correlation: 0.6816
#
# Epoch 00048: val_matthews_correlation did not improve from 0.73217
# Epoch 49/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 7.2467e-05 - matthews_correlation: 1.0000 - val_loss: 0.2137 - val_matthews_correlation: 0.6570
#
# Epoch 00049: val_matthews_correlation did not improve from 0.73217
# Epoch 50/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 6.7387e-05 - matthews_correlation: 1.0000 - val_loss: 0.2152 - val_matthews_correlation: 0.6570
#
# Epoch 00050: val_matthews_correlation did not improve from 0.73217
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.2776 - matthews_correlation: 0.0000e+00 - val_loss: 0.1916 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.1614 - matthews_correlation: 0.2269 - val_loss: 0.1333 - val_matthews_correlation: 0.6203
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.62025, saving model to weights_2.h5
# Epoch 3/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.1294 - matthews_correlation: 0.5204 - val_loss: 0.1142 - val_matthews_correlation: 0.5805
#
# Epoch 00003: val_matthews_correlation did not improve from 0.62025
# Epoch 4/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.1162 - matthews_correlation: 0.6173 - val_loss: 0.0999 - val_matthews_correlation: 0.7000
#
# Epoch 00004: val_matthews_correlation improved from 0.62025 to 0.69997, saving model to weights_2.h5
# Epoch 5/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1030 - matthews_correlation: 0.6003 - val_loss: 0.0992 - val_matthews_correlation: 0.6853
#
# Epoch 00005: val_matthews_correlation did not improve from 0.69997
# Epoch 6/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.0930 - matthews_correlation: 0.6328 - val_loss: 0.0931 - val_matthews_correlation: 0.6465
#
# Epoch 00006: val_matthews_correlation did not improve from 0.69997
# Epoch 7/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0835 - matthews_correlation: 0.7039 - val_loss: 0.0968 - val_matthews_correlation: 0.6789
#
# Epoch 00007: val_matthews_correlation did not improve from 0.69997
# Epoch 8/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0789 - matthews_correlation: 0.7224 - val_loss: 0.1407 - val_matthews_correlation: 0.6352
#
# Epoch 00008: val_matthews_correlation did not improve from 0.69997
# Epoch 9/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0783 - matthews_correlation: 0.7709 - val_loss: 0.0871 - val_matthews_correlation: 0.7177
#
# Epoch 00009: val_matthews_correlation improved from 0.69997 to 0.71767, saving model to weights_2.h5
# Epoch 10/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0620 - matthews_correlation: 0.7763 - val_loss: 0.1495 - val_matthews_correlation: 0.6250
#
# Epoch 00010: val_matthews_correlation did not improve from 0.71767
# Epoch 11/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0728 - matthews_correlation: 0.7231 - val_loss: 0.1140 - val_matthews_correlation: 0.6886
#
# Epoch 00011: val_matthews_correlation did not improve from 0.71767
# Epoch 12/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0544 - matthews_correlation: 0.8105 - val_loss: 0.1104 - val_matthews_correlation: 0.6869
#
# Epoch 00012: val_matthews_correlation did not improve from 0.71767
# Epoch 13/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0412 - matthews_correlation: 0.8706 - val_loss: 0.1184 - val_matthews_correlation: 0.7261
#
# Epoch 00013: val_matthews_correlation improved from 0.71767 to 0.72610, saving model to weights_2.h5
# Epoch 14/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.0425 - matthews_correlation: 0.8677 - val_loss: 0.1014 - val_matthews_correlation: 0.7938
#
# Epoch 00014: val_matthews_correlation improved from 0.72610 to 0.79384, saving model to weights_2.h5
# Epoch 15/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.0335 - matthews_correlation: 0.8851 - val_loss: 0.1189 - val_matthews_correlation: 0.7159
#
# Epoch 00015: val_matthews_correlation did not improve from 0.79384
# Epoch 16/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.0270 - matthews_correlation: 0.9109 - val_loss: 0.1404 - val_matthews_correlation: 0.7358
#
# Epoch 00016: val_matthews_correlation did not improve from 0.79384
# Epoch 17/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0227 - matthews_correlation: 0.9382 - val_loss: 0.1267 - val_matthews_correlation: 0.6833
#
# Epoch 00017: val_matthews_correlation did not improve from 0.79384
# Epoch 18/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.0166 - matthews_correlation: 0.9518 - val_loss: 0.1352 - val_matthews_correlation: 0.6193
#
# Epoch 00018: val_matthews_correlation did not improve from 0.79384
# Epoch 19/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0143 - matthews_correlation: 0.9646 - val_loss: 0.1741 - val_matthews_correlation: 0.6146
#
# Epoch 00019: val_matthews_correlation did not improve from 0.79384
# Epoch 20/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0466 - matthews_correlation: 0.8672 - val_loss: 0.1293 - val_matthews_correlation: 0.7431
#
# Epoch 00020: val_matthews_correlation did not improve from 0.79384
# Epoch 21/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0381 - matthews_correlation: 0.8550 - val_loss: 0.1212 - val_matthews_correlation: 0.7433
#
# Epoch 00021: val_matthews_correlation did not improve from 0.79384
# Epoch 22/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0287 - matthews_correlation: 0.9204 - val_loss: 0.1285 - val_matthews_correlation: 0.6436
#
# Epoch 00022: val_matthews_correlation did not improve from 0.79384
# Epoch 23/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0227 - matthews_correlation: 0.8792 - val_loss: 0.1311 - val_matthews_correlation: 0.7039
#
# Epoch 00023: val_matthews_correlation did not improve from 0.79384
# Epoch 24/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0133 - matthews_correlation: 0.9600 - val_loss: 0.1373 - val_matthews_correlation: 0.7061
#
# Epoch 00024: val_matthews_correlation did not improve from 0.79384
# Epoch 25/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0099 - matthews_correlation: 0.9837 - val_loss: 0.1380 - val_matthews_correlation: 0.7244
#
# Epoch 00025: val_matthews_correlation did not improve from 0.79384
# Epoch 26/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0075 - matthews_correlation: 0.9863 - val_loss: 0.1604 - val_matthews_correlation: 0.7012
#
# Epoch 00026: val_matthews_correlation did not improve from 0.79384
# Epoch 27/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0114 - matthews_correlation: 0.9788 - val_loss: 0.1529 - val_matthews_correlation: 0.7010
#
# Epoch 00027: val_matthews_correlation did not improve from 0.79384
# Epoch 28/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0082 - matthews_correlation: 0.9669 - val_loss: 0.1405 - val_matthews_correlation: 0.6735
#
# Epoch 00028: val_matthews_correlation did not improve from 0.79384
# Epoch 29/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.0047 - matthews_correlation: 0.9907 - val_loss: 0.1371 - val_matthews_correlation: 0.7196
#
# Epoch 00029: val_matthews_correlation did not improve from 0.79384
# Epoch 30/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0032 - matthews_correlation: 0.9940 - val_loss: 0.1561 - val_matthews_correlation: 0.6687
#
# Epoch 00030: val_matthews_correlation did not improve from 0.79384
# Epoch 31/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 0.0021 - matthews_correlation: 0.9940 - val_loss: 0.1540 - val_matthews_correlation: 0.7234
#
# Epoch 00031: val_matthews_correlation did not improve from 0.79384
# Epoch 32/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.0013 - matthews_correlation: 0.9970 - val_loss: 0.1592 - val_matthews_correlation: 0.7496
#
# Epoch 00032: val_matthews_correlation did not improve from 0.79384
# Epoch 33/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 5.0250e-04 - matthews_correlation: 1.0000 - val_loss: 0.1693 - val_matthews_correlation: 0.7496
#
# Epoch 00033: val_matthews_correlation did not improve from 0.79384
# Epoch 34/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 3.1685e-04 - matthews_correlation: 0.9918 - val_loss: 0.1710 - val_matthews_correlation: 0.7496
#
# Epoch 00034: val_matthews_correlation did not improve from 0.79384
# Epoch 35/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 2.4605e-04 - matthews_correlation: 1.0000 - val_loss: 0.1760 - val_matthews_correlation: 0.7496
#
# Epoch 00035: val_matthews_correlation did not improve from 0.79384
# Epoch 36/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 2.0015e-04 - matthews_correlation: 1.0000 - val_loss: 0.1798 - val_matthews_correlation: 0.7496
#
# Epoch 00036: val_matthews_correlation did not improve from 0.79384
# Epoch 37/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 1.6734e-04 - matthews_correlation: 1.0000 - val_loss: 0.1802 - val_matthews_correlation: 0.7496
#
# Epoch 00037: val_matthews_correlation did not improve from 0.79384
# Epoch 38/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 1.4673e-04 - matthews_correlation: 1.0000 - val_loss: 0.1843 - val_matthews_correlation: 0.7496
#
# Epoch 00038: val_matthews_correlation did not improve from 0.79384
# Epoch 39/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 1.2790e-04 - matthews_correlation: 1.0000 - val_loss: 0.1872 - val_matthews_correlation: 0.7496
#
# Epoch 00039: val_matthews_correlation did not improve from 0.79384
# Epoch 40/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 1.1532e-04 - matthews_correlation: 1.0000 - val_loss: 0.1897 - val_matthews_correlation: 0.7496
#
# Epoch 00040: val_matthews_correlation did not improve from 0.79384
# Epoch 41/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 1.0430e-04 - matthews_correlation: 0.9918 - val_loss: 0.1915 - val_matthews_correlation: 0.7496
#
# Epoch 00041: val_matthews_correlation did not improve from 0.79384
# Epoch 42/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 9.3234e-05 - matthews_correlation: 1.0000 - val_loss: 0.1939 - val_matthews_correlation: 0.7496
#
# Epoch 00042: val_matthews_correlation did not improve from 0.79384
# Epoch 43/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 8.5135e-05 - matthews_correlation: 0.9918 - val_loss: 0.1957 - val_matthews_correlation: 0.7496
#
# Epoch 00043: val_matthews_correlation did not improve from 0.79384
# Epoch 44/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 7.8249e-05 - matthews_correlation: 1.0000 - val_loss: 0.1974 - val_matthews_correlation: 0.7496
#
# Epoch 00044: val_matthews_correlation did not improve from 0.79384
# Epoch 45/50
# 2323/2323 [==============================] - 20s 8ms/step - loss: 7.2749e-05 - matthews_correlation: 1.0000 - val_loss: 0.1984 - val_matthews_correlation: 0.7496
#
# Epoch 00045: val_matthews_correlation did not improve from 0.79384
# Epoch 46/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 6.7318e-05 - matthews_correlation: 1.0000 - val_loss: 0.2006 - val_matthews_correlation: 0.7496
#
# Epoch 00046: val_matthews_correlation did not improve from 0.79384
# Epoch 47/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 6.2976e-05 - matthews_correlation: 1.0000 - val_loss: 0.2022 - val_matthews_correlation: 0.7496
#
# Epoch 00047: val_matthews_correlation did not improve from 0.79384
# Epoch 48/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 5.8613e-05 - matthews_correlation: 1.0000 - val_loss: 0.2039 - val_matthews_correlation: 0.7496
#
# Epoch 00048: val_matthews_correlation did not improve from 0.79384
# Epoch 49/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 5.4922e-05 - matthews_correlation: 1.0000 - val_loss: 0.2051 - val_matthews_correlation: 0.7496
#
# Epoch 00049: val_matthews_correlation did not improve from 0.79384
# Epoch 50/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 5.1889e-05 - matthews_correlation: 0.9918 - val_loss: 0.2061 - val_matthews_correlation: 0.7496
#
# Epoch 00050: val_matthews_correlation did not improve from 0.79384
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.2750 - matthews_correlation: 0.0204 - val_loss: 0.1933 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1584 - matthews_correlation: 0.1775 - val_loss: 0.1299 - val_matthews_correlation: 0.5845
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.58448, saving model to weights_3.h5
# Epoch 3/50
# 2324/2324 [==============================] - 19s 8ms/step - loss: 0.1288 - matthews_correlation: 0.5360 - val_loss: 0.1188 - val_matthews_correlation: 0.6176
#
# Epoch 00003: val_matthews_correlation improved from 0.58448 to 0.61756, saving model to weights_3.h5
# Epoch 4/50
# 2324/2324 [==============================] - 19s 8ms/step - loss: 0.1130 - matthews_correlation: 0.5935 - val_loss: 0.1218 - val_matthews_correlation: 0.5529
#
# Epoch 00004: val_matthews_correlation did not improve from 0.61756
# Epoch 5/50
# 2324/2324 [==============================] - 19s 8ms/step - loss: 0.1029 - matthews_correlation: 0.6223 - val_loss: 0.1085 - val_matthews_correlation: 0.5568
#
# Epoch 00005: val_matthews_correlation did not improve from 0.61756
# Epoch 6/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0891 - matthews_correlation: 0.7051 - val_loss: 0.1035 - val_matthews_correlation: 0.6213
#
# Epoch 00006: val_matthews_correlation improved from 0.61756 to 0.62134, saving model to weights_3.h5
# Epoch 7/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0795 - matthews_correlation: 0.7658 - val_loss: 0.1044 - val_matthews_correlation: 0.6153
#
# Epoch 00007: val_matthews_correlation did not improve from 0.62134
# Epoch 8/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0816 - matthews_correlation: 0.7162 - val_loss: 0.1031 - val_matthews_correlation: 0.6403
#
# Epoch 00008: val_matthews_correlation improved from 0.62134 to 0.64027, saving model to weights_3.h5
# Epoch 9/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0760 - matthews_correlation: 0.7292 - val_loss: 0.1069 - val_matthews_correlation: 0.6455
#
# Epoch 00009: val_matthews_correlation improved from 0.64027 to 0.64554, saving model to weights_3.h5
# Epoch 10/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0612 - matthews_correlation: 0.8106 - val_loss: 0.1391 - val_matthews_correlation: 0.5521
#
# Epoch 00010: val_matthews_correlation did not improve from 0.64554
# Epoch 11/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0734 - matthews_correlation: 0.7594 - val_loss: 0.1136 - val_matthews_correlation: 0.5663
#
# Epoch 00011: val_matthews_correlation did not improve from 0.64554
# Epoch 12/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0516 - matthews_correlation: 0.8283 - val_loss: 0.1434 - val_matthews_correlation: 0.4206
#
# Epoch 00012: val_matthews_correlation did not improve from 0.64554
# Epoch 13/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0564 - matthews_correlation: 0.7966 - val_loss: 0.1141 - val_matthews_correlation: 0.6829
#
# Epoch 00013: val_matthews_correlation improved from 0.64554 to 0.68288, saving model to weights_3.h5
# Epoch 14/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0555 - matthews_correlation: 0.7922 - val_loss: 0.1262 - val_matthews_correlation: 0.5977
#
# Epoch 00014: val_matthews_correlation did not improve from 0.68288
# Epoch 15/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0393 - matthews_correlation: 0.8723 - val_loss: 0.1271 - val_matthews_correlation: 0.5897
#
# Epoch 00015: val_matthews_correlation did not improve from 0.68288
# Epoch 16/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0324 - matthews_correlation: 0.8763 - val_loss: 0.1374 - val_matthews_correlation: 0.6147
#
# Epoch 00016: val_matthews_correlation did not improve from 0.68288
# Epoch 17/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0275 - matthews_correlation: 0.9012 - val_loss: 0.1395 - val_matthews_correlation: 0.5807
#
# Epoch 00017: val_matthews_correlation did not improve from 0.68288
# Epoch 18/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0372 - matthews_correlation: 0.8885 - val_loss: 0.1421 - val_matthews_correlation: 0.5108
#
# Epoch 00018: val_matthews_correlation did not improve from 0.68288
# Epoch 19/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0258 - matthews_correlation: 0.9049 - val_loss: 0.1364 - val_matthews_correlation: 0.6295
#
# Epoch 00019: val_matthews_correlation did not improve from 0.68288
# Epoch 20/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0242 - matthews_correlation: 0.9288 - val_loss: 0.1571 - val_matthews_correlation: 0.6338
#
# Epoch 00020: val_matthews_correlation did not improve from 0.68288
# Epoch 21/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0200 - matthews_correlation: 0.9594 - val_loss: 0.1683 - val_matthews_correlation: 0.6135
#
# Epoch 00021: val_matthews_correlation did not improve from 0.68288
# Epoch 22/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0094 - matthews_correlation: 0.9690 - val_loss: 0.1731 - val_matthews_correlation: 0.6240
#
# Epoch 00022: val_matthews_correlation did not improve from 0.68288
# Epoch 23/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0476 - matthews_correlation: 0.8324 - val_loss: 0.1388 - val_matthews_correlation: 0.6152
#
# Epoch 00023: val_matthews_correlation did not improve from 0.68288
# Epoch 24/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0209 - matthews_correlation: 0.9336 - val_loss: 0.1660 - val_matthews_correlation: 0.6296
#
# Epoch 00024: val_matthews_correlation did not improve from 0.68288
# Epoch 25/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0072 - matthews_correlation: 0.9817 - val_loss: 0.1854 - val_matthews_correlation: 0.5420
#
# Epoch 00025: val_matthews_correlation did not improve from 0.68288
# Epoch 26/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0025 - matthews_correlation: 0.9974 - val_loss: 0.1718 - val_matthews_correlation: 0.6354
#
# Epoch 00026: val_matthews_correlation did not improve from 0.68288
# Epoch 27/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0018 - matthews_correlation: 0.9859 - val_loss: 0.2110 - val_matthews_correlation: 0.6579
#
# Epoch 00027: val_matthews_correlation did not improve from 0.68288
# Epoch 28/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 6.9023e-04 - matthews_correlation: 1.0000 - val_loss: 0.2012 - val_matthews_correlation: 0.6354
#
# Epoch 00028: val_matthews_correlation did not improve from 0.68288
# Epoch 29/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 4.9738e-04 - matthews_correlation: 1.0000 - val_loss: 0.2222 - val_matthews_correlation: 0.6707
#
# Epoch 00029: val_matthews_correlation did not improve from 0.68288
# Epoch 30/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 3.4173e-04 - matthews_correlation: 1.0000 - val_loss: 0.2300 - val_matthews_correlation: 0.6579
#
# Epoch 00030: val_matthews_correlation did not improve from 0.68288
# Epoch 31/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 2.3859e-04 - matthews_correlation: 0.9914 - val_loss: 0.2272 - val_matthews_correlation: 0.6478
#
# Epoch 00031: val_matthews_correlation did not improve from 0.68288
# Epoch 32/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 2.0252e-04 - matthews_correlation: 1.0000 - val_loss: 0.2357 - val_matthews_correlation: 0.6606
#
# Epoch 00032: val_matthews_correlation did not improve from 0.68288
# Epoch 33/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 1.7710e-04 - matthews_correlation: 0.9914 - val_loss: 0.2396 - val_matthews_correlation: 0.6478
#
# Epoch 00033: val_matthews_correlation did not improve from 0.68288
# Epoch 34/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 1.5268e-04 - matthews_correlation: 1.0000 - val_loss: 0.2428 - val_matthews_correlation: 0.6354
#
# Epoch 00034: val_matthews_correlation did not improve from 0.68288
# Epoch 35/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 1.3541e-04 - matthews_correlation: 1.0000 - val_loss: 0.2465 - val_matthews_correlation: 0.6478
#
# Epoch 00035: val_matthews_correlation did not improve from 0.68288
# Epoch 36/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 1.2156e-04 - matthews_correlation: 0.9914 - val_loss: 0.2490 - val_matthews_correlation: 0.6354
#
# Epoch 00036: val_matthews_correlation did not improve from 0.68288
# Epoch 37/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 1.1080e-04 - matthews_correlation: 1.0000 - val_loss: 0.2520 - val_matthews_correlation: 0.6354
#
# Epoch 00037: val_matthews_correlation did not improve from 0.68288
# Epoch 38/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 1.0152e-04 - matthews_correlation: 1.0000 - val_loss: 0.2552 - val_matthews_correlation: 0.6354
#
# Epoch 00038: val_matthews_correlation did not improve from 0.68288
# Epoch 39/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 9.3584e-05 - matthews_correlation: 1.0000 - val_loss: 0.2578 - val_matthews_correlation: 0.6354
#
# Epoch 00039: val_matthews_correlation did not improve from 0.68288
# Epoch 40/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 8.6573e-05 - matthews_correlation: 1.0000 - val_loss: 0.2600 - val_matthews_correlation: 0.6354
#
# Epoch 00040: val_matthews_correlation did not improve from 0.68288
# Epoch 41/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 8.0269e-05 - matthews_correlation: 0.9914 - val_loss: 0.2616 - val_matthews_correlation: 0.6354
#
# Epoch 00041: val_matthews_correlation did not improve from 0.68288
# Epoch 42/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 7.4704e-05 - matthews_correlation: 1.0000 - val_loss: 0.2639 - val_matthews_correlation: 0.6354
#
# Epoch 00042: val_matthews_correlation did not improve from 0.68288
# Epoch 43/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 6.9601e-05 - matthews_correlation: 1.0000 - val_loss: 0.2663 - val_matthews_correlation: 0.6482
#
# Epoch 00043: val_matthews_correlation did not improve from 0.68288
# Epoch 44/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 6.5293e-05 - matthews_correlation: 1.0000 - val_loss: 0.2684 - val_matthews_correlation: 0.6482
#
# Epoch 00044: val_matthews_correlation did not improve from 0.68288
# Epoch 45/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 6.1240e-05 - matthews_correlation: 0.9914 - val_loss: 0.2707 - val_matthews_correlation: 0.6482
#
# Epoch 00045: val_matthews_correlation did not improve from 0.68288
# Epoch 46/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 5.7859e-05 - matthews_correlation: 1.0000 - val_loss: 0.2724 - val_matthews_correlation: 0.6482
#
# Epoch 00046: val_matthews_correlation did not improve from 0.68288
# Epoch 47/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 5.4619e-05 - matthews_correlation: 1.0000 - val_loss: 0.2743 - val_matthews_correlation: 0.6482
#
# Epoch 00047: val_matthews_correlation did not improve from 0.68288
# Epoch 48/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 5.1592e-05 - matthews_correlation: 0.9914 - val_loss: 0.2766 - val_matthews_correlation: 0.6482
#
# Epoch 00048: val_matthews_correlation did not improve from 0.68288
# Epoch 49/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 4.8962e-05 - matthews_correlation: 1.0000 - val_loss: 0.2779 - val_matthews_correlation: 0.6482
#
# Epoch 00049: val_matthews_correlation did not improve from 0.68288
# Epoch 50/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 4.6432e-05 - matthews_correlation: 1.0000 - val_loss: 0.2795 - val_matthews_correlation: 0.6482
#
# Epoch 00050: val_matthews_correlation did not improve from 0.68288
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.2983 - matthews_correlation: 0.0011 - val_loss: 0.1867 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.1576 - matthews_correlation: 0.0993 - val_loss: 0.1499 - val_matthews_correlation: 0.5797
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.57967, saving model to weights_4.h5
# Epoch 3/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1321 - matthews_correlation: 0.4389 - val_loss: 0.1379 - val_matthews_correlation: 0.5808
#
# Epoch 00003: val_matthews_correlation improved from 0.57967 to 0.58081, saving model to weights_4.h5
# Epoch 4/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1197 - matthews_correlation: 0.5848 - val_loss: 0.1315 - val_matthews_correlation: 0.5751
#
# Epoch 00004: val_matthews_correlation did not improve from 0.58081
# Epoch 5/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.1053 - matthews_correlation: 0.6183 - val_loss: 0.1491 - val_matthews_correlation: 0.5728
#
# Epoch 00005: val_matthews_correlation did not improve from 0.58081
# Epoch 6/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.1082 - matthews_correlation: 0.5791 - val_loss: 0.1320 - val_matthews_correlation: 0.5702
#
# Epoch 00006: val_matthews_correlation did not improve from 0.58081
# Epoch 7/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0894 - matthews_correlation: 0.6519 - val_loss: 0.1467 - val_matthews_correlation: 0.6210
#
# Epoch 00007: val_matthews_correlation improved from 0.58081 to 0.62104, saving model to weights_4.h5
# Epoch 8/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1020 - matthews_correlation: 0.5738 - val_loss: 0.1287 - val_matthews_correlation: 0.5478
#
# Epoch 00008: val_matthews_correlation did not improve from 0.62104
# Epoch 9/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0805 - matthews_correlation: 0.6850 - val_loss: 0.1301 - val_matthews_correlation: 0.4509
#
# Epoch 00009: val_matthews_correlation did not improve from 0.62104
# Epoch 10/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0738 - matthews_correlation: 0.7295 - val_loss: 0.1340 - val_matthews_correlation: 0.5674
#
# Epoch 00010: val_matthews_correlation did not improve from 0.62104
# Epoch 11/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0758 - matthews_correlation: 0.6763 - val_loss: 0.1324 - val_matthews_correlation: 0.4244
#
# Epoch 00011: val_matthews_correlation did not improve from 0.62104
# Epoch 12/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0675 - matthews_correlation: 0.7847 - val_loss: 0.1425 - val_matthews_correlation: 0.5766
#
# Epoch 00012: val_matthews_correlation did not improve from 0.62104
# Epoch 13/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0816 - matthews_correlation: 0.7569 - val_loss: 0.1337 - val_matthews_correlation: 0.5833
#
# Epoch 00013: val_matthews_correlation did not improve from 0.62104
# Epoch 14/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0692 - matthews_correlation: 0.7885 - val_loss: 0.1316 - val_matthews_correlation: 0.6627
#
# Epoch 00014: val_matthews_correlation improved from 0.62104 to 0.66273, saving model to weights_4.h5
# Epoch 15/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0504 - matthews_correlation: 0.8340 - val_loss: 0.1319 - val_matthews_correlation: 0.5720
#
# Epoch 00015: val_matthews_correlation did not improve from 0.66273
# Epoch 16/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0533 - matthews_correlation: 0.7738 - val_loss: 0.2350 - val_matthews_correlation: 0.5379
#
# Epoch 00016: val_matthews_correlation did not improve from 0.66273
# Epoch 17/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0666 - matthews_correlation: 0.8034 - val_loss: 0.1436 - val_matthews_correlation: 0.5856
#
# Epoch 00017: val_matthews_correlation did not improve from 0.66273
# Epoch 18/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0433 - matthews_correlation: 0.8531 - val_loss: 0.1423 - val_matthews_correlation: 0.5856
#
# Epoch 00018: val_matthews_correlation did not improve from 0.66273
# Epoch 19/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0255 - matthews_correlation: 0.9410 - val_loss: 0.1731 - val_matthews_correlation: 0.5320
#
# Epoch 00019: val_matthews_correlation did not improve from 0.66273
# Epoch 20/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0187 - matthews_correlation: 0.9585 - val_loss: 0.1989 - val_matthews_correlation: 0.5324
#
# Epoch 00020: val_matthews_correlation did not improve from 0.66273
# Epoch 21/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0254 - matthews_correlation: 0.9088 - val_loss: 0.2018 - val_matthews_correlation: 0.5574
#
# Epoch 00021: val_matthews_correlation did not improve from 0.66273
# Epoch 22/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0287 - matthews_correlation: 0.9045 - val_loss: 0.1715 - val_matthews_correlation: 0.5666
#
# Epoch 00022: val_matthews_correlation did not improve from 0.66273
# Epoch 23/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0316 - matthews_correlation: 0.9153 - val_loss: 0.1885 - val_matthews_correlation: 0.5952
#
# Epoch 00023: val_matthews_correlation did not improve from 0.66273
# Epoch 24/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0271 - matthews_correlation: 0.8895 - val_loss: 0.1767 - val_matthews_correlation: 0.5970
#
# Epoch 00024: val_matthews_correlation did not improve from 0.66273
# Epoch 25/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0174 - matthews_correlation: 0.9487 - val_loss: 0.1945 - val_matthews_correlation: 0.5826
#
# Epoch 00025: val_matthews_correlation did not improve from 0.66273
# Epoch 26/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0091 - matthews_correlation: 0.9869 - val_loss: 0.1968 - val_matthews_correlation: 0.5939
#
# Epoch 00026: val_matthews_correlation did not improve from 0.66273
# Epoch 27/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0029 - matthews_correlation: 0.9880 - val_loss: 0.2119 - val_matthews_correlation: 0.6211
#
# Epoch 00027: val_matthews_correlation did not improve from 0.66273
# Epoch 28/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 0.0014 - matthews_correlation: 0.9972 - val_loss: 0.2313 - val_matthews_correlation: 0.5668
#
# Epoch 00028: val_matthews_correlation did not improve from 0.66273
# Epoch 29/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 6.7889e-04 - matthews_correlation: 1.0000 - val_loss: 0.2384 - val_matthews_correlation: 0.5749
#
# Epoch 00029: val_matthews_correlation did not improve from 0.66273
# Epoch 30/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 4.6318e-04 - matthews_correlation: 1.0000 - val_loss: 0.2460 - val_matthews_correlation: 0.5749
#
# Epoch 00030: val_matthews_correlation did not improve from 0.66273
# Epoch 31/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 3.3031e-04 - matthews_correlation: 1.0000 - val_loss: 0.2475 - val_matthews_correlation: 0.5865
#
# Epoch 00031: val_matthews_correlation did not improve from 0.66273
# Epoch 32/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 2.6186e-04 - matthews_correlation: 1.0000 - val_loss: 0.2552 - val_matthews_correlation: 0.6170
#
# Epoch 00032: val_matthews_correlation did not improve from 0.66273
# Epoch 33/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 2.0797e-04 - matthews_correlation: 1.0000 - val_loss: 0.2612 - val_matthews_correlation: 0.6286
#
# Epoch 00033: val_matthews_correlation did not improve from 0.66273
# Epoch 34/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 1.7901e-04 - matthews_correlation: 1.0000 - val_loss: 0.2670 - val_matthews_correlation: 0.5985
#
# Epoch 00034: val_matthews_correlation did not improve from 0.66273
# Epoch 35/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 1.5332e-04 - matthews_correlation: 1.0000 - val_loss: 0.2693 - val_matthews_correlation: 0.6170
#
# Epoch 00035: val_matthews_correlation did not improve from 0.66273
# Epoch 36/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 1.3524e-04 - matthews_correlation: 1.0000 - val_loss: 0.2723 - val_matthews_correlation: 0.6170
#
# Epoch 00036: val_matthews_correlation did not improve from 0.66273
# Epoch 37/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 1.2241e-04 - matthews_correlation: 1.0000 - val_loss: 0.2758 - val_matthews_correlation: 0.6170
#
# Epoch 00037: val_matthews_correlation did not improve from 0.66273
# Epoch 38/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 1.0859e-04 - matthews_correlation: 0.9914 - val_loss: 0.2780 - val_matthews_correlation: 0.6286
#
# Epoch 00038: val_matthews_correlation did not improve from 0.66273
# Epoch 39/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 9.8260e-05 - matthews_correlation: 1.0000 - val_loss: 0.2814 - val_matthews_correlation: 0.6170
#
# Epoch 00039: val_matthews_correlation did not improve from 0.66273
# Epoch 40/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 8.9566e-05 - matthews_correlation: 1.0000 - val_loss: 0.2844 - val_matthews_correlation: 0.6170
#
# Epoch 00040: val_matthews_correlation did not improve from 0.66273
# Epoch 41/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 8.2480e-05 - matthews_correlation: 1.0000 - val_loss: 0.2862 - val_matthews_correlation: 0.6170
#
# Epoch 00041: val_matthews_correlation did not improve from 0.66273
# Epoch 42/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 7.5539e-05 - matthews_correlation: 0.9914 - val_loss: 0.2881 - val_matthews_correlation: 0.6170
#
# Epoch 00042: val_matthews_correlation did not improve from 0.66273
# Epoch 43/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 6.9955e-05 - matthews_correlation: 1.0000 - val_loss: 0.2897 - val_matthews_correlation: 0.6286
#
# Epoch 00043: val_matthews_correlation did not improve from 0.66273
# Epoch 44/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 6.4709e-05 - matthews_correlation: 0.9914 - val_loss: 0.2920 - val_matthews_correlation: 0.6286
#
# Epoch 00044: val_matthews_correlation did not improve from 0.66273
# Epoch 45/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 6.0729e-05 - matthews_correlation: 1.0000 - val_loss: 0.2943 - val_matthews_correlation: 0.6170
#
# Epoch 00045: val_matthews_correlation did not improve from 0.66273
# Epoch 46/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 5.6180e-05 - matthews_correlation: 0.9914 - val_loss: 0.2961 - val_matthews_correlation: 0.6170
#
# Epoch 00046: val_matthews_correlation did not improve from 0.66273
# Epoch 47/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 5.2759e-05 - matthews_correlation: 1.0000 - val_loss: 0.2977 - val_matthews_correlation: 0.6170
#
# Epoch 00047: val_matthews_correlation did not improve from 0.66273
# Epoch 48/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 4.9530e-05 - matthews_correlation: 0.9914 - val_loss: 0.3000 - val_matthews_correlation: 0.6170
#
# Epoch 00048: val_matthews_correlation did not improve from 0.66273
# Epoch 49/50
# 2324/2324 [==============================] - 20s 8ms/step - loss: 4.6619e-05 - matthews_correlation: 1.0000 - val_loss: 0.3013 - val_matthews_correlation: 0.6170
#
# Epoch 00049: val_matthews_correlation did not improve from 0.66273
# Epoch 50/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 4.3815e-05 - matthews_correlation: 1.0000 - val_loss: 0.3027 - val_matthews_correlation: 0.6286
#
# Epoch 00050: val_matthews_correlation did not improve from 0.66273
# ((2904,), (2904,))

# %%
np.save('./tmp/y_val_tmp_5.npy', y_val)
np.save('./tmp/preds_val_tmp_5.npy', preds_val)

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    
    #y_pred = K.cast(y_pred, np.float)
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = np.round(np.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)

    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        #score = matthews_correlation(y_true, (y_proba > threshold).astype(int))
        #score = K.eval(matthews_correlation(y_true, (y_proba > threshold).astype(int)))
        #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        score = matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 10792.82it/s]

# %%
best_threshold
# Out:
# 0.53

# %%
matthews_correlation(y_val, preds_val)
# Out:
# 0.7446631456531048

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')
df_test = meta_test.set_index(['id_measurement', 'phase'])
# Out:
# CPU times: user 16.7 ms, sys: 0 ns, total: 16.7 ms
# Wall time: 49.5 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data_test(start, end):
    # load a piece of data from file
    praq_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start+8712, end+8712)]).to_pandas()
    X = []

    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_test.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id = df_test.loc[id_measurement].loc[phase][0]
            # but just append the target one time, to not triplicate it
            
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_test[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    return X

# %%
def process_subtest(arg_tuple):
    start, end, idx = arg_tuple
    X = prep_data_test(start, end)
    return idx, X

# %%
all_chunks = []

num_cores = 16 
#def load_all():
total_size = len(meta_test)
chunk_size = np.ceil(total_size/num_cores)
#train_size = len(df_train)

for i in range(16):
    if i != 15:
        start_idx = int(i * chunk_size)
        end_idx = int(start_idx + chunk_size)
        #chunk = (start_idx+train_size, end_idx+train_size, i)
        chunk = (start_idx, end_idx, i)
        all_chunks.append(chunk)
    else:
        start_idx = int(i * chunk_size)
        end_idx = int(total_size)
        #chunk = (start_idx+train_size, end_idx+train_size, i)
        chunk = (start_idx, end_idx, i)
        all_chunks.append(chunk)

# %%
pool = Pool()
results_1 = pool.map(process_subtest, all_chunks[0:8])    
results_1 = sorted(results_1, key=lambda tup: tup[0])
# Out:
# 100%|██████████| 424/424 [14:04<00:00,  2.13s/it]
# 100%|██████████| 424/424 [14:10<00:00,  2.00s/it]
# 100%|██████████| 424/424 [15:52<00:00,  1.02s/it]
# 100%|██████████| 424/424 [15:54<00:00,  1.02it/s]
# 100%|██████████| 424/424 [16:03<00:00,  1.27it/s]
# 100%|██████████| 424/424 [16:05<00:00,  2.36s/it]
# 100%|██████████| 424/424 [16:20<00:00,  1.80it/s]
# 100%|██████████| 424/424 [16:44<00:00,  1.06s/it]
# 100%|██████████| 424/424 [13:48<00:00,  3.07s/it]
# 100%|██████████| 424/424 [14:52<00:00,  2.91s/it]
# 100%|██████████| 424/424 [14:55<00:00,  5.06s/it]
# 100%|██████████| 419/419 [14:59<00:00,  1.68s/it]
# 100%|██████████| 424/424 [15:14<00:00,  1.30s/it]
#  96%|█████████▌| 408/424 [15:46<00:08,  1.81it/s]
# 100%|██████████| 424/424 [15:50<00:00,  1.89it/s]
# 100%|██████████| 424/424 [16:06<00:00,  1.03s/it]

# %%
results_2 = pool.map(process_subtest, all_chunks[8:16])    
results_2 = sorted(results_2, key=lambda tup: tup[0])

# %%
results = results_1 + results_2
X_test = np.concatenate([item[1] for item in results], axis=0)

# %%
np.save("X_test_3.npy",X_test)

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %% [markdown]
# splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
#
# for idx, (train_idx, val_idx) in enumerate(splits):
#     K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
#     print("Beginning fold {}".format(idx+1))
#     # use the indexes to extract the folds in the train and validation data
#     train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
#     # instantiate the model for this fold
#     model = model_lstm(train_X.shape)

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 16s 2ms/step
# 6779/6779 [==============================] - 15s 2ms/step
# 6779/6779 [==============================] - 15s 2ms/step
# 6779/6779 [==============================] - 15s 2ms/step
# 6779/6779 [==============================] - 15s 2ms/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('../output/submission_19.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
lstm_preds = np.squeeze(np.mean(preds_test, axis=0))
np.save("./lstm_preds.npy", lstm_preds)
