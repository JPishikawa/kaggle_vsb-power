# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from scipy.signal import chirp, find_peaks, peak_widths
import pywt

from multiprocessing import Pool
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import warnings

warnings.filterwarnings('ignore')
# Out:
# /home/cwademo123/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 4
# it is just a constant with the measurements data size
sample_size = 800000

# %%
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
def maddest(d, axis=None):
    """
    Mean Absolute Deviation
    """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

# %%
def denoise_signal( x, wavelet='db4', level=1):
    """
    1. Adapted from waveletSmooth function found here:
    http://connor-johnson.com/2016/01/24/using-pywavelets-to-remove-high-frequency-noise/
    2. Threshold equation and using hard mode in threshold as mentioned
    in section '3.2 denoising based on optimized singular values' from paper by Tomas Vantuch:
    http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    """
    
    # Decompose to get the wavelet coefficients
    coeff = pywt.wavedec( x, wavelet, mode="per", level=level)
    
    # Calculate sigma for threshold as defined in http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    # As noted by @harshit92 MAD referred to in the paper is Mean Absolute Deviation not Median Absolute Deviation
    sigma = (1/0.6745) * maddest( coeff[-level] )

    # Calculte the univeral threshold
    uthresh = sigma * np.sqrt( 2*np.log( len( x ) ) )
    coeff[1:] = ( pywt.threshold( i, value=uthresh, mode='hard' ) for i in coeff[1:] )
    
    # Reconstruct the signal using the thresholded coefficients
    return pywt.waverec( coeff[1:], wavelet, mode='per' )

# %%
def denoise_signal_2( x, wavelet='db4', level=1):
    """
    1. Adapted from waveletSmooth function found here:
    http://connor-johnson.com/2016/01/24/using-pywavelets-to-remove-high-frequency-noise/
    2. Threshold equation and using hard mode in threshold as mentioned
    in section '3.2 denoising based on optimized singular values' from paper by Tomas Vantuch:
    http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    """
    
    # Decompose to get the wavelet coefficients
    coeff = pywt.wavedec( x, wavelet, mode="per", level=level)
    
    # Calculate sigma for threshold as defined in http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    # As noted by @harshit92 MAD referred to in the paper is Mean Absolute Deviation not Median Absolute Deviation
    sigma = (1/0.6745) * maddest( coeff[-level] )

    # Calculte the univeral threshold
    uthresh = sigma * np.sqrt( 2*np.log( len( x ) ) )
    coeff[1:] = ( pywt.threshold( i, value=uthresh, mode='hard' ) for i in coeff[1:] )
    
    # Reconstruct the signal using the thresholded coefficients
    return pywt.waverec( coeff[0:], wavelet, mode='per' )

# %%
def remove_corona(x_dn, maxDistance=10, maxHeightRatio=0.25, maxTicksRemoval=500):
    index = pd.Series(x_dn).loc[np.abs(x_dn)>0].index
    corona_idx = []
    for idx in index:
        for i in range(1,maxDistance+1):
            if idx+i < pd.Series(x_dn).shape[0]:
                if x_dn[idx+i]/(x_dn[idx]+1e-04)<-maxHeightRatio:
                    x_dn[idx:idx+maxTicksRemoval] = 0
                    corona_idx.append(idx)
    return x_dn, corona_idx

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    ts_wave = denoise_signal_2(ts_std, wavelet='haar', level=1)
    #ts_rm, corona_idx = remove_corona(ts_wave)
    
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        ts_wave_range = ts_wave[i:i + bucket_size]
        #ts_rm_range = pd.Series(ts_rm_range)
        
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        
        mean_wave = ts_wave_range.mean()
        #numpeaks = np.sum(ts_range!=0)/len(ts_range)
        #numpospeaks = ts_rm_range[ts_rm_range>0].count()
        #numpospeaks = np.sum(ts_range>0)/len(ts_range)
        #numnegpeaks = ts_rm_range[ts_rm_range<0].count()
        #numnegpeaks = np.sum(ts_range<0)/len(ts_range)
        #numpeaks = ts_rm_range[ts_rm_range!=0].count()
        #numpeaks = np.sum(ts_rm_range!=0)/len(ts_rm_range)
        #numpospeaks = ts_rm_range[ts_rm_range>0].count()
        #numpospeaks = np.sum(ts_rm_range>0)/len(ts_rm_range)
        #numnegpeaks = ts_rm_range[ts_rm_range<0].count()
        #numnegpeaks = np.sum(ts_rm_range<0)/len(ts_rm_range)

        #meanamp = np.mean(ts_rm_range)
        #meanamppos = np.mean(ts_rm_range[ts_rm_range>0])
        #meanampneg = np.mean(ts_rm_range[ts_rm_range<0])

        #maxamp = np.max(ts_rm_range)
        #minamp = np.min(ts_rm_range)
        
        #peaks, _ = find_peaks(ts_rm_range)
        #results_full = peak_widths(ts_rm_range, peaks, rel_height=1)
        
        #if len(results_full[0])==0:
         #   maxwidth = 0
         #   minwidth = 0
        #else:
         #   maxwidth = np.max(results_full[0])/len(ts_rm_range)
         #   minwidth = np.min(results_full[0])/len(ts_rm_range)
        
        
        
        feat_array = np.asarray([mean, mean_wave, std, std_top, std_bot, max_range])
        #feat_array_2 = np.asarray([numpeaks, numpospeaks, numnegpeaks
        #                           , meanamp, meanamppos, meanampneg,
        #                         maxamp, minamp, maxwidth, minwidth
        #                          ])
        
        new_ts.append(np.concatenate([feat_array
                                      , percentil_calc, relative_percentile]))
        
    #scaler = MinMaxScaler(feature_range=(-1, 1))
    #scaler = StandardScaler()
    #new_ts = np.asarray(new_ts)
    #new_ts[np.isnan(new_ts)] = 0
    
    #new_ts = scaler.fit_transform(new_ts)
        
    return new_ts

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts_sum(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    #ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    #ts_wave = denoise_signal(ts_std, wavelet='haar', level=1)
    #ts_rm, corona_idx = remove_corona(ts_wave)
    
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, 400000, 2500):
        # cut each bucket to ts_range
        ts_range = ts[i:i + 2500]
        #ts_rm_range = ts_rm[int(i/2):int(i/2) + int(bucket_size/2)]
        #ts_rm_range = pd.Series(ts_rm_range)
        
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        
        #numpeaks = ts_rm_range[ts_rm_range!=0].count()
        
        numpeaks = np.sum(ts_range!=0)/len(ts_range)
        #numpospeaks = ts_rm_range[ts_rm_range>0].count()
        numpospeaks = np.sum(ts_range>0)/len(ts_range)
        #numnegpeaks = ts_rm_range[ts_rm_range<0].count()
        numnegpeaks = np.sum(ts_range<0)/len(ts_range)

        #meanamp = np.mean(ts_rm_range)
        meanamppos = np.mean(ts_range[ts_range>0])
        meanampneg = np.mean(ts_range[ts_range<0])

        #maxamp = np.max(ts_rm_range)
        #minamp = np.min(ts_rm_range)
        
        #peaks, _ = find_peaks(ts_range)
        #results_full = peak_widths(ts_range, peaks, rel_height=1)
        
        #if len(results_full[0])==0:
        #    maxwidth = 0
        #    minwidth = 0
        #else:
        #    maxwidth = np.max(results_full[0])/len(ts_range)
        #    minwidth = np.min(results_full[0])/len(ts_range)
        
        
        
        feat_array = np.asarray([mean, std, std_top, std_bot, max_range])
        feat_array_2 = np.asarray([numpeaks, numpospeaks, numnegpeaks
                                   #, meanamppos, meanampneg,
                                 #maxwidth, minwidth
                                  ])
        
        new_ts.append(np.concatenate([feat_array, feat_array_2, percentil_calc, relative_percentile]))
        
    #scaler = MinMaxScaler(feature_range=(-1, 1))
    #scaler = StandardScaler()
    #new_ts = np.asarray(new_ts)
    #new_ts[np.isnan(new_ts)] = 0
    
    #new_ts = scaler.fit_transform(new_ts)
        
    return new_ts

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
                ts_1 = min_max_transf(praq_train[str(signal_id)], min_data=min_num, max_data=max_num)
                ts_2 = min_max_transf(praq_train[str(signal_id+1)], min_data=min_num, max_data=max_num)
                ts_3 = min_max_transf(praq_train[str(signal_id+2)], min_data=min_num, max_data=max_num)
                
                ts_wave_1 = denoise_signal(ts_1, wavelet='haar', level=1)
                ts_wave_2 = denoise_signal(ts_2, wavelet='haar', level=1)
                ts_wave_3 = denoise_signal(ts_3, wavelet='haar', level=1)
                
                ts_rm_1, _ = remove_corona(ts_wave_1)
                ts_rm_2, _ = remove_corona(ts_wave_2)
                ts_rm_3, _ = remove_corona(ts_wave_3)
                
                ts_sum = ts_rm_1 + ts_rm_2 + ts_rm_3
                X_signal.append(transform_ts_sum(ts_sum))
                
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
def process_subtrain(arg_tuple):
    start, end, idx = arg_tuple
    X, y = prep_data(start, end)
    return idx, X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
#X = []
#y = []
all_chunks = []

num_cores = 8 
#def load_all():
total_size = len(df_train)
chunk_size = total_size/num_cores

for i in range(8):
    start_idx = int(i * chunk_size)
    end_idx = int(start_idx + chunk_size)
    chunk = (start_idx, end_idx, i)
    all_chunks.append(chunk)

pool = Pool()
results = pool.map(process_subtrain, all_chunks)    
results = sorted(results, key=lambda tup: tup[0])

X = np.concatenate([item[1] for item in results], axis=0)
y = np.concatenate([item[2] for item in results], axis=0)

#load_all()

#X = np.asarray(X)
#y = np.asarray(y)
# Out:
# 100%|██████████| 363/363 [14:59<00:00,  3.05s/it]
# 100%|██████████| 363/363 [15:40<00:00,  3.05s/it]
# 100%|██████████| 363/363 [16:06<00:00,  1.98s/it]
# 100%|██████████| 363/363 [16:16<00:00,  1.09it/s]
# 100%|██████████| 363/363 [16:17<00:00,  2.18s/it]
# 100%|██████████| 363/363 [16:24<00:00,  1.36s/it]
# 100%|██████████| 363/363 [16:29<00:00,  1.11s/it]
# 100%|██████████| 363/363 [16:42<00:00,  1.15s/it]

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# Out:
# (2904, 160, 82) (2904,)

# %%
#X = X.reshape(2904, 160, 26)

# %%
print(np.max(X), np.min(X))
# Out:
# 2.257195764258234 -2.0020827294772054

# %%
X[np.isnan(X)] = 0

# %%
# save data into file, a numpy specific format
np.save("X_7.npy",X)
np.save("y_7.npy",y)

# %%
X = np.load("./X_6.npy")
y = np.load("./y_6.npy")

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(LSTM(128, return_sequences=True))(inp)
    print(x.shape)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    print(x.shape)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    print(x.shape)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64)(x)
    print(x.shape)
    
    x = LeakyReLU(alpha=0.1)(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2177 samples, validate on 727 samples
# Epoch 1/50
# 2177/2177 [==============================] - 25s 11ms/step - loss: 0.4001 - matthews_correlation: 0.0274 - val_loss: 0.2337 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.2317 - matthews_correlation: 0.0000e+00 - val_loss: 0.2297 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.2135 - matthews_correlation: 0.0000e+00 - val_loss: 0.2031 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1775 - matthews_correlation: 0.3024 - val_loss: 0.1214 - val_matthews_correlation: 0.4422
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.44221, saving model to weights_0.h5
# Epoch 5/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1587 - matthews_correlation: 0.4372 - val_loss: 0.1433 - val_matthews_correlation: 0.4143
#
# Epoch 00005: val_matthews_correlation did not improve from 0.44221
# Epoch 6/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1306 - matthews_correlation: 0.3935 - val_loss: 0.1022 - val_matthews_correlation: 0.5171
#
# Epoch 00006: val_matthews_correlation improved from 0.44221 to 0.51710, saving model to weights_0.h5
# Epoch 7/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1230 - matthews_correlation: 0.5675 - val_loss: 0.1030 - val_matthews_correlation: 0.5277
#
# Epoch 00007: val_matthews_correlation improved from 0.51710 to 0.52766, saving model to weights_0.h5
# Epoch 8/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1182 - matthews_correlation: 0.5197 - val_loss: 0.0948 - val_matthews_correlation: 0.6772
#
# Epoch 00008: val_matthews_correlation improved from 0.52766 to 0.67717, saving model to weights_0.h5
# Epoch 9/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1235 - matthews_correlation: 0.5348 - val_loss: 0.0922 - val_matthews_correlation: 0.5951
#
# Epoch 00009: val_matthews_correlation did not improve from 0.67717
# Epoch 10/50
# 2177/2177 [==============================] - 20s 9ms/step - loss: 0.1137 - matthews_correlation: 0.5634 - val_loss: 0.0757 - val_matthews_correlation: 0.7749
#
# Epoch 00010: val_matthews_correlation improved from 0.67717 to 0.77486, saving model to weights_0.h5
# Epoch 11/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1126 - matthews_correlation: 0.6205 - val_loss: 0.1262 - val_matthews_correlation: 0.7052
#
# Epoch 00011: val_matthews_correlation did not improve from 0.77486
# Epoch 12/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.2620 - matthews_correlation: 0.1863 - val_loss: 0.1403 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00012: val_matthews_correlation did not improve from 0.77486
# Epoch 13/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1421 - matthews_correlation: 0.0000e+00 - val_loss: 0.1152 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00013: val_matthews_correlation did not improve from 0.77486
# Epoch 14/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1256 - matthews_correlation: 0.2759 - val_loss: 0.0981 - val_matthews_correlation: 0.4832
#
# Epoch 00014: val_matthews_correlation did not improve from 0.77486
# Epoch 15/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1271 - matthews_correlation: 0.4457 - val_loss: 0.1011 - val_matthews_correlation: 0.4739
#
# Epoch 00015: val_matthews_correlation did not improve from 0.77486
# Epoch 16/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1144 - matthews_correlation: 0.4611 - val_loss: 0.0943 - val_matthews_correlation: 0.6362
#
# Epoch 00016: val_matthews_correlation did not improve from 0.77486
# Epoch 17/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1108 - matthews_correlation: 0.5103 - val_loss: 0.0866 - val_matthews_correlation: 0.6482
#
# Epoch 00017: val_matthews_correlation did not improve from 0.77486
# Epoch 18/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1073 - matthews_correlation: 0.5893 - val_loss: 0.0856 - val_matthews_correlation: 0.7422
#
# Epoch 00018: val_matthews_correlation did not improve from 0.77486
# Epoch 19/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1048 - matthews_correlation: 0.6085 - val_loss: 0.0821 - val_matthews_correlation: 0.7569
#
# Epoch 00019: val_matthews_correlation did not improve from 0.77486
# Epoch 20/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1059 - matthews_correlation: 0.6403 - val_loss: 0.0809 - val_matthews_correlation: 0.7422
#
# Epoch 00020: val_matthews_correlation did not improve from 0.77486
# Epoch 21/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1038 - matthews_correlation: 0.6262 - val_loss: 0.0820 - val_matthews_correlation: 0.7764
#
# Epoch 00021: val_matthews_correlation improved from 0.77486 to 0.77636, saving model to weights_0.h5
# Epoch 22/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1065 - matthews_correlation: 0.6377 - val_loss: 0.0821 - val_matthews_correlation: 0.7494
#
# Epoch 00022: val_matthews_correlation did not improve from 0.77636
# Epoch 23/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1108 - matthews_correlation: 0.5874 - val_loss: 0.0825 - val_matthews_correlation: 0.6804
#
# Epoch 00023: val_matthews_correlation did not improve from 0.77636
# Epoch 24/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1042 - matthews_correlation: 0.5603 - val_loss: 0.0852 - val_matthews_correlation: 0.7761
#
# Epoch 00024: val_matthews_correlation did not improve from 0.77636
# Epoch 25/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1050 - matthews_correlation: 0.6645 - val_loss: 0.0835 - val_matthews_correlation: 0.7990
#
# Epoch 00025: val_matthews_correlation improved from 0.77636 to 0.79904, saving model to weights_0.h5
# Epoch 26/50
# 2177/2177 [==============================] - 20s 9ms/step - loss: 0.1001 - matthews_correlation: 0.6417 - val_loss: 0.1544 - val_matthews_correlation: 0.6195
#
# Epoch 00026: val_matthews_correlation did not improve from 0.79904
# Epoch 27/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.2869 - matthews_correlation: 0.2006 - val_loss: 0.1127 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00027: val_matthews_correlation did not improve from 0.79904
# Epoch 28/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1338 - matthews_correlation: 0.0000e+00 - val_loss: 0.1061 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00028: val_matthews_correlation did not improve from 0.79904
# Epoch 29/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1171 - matthews_correlation: 0.0000e+00 - val_loss: 0.0895 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00029: val_matthews_correlation did not improve from 0.79904
# Epoch 30/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1096 - matthews_correlation: 0.3715 - val_loss: 0.0826 - val_matthews_correlation: 0.7376
#
# Epoch 00030: val_matthews_correlation did not improve from 0.79904
# Epoch 31/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1067 - matthews_correlation: 0.5733 - val_loss: 0.0814 - val_matthews_correlation: 0.7553
#
# Epoch 00031: val_matthews_correlation did not improve from 0.79904
# Epoch 32/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1055 - matthews_correlation: 0.6246 - val_loss: 0.0828 - val_matthews_correlation: 0.7545
#
# Epoch 00032: val_matthews_correlation did not improve from 0.79904
# Epoch 33/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1028 - matthews_correlation: 0.6238 - val_loss: 0.0796 - val_matthews_correlation: 0.7932
# Epoch 00033: val_matthews_correlation did not improve from 0.79904
# Epoch 34/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1017 - matthews_correlation: 0.6246 - val_loss: 0.0796 - val_matthews_correlation: 0.7730
#
# Epoch 00034: val_matthews_correlation did not improve from 0.79904
# Epoch 35/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1036 - matthews_correlation: 0.6259 - val_loss: 0.0794 - val_matthews_correlation: 0.7673
#
# Epoch 00035: val_matthews_correlation did not improve from 0.79904
# Epoch 36/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1001 - matthews_correlation: 0.6080 - val_loss: 0.0821 - val_matthews_correlation: 0.7866
#
# Epoch 00036: val_matthews_correlation did not improve from 0.79904
# Epoch 37/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1002 - matthews_correlation: 0.6590 - val_loss: 0.0792 - val_matthews_correlation: 0.7771
#
# Epoch 00037: val_matthews_correlation did not improve from 0.79904
# Epoch 38/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0983 - matthews_correlation: 0.6572 - val_loss: 0.0773 - val_matthews_correlation: 0.7850
#
# Epoch 00038: val_matthews_correlation did not improve from 0.79904
# Epoch 39/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0978 - matthews_correlation: 0.6633 - val_loss: 0.0762 - val_matthews_correlation: 0.8120
#
# Epoch 00039: val_matthews_correlation improved from 0.79904 to 0.81197, saving model to weights_0.h5
# Epoch 40/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0972 - matthews_correlation: 0.6479 - val_loss: 0.0763 - val_matthews_correlation: 0.7850
#
# Epoch 00040: val_matthews_correlation did not improve from 0.81197
# Epoch 41/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0973 - matthews_correlation: 0.6634 - val_loss: 0.0751 - val_matthews_correlation: 0.8038
#
# Epoch 00041: val_matthews_correlation did not improve from 0.81197
# Epoch 42/50
# 2177/2177 [==============================] - 20s 9ms/step - loss: 0.0967 - matthews_correlation: 0.6618 - val_loss: 0.0743 - val_matthews_correlation: 0.7850
#
# Epoch 00042: val_matthews_correlation did not improve from 0.81197
# Epoch 43/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1075 - matthews_correlation: 0.6322 - val_loss: 0.0717 - val_matthews_correlation: 0.7939
#
# Epoch 00043: val_matthews_correlation did not improve from 0.81197
# Epoch 44/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0979 - matthews_correlation: 0.6844 - val_loss: 0.0764 - val_matthews_correlation: 0.8186
#
# Epoch 00044: val_matthews_correlation improved from 0.81197 to 0.81865, saving model to weights_0.h5
# Epoch 45/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0963 - matthews_correlation: 0.6552 - val_loss: 0.0719 - val_matthews_correlation: 0.8290
#
# Epoch 00045: val_matthews_correlation improved from 0.81865 to 0.82902, saving model to weights_0.h5
# Epoch 46/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0983 - matthews_correlation: 0.6593 - val_loss: 0.0774 - val_matthews_correlation: 0.8080
#
# Epoch 00046: val_matthews_correlation did not improve from 0.82902
# Epoch 47/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1000 - matthews_correlation: 0.6592 - val_loss: 0.0758 - val_matthews_correlation: 0.7631
#
# Epoch 00047: val_matthews_correlation did not improve from 0.82902
# Epoch 48/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0995 - matthews_correlation: 0.6041 - val_loss: 0.0764 - val_matthews_correlation: 0.8036
#
# Epoch 00048: val_matthews_correlation did not improve from 0.82902
# Epoch 49/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0981 - matthews_correlation: 0.6313 - val_loss: 0.0726 - val_matthews_correlation: 0.7851
#
# Epoch 00049: val_matthews_correlation did not improve from 0.82902
# Epoch 50/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0978 - matthews_correlation: 0.6766 - val_loss: 0.0692 - val_matthews_correlation: 0.8009
#
# Epoch 00050: val_matthews_correlation did not improve from 0.82902
# Beginning fold 2
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2177 samples, validate on 727 samples
# Epoch 1/50
# 2177/2177 [==============================] - 23s 10ms/step - loss: 0.4016 - matthews_correlation: 0.0000e+00 - val_loss: 0.2366 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.2307 - matthews_correlation: 0.0000e+00 - val_loss: 0.2228 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.2186 - matthews_correlation: 0.0000e+00 - val_loss: 0.2098 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1903 - matthews_correlation: 0.1957 - val_loss: 0.1821 - val_matthews_correlation: 0.2092
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.20924, saving model to weights_1.h5
# Epoch 5/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1365 - matthews_correlation: 0.4346 - val_loss: 0.1311 - val_matthews_correlation: 0.4983
#
# Epoch 00005: val_matthews_correlation improved from 0.20924 to 0.49825, saving model to weights_1.h5
# Epoch 6/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1172 - matthews_correlation: 0.5888 - val_loss: 0.1112 - val_matthews_correlation: 0.5726
#
# Epoch 00006: val_matthews_correlation improved from 0.49825 to 0.57257, saving model to weights_1.h5
# Epoch 7/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0972 - matthews_correlation: 0.6591 - val_loss: 0.1109 - val_matthews_correlation: 0.6520
#
# Epoch 00007: val_matthews_correlation improved from 0.57257 to 0.65195, saving model to weights_1.h5
# Epoch 8/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0940 - matthews_correlation: 0.6753 - val_loss: 0.1246 - val_matthews_correlation: 0.5953
#
# Epoch 00008: val_matthews_correlation did not improve from 0.65195
# Epoch 9/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0976 - matthews_correlation: 0.6708 - val_loss: 0.1102 - val_matthews_correlation: 0.6307
#
# Epoch 00009: val_matthews_correlation did not improve from 0.65195
# Epoch 10/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0953 - matthews_correlation: 0.6616 - val_loss: 0.1063 - val_matthews_correlation: 0.6203
#
# Epoch 00010: val_matthews_correlation did not improve from 0.65195
# Epoch 11/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0920 - matthews_correlation: 0.6438 - val_loss: 0.1172 - val_matthews_correlation: 0.6208
#
# Epoch 00011: val_matthews_correlation did not improve from 0.65195
# Epoch 12/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0946 - matthews_correlation: 0.6725 - val_loss: 0.1322 - val_matthews_correlation: 0.4410
#
# Epoch 00012: val_matthews_correlation did not improve from 0.65195
# Epoch 13/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0992 - matthews_correlation: 0.5903 - val_loss: 0.1140 - val_matthews_correlation: 0.5528
#
# Epoch 00013: val_matthews_correlation did not improve from 0.65195
# Epoch 14/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0878 - matthews_correlation: 0.7001 - val_loss: 0.1162 - val_matthews_correlation: 0.6307
#
# Epoch 00014: val_matthews_correlation did not improve from 0.65195
# Epoch 15/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1019 - matthews_correlation: 0.2042 - val_loss: 0.1226 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00015: val_matthews_correlation did not improve from 0.65195
# Epoch 16/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0964 - matthews_correlation: 0.2475 - val_loss: 0.1235 - val_matthews_correlation: 0.6203
#
# Epoch 00016: val_matthews_correlation did not improve from 0.65195
# Epoch 17/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1022 - matthews_correlation: 0.6626 - val_loss: 0.1117 - val_matthews_correlation: 0.6245
#
# Epoch 00017: val_matthews_correlation did not improve from 0.65195
# Epoch 18/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0953 - matthews_correlation: 0.6742 - val_loss: 0.1110 - val_matthews_correlation: 0.6035
#
# Epoch 00018: val_matthews_correlation did not improve from 0.65195
# Epoch 19/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0904 - matthews_correlation: 0.7032 - val_loss: 0.1087 - val_matthews_correlation: 0.6450
#
# Epoch 00019: val_matthews_correlation did not improve from 0.65195
# Epoch 20/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0859 - matthews_correlation: 0.6875 - val_loss: 0.1193 - val_matthews_correlation: 0.6171
#
# Epoch 00020: val_matthews_correlation did not improve from 0.65195
# Epoch 21/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0929 - matthews_correlation: 0.7160 - val_loss: 0.1091 - val_matthews_correlation: 0.5809
#
# Epoch 00021: val_matthews_correlation did not improve from 0.65195
# Epoch 22/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0913 - matthews_correlation: 0.6823 - val_loss: 0.1448 - val_matthews_correlation: 0.6071
#
# Epoch 00022: val_matthews_correlation did not improve from 0.65195
# Epoch 23/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.2818 - matthews_correlation: 0.2785 - val_loss: 0.1661 - val_matthews_correlation: 0.0937
#
# Epoch 00023: val_matthews_correlation did not improve from 0.65195
# Epoch 24/50
# 2177/2177 [==============================] - 20s 9ms/step - loss: 0.1309 - matthews_correlation: 0.5101 - val_loss: 0.1216 - val_matthews_correlation: 0.5412
#
# Epoch 00024: val_matthews_correlation did not improve from 0.65195
# Epoch 25/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0993 - matthews_correlation: 0.6443 - val_loss: 0.1203 - val_matthews_correlation: 0.5479
#
# Epoch 00025: val_matthews_correlation did not improve from 0.65195
# Epoch 26/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0965 - matthews_correlation: 0.6559 - val_loss: 0.1193 - val_matthews_correlation: 0.6121
#
# Epoch 00026: val_matthews_correlation did not improve from 0.65195
# Epoch 27/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0925 - matthews_correlation: 0.6546 - val_loss: 0.1112 - val_matthews_correlation: 0.6251
#
# Epoch 00027: val_matthews_correlation did not improve from 0.65195
# Epoch 28/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0884 - matthews_correlation: 0.7050 - val_loss: 0.1131 - val_matthews_correlation: 0.6174
#
# Epoch 00028: val_matthews_correlation did not improve from 0.65195
# Epoch 29/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0877 - matthews_correlation: 0.6858 - val_loss: 0.1265 - val_matthews_correlation: 0.6423
#
# Epoch 00029: val_matthews_correlation did not improve from 0.65195
# Epoch 30/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1034 - matthews_correlation: 0.6735 - val_loss: 0.1238 - val_matthews_correlation: 0.6116
#
# Epoch 00030: val_matthews_correlation did not improve from 0.65195
# Epoch 31/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0914 - matthews_correlation: 0.6753 - val_loss: 0.1119 - val_matthews_correlation: 0.6105
#
# Epoch 00031: val_matthews_correlation did not improve from 0.65195
# Epoch 32/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0848 - matthews_correlation: 0.6865 - val_loss: 0.1126 - val_matthews_correlation: 0.6112
#
# Epoch 00032: val_matthews_correlation did not improve from 0.65195
# Epoch 33/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0832 - matthews_correlation: 0.7128 - val_loss: 0.1129 - val_matthews_correlation: 0.5707
#
# Epoch 00033: val_matthews_correlation did not improve from 0.65195
# Epoch 34/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0856 - matthews_correlation: 0.6910 - val_loss: 0.1214 - val_matthews_correlation: 0.6360
#
# Epoch 00034: val_matthews_correlation did not improve from 0.65195
# Epoch 35/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1099 - matthews_correlation: 0.6652 - val_loss: 0.1148 - val_matthews_correlation: 0.5760
#
# Epoch 00035: val_matthews_correlation did not improve from 0.65195
# Epoch 36/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0879 - matthews_correlation: 0.6604 - val_loss: 0.1126 - val_matthews_correlation: 0.5636
#
# Epoch 00036: val_matthews_correlation did not improve from 0.65195
# Epoch 37/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0864 - matthews_correlation: 0.6691 - val_loss: 0.1094 - val_matthews_correlation: 0.5574
#
# Epoch 00037: val_matthews_correlation did not improve from 0.65195
# Epoch 38/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0830 - matthews_correlation: 0.6778 - val_loss: 0.1146 - val_matthews_correlation: 0.6343
#
# Epoch 00038: val_matthews_correlation did not improve from 0.65195
# Epoch 39/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0846 - matthews_correlation: 0.7183 - val_loss: 0.1127 - val_matthews_correlation: 0.6007
#
# Epoch 00039: val_matthews_correlation did not improve from 0.65195
# Epoch 40/50
# 2177/2177 [==============================] - 20s 9ms/step - loss: 0.0808 - matthews_correlation: 0.7025 - val_loss: 0.1157 - val_matthews_correlation: 0.5317
#
# Epoch 00040: val_matthews_correlation did not improve from 0.65195
# Epoch 41/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0812 - matthews_correlation: 0.7323 - val_loss: 0.1206 - val_matthews_correlation: 0.5507
#
# Epoch 00041: val_matthews_correlation did not improve from 0.65195
# Epoch 42/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0831 - matthews_correlation: 0.6485 - val_loss: 0.1182 - val_matthews_correlation: 0.5685
#
# Epoch 00042: val_matthews_correlation did not improve from 0.65195
# Epoch 43/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0920 - matthews_correlation: 0.6712 - val_loss: 0.1270 - val_matthews_correlation: 0.5602
#
# Epoch 00043: val_matthews_correlation did not improve from 0.65195
# Epoch 44/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.1525 - matthews_correlation: 0.4813 - val_loss: 0.1194 - val_matthews_correlation: 0.5226
#
# Epoch 00044: val_matthews_correlation did not improve from 0.65195
# Epoch 45/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0999 - matthews_correlation: 0.6138 - val_loss: 0.1056 - val_matthews_correlation: 0.5842
#
# Epoch 00045: val_matthews_correlation did not improve from 0.65195
# Epoch 46/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0914 - matthews_correlation: 0.6600 - val_loss: 0.1085 - val_matthews_correlation: 0.6244
#
# Epoch 00046: val_matthews_correlation did not improve from 0.65195
# Epoch 47/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0939 - matthews_correlation: 0.6269 - val_loss: 0.1103 - val_matthews_correlation: 0.5866
#
# Epoch 00047: val_matthews_correlation did not improve from 0.65195
# Epoch 48/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0874 - matthews_correlation: 0.6738 - val_loss: 0.1055 - val_matthews_correlation: 0.6213
#
# Epoch 00048: val_matthews_correlation did not improve from 0.65195
# Epoch 49/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0841 - matthews_correlation: 0.6849 - val_loss: 0.1058 - val_matthews_correlation: 0.6318
#
# Epoch 00049: val_matthews_correlation did not improve from 0.65195
# Epoch 50/50
# 2177/2177 [==============================] - 19s 9ms/step - loss: 0.0839 - matthews_correlation: 0.6706 - val_loss: 0.1079 - val_matthews_correlation: 0.6235
# Epoch 00050: val_matthews_correlation did not improve from 0.65195
# Beginning fold 3
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2179 samples, validate on 725 samples
# Epoch 1/50
# 2179/2179 [==============================] - 23s 10ms/step - loss: 0.3829 - matthews_correlation: 0.0212 - val_loss: 0.2345 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.2285 - matthews_correlation: 0.0000e+00 - val_loss: 0.2091 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.2097 - matthews_correlation: 0.0000e+00 - val_loss: 0.1785 - val_matthews_correlation: 0.1218
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.12176, saving model to weights_2.h5
# Epoch 4/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1688 - matthews_correlation: 0.3278 - val_loss: 0.1176 - val_matthews_correlation: 0.4516
#
# Epoch 00004: val_matthews_correlation improved from 0.12176 to 0.45157, saving model to weights_2.h5
# Epoch 5/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1335 - matthews_correlation: 0.4432 - val_loss: 0.1175 - val_matthews_correlation: 0.5096
#
# Epoch 00005: val_matthews_correlation improved from 0.45157 to 0.50962, saving model to weights_2.h5
# Epoch 6/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1095 - matthews_correlation: 0.5962 - val_loss: 0.1447 - val_matthews_correlation: 0.5936
#
# Epoch 00006: val_matthews_correlation improved from 0.50962 to 0.59361, saving model to weights_2.h5
# Epoch 7/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1164 - matthews_correlation: 0.5945 - val_loss: 0.1123 - val_matthews_correlation: 0.5332
#
# Epoch 00007: val_matthews_correlation did not improve from 0.59361
# Epoch 8/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1166 - matthews_correlation: 0.5922 - val_loss: 0.1237 - val_matthews_correlation: 0.5253
#
# Epoch 00008: val_matthews_correlation did not improve from 0.59361
# Epoch 9/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1124 - matthews_correlation: 0.5936 - val_loss: 0.1241 - val_matthews_correlation: 0.5781
#
# Epoch 00009: val_matthews_correlation did not improve from 0.59361
# Epoch 10/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1074 - matthews_correlation: 0.6293 - val_loss: 0.1166 - val_matthews_correlation: 0.5990
#
# Epoch 00010: val_matthews_correlation improved from 0.59361 to 0.59901, saving model to weights_2.h5
# Epoch 11/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0970 - matthews_correlation: 0.7044 - val_loss: 0.1109 - val_matthews_correlation: 0.5846
#
# Epoch 00011: val_matthews_correlation did not improve from 0.59901
# Epoch 12/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0989 - matthews_correlation: 0.6712 - val_loss: 0.1126 - val_matthews_correlation: 0.5752
#
# Epoch 00012: val_matthews_correlation did not improve from 0.59901
# Epoch 13/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0959 - matthews_correlation: 0.6716 - val_loss: 0.1119 - val_matthews_correlation: 0.5683
#
# Epoch 00013: val_matthews_correlation did not improve from 0.59901
# Epoch 14/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0981 - matthews_correlation: 0.6108 - val_loss: 0.1089 - val_matthews_correlation: 0.5765
#
# Epoch 00014: val_matthews_correlation did not improve from 0.59901
# Epoch 15/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0977 - matthews_correlation: 0.6881 - val_loss: 0.1091 - val_matthews_correlation: 0.5668
#
# Epoch 00015: val_matthews_correlation did not improve from 0.59901
# Epoch 16/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0970 - matthews_correlation: 0.7085 - val_loss: 0.1121 - val_matthews_correlation: 0.6294
#
# Epoch 00016: val_matthews_correlation improved from 0.59901 to 0.62943, saving model to weights_2.h5
# Epoch 17/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0953 - matthews_correlation: 0.6939 - val_loss: 0.1110 - val_matthews_correlation: 0.5746
#
# Epoch 00017: val_matthews_correlation did not improve from 0.62943
# Epoch 18/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0955 - matthews_correlation: 0.6979 - val_loss: 0.1119 - val_matthews_correlation: 0.5806
#
# Epoch 00018: val_matthews_correlation did not improve from 0.62943
# Epoch 19/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0880 - matthews_correlation: 0.7069 - val_loss: 0.1075 - val_matthews_correlation: 0.6246
#
# Epoch 00019: val_matthews_correlation did not improve from 0.62943
# Epoch 20/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0931 - matthews_correlation: 0.6961 - val_loss: 0.1166 - val_matthews_correlation: 0.5799
#
# Epoch 00020: val_matthews_correlation did not improve from 0.62943
# Epoch 21/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0958 - matthews_correlation: 0.6756 - val_loss: 0.1242 - val_matthews_correlation: 0.4474
#
# Epoch 00021: val_matthews_correlation did not improve from 0.62943
# Epoch 22/50
# 2179/2179 [==============================] - 20s 9ms/step - loss: 0.1463 - matthews_correlation: 0.0972 - val_loss: 0.1156 - val_matthews_correlation: 0.2083
#
# Epoch 00022: val_matthews_correlation did not improve from 0.62943
# Epoch 23/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1068 - matthews_correlation: 0.4652 - val_loss: 0.1025 - val_matthews_correlation: 0.5727
#
# Epoch 00023: val_matthews_correlation did not improve from 0.62943
# Epoch 24/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0982 - matthews_correlation: 0.6825 - val_loss: 0.1093 - val_matthews_correlation: 0.5972
#
# Epoch 00024: val_matthews_correlation did not improve from 0.62943
# Epoch 25/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0913 - matthews_correlation: 0.6702 - val_loss: 0.1039 - val_matthews_correlation: 0.6436
#
# Epoch 00025: val_matthews_correlation improved from 0.62943 to 0.64356, saving model to weights_2.h5
# Epoch 26/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0929 - matthews_correlation: 0.6919 - val_loss: 0.1118 - val_matthews_correlation: 0.6106
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64356
# Epoch 27/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0900 - matthews_correlation: 0.6876 - val_loss: 0.1168 - val_matthews_correlation: 0.5806
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64356
# Epoch 28/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0896 - matthews_correlation: 0.7074 - val_loss: 0.1099 - val_matthews_correlation: 0.5768
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64356
# Epoch 29/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0920 - matthews_correlation: 0.6855 - val_loss: 0.1206 - val_matthews_correlation: 0.5473
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64356
# Epoch 30/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1238 - matthews_correlation: 0.4894 - val_loss: 0.1102 - val_matthews_correlation: 0.5253
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64356
# Epoch 31/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0931 - matthews_correlation: 0.6530 - val_loss: 0.1067 - val_matthews_correlation: 0.6301
#
# Epoch 00031: val_matthews_correlation did not improve from 0.64356
# Epoch 32/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0873 - matthews_correlation: 0.7279 - val_loss: 0.1112 - val_matthews_correlation: 0.5629
#
# Epoch 00032: val_matthews_correlation did not improve from 0.64356
# Epoch 33/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0922 - matthews_correlation: 0.6769 - val_loss: 0.1050 - val_matthews_correlation: 0.6012
# Epoch 00033: val_matthews_correlation did not improve from 0.64356
# Epoch 34/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0829 - matthews_correlation: 0.7216 - val_loss: 0.1105 - val_matthews_correlation: 0.5847
#
# Epoch 00034: val_matthews_correlation did not improve from 0.64356
# Epoch 35/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0843 - matthews_correlation: 0.7176 - val_loss: 0.1128 - val_matthews_correlation: 0.6051
#
# Epoch 00035: val_matthews_correlation did not improve from 0.64356
# Epoch 36/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0845 - matthews_correlation: 0.7175 - val_loss: 0.1102 - val_matthews_correlation: 0.5757
#
# Epoch 00036: val_matthews_correlation did not improve from 0.64356
# Epoch 37/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0852 - matthews_correlation: 0.6728 - val_loss: 0.1100 - val_matthews_correlation: 0.5875
#
# Epoch 00037: val_matthews_correlation did not improve from 0.64356
# Epoch 38/50
# 2179/2179 [==============================] - 20s 9ms/step - loss: 0.0829 - matthews_correlation: 0.6933 - val_loss: 0.1075 - val_matthews_correlation: 0.6347
#
# Epoch 00038: val_matthews_correlation did not improve from 0.64356
# Epoch 39/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0861 - matthews_correlation: 0.6806 - val_loss: 0.1171 - val_matthews_correlation: 0.4483
#
# Epoch 00039: val_matthews_correlation did not improve from 0.64356
# Epoch 40/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0865 - matthews_correlation: 0.6874 - val_loss: 0.1196 - val_matthews_correlation: 0.5783
#
# Epoch 00040: val_matthews_correlation did not improve from 0.64356
# Epoch 41/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0826 - matthews_correlation: 0.7003 - val_loss: 0.1150 - val_matthews_correlation: 0.6473
#
# Epoch 00041: val_matthews_correlation improved from 0.64356 to 0.64733, saving model to weights_2.h5
# Epoch 42/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0862 - matthews_correlation: 0.7354 - val_loss: 0.1094 - val_matthews_correlation: 0.5531
#
# Epoch 00042: val_matthews_correlation did not improve from 0.64733
# Epoch 43/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1069 - matthews_correlation: 0.6846 - val_loss: 0.1120 - val_matthews_correlation: 0.5708
#
# Epoch 00043: val_matthews_correlation did not improve from 0.64733
# Epoch 44/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0880 - matthews_correlation: 0.7034 - val_loss: 0.1171 - val_matthews_correlation: 0.5351
#
# Epoch 00044: val_matthews_correlation did not improve from 0.64733
# Epoch 45/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0859 - matthews_correlation: 0.6908 - val_loss: 0.1018 - val_matthews_correlation: 0.6220
#
# Epoch 00045: val_matthews_correlation did not improve from 0.64733
# Epoch 46/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0792 - matthews_correlation: 0.7364 - val_loss: 0.1070 - val_matthews_correlation: 0.5841
#
# Epoch 00046: val_matthews_correlation did not improve from 0.64733
# Epoch 47/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0773 - matthews_correlation: 0.7198 - val_loss: 0.1091 - val_matthews_correlation: 0.5450
#
# Epoch 00047: val_matthews_correlation did not improve from 0.64733
# Epoch 48/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0742 - matthews_correlation: 0.7475 - val_loss: 0.1106 - val_matthews_correlation: 0.5904
#
# Epoch 00048: val_matthews_correlation did not improve from 0.64733
# Epoch 49/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0765 - matthews_correlation: 0.7021 - val_loss: 0.1062 - val_matthews_correlation: 0.6092
#
# Epoch 00049: val_matthews_correlation did not improve from 0.64733
# Epoch 50/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0744 - matthews_correlation: 0.7436 - val_loss: 0.1142 - val_matthews_correlation: 0.6084
#
# Epoch 00050: val_matthews_correlation did not improve from 0.64733
# Beginning fold 4
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2179 samples, validate on 725 samples
# Epoch 1/50
# 2179/2179 [==============================] - 23s 10ms/step - loss: 0.3867 - matthews_correlation: 0.0000e+00 - val_loss: 0.2378 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.2433 - matthews_correlation: 0.0000e+00 - val_loss: 0.2270 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.2190 - matthews_correlation: 0.0000e+00 - val_loss: 0.1979 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1845 - matthews_correlation: 0.1876 - val_loss: 0.1442 - val_matthews_correlation: 0.3502
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.35016, saving model to weights_3.h5
# Epoch 5/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1895 - matthews_correlation: 0.0579 - val_loss: 0.1853 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.35016
# Epoch 6/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1597 - matthews_correlation: 0.2203 - val_loss: 0.2569 - val_matthews_correlation: 0.4630
#
# Epoch 00006: val_matthews_correlation improved from 0.35016 to 0.46298, saving model to weights_3.h5
# Epoch 7/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1831 - matthews_correlation: 0.3512 - val_loss: 0.1496 - val_matthews_correlation: 0.3579
#
# Epoch 00007: val_matthews_correlation did not improve from 0.46298
# Epoch 8/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1375 - matthews_correlation: 0.3282 - val_loss: 0.1278 - val_matthews_correlation: 0.4116
#
# Epoch 00008: val_matthews_correlation did not improve from 0.46298
# Epoch 9/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1176 - matthews_correlation: 0.5020 - val_loss: 0.1222 - val_matthews_correlation: 0.4953
#
# Epoch 00009: val_matthews_correlation improved from 0.46298 to 0.49528, saving model to weights_3.h5
# Epoch 10/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1072 - matthews_correlation: 0.6006 - val_loss: 0.1144 - val_matthews_correlation: 0.4631
#
# Epoch 00010: val_matthews_correlation did not improve from 0.49528
# Epoch 11/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1022 - matthews_correlation: 0.5769 - val_loss: 0.1152 - val_matthews_correlation: 0.5230
#
# Epoch 00011: val_matthews_correlation improved from 0.49528 to 0.52296, saving model to weights_3.h5
# Epoch 12/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1177 - matthews_correlation: 0.6040 - val_loss: 0.1458 - val_matthews_correlation: 0.3434
#
# Epoch 00012: val_matthews_correlation did not improve from 0.52296
# Epoch 13/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1165 - matthews_correlation: 0.4675 - val_loss: 0.1196 - val_matthews_correlation: 0.4701
#
# Epoch 00013: val_matthews_correlation did not improve from 0.52296
# Epoch 14/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1047 - matthews_correlation: 0.6433 - val_loss: 0.1122 - val_matthews_correlation: 0.5142
#
# Epoch 00014: val_matthews_correlation did not improve from 0.52296
# Epoch 15/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0999 - matthews_correlation: 0.6565 - val_loss: 0.1108 - val_matthews_correlation: 0.4949
#
# Epoch 00015: val_matthews_correlation did not improve from 0.52296
# Epoch 16/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0952 - matthews_correlation: 0.6374 - val_loss: 0.1115 - val_matthews_correlation: 0.5546
#
# Epoch 00016: val_matthews_correlation improved from 0.52296 to 0.55462, saving model to weights_3.h5
# Epoch 17/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0950 - matthews_correlation: 0.6782 - val_loss: 0.1249 - val_matthews_correlation: 0.4682
#
# Epoch 00017: val_matthews_correlation did not improve from 0.55462
# Epoch 18/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1039 - matthews_correlation: 0.4728 - val_loss: 0.1194 - val_matthews_correlation: 0.4724
#
# Epoch 00018: val_matthews_correlation did not improve from 0.55462
# Epoch 19/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0995 - matthews_correlation: 0.6311 - val_loss: 0.1147 - val_matthews_correlation: 0.5422
#
# Epoch 00019: val_matthews_correlation did not improve from 0.55462
# Epoch 20/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1001 - matthews_correlation: 0.6413 - val_loss: 0.1100 - val_matthews_correlation: 0.5562
#
# Epoch 00020: val_matthews_correlation improved from 0.55462 to 0.55617, saving model to weights_3.h5
# Epoch 21/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0948 - matthews_correlation: 0.6648 - val_loss: 0.1258 - val_matthews_correlation: 0.4667
#
# Epoch 00021: val_matthews_correlation did not improve from 0.55617
# Epoch 22/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0974 - matthews_correlation: 0.6554 - val_loss: 0.1117 - val_matthews_correlation: 0.5140
#
# Epoch 00022: val_matthews_correlation did not improve from 0.55617
# Epoch 23/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0997 - matthews_correlation: 0.5834 - val_loss: 0.1135 - val_matthews_correlation: 0.4779
#
# Epoch 00023: val_matthews_correlation did not improve from 0.55617
# Epoch 24/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0974 - matthews_correlation: 0.5759 - val_loss: 0.1172 - val_matthews_correlation: 0.5283
#
# Epoch 00024: val_matthews_correlation did not improve from 0.55617
# Epoch 25/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1256 - matthews_correlation: 0.6181 - val_loss: 0.1167 - val_matthews_correlation: 0.4975
#
# Epoch 00025: val_matthews_correlation did not improve from 0.55617
# Epoch 26/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0959 - matthews_correlation: 0.6817 - val_loss: 0.1113 - val_matthews_correlation: 0.5305
#
# Epoch 00026: val_matthews_correlation did not improve from 0.55617
# Epoch 27/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0903 - matthews_correlation: 0.6845 - val_loss: 0.1094 - val_matthews_correlation: 0.5526
#
# Epoch 00027: val_matthews_correlation did not improve from 0.55617
# Epoch 28/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0906 - matthews_correlation: 0.6652 - val_loss: 0.1118 - val_matthews_correlation: 0.5491
#
# Epoch 00028: val_matthews_correlation did not improve from 0.55617
# Epoch 29/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0951 - matthews_correlation: 0.6857 - val_loss: 0.1093 - val_matthews_correlation: 0.5735
#
# Epoch 00029: val_matthews_correlation improved from 0.55617 to 0.57354, saving model to weights_3.h5
# Epoch 30/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0910 - matthews_correlation: 0.7174 - val_loss: 0.1148 - val_matthews_correlation: 0.5491
#
# Epoch 00030: val_matthews_correlation did not improve from 0.57354
# Epoch 31/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0905 - matthews_correlation: 0.6935 - val_loss: 0.1118 - val_matthews_correlation: 0.5491
#
# Epoch 00031: val_matthews_correlation did not improve from 0.57354
# Epoch 32/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0883 - matthews_correlation: 0.6850 - val_loss: 0.1098 - val_matthews_correlation: 0.5631
#
# Epoch 00032: val_matthews_correlation did not improve from 0.57354
# Epoch 33/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0883 - matthews_correlation: 0.7059 - val_loss: 0.1155 - val_matthews_correlation: 0.4981
#
# Epoch 00033: val_matthews_correlation did not improve from 0.57354
# Epoch 34/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0857 - matthews_correlation: 0.6806 - val_loss: 0.1097 - val_matthews_correlation: 0.5633
#
# Epoch 00034: val_matthews_correlation did not improve from 0.57354
# Epoch 35/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0885 - matthews_correlation: 0.7131 - val_loss: 0.1143 - val_matthews_correlation: 0.4646
#
# Epoch 00035: val_matthews_correlation did not improve from 0.57354
# Epoch 36/50
# 2179/2179 [==============================] - 20s 9ms/step - loss: 0.1168 - matthews_correlation: 0.3820 - val_loss: 0.1214 - val_matthews_correlation: 0.4289
#
# Epoch 00036: val_matthews_correlation did not improve from 0.57354
# Epoch 37/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1070 - matthews_correlation: 0.6218 - val_loss: 0.1126 - val_matthews_correlation: 0.4906
#
# Epoch 00037: val_matthews_correlation did not improve from 0.57354
# Epoch 38/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0940 - matthews_correlation: 0.6675 - val_loss: 0.1103 - val_matthews_correlation: 0.5876
#
# Epoch 00038: val_matthews_correlation improved from 0.57354 to 0.58756, saving model to weights_3.h5
# Epoch 39/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0906 - matthews_correlation: 0.6914 - val_loss: 0.1132 - val_matthews_correlation: 0.4937
#
# Epoch 00039: val_matthews_correlation did not improve from 0.58756
# Epoch 40/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0905 - matthews_correlation: 0.6804 - val_loss: 0.1109 - val_matthews_correlation: 0.5135
#
# Epoch 00040: val_matthews_correlation did not improve from 0.58756
# Epoch 41/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0893 - matthews_correlation: 0.6925 - val_loss: 0.1150 - val_matthews_correlation: 0.5089
#
# Epoch 00041: val_matthews_correlation did not improve from 0.58756
# Epoch 42/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0939 - matthews_correlation: 0.6456 - val_loss: 0.1133 - val_matthews_correlation: 0.4790
#
# Epoch 00042: val_matthews_correlation did not improve from 0.58756
# Epoch 43/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0852 - matthews_correlation: 0.6950 - val_loss: 0.1307 - val_matthews_correlation: 0.4845
#
# Epoch 00043: val_matthews_correlation did not improve from 0.58756
# Epoch 44/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1178 - matthews_correlation: 0.5652 - val_loss: 0.1158 - val_matthews_correlation: 0.4098
#
# Epoch 00044: val_matthews_correlation did not improve from 0.58756
# Epoch 45/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0977 - matthews_correlation: 0.6793 - val_loss: 0.1122 - val_matthews_correlation: 0.4964
#
# Epoch 00045: val_matthews_correlation did not improve from 0.58756
# Epoch 46/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0890 - matthews_correlation: 0.6431 - val_loss: 0.1148 - val_matthews_correlation: 0.4905
#
# Epoch 00046: val_matthews_correlation did not improve from 0.58756
# Epoch 47/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0897 - matthews_correlation: 0.6816 - val_loss: 0.1079 - val_matthews_correlation: 0.5066
#
# Epoch 00047: val_matthews_correlation did not improve from 0.58756
# Epoch 48/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1054 - matthews_correlation: 0.6028 - val_loss: 0.1171 - val_matthews_correlation: 0.4424
#
# Epoch 00048: val_matthews_correlation did not improve from 0.58756
# Epoch 49/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.0922 - matthews_correlation: 0.6895 - val_loss: 0.1250 - val_matthews_correlation: 0.5425
#
# Epoch 00049: val_matthews_correlation did not improve from 0.58756
# Epoch 50/50
# 2179/2179 [==============================] - 19s 9ms/step - loss: 0.1183 - matthews_correlation: 0.5751 - val_loss: 0.1170 - val_matthews_correlation: 0.4657
#
# Epoch 00050: val_matthews_correlation did not improve from 0.58756
# ((2904,), (2904,))

# %%
np.save('./tmp/y_val_tmp_8.npy', y_val)
np.save('./tmp/preds_val_tmp_8.npy', preds_val)

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    
    #y_pred = K.cast(y_pred, np.float)
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = np.round(np.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)

    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        #score = matthews_correlation(y_true, (y_proba > threshold).astype(int))
        #score = K.eval(matthews_correlation(y_true, (y_proba > threshold).astype(int)))
        #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        score = matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 9987.86it/s]

# %%
best_threshold
# Out:
# 0.5

# %%
matthews_correlation(y_val, preds_val)
# Out:
# 0.7057887705890922

# %%
threshold_search(y_val[:582], preds_val[:582])['threshold']
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 15442.95it/s]
# 0.28

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')
df_test = meta_test.set_index(['id_measurement', 'phase'])
# Out:
# CPU times: user 8.76 ms, sys: 8.21 ms, total: 17 ms
# Wall time: 36.9 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data_test(start, end):
    # load a piece of data from file
    praq_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start+8712, end+8712)]).to_pandas()
    X = []

    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_test.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id = df_test.loc[id_measurement].loc[phase][0]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                ts_1 = min_max_transf(praq_test[str(signal_id)], min_data=min_num, max_data=max_num)
                ts_2 = min_max_transf(praq_test[str(signal_id+1)], min_data=min_num, max_data=max_num)
                ts_3 = min_max_transf(praq_test[str(signal_id+2)], min_data=min_num, max_data=max_num)
                
                ts_wave_1 = denoise_signal(ts_1, wavelet='haar', level=1)
                ts_wave_2 = denoise_signal(ts_2, wavelet='haar', level=1)
                ts_wave_3 = denoise_signal(ts_3, wavelet='haar', level=1)
                
                ts_rm_1, _ = remove_corona(ts_wave_1)
                ts_rm_2, _ = remove_corona(ts_wave_2)
                ts_rm_3, _ = remove_corona(ts_wave_3)
                
                ts_sum = ts_rm_1 + ts_rm_2 + ts_rm_3
                X_signal.append(transform_ts_sum(ts_sum))
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_test[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    return X

# %%
def process_subtest(arg_tuple):
    start, end, idx = arg_tuple
    X = prep_data_test(start, end)
    return idx, X

# %%
all_chunks = []

num_cores = 16 
#def load_all():
total_size = len(meta_test)
chunk_size = np.ceil(total_size/num_cores)
#train_size = len(df_train)

for i in range(16):
    if i != 15:
        start_idx = int(i * chunk_size)
        end_idx = int(start_idx + chunk_size)
        #chunk = (start_idx+train_size, end_idx+train_size, i)
        chunk = (start_idx, end_idx, i)
        all_chunks.append(chunk)
    else:
        start_idx = int(i * chunk_size)
        end_idx = int(total_size)
        #chunk = (start_idx+train_size, end_idx+train_size, i)
        chunk = (start_idx, end_idx, i)
        all_chunks.append(chunk)

# %%
pool = Pool()
results_1 = pool.map(process_subtest, all_chunks[0:8])    
results_1 = sorted(results_1, key=lambda tup: tup[0])
# Out:
# 100%|██████████| 424/424 [17:04<00:00,  2.47s/it]
# 100%|██████████| 424/424 [17:07<00:00,  2.17s/it]
# 100%|██████████| 424/424 [18:41<00:00,  1.07it/s]
# 100%|██████████| 424/424 [18:56<00:00,  1.08s/it]
# 100%|██████████| 424/424 [19:10<00:00,  2.86s/it]
# 100%|██████████| 424/424 [19:11<00:00,  1.12it/s]
# 100%|██████████| 424/424 [19:21<00:00,  1.58it/s]
# 100%|██████████| 424/424 [19:43<00:00,  1.14s/it]
# 100%|██████████| 424/424 [16:36<00:00,  3.40s/it]
# 100%|██████████| 424/424 [17:54<00:00,  5.51s/it]
# 100%|██████████| 424/424 [18:00<00:00,  2.82s/it]
# 100%|██████████| 419/419 [17:59<00:00,  2.27s/it]
# 100%|██████████| 424/424 [18:11<00:00,  1.70s/it]
# 100%|██████████| 424/424 [18:51<00:00,  1.00it/s]
# 100%|██████████| 424/424 [18:56<00:00,  1.47it/s]
# 100%|██████████| 424/424 [19:13<00:00,  1.11s/it]

# %%
results_2 = pool.map(process_subtest, all_chunks[8:16])    
results_2 = sorted(results_2, key=lambda tup: tup[0])

# %%
results = results_1 + results_2
X_test = np.concatenate([item[1] for item in results], axis=0)

# %%
np.save("X_test_7.npy",X_test)

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %% [markdown]
# splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
#
# for idx, (train_idx, val_idx) in enumerate(splits):
#     K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
#     print("Beginning fold {}".format(idx+1))
#     # use the indexes to extract the folds in the train and validation data
#     train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
#     # instantiate the model for this fold
#     model = model_lstm(train_X.shape)

# %%
X_test[np.isnan(X_test)] = 0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 16s 2ms/step
# 6779/6779 [==============================] - 16s 2ms/step
# 6779/6779 [==============================] - 16s 2ms/step
# 6779/6779 [==============================] - 16s 2ms/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('../output/submission_26.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
lstm_preds = np.squeeze(np.mean(preds_test, axis=0))
np.save("./lstm_preds.npy", lstm_preds)

# %%
np.sum(preds_test[preds_test==1])
# Out:
# 846

# %%
submission['target'].value_counts()
# Out:
# 0    19404
# 1      933
# Name: target, dtype: int64

# %%
model.load_weights('weights_0.h5')
pred = model.predict(X_test, batch_size=300, verbose=1)
pred_3 = []
for pred_scalar in pred:
    for i in range(3):
        pred_3.append(pred_scalar)
# Out:
# 6779/6779 [==============================] - 17s 2ms/step

# %%
pred_3>0.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-5823f4244eaa> in <module>()
# ----> 1 pred_3>0.5
#
# TypeError: '>' not supported between instances of 'list' and 'float'

# %%
preds_3 = (np.squeeze(pred_3) > 0.5).astype(np.int)

# %%
np.sum(preds_3[preds_3==1])
# Out:
# 1209

# %%
submission['target'] = preds_3
submission.to_csv('../output/submission_22.csv', index=False)

# %%
submission['target'].value_counts()
# Out:
# 0    19128
# 1     1209
# Name: target, dtype: int64
