# %%
import pandas as pd
import numpy as np
import random as rnd
import os
import datetime
import pickle

from scipy import stats
from scipy.special import boxcox1p

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm_notebook

from itertools import product

import gc

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone

import xgboost as xgb
import lightgbm as lgb

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,r2_score

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 200)

import warnings
warnings.filterwarnings('ignore')

# %%
from numba import jit

# %%
@jit
def mcc(tp, tn, fp, fn):
    sup = tp * tn - fp * fn
    inf = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    if inf==0:
        return 0
    else:
        return sup / np.sqrt(inf)

# %%
def eval_mcc(y_true, y_prob, show=False):
    idx = np.argsort(y_prob)
    y_true_sort = y_true[idx]
    n = y_true.shape[0]
    nump = 1.0 * np.sum(y_true) # number of positive
    numn = n - nump # number of negative
    tp = nump
    tn = 0.0
    fp = numn
    fn = 0.0
    best_mcc = 0.0
    best_id = -1
    prev_proba = -1
    best_proba = -1
    mccs = np.zeros(n)
    for i in range(n):
        # all items with idx < i are predicted negative while others are predicted positive
        # only evaluate mcc when probability changes
        proba = y_prob[idx[i]]
        if proba != prev_proba:
            prev_proba = proba
            new_mcc = mcc(tp, tn, fp, fn)
            if new_mcc >= best_mcc:
                best_mcc = new_mcc
                best_id = i
                best_proba = proba
        mccs[i] = new_mcc
        if y_true_sort[i] == 1:
            tp -= 1.0
            fn += 1.0
        else:
            fp -= 1.0
            tn += 1.0
    if show:
        y_pred = (y_prob >= best_proba).astype(int)
        score = matthews_corrcoef(y_true, y_pred)
        print(score, best_mcc)
        plt.plot(mccs)
        return best_proba, best_mcc, y_pred
    else:
        return best_mcc

# %%
def mcc_eval(y_prob, dtrain):
    y_true = dtrain.get_label()
    best_mcc = eval_mcc(y_true, y_prob)
    is_higher_better = True
    return 'MCC', best_mcc, is_higher_better

# %%
meta_train = pd.read_csv('../input/metadata_train.csv')
meta_test = pd.read_csv('../input/metadata_test.csv')

# %%
numpeaks = np.load('../features/numpeaks.npy')
numpospeaks = np.load('../features/numpospeaks.npy')
numnegpeaks = np.load('../features/numnegpeaks.npy')

maxpeakwidth = np.load('../features/maxpeakwidth.npy')
minpeakwidth = np.load('../features/minpeakwidth.npy')
meanpeakwidth = np.load('../features/meanpeakwidth.npy')
maxamp = np.load('../features/maxamp.npy')
minamp = np.load('../features/minamp.npy')
meanamp = np.load('../features/meanamp.npy')

stdampall = np.load('../features/stdampall.npy')
stdposall = np.load('../features/stdposall.npy')
stdwidthall = np.load('../features/stdwidthall.npy')

stdampq2 = np.load('../features/stdampq2.npy')
stdposq2 = np.load('../features/stdposq2.npy')
stdwidthq2 = np.load('../features/stdwidthq2.npy')
stdampq3 = np.load('../features/stdampq3.npy')
stdposq3 = np.load('../features/stdposq3.npy')
stdwidthq3 = np.load('../features/stdwidthq3.npy')
stdampq4 = np.load('../features/stdampq4.npy')
stdposq4 = np.load('../features/stdposq4.npy')
stdwidthq4 = np.load('../features/stdwidthq4.npy')

# %%
stdampall_ad = np.load('../features/stdampall_ad.npy')
stdampq2_ad = np.load('../features/stdampq2_ad.npy')
stdampq3_ad = np.load('../features/stdampq3_ad.npy')
stdampq4_ad = np.load('../features/stdampq4_ad.npy')

meanampall_ad = np.load('../features/meanampall_ad.npy')
meanampq2_ad = np.load('../features/meanampq2_ad.npy')
meanampq3_ad = np.load('../features/meanampq3_ad.npy')
meanampq4_ad = np.load('../features/meanampq4_ad.npy')

meanamppos = np.load('../features/meanamppos.npy')
meanampneg = np.load('../features/meanampneg.npy')

# %%
train_features = pd.DataFrame({'NumPeaks':numpeaks, 'NumPosPeaks':numpospeaks, 'NumNegPeaks':numnegpeaks, 'MaxWidth':maxpeakwidth,
                         'MinWidth':minpeakwidth, 'MeanWidth':meanpeakwidth, 'MaxAmp':maxamp, 'MinAmp':minamp, 'MeanAmp':meanamp,
                        'StdAmpAll':stdampall, 'StdPosAll':stdposall, 'StdWidthAll':stdwidthall, 'StdAmpQ2':stdampq2, 'StdPosQ2':stdposq2,
                         'StdWidthQ2':stdwidthq2, 'StdAmpQ3':stdampq3, 'StdPosQ3':stdposq3, 'StdWidthQ3':stdwidthq3,
                        'StdAmpQ4':stdampq4, 'StdPosQ4':stdposq4, 'StdWidthQ4':stdwidthq4, 
                        'StdAmpAll_AD':stdampall_ad, 'StdAmpQ2_AD': stdampq2_ad, 'StdAmpQ3_AD': stdampq3_ad, 'StdAmpQ4_AD': stdampq4_ad,
                        'MeanAmpAll_AD':meanampall_ad, 'MeanAmpQ2_AD': meanampq2_ad,
                        'MeanAmpQ3_AD': meanampq3_ad, 'MeanAmpQ4_AD': meanampq4_ad,
                        'MeanAmpPos':meanamppos, 'MeanAmpNeg':meanampneg})

# %%
train = pd.concat([meta_train, train_features], axis=1)

# %%
train.head()
# Out:
#    signal_id  id_measurement  phase  target  NumPeaks  NumPosPeaks  \
# 0          0               0      0       0       105           48
# 1          1               0      1       0        23           14
# 2          2               0      2       0       121           67
# 3          3               1      0       1       217           99
# 4          4               1      1       1       141           68
#
#    NumNegPeaks  MaxWidth  MinWidth     MeanWidth     MaxAmp     MinAmp  \
# 0           57     41741         1   3676.451923  46.676929 -21.931899
# 1            9     69734         1  10977.954545  13.454715 -12.666357
# 2           54     58988         1   3175.458333  26.176798 -30.415865
# 3          118     44999         1   1820.212963  91.147620 -38.193195
# 4           73     37017         1   2803.257143  14.246623  -9.247347
#
#     MeanAmp  StdAmpAll      StdPosAll   StdWidthAll   StdAmpQ2      StdPosQ2  \
# 0 -0.000125  11.866878   77424.493902   7099.857490  11.214203  25011.751218
# 1  0.000094   8.663170   76017.661321  16116.212440   9.545417   8608.000000
# 2  0.000112  11.285462   74713.050192   7570.433485  14.920124  24129.371090
# 3  0.000239  11.473998  131660.062871   4198.542517   5.535926  25928.722290
# 4 -0.000065   4.289404  126355.390058   5433.900865   4.720264  21722.232143
#
#      StdWidthQ2   StdAmpQ3      StdPosQ3   StdWidthQ3   StdAmpQ4  \
# 0   6165.933632  12.479814  22686.469829  2801.657114   8.081718
# 1      0.000000   8.286657  19963.709475  6986.037612   5.719954
# 2   7265.204158  11.041417  20894.197560  1152.704984  11.427326
# 3  12482.994099   5.538974  22936.531117  3615.659712   5.086507
# 4   7837.139326   3.000449  25632.115546  9773.675906   3.425179
#
#        StdPosQ4   StdWidthQ4  StdAmpAll_AD  StdAmpQ2_AD  StdAmpQ3_AD  \
# 0  22092.125444  8984.882428     44.891664     0.670594    85.296720
# 1  15027.735166  9284.827461     30.568193    35.273220    43.143698
# 2  21303.210731  5779.776683     30.570660    43.144629    35.274377
# 3  34060.095196  2594.629391     87.000132    60.780813    70.004487
# 4  29998.890319  4142.901139     84.430994    60.780715    65.567084
#
#    StdAmpQ4_AD  MeanAmpAll_AD  MeanAmpQ2_AD  MeanAmpQ3_AD  MeanAmpQ4_AD  \
# 0    24.976989       4.062346      0.000151     14.999402      1.249880
# 1    24.977523       1.875258      2.500917      3.750465      1.249668
# 2    24.978110       1.875325      3.750685      2.500106      1.250578
# 3    43.144785      15.624495      7.500015      9.998660      3.750652
# 4    24.979410      14.686710      7.499892      8.748330      1.249292
#
#    MeanAmpPos  MeanAmpNeg
# 0   11.181670  -10.294509
# 1    8.331531   -8.799846
# 2    9.514662  -10.973763
# 3    8.910585   -6.666027
# 4    3.898276   -3.984866

# %%
id_target = train.groupby('id_measurement', as_index=False)['target'].sum()

target1_index = id_target[id_target['target']==1].index

target2_index = id_target[id_target['target']==2].index

# %%
for idx in target1_index:
    train.loc[train['id_measurement'] == idx, 'target'] = 0
        
for idx in target2_index:
    train.loc[train['id_measurement'] == idx, 'target'] = 1

# %%
train['target'].value_counts()
# Out:
# 0    8187
# 1     525
# Name: target, dtype: int64

# %%
signal_id = train['signal_id'].values
del train['signal_id']

# %%
target = train['target'].values
del train['target']

# %%
from sklearn.metrics import matthews_corrcoef

# %%
skf = StratifiedKFold(n_splits=4, random_state=123, shuffle=True)

# %%
clf = []
val_mcc = []
val_pred = pd.DataFrame([])
proba = []
lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'None',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'binary', 
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }


for train_idx, val_idx in skf.split(train, target):
    X_tr, y_tr = train.iloc[train_idx, :], target[train_idx]
    X_val, y_val = train.iloc[val_idx, :], target[val_idx]
 
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30, feval=mcc_eval)
    pred_lgb = model_lgb.predict(X_val)
    
    best_proba, best_mcc, y_pred = eval_mcc(y_val, pred_lgb, show=True)
    val_mcc.append(best_mcc)
    proba.append(best_proba)
    
    pred_lgb = pd.DataFrame(pred_lgb, index=val_idx)
    val_pred = pd.concat([val_pred, pred_lgb], axis=1)
    
    clf.append(model_lgb)
# Out:
# [1]	valid_0's MCC: 0.585257
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's MCC: 0.613089
# [3]	valid_0's MCC: 0.621021
# [4]	valid_0's MCC: 0.627252
# [5]	valid_0's MCC: 0.637331
# [6]	valid_0's MCC: 0.630905
# [7]	valid_0's MCC: 0.626894
# [8]	valid_0's MCC: 0.627618
# [9]	valid_0's MCC: 0.621424
# [10]	valid_0's MCC: 0.621424
# [11]	valid_0's MCC: 0.630012
# [12]	valid_0's MCC: 0.626456
# [13]	valid_0's MCC: 0.624125
# [14]	valid_0's MCC: 0.624125
# [15]	valid_0's MCC: 0.618265
# [16]	valid_0's MCC: 0.618892
# [17]	valid_0's MCC: 0.621148
# [18]	valid_0's MCC: 0.622413
# [19]	valid_0's MCC: 0.622898
# [20]	valid_0's MCC: 0.624004
# [21]	valid_0's MCC: 0.622413
# [22]	valid_0's MCC: 0.624044
# [23]	valid_0's MCC: 0.622491
# [24]	valid_0's MCC: 0.628597
# [25]	valid_0's MCC: 0.630905
# [26]	valid_0's MCC: 0.630905
# [27]	valid_0's MCC: 0.625749
# [28]	valid_0's MCC: 0.625749
# [29]	valid_0's MCC: 0.625749
# [30]	valid_0's MCC: 0.62631
# [31]	valid_0's MCC: 0.628597
# [32]	valid_0's MCC: 0.62631
# [33]	valid_0's MCC: 0.631216
# [34]	valid_0's MCC: 0.632813
# [35]	valid_0's MCC: 0.631441
# Early stopping, best iteration is:
# [5]	valid_0's MCC: 0.637331
# 0.6373313095610683 0.6373313095610683
# [1]	valid_0's MCC: 0.53803
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's MCC: 0.544381
# [3]	valid_0's MCC: 0.563364
# [4]	valid_0's MCC: 0.579846
# [5]	valid_0's MCC: 0.578727
# [6]	valid_0's MCC: 0.583676
# [7]	valid_0's MCC: 0.587016
# [8]	valid_0's MCC: 0.590258
# [9]	valid_0's MCC: 0.588552
# [10]	valid_0's MCC: 0.593169
# [11]	valid_0's MCC: 0.60323
# [12]	valid_0's MCC: 0.60234
# [13]	valid_0's MCC: 0.605382
# [14]	valid_0's MCC: 0.599173
# [15]	valid_0's MCC: 0.600703
# [16]	valid_0's MCC: 0.598458
# [17]	valid_0's MCC: 0.605969
# [18]	valid_0's MCC: 0.614355
# [19]	valid_0's MCC: 0.610181
# [20]	valid_0's MCC: 0.611211
# [21]	valid_0's MCC: 0.608963
# [22]	valid_0's MCC: 0.608963
# [23]	valid_0's MCC: 0.613725
# [24]	valid_0's MCC: 0.616874
# [25]	valid_0's MCC: 0.613631
# [26]	valid_0's MCC: 0.617273
# [27]	valid_0's MCC: 0.619053
# [28]	valid_0's MCC: 0.619962
# [29]	valid_0's MCC: 0.619385
# [30]	valid_0's MCC: 0.619385
# [31]	valid_0's MCC: 0.619385
# [32]	valid_0's MCC: 0.627985
# [33]	valid_0's MCC: 0.627985
# [34]	valid_0's MCC: 0.623897
# [35]	valid_0's MCC: 0.623897
# [36]	valid_0's MCC: 0.622441
# [37]	valid_0's MCC: 0.632755
# [38]	valid_0's MCC: 0.632755
# [39]	valid_0's MCC: 0.637226
# [40]	valid_0's MCC: 0.637226
# [41]	valid_0's MCC: 0.637226
# [42]	valid_0's MCC: 0.63883
# [43]	valid_0's MCC: 0.636013
# [44]	valid_0's MCC: 0.632414
# [45]	valid_0's MCC: 0.630837
# [46]	valid_0's MCC: 0.640749
# [47]	valid_0's MCC: 0.640749
# [48]	valid_0's MCC: 0.643151
# [49]	valid_0's MCC: 0.636515
# [50]	valid_0's MCC: 0.634221
# [51]	valid_0's MCC: 0.636585
# [52]	valid_0's MCC: 0.643151
# [53]	valid_0's MCC: 0.637641
# [54]	valid_0's MCC: 0.642844
# [55]	valid_0's MCC: 0.635194
# [56]	valid_0's MCC: 0.642607
# [57]	valid_0's MCC: 0.64767
# [58]	valid_0's MCC: 0.648022
# [59]	valid_0's MCC: 0.639899
# [60]	valid_0's MCC: 0.637375
# [61]	valid_0's MCC: 0.639858
# [62]	valid_0's MCC: 0.645184
# [63]	valid_0's MCC: 0.648258
# [64]	valid_0's MCC: 0.643299
# [65]	valid_0's MCC: 0.645427
# [66]	valid_0's MCC: 0.645427
# [67]	valid_0's MCC: 0.645774
# [68]	valid_0's MCC: 0.645774
# [69]	valid_0's MCC: 0.643299
# [70]	valid_0's MCC: 0.640399
# [71]	valid_0's MCC: 0.637276
# [72]	valid_0's MCC: 0.637276
# [73]	valid_0's MCC: 0.640077
# [74]	valid_0's MCC: 0.637276
# [75]	valid_0's MCC: 0.639858
# [76]	valid_0's MCC: 0.645427
# [77]	valid_0's MCC: 0.648258
# [78]	valid_0's MCC: 0.645427
# [79]	valid_0's MCC: 0.648258
# [80]	valid_0's MCC: 0.645427
# [81]	valid_0's MCC: 0.650482
# [82]	valid_0's MCC: 0.648258
# [83]	valid_0's MCC: 0.648258
# [84]	valid_0's MCC: 0.648258
# [85]	valid_0's MCC: 0.65112
# [86]	valid_0's MCC: 0.65112
# [87]	valid_0's MCC: 0.65112
# [88]	valid_0's MCC: 0.639858
# [89]	valid_0's MCC: 0.65112
# [90]	valid_0's MCC: 0.64761
# [91]	valid_0's MCC: 0.64761
# [92]	valid_0's MCC: 0.64761
# [93]	valid_0's MCC: 0.645014
# [94]	valid_0's MCC: 0.645774
# [95]	valid_0's MCC: 0.640399
# [96]	valid_0's MCC: 0.640399
# [97]	valid_0's MCC: 0.645774
# [98]	valid_0's MCC: 0.640399
# [99]	valid_0's MCC: 0.640077
# [100]	valid_0's MCC: 0.636498
# [101]	valid_0's MCC: 0.636498
# [102]	valid_0's MCC: 0.639899
# [103]	valid_0's MCC: 0.639899
# [104]	valid_0's MCC: 0.634885
# [105]	valid_0's MCC: 0.639899
# [106]	valid_0's MCC: 0.639706
# [107]	valid_0's MCC: 0.642358
# [108]	valid_0's MCC: 0.644167
# [109]	valid_0's MCC: 0.646241
# [110]	valid_0's MCC: 0.646241
# [111]	valid_0's MCC: 0.646241
# [112]	valid_0's MCC: 0.646241
# [113]	valid_0's MCC: 0.646241
# [114]	valid_0's MCC: 0.644167
# [115]	valid_0's MCC: 0.644167
# Early stopping, best iteration is:
# [85]	valid_0's MCC: 0.65112
# 0.6511201205827589 0.6511201205827589
# [1]	valid_0's MCC: 0.534845
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's MCC: 0.550147
# [3]	valid_0's MCC: 0.563317
# [4]	valid_0's MCC: 0.579489
# [5]	valid_0's MCC: 0.575863
# [6]	valid_0's MCC: 0.583928
# [7]	valid_0's MCC: 0.589681
# [8]	valid_0's MCC: 0.598458
# [9]	valid_0's MCC: 0.598458
# [10]	valid_0's MCC: 0.595412
# [11]	valid_0's MCC: 0.59403
# [12]	valid_0's MCC: 0.601097
# [13]	valid_0's MCC: 0.598983
# [14]	valid_0's MCC: 0.596224
# [15]	valid_0's MCC: 0.59758
# [16]	valid_0's MCC: 0.595115
# [17]	valid_0's MCC: 0.59758
# [18]	valid_0's MCC: 0.598646
# [19]	valid_0's MCC: 0.59327
# [20]	valid_0's MCC: 0.592144
# [21]	valid_0's MCC: 0.594808
# [22]	valid_0's MCC: 0.59403
# [23]	valid_0's MCC: 0.599291
# [24]	valid_0's MCC: 0.598458
# [25]	valid_0's MCC: 0.598458
# [26]	valid_0's MCC: 0.598458
# [27]	valid_0's MCC: 0.595412
# [28]	valid_0's MCC: 0.599274
# [29]	valid_0's MCC: 0.600703
# [30]	valid_0's MCC: 0.605255
# [31]	valid_0's MCC: 0.605969
# [32]	valid_0's MCC: 0.605969
# [33]	valid_0's MCC: 0.598458
# [34]	valid_0's MCC: 0.598458
# [35]	valid_0's MCC: 0.598458
# [36]	valid_0's MCC: 0.599961
# [37]	valid_0's MCC: 0.600703
# [38]	valid_0's MCC: 0.599693
# [39]	valid_0's MCC: 0.597676
# [40]	valid_0's MCC: 0.607702
# [41]	valid_0's MCC: 0.605132
# [42]	valid_0's MCC: 0.605132
# [43]	valid_0's MCC: 0.607354
# [44]	valid_0's MCC: 0.610299
# [45]	valid_0's MCC: 0.610299
# [46]	valid_0's MCC: 0.60486
# [47]	valid_0's MCC: 0.599392
# [48]	valid_0's MCC: 0.599173
# [49]	valid_0's MCC: 0.601041
# [50]	valid_0's MCC: 0.601041
# [51]	valid_0's MCC: 0.601041
# [52]	valid_0's MCC: 0.601041
# [53]	valid_0's MCC: 0.602263
# [54]	valid_0's MCC: 0.602263
# [55]	valid_0's MCC: 0.602588
# [56]	valid_0's MCC: 0.598646
# [57]	valid_0's MCC: 0.598646
# [58]	valid_0's MCC: 0.598646
# [59]	valid_0's MCC: 0.596324
# [60]	valid_0's MCC: 0.599274
# [61]	valid_0's MCC: 0.599291
# [62]	valid_0's MCC: 0.604855
# [63]	valid_0's MCC: 0.608963
# [64]	valid_0's MCC: 0.61348
# [65]	valid_0's MCC: 0.61044
# [66]	valid_0's MCC: 0.61044
# [67]	valid_0's MCC: 0.611211
# [68]	valid_0's MCC: 0.61348
# [69]	valid_0's MCC: 0.618081
# [70]	valid_0's MCC: 0.618081
# [71]	valid_0's MCC: 0.61643
# [72]	valid_0's MCC: 0.6187
# [73]	valid_0's MCC: 0.6187
# [74]	valid_0's MCC: 0.620991
# [75]	valid_0's MCC: 0.619375
# [76]	valid_0's MCC: 0.616367
# [77]	valid_0's MCC: 0.614181
# [78]	valid_0's MCC: 0.616864
# [79]	valid_0's MCC: 0.613386
# [80]	valid_0's MCC: 0.614933
# [81]	valid_0's MCC: 0.621724
# [82]	valid_0's MCC: 0.621724
# [83]	valid_0's MCC: 0.61983
# [84]	valid_0's MCC: 0.617356
# [85]	valid_0's MCC: 0.623416
# [86]	valid_0's MCC: 0.623416
# [87]	valid_0's MCC: 0.627421
# [88]	valid_0's MCC: 0.622441
# [89]	valid_0's MCC: 0.623416
# [90]	valid_0's MCC: 0.628415
# [91]	valid_0's MCC: 0.621028
# [92]	valid_0's MCC: 0.625555
# [93]	valid_0's MCC: 0.630509
# [94]	valid_0's MCC: 0.628668
# [95]	valid_0's MCC: 0.628584
# [96]	valid_0's MCC: 0.628584
# [97]	valid_0's MCC: 0.628584
# [98]	valid_0's MCC: 0.629445
# [99]	valid_0's MCC: 0.626674
# [100]	valid_0's MCC: 0.629494
# [101]	valid_0's MCC: 0.628584
# [102]	valid_0's MCC: 0.627823
# [103]	valid_0's MCC: 0.628211
# [104]	valid_0's MCC: 0.626674
# [105]	valid_0's MCC: 0.630509
# [106]	valid_0's MCC: 0.628584
# [107]	valid_0's MCC: 0.626275
# [108]	valid_0's MCC: 0.632921
# [109]	valid_0's MCC: 0.643802
# [110]	valid_0's MCC: 0.638376
# [111]	valid_0's MCC: 0.635404
# [112]	valid_0's MCC: 0.643802
# [113]	valid_0's MCC: 0.646807
# [114]	valid_0's MCC: 0.649198
# [115]	valid_0's MCC: 0.646231
# [116]	valid_0's MCC: 0.649198
# [117]	valid_0's MCC: 0.640399
# [118]	valid_0's MCC: 0.647509
# [119]	valid_0's MCC: 0.649198
# [120]	valid_0's MCC: 0.645185
# [121]	valid_0's MCC: 0.649198
# [122]	valid_0's MCC: 0.655237
# [123]	valid_0's MCC: 0.6522
# [124]	valid_0's MCC: 0.6522
# [125]	valid_0's MCC: 0.649198
# [126]	valid_0's MCC: 0.649198
# [127]	valid_0's MCC: 0.6522
# [128]	valid_0's MCC: 0.651601
# [129]	valid_0's MCC: 0.651601
# [130]	valid_0's MCC: 0.646231
# [131]	valid_0's MCC: 0.647509
# [132]	valid_0's MCC: 0.642062
# [133]	valid_0's MCC: 0.644428
# [134]	valid_0's MCC: 0.650627
# [135]	valid_0's MCC: 0.650627
# [136]	valid_0's MCC: 0.647509
# [137]	valid_0's MCC: 0.646231
# [138]	valid_0's MCC: 0.645185
# [139]	valid_0's MCC: 0.648346
# [140]	valid_0's MCC: 0.648346
# [141]	valid_0's MCC: 0.650627
# [142]	valid_0's MCC: 0.646231
# [143]	valid_0's MCC: 0.645185
# [144]	valid_0's MCC: 0.645014
# [145]	valid_0's MCC: 0.64761
# [146]	valid_0's MCC: 0.645314
# [147]	valid_0's MCC: 0.647809
# [148]	valid_0's MCC: 0.65073
# [149]	valid_0's MCC: 0.653177
# [150]	valid_0's MCC: 0.653177
# [151]	valid_0's MCC: 0.65073
# [152]	valid_0's MCC: 0.653177
# Early stopping, best iteration is:
# [122]	valid_0's MCC: 0.655237
# 0.655237409482237 0.655237409482237
# [1]	valid_0's MCC: 0.555181
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's MCC: 0.561269
# [3]	valid_0's MCC: 0.579354
# [4]	valid_0's MCC: 0.573446
# [5]	valid_0's MCC: 0.587003
# [6]	valid_0's MCC: 0.576241
# [7]	valid_0's MCC: 0.579475
# [8]	valid_0's MCC: 0.577638
# [9]	valid_0's MCC: 0.585169
# [10]	valid_0's MCC: 0.591286
# [11]	valid_0's MCC: 0.593471
# [12]	valid_0's MCC: 0.593575
# [13]	valid_0's MCC: 0.596216
# [14]	valid_0's MCC: 0.59069
# [15]	valid_0's MCC: 0.599055
# [16]	valid_0's MCC: 0.597568
# [17]	valid_0's MCC: 0.595399
# [18]	valid_0's MCC: 0.596507
# [19]	valid_0's MCC: 0.601774
# [20]	valid_0's MCC: 0.59903
# [21]	valid_0's MCC: 0.596213
# [22]	valid_0's MCC: 0.60051
# [23]	valid_0's MCC: 0.602251
# [24]	valid_0's MCC: 0.601774
# [25]	valid_0's MCC: 0.601774
# [26]	valid_0's MCC: 0.602255
# [27]	valid_0's MCC: 0.605243
# [28]	valid_0's MCC: 0.608951
# [29]	valid_0's MCC: 0.608951
# [30]	valid_0's MCC: 0.608951
# [31]	valid_0's MCC: 0.60371
# [32]	valid_0's MCC: 0.60371
# [33]	valid_0's MCC: 0.596935
# [34]	valid_0's MCC: 0.605957
# [35]	valid_0's MCC: 0.607551
# [36]	valid_0's MCC: 0.605369
# [37]	valid_0's MCC: 0.610512
# [38]	valid_0's MCC: 0.610512
# [39]	valid_0's MCC: 0.612822
# [40]	valid_0's MCC: 0.612822
# [41]	valid_0's MCC: 0.608224
# [42]	valid_0's MCC: 0.606723
# [43]	valid_0's MCC: 0.613468
# [44]	valid_0's MCC: 0.611199
# [45]	valid_0's MCC: 0.606723
# [46]	valid_0's MCC: 0.609729
# [47]	valid_0's MCC: 0.608224
# [48]	valid_0's MCC: 0.608224
# [49]	valid_0's MCC: 0.607539
# [50]	valid_0's MCC: 0.606723
# [51]	valid_0's MCC: 0.607473
# [52]	valid_0's MCC: 0.606723
# [53]	valid_0's MCC: 0.602251
# [54]	valid_0's MCC: 0.604848
# [55]	valid_0's MCC: 0.61281
# [56]	valid_0's MCC: 0.610127
# [57]	valid_0's MCC: 0.610055
# [58]	valid_0's MCC: 0.61281
# [59]	valid_0's MCC: 0.61281
# [60]	valid_0's MCC: 0.607791
# [61]	valid_0's MCC: 0.607342
# [62]	valid_0's MCC: 0.607342
# [63]	valid_0's MCC: 0.607342
# [64]	valid_0's MCC: 0.605601
# [65]	valid_0's MCC: 0.605249
# [66]	valid_0's MCC: 0.607342
# [67]	valid_0's MCC: 0.612234
# [68]	valid_0's MCC: 0.612234
# [69]	valid_0's MCC: 0.611204
# [70]	valid_0's MCC: 0.611204
# [71]	valid_0's MCC: 0.611204
# [72]	valid_0's MCC: 0.609881
# [73]	valid_0's MCC: 0.607808
# Early stopping, best iteration is:
# [43]	valid_0's MCC: 0.613468
# 0.6134677751131918 0.6134677751131918

# %%
proba
# Out:
# [0.19453582727751262,
#  0.29235502655241863,
#  0.29217856260225183,
#  0.2935320457426654]

# %%
val_mcc
# Out:
# [0.6373313095610683, 0.6511201205827589, 0.655237409482237, 0.6134677751131918]

# %%
np.mean(val_mcc)
# Out:
# 0.639289153684814

# %%
best_proba, best_mcc, y_pred = eval_mcc(target, np.sum(val_pred, axis=1), show=True)
# Out:
# 0.6120159324859432 0.6120159324859432

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(target, (np.sum(val_pred, axis=1)>np.mean(best_proba)).astype(int))
# Out:
# array([[7925,  262],
#        [ 160,  365]])

# %%
feature_imp = np.zeros(train.shape[1])
for model in clf:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp/4, index=train.columns).sort_values(by=0, ascending=False)
# Out:
#                           0
# NumNegPeaks     3092.862820
# MeanAmpAll_AD   1594.526432
# MeanAmpNeg       680.433201
# NumPosPeaks      656.453051
# MinAmp           423.539819
# MeanAmpPos       421.080015
# StdAmpAll_AD     298.987120
# StdAmpQ2         295.385899
# StdAmpQ3         289.100460
# MaxAmp           266.334216
# StdAmpQ4         246.313501
# id_measurement   242.455933
# NumPeaks         223.497867
# StdWidthQ2       215.711290
# StdAmpQ2_AD      196.903459
# MeanWidth        180.695727
# StdWidthQ3       178.570968
# MaxWidth         173.801324
# MeanAmpQ2_AD     171.245531
# StdPosQ4         144.158217
# StdWidthQ4       135.240882
# StdPosQ2         130.863849
# StdAmpQ4_AD      127.031762
# StdAmpAll        125.982143
# StdAmpQ3_AD      117.870481
# MeanAmp          117.257013
# StdPosQ3         115.168825
# phase            113.520077
# StdPosAll         84.091726
# MeanAmpQ4_AD      82.154637
# StdWidthAll       75.203858
# MeanAmpQ3_AD      65.786789
# MinWidth          58.471123

# %%
best_proba
# Out:
# 0.20295435264358713

# %%
comparison = pd.DataFrame({'target':target, 'val_pred':(np.sum(val_pred, axis=1)>np.mean(best_proba)).astype(int)})
train = pd.concat([train, comparison], axis=1)

# %%
id_target = train.groupby('id_measurement', as_index=False)['target'].sum()
id_target[id_target['target']==1].count()

# %%
id_target[id_target['target']==2]

# %%
train[train['target']==1].loc[:, ['MeanAmpAll_AD', 'MeanAmpNeg', 'NumNegPeaks','target', 'val_pred']].sort_values('NumNegPeaks', ascending=False)

# %%
train.loc[:, ['MeanAmpAll_AD', 'MeanAmpNeg', 'NumNegPeaks','target', 'val_pred']].sort_values('NumNegPeaks', ascending=False).tail(1000)
