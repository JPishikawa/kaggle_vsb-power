# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from scipy.signal import chirp, find_peaks, peak_widths
import pywt

from multiprocessing import Pool
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import warnings

warnings.filterwarnings('ignore')
# Out:
# /home/cwademo123/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
def maddest(d, axis=None):
    """
    Mean Absolute Deviation
    """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

# %%
def denoise_signal( x, wavelet='db4', level=1):
    """
    1. Adapted from waveletSmooth function found here:
    http://connor-johnson.com/2016/01/24/using-pywavelets-to-remove-high-frequency-noise/
    2. Threshold equation and using hard mode in threshold as mentioned
    in section '3.2 denoising based on optimized singular values' from paper by Tomas Vantuch:
    http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    """
    
    # Decompose to get the wavelet coefficients
    coeff = pywt.wavedec( x, wavelet, mode="per", level=level)
    
    # Calculate sigma for threshold as defined in http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    # As noted by @harshit92 MAD referred to in the paper is Mean Absolute Deviation not Median Absolute Deviation
    sigma = (1/0.6745) * maddest( coeff[-level] )

    # Calculte the univeral threshold
    uthresh = sigma * np.sqrt( 2*np.log( len( x ) ) )
    coeff[1:] = ( pywt.threshold( i, value=uthresh, mode='hard' ) for i in coeff[1:] )
    
    # Reconstruct the signal using the thresholded coefficients
    return pywt.waverec( coeff[1:], wavelet, mode='per' )

# %%
def remove_corona(x_dn, maxDistance=10, maxHeightRatio=0.25, maxTicksRemoval=500):
    index = pd.Series(x_dn).loc[np.abs(x_dn)>0].index
    corona_idx = []
    for idx in index:
        for i in range(1,maxDistance+1):
            if idx+i < pd.Series(x_dn).shape[0]:
                if x_dn[idx+i]/(x_dn[idx]+1e-04)<-maxHeightRatio:
                    x_dn[idx:idx+maxTicksRemoval] = 0
                    corona_idx.append(idx)
    return x_dn, corona_idx

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    ts_wave = denoise_signal(ts_std, wavelet='haar', level=1)
    ts_rm, corona_idx = remove_corona(ts_wave)
    
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        ts_rm_range = ts_rm[int(i/2):int(i/2) + int(bucket_size/2)]
        #ts_rm_range = pd.Series(ts_rm_range)
        
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        
        #numpeaks = ts_rm_range[ts_rm_range!=0].count()
        numpeaks = np.sum(ts_rm_range!=0)/len(ts_rm_range)
        #numpospeaks = ts_rm_range[ts_rm_range>0].count()
        numpospeaks = np.sum(ts_rm_range>0)/len(ts_rm_range)
        #numnegpeaks = ts_rm_range[ts_rm_range<0].count()
        numnegpeaks = np.sum(ts_rm_range<0)/len(ts_rm_range)

        meanamp = np.mean(ts_rm_range)
        meanamppos = np.mean(ts_rm_range[ts_rm_range>0])
        meanampneg = np.mean(ts_rm_range[ts_rm_range<0])

        maxamp = np.max(ts_rm_range)
        minamp = np.min(ts_rm_range)
        
        peaks, _ = find_peaks(ts_rm_range)
        results_full = peak_widths(ts_rm_range, peaks, rel_height=1)
        
        if len(results_full[0])==0:
            maxwidth = 0
            minwidth = 0
        else:
            maxwidth = np.max(results_full[0])/len(ts_rm_range)
            minwidth = np.min(results_full[0])/len(ts_rm_range)
        
        
        
        feat_array = np.asarray([mean, std, std_top, std_bot, max_range])
        feat_array_2 = np.asarray([numpeaks, numpospeaks, numnegpeaks
                                   , meanamp, meanamppos, meanampneg,
                                 maxamp, minamp, maxwidth, minwidth
                                  ])
        
        new_ts.append(np.concatenate([feat_array, feat_array_2, percentil_calc, relative_percentile]))
        
    #scaler = MinMaxScaler(feature_range=(-1, 1))
    #scaler = StandardScaler()
    #new_ts = np.asarray(new_ts)
    #new_ts[np.isnan(new_ts)] = 0
    
    #new_ts = scaler.fit_transform(new_ts)
        
    return new_ts

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
def process_subtrain(arg_tuple):
    start, end, idx = arg_tuple
    X, y = prep_data(start, end)
    return idx, X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
#X = []
#y = []
all_chunks = []

num_cores = 8 
#def load_all():
total_size = len(df_train)
chunk_size = total_size/num_cores

for i in range(8):
    start_idx = int(i * chunk_size)
    end_idx = int(start_idx + chunk_size)
    chunk = (start_idx, end_idx, i)
    all_chunks.append(chunk)

pool = Pool()
results = pool.map(process_subtrain, all_chunks)    
results = sorted(results, key=lambda tup: tup[0])

X = np.concatenate([item[1] for item in results], axis=0)
y = np.concatenate([item[2] for item in results], axis=0)

#load_all()

#X = np.asarray(X)
#y = np.asarray(y)
# Out:
# 100%|██████████| 363/363 [14:43<00:00,  2.94s/it]
# 100%|██████████| 363/363 [15:18<00:00,  3.29s/it]
# 100%|██████████| 363/363 [15:43<00:00,  1.98s/it]
# 100%|██████████| 363/363 [15:49<00:00,  2.16s/it]
# 100%|██████████| 363/363 [16:02<00:00,  1.43it/s]
# 100%|██████████| 363/363 [16:03<00:00,  2.06s/it]
# 100%|██████████| 363/363 [16:11<00:00,  1.22s/it]
# 100%|██████████| 363/363 [16:19<00:00,  1.31s/it]

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# Out:
# (2904, 160, 87) (2904,)

# %%
X[np.isnan(X)] = 0

# %%
print(np.max(X), np.min(X))
# Out:
# 2.0 -1.4142135623730951

# %%
# save data into file, a numpy specific format
np.save("X_4.npy",X)
np.save("y_4.npy",y)

# %%
X = np.load("./X_3.npy")
y = np.load("./y_3.npy")

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(LSTM(128, return_sequences=True))(inp)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64)(x)
    
    x = LeakyReLU(alpha=0.1)(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 29s 12ms/step - loss: 0.3795 - matthews_correlation: 0.0000e+00 - val_loss: 0.2373 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 24s 10ms/step - loss: 0.2254 - matthews_correlation: 0.0000e+00 - val_loss: 0.2226 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.2032 - matthews_correlation: 0.0358 - val_loss: 0.1651 - val_matthews_correlation: 0.3198
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.31985, saving model to weights_0.h5
# Epoch 4/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1484 - matthews_correlation: 0.3627 - val_loss: 0.1119 - val_matthews_correlation: 0.3085
#
# Epoch 00004: val_matthews_correlation did not improve from 0.31985
# Epoch 5/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1238 - matthews_correlation: 0.4500 - val_loss: 0.0888 - val_matthews_correlation: 0.5276
#
# Epoch 00005: val_matthews_correlation improved from 0.31985 to 0.52762, saving model to weights_0.h5
# Epoch 6/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1101 - matthews_correlation: 0.5535 - val_loss: 0.0835 - val_matthews_correlation: 0.6566
#
# Epoch 00006: val_matthews_correlation improved from 0.52762 to 0.65661, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1027 - matthews_correlation: 0.5948 - val_loss: 0.0753 - val_matthews_correlation: 0.6925
#
# Epoch 00007: val_matthews_correlation improved from 0.65661 to 0.69247, saving model to weights_0.h5
# Epoch 8/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1113 - matthews_correlation: 0.5667 - val_loss: 0.1035 - val_matthews_correlation: 0.7150
#
# Epoch 00008: val_matthews_correlation improved from 0.69247 to 0.71499, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1217 - matthews_correlation: 0.5720 - val_loss: 0.0858 - val_matthews_correlation: 0.6444
#
# Epoch 00009: val_matthews_correlation did not improve from 0.71499
# Epoch 10/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1065 - matthews_correlation: 0.6147 - val_loss: 0.0786 - val_matthews_correlation: 0.6874
#
# Epoch 00010: val_matthews_correlation did not improve from 0.71499
# Epoch 11/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1036 - matthews_correlation: 0.6439 - val_loss: 0.0741 - val_matthews_correlation: 0.7429
#
# Epoch 00011: val_matthews_correlation improved from 0.71499 to 0.74293, saving model to weights_0.h5
# Epoch 12/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1093 - matthews_correlation: 0.5870 - val_loss: 0.0812 - val_matthews_correlation: 0.5566
#
# Epoch 00012: val_matthews_correlation did not improve from 0.74293
# Epoch 13/50
# 2322/2322 [==============================] - 22s 10ms/step - loss: 0.1164 - matthews_correlation: 0.5813 - val_loss: 0.0962 - val_matthews_correlation: 0.5022
#
# Epoch 00013: val_matthews_correlation did not improve from 0.74293
# Epoch 14/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.1010 - matthews_correlation: 0.6423 - val_loss: 0.0863 - val_matthews_correlation: 0.6207
#
# Epoch 00014: val_matthews_correlation did not improve from 0.74293
# Epoch 15/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0986 - matthews_correlation: 0.6340 - val_loss: 0.0755 - val_matthews_correlation: 0.7036
#
# Epoch 00015: val_matthews_correlation did not improve from 0.74293
# Epoch 16/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0965 - matthews_correlation: 0.6505 - val_loss: 0.0736 - val_matthews_correlation: 0.6697
#
# Epoch 00016: val_matthews_correlation did not improve from 0.74293
# Epoch 17/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0961 - matthews_correlation: 0.6500 - val_loss: 0.0796 - val_matthews_correlation: 0.6207
#
# Epoch 00017: val_matthews_correlation did not improve from 0.74293
# Epoch 18/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0929 - matthews_correlation: 0.6617 - val_loss: 0.0770 - val_matthews_correlation: 0.7474
#
# Epoch 00018: val_matthews_correlation improved from 0.74293 to 0.74743, saving model to weights_0.h5
# Epoch 19/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0925 - matthews_correlation: 0.6727 - val_loss: 0.0694 - val_matthews_correlation: 0.7057
#
# Epoch 00019: val_matthews_correlation did not improve from 0.74743
# Epoch 20/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0910 - matthews_correlation: 0.6689 - val_loss: 0.0785 - val_matthews_correlation: 0.7610
#
# Epoch 00020: val_matthews_correlation improved from 0.74743 to 0.76097, saving model to weights_0.h5
# Epoch 21/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0943 - matthews_correlation: 0.6755 - val_loss: 0.0717 - val_matthews_correlation: 0.7189
#
# Epoch 00021: val_matthews_correlation did not improve from 0.76097
# Epoch 22/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0915 - matthews_correlation: 0.6718 - val_loss: 0.0728 - val_matthews_correlation: 0.8174
#
# Epoch 00022: val_matthews_correlation improved from 0.76097 to 0.81739, saving model to weights_0.h5
# Epoch 23/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0910 - matthews_correlation: 0.6689 - val_loss: 0.0760 - val_matthews_correlation: 0.7224
#
# Epoch 00023: val_matthews_correlation did not improve from 0.81739
# Epoch 24/50
# 2322/2322 [==============================] - 24s 10ms/step - loss: 0.0889 - matthews_correlation: 0.6497 - val_loss: 0.0723 - val_matthews_correlation: 0.7680
#
# Epoch 00024: val_matthews_correlation did not improve from 0.81739
# Epoch 25/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0880 - matthews_correlation: 0.6689 - val_loss: 0.0696 - val_matthews_correlation: 0.7512
#
# Epoch 00025: val_matthews_correlation did not improve from 0.81739
# Epoch 26/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0855 - matthews_correlation: 0.6651 - val_loss: 0.0817 - val_matthews_correlation: 0.7881
#
# Epoch 00026: val_matthews_correlation did not improve from 0.81739
# Epoch 27/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0905 - matthews_correlation: 0.6603 - val_loss: 0.1219 - val_matthews_correlation: 0.6612
#
# Epoch 00027: val_matthews_correlation did not improve from 0.81739
# Epoch 28/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0987 - matthews_correlation: 0.6359 - val_loss: 0.0929 - val_matthews_correlation: 0.7150
#
# Epoch 00028: val_matthews_correlation did not improve from 0.81739
# Epoch 29/50
# 2322/2322 [==============================] - 24s 10ms/step - loss: 0.0879 - matthews_correlation: 0.6733 - val_loss: 0.0696 - val_matthews_correlation: 0.8174
#
# Epoch 00029: val_matthews_correlation did not improve from 0.81739
# Epoch 30/50
# 2322/2322 [==============================] - 22s 10ms/step - loss: 0.0844 - matthews_correlation: 0.6972 - val_loss: 0.0826 - val_matthews_correlation: 0.8423
#
# Epoch 00030: val_matthews_correlation improved from 0.81739 to 0.84228, saving model to weights_0.h5
# Epoch 31/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0841 - matthews_correlation: 0.6658 - val_loss: 0.0685 - val_matthews_correlation: 0.8135
#
# Epoch 00031: val_matthews_correlation did not improve from 0.84228
# Epoch 32/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0914 - matthews_correlation: 0.6585 - val_loss: 0.0676 - val_matthews_correlation: 0.7952
#
# Epoch 00032: val_matthews_correlation did not improve from 0.84228
# Epoch 33/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0822 - matthews_correlation: 0.6616 - val_loss: 0.0869 - val_matthews_correlation: 0.7703
#
# Epoch 00033: val_matthews_correlation did not improve from 0.84228
# Epoch 34/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0814 - matthews_correlation: 0.6832 - val_loss: 0.0734 - val_matthews_correlation: 0.7567
#
# Epoch 00034: val_matthews_correlation did not improve from 0.84228
# Epoch 35/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0848 - matthews_correlation: 0.6822 - val_loss: 0.0710 - val_matthews_correlation: 0.7498
#
# Epoch 00035: val_matthews_correlation did not improve from 0.84228
# Epoch 36/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0796 - matthews_correlation: 0.6872 - val_loss: 0.0692 - val_matthews_correlation: 0.7201
#
# Epoch 00036: val_matthews_correlation did not improve from 0.84228
# Epoch 37/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0763 - matthews_correlation: 0.7331 - val_loss: 0.0725 - val_matthews_correlation: 0.7506
#
# Epoch 00037: val_matthews_correlation did not improve from 0.84228
# Epoch 38/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0844 - matthews_correlation: 0.7094 - val_loss: 0.0811 - val_matthews_correlation: 0.6423
#
# Epoch 00038: val_matthews_correlation did not improve from 0.84228
# Epoch 39/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0825 - matthews_correlation: 0.6228 - val_loss: 0.0962 - val_matthews_correlation: 0.7312
#
# Epoch 00039: val_matthews_correlation did not improve from 0.84228
# Epoch 40/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0863 - matthews_correlation: 0.7014 - val_loss: 0.0655 - val_matthews_correlation: 0.7922
#
# Epoch 00040: val_matthews_correlation did not improve from 0.84228
# Epoch 41/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0804 - matthews_correlation: 0.6998 - val_loss: 0.0668 - val_matthews_correlation: 0.7505
#
# Epoch 00041: val_matthews_correlation did not improve from 0.84228
# Epoch 42/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0961 - matthews_correlation: 0.6177 - val_loss: 0.1313 - val_matthews_correlation: 0.6815
#
# Epoch 00042: val_matthews_correlation did not improve from 0.84228
# Epoch 43/50
# 2322/2322 [==============================] - 24s 10ms/step - loss: 0.0963 - matthews_correlation: 0.6887 - val_loss: 0.0854 - val_matthews_correlation: 0.7424
#
# Epoch 00043: val_matthews_correlation did not improve from 0.84228
# Epoch 44/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0807 - matthews_correlation: 0.6184 - val_loss: 0.1023 - val_matthews_correlation: 0.6991
#
# Epoch 00044: val_matthews_correlation did not improve from 0.84228
# Epoch 45/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0859 - matthews_correlation: 0.6910 - val_loss: 0.0833 - val_matthews_correlation: 0.7179
#
# Epoch 00045: val_matthews_correlation did not improve from 0.84228
# Epoch 46/50
# 2322/2322 [==============================] - 22s 10ms/step - loss: 0.0818 - matthews_correlation: 0.6715 - val_loss: 0.0698 - val_matthews_correlation: 0.7930
#
# Epoch 00046: val_matthews_correlation did not improve from 0.84228
# Epoch 47/50
# 2322/2322 [==============================] - 22s 10ms/step - loss: 0.0778 - matthews_correlation: 0.6717 - val_loss: 0.0711 - val_matthews_correlation: 0.7692
#
# Epoch 00047: val_matthews_correlation did not improve from 0.84228
# Epoch 48/50
# 2322/2322 [==============================] - 22s 10ms/step - loss: 0.0738 - matthews_correlation: 0.7015 - val_loss: 0.0795 - val_matthews_correlation: 0.7721
#
# Epoch 00048: val_matthews_correlation did not improve from 0.84228
# Epoch 49/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0739 - matthews_correlation: 0.7137 - val_loss: 0.0744 - val_matthews_correlation: 0.7603
#
# Epoch 00049: val_matthews_correlation did not improve from 0.84228
# Epoch 50/50
# 2322/2322 [==============================] - 23s 10ms/step - loss: 0.0717 - matthews_correlation: 0.7178 - val_loss: 0.0767 - val_matthews_correlation: 0.7122
#
# Epoch 00050: val_matthews_correlation did not improve from 0.84228
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 28s 12ms/step - loss: 0.3546 - matthews_correlation: 0.0000e+00 - val_loss: 0.2583 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.2138 - matthews_correlation: 0.0037 - val_loss: 0.1706 - val_matthews_correlation: 0.2566
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.25660, saving model to weights_1.h5
# Epoch 3/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.1331 - matthews_correlation: 0.5181 - val_loss: 0.1174 - val_matthews_correlation: 0.6360
#
# Epoch 00003: val_matthews_correlation improved from 0.25660 to 0.63600, saving model to weights_1.h5
# Epoch 4/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.1058 - matthews_correlation: 0.6563 - val_loss: 0.1052 - val_matthews_correlation: 0.6479
#
# Epoch 00004: val_matthews_correlation improved from 0.63600 to 0.64794, saving model to weights_1.h5
# Epoch 5/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0995 - matthews_correlation: 0.6908 - val_loss: 0.0950 - val_matthews_correlation: 0.6456
#
# Epoch 00005: val_matthews_correlation did not improve from 0.64794
# Epoch 6/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0965 - matthews_correlation: 0.6570 - val_loss: 0.0984 - val_matthews_correlation: 0.6624
#
# Epoch 00006: val_matthews_correlation improved from 0.64794 to 0.66238, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0966 - matthews_correlation: 0.6936 - val_loss: 0.0945 - val_matthews_correlation: 0.6619
#
# Epoch 00007: val_matthews_correlation did not improve from 0.66238
# Epoch 8/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0968 - matthews_correlation: 0.6699 - val_loss: 0.1078 - val_matthews_correlation: 0.6564
#
# Epoch 00008: val_matthews_correlation did not improve from 0.66238
# Epoch 9/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.1014 - matthews_correlation: 0.7053 - val_loss: 0.1008 - val_matthews_correlation: 0.6386
#
# Epoch 00009: val_matthews_correlation did not improve from 0.66238
# Epoch 10/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0954 - matthews_correlation: 0.7037 - val_loss: 0.0901 - val_matthews_correlation: 0.6743
#
# Epoch 00010: val_matthews_correlation improved from 0.66238 to 0.67433, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0997 - matthews_correlation: 0.6769 - val_loss: 0.1127 - val_matthews_correlation: 0.5594
#
# Epoch 00011: val_matthews_correlation did not improve from 0.67433
# Epoch 12/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0984 - matthews_correlation: 0.6429 - val_loss: 0.1027 - val_matthews_correlation: 0.6522
#
# Epoch 00012: val_matthews_correlation did not improve from 0.67433
# Epoch 13/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0920 - matthews_correlation: 0.6818 - val_loss: 0.1041 - val_matthews_correlation: 0.6522
#
# Epoch 00013: val_matthews_correlation did not improve from 0.67433
# Epoch 14/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0936 - matthews_correlation: 0.6976 - val_loss: 0.1002 - val_matthews_correlation: 0.6473
#
# Epoch 00014: val_matthews_correlation did not improve from 0.67433
# Epoch 15/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0920 - matthews_correlation: 0.6987 - val_loss: 0.0951 - val_matthews_correlation: 0.6382
#
# Epoch 00015: val_matthews_correlation did not improve from 0.67433
# Epoch 16/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0891 - matthews_correlation: 0.7193 - val_loss: 0.0998 - val_matthews_correlation: 0.6502
#
# Epoch 00016: val_matthews_correlation did not improve from 0.67433
# Epoch 17/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0861 - matthews_correlation: 0.7117 - val_loss: 0.0941 - val_matthews_correlation: 0.6875
#
# Epoch 00017: val_matthews_correlation improved from 0.67433 to 0.68748, saving model to weights_1.h5
# Epoch 18/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0927 - matthews_correlation: 0.7071 - val_loss: 0.0935 - val_matthews_correlation: 0.6454
#
# Epoch 00018: val_matthews_correlation did not improve from 0.68748
# Epoch 19/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0882 - matthews_correlation: 0.7163 - val_loss: 0.0958 - val_matthews_correlation: 0.6724
#
# Epoch 00019: val_matthews_correlation did not improve from 0.68748
# Epoch 20/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0852 - matthews_correlation: 0.7226 - val_loss: 0.0940 - val_matthews_correlation: 0.6502
#
# Epoch 00020: val_matthews_correlation did not improve from 0.68748
# Epoch 21/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0827 - matthews_correlation: 0.6812 - val_loss: 0.0942 - val_matthews_correlation: 0.6749
#
# Epoch 00021: val_matthews_correlation did not improve from 0.68748
# Epoch 22/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0819 - matthews_correlation: 0.7268 - val_loss: 0.0924 - val_matthews_correlation: 0.6971
#
# Epoch 00022: val_matthews_correlation improved from 0.68748 to 0.69714, saving model to weights_1.h5
# Epoch 23/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0898 - matthews_correlation: 0.7460 - val_loss: 0.0977 - val_matthews_correlation: 0.7280
#
# Epoch 00023: val_matthews_correlation improved from 0.69714 to 0.72798, saving model to weights_1.h5
# Epoch 24/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0900 - matthews_correlation: 0.6781 - val_loss: 0.1086 - val_matthews_correlation: 0.5458
#
# Epoch 00024: val_matthews_correlation did not improve from 0.72798
# Epoch 25/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0803 - matthews_correlation: 0.7383 - val_loss: 0.0811 - val_matthews_correlation: 0.7897
#
# Epoch 00025: val_matthews_correlation improved from 0.72798 to 0.78971, saving model to weights_1.h5
# Epoch 26/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0786 - matthews_correlation: 0.7218 - val_loss: 0.0894 - val_matthews_correlation: 0.6463
#
# Epoch 00026: val_matthews_correlation did not improve from 0.78971
# Epoch 27/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0783 - matthews_correlation: 0.6657 - val_loss: 0.0968 - val_matthews_correlation: 0.5894
#
# Epoch 00027: val_matthews_correlation did not improve from 0.78971
# Epoch 28/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0782 - matthews_correlation: 0.7024 - val_loss: 0.0907 - val_matthews_correlation: 0.6729
#
# Epoch 00028: val_matthews_correlation did not improve from 0.78971
# Epoch 29/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0784 - matthews_correlation: 0.7251 - val_loss: 0.0876 - val_matthews_correlation: 0.6440
#
# Epoch 00029: val_matthews_correlation did not improve from 0.78971
# Epoch 30/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0784 - matthews_correlation: 0.7386 - val_loss: 0.0992 - val_matthews_correlation: 0.5583
#
# Epoch 00030: val_matthews_correlation did not improve from 0.78971
# Epoch 31/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0914 - matthews_correlation: 0.6837 - val_loss: 0.0872 - val_matthews_correlation: 0.6500
#
# Epoch 00031: val_matthews_correlation did not improve from 0.78971
# Epoch 32/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0830 - matthews_correlation: 0.6578 - val_loss: 0.0777 - val_matthews_correlation: 0.7437
#
# Epoch 00032: val_matthews_correlation did not improve from 0.78971
# Epoch 33/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0907 - matthews_correlation: 0.5785 - val_loss: 0.0869 - val_matthews_correlation: 0.6659
#
# Epoch 00033: val_matthews_correlation did not improve from 0.78971
# Epoch 34/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0770 - matthews_correlation: 0.7268 - val_loss: 0.0946 - val_matthews_correlation: 0.6883
#
# Epoch 00034: val_matthews_correlation did not improve from 0.78971
# Epoch 35/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0747 - matthews_correlation: 0.7362 - val_loss: 0.0844 - val_matthews_correlation: 0.7094
#
# Epoch 00035: val_matthews_correlation did not improve from 0.78971
# Epoch 36/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0714 - matthews_correlation: 0.7405 - val_loss: 0.0843 - val_matthews_correlation: 0.7001
#
# Epoch 00036: val_matthews_correlation did not improve from 0.78971
# Epoch 37/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0793 - matthews_correlation: 0.7305 - val_loss: 0.0823 - val_matthews_correlation: 0.7277
#
# Epoch 00037: val_matthews_correlation did not improve from 0.78971
# Epoch 38/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0721 - matthews_correlation: 0.7844 - val_loss: 0.0875 - val_matthews_correlation: 0.6720
#
# Epoch 00038: val_matthews_correlation did not improve from 0.78971
# Epoch 39/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0685 - matthews_correlation: 0.7439 - val_loss: 0.0891 - val_matthews_correlation: 0.5872
#
# Epoch 00039: val_matthews_correlation did not improve from 0.78971
# Epoch 40/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0662 - matthews_correlation: 0.7500 - val_loss: 0.0959 - val_matthews_correlation: 0.6425
#
# Epoch 00040: val_matthews_correlation did not improve from 0.78971
# Epoch 41/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0640 - matthews_correlation: 0.7918 - val_loss: 0.0988 - val_matthews_correlation: 0.6325
#
# Epoch 00041: val_matthews_correlation did not improve from 0.78971
# Epoch 42/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0648 - matthews_correlation: 0.8002 - val_loss: 0.1196 - val_matthews_correlation: 0.4809
#
# Epoch 00042: val_matthews_correlation did not improve from 0.78971
# Epoch 43/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0651 - matthews_correlation: 0.7761 - val_loss: 0.0996 - val_matthews_correlation: 0.6390
#
# Epoch 00043: val_matthews_correlation did not improve from 0.78971
# Epoch 44/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0637 - matthews_correlation: 0.7531 - val_loss: 0.0965 - val_matthews_correlation: 0.6719
#
# Epoch 00044: val_matthews_correlation did not improve from 0.78971
# Epoch 45/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0675 - matthews_correlation: 0.7522 - val_loss: 0.0914 - val_matthews_correlation: 0.6472
#
# Epoch 00045: val_matthews_correlation did not improve from 0.78971
# Epoch 46/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0782 - matthews_correlation: 0.7317 - val_loss: 0.0786 - val_matthews_correlation: 0.7057
#
# Epoch 00046: val_matthews_correlation did not improve from 0.78971
# Epoch 47/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0708 - matthews_correlation: 0.6631 - val_loss: 0.1133 - val_matthews_correlation: 0.6198
#
# Epoch 00047: val_matthews_correlation did not improve from 0.78971
# Epoch 48/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0804 - matthews_correlation: 0.6810 - val_loss: 0.0908 - val_matthews_correlation: 0.6542
#
# Epoch 00048: val_matthews_correlation did not improve from 0.78971
# Epoch 49/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0682 - matthews_correlation: 0.7930 - val_loss: 0.1154 - val_matthews_correlation: 0.6432
#
# Epoch 00049: val_matthews_correlation did not improve from 0.78971
# Epoch 50/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0725 - matthews_correlation: 0.7672 - val_loss: 0.0876 - val_matthews_correlation: 0.7066
#
# Epoch 00050: val_matthews_correlation did not improve from 0.78971
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 28s 12ms/step - loss: 0.3369 - matthews_correlation: 0.0000e+00 - val_loss: 0.2231 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.1656 - matthews_correlation: 0.2421 - val_loss: 0.1301 - val_matthews_correlation: 0.6175
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.61752, saving model to weights_2.h5
# Epoch 3/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.1127 - matthews_correlation: 0.6100 - val_loss: 0.1159 - val_matthews_correlation: 0.6346
#
# Epoch 00003: val_matthews_correlation improved from 0.61752 to 0.63457, saving model to weights_2.h5
# Epoch 4/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.1069 - matthews_correlation: 0.6684 - val_loss: 0.1172 - val_matthews_correlation: 0.6502
#
# Epoch 00004: val_matthews_correlation improved from 0.63457 to 0.65024, saving model to weights_2.h5
# Epoch 5/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0976 - matthews_correlation: 0.6768 - val_loss: 0.1242 - val_matthews_correlation: 0.5533
#
# Epoch 00005: val_matthews_correlation did not improve from 0.65024
# Epoch 6/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0971 - matthews_correlation: 0.6822 - val_loss: 0.1165 - val_matthews_correlation: 0.5383
#
# Epoch 00006: val_matthews_correlation did not improve from 0.65024
# Epoch 7/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0982 - matthews_correlation: 0.6644 - val_loss: 0.1202 - val_matthews_correlation: 0.5319
#
# Epoch 00007: val_matthews_correlation did not improve from 0.65024
# Epoch 8/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.1036 - matthews_correlation: 0.6456 - val_loss: 0.1173 - val_matthews_correlation: 0.5265
#
# Epoch 00008: val_matthews_correlation did not improve from 0.65024
# Epoch 9/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0910 - matthews_correlation: 0.6879 - val_loss: 0.1152 - val_matthews_correlation: 0.4846
#
# Epoch 00009: val_matthews_correlation did not improve from 0.65024
# Epoch 10/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0902 - matthews_correlation: 0.6829 - val_loss: 0.1149 - val_matthews_correlation: 0.6236
#
# Epoch 00010: val_matthews_correlation did not improve from 0.65024
# Epoch 11/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0890 - matthews_correlation: 0.6771 - val_loss: 0.1139 - val_matthews_correlation: 0.4736
#
# Epoch 00011: val_matthews_correlation did not improve from 0.65024
# Epoch 12/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0914 - matthews_correlation: 0.6411 - val_loss: 0.1161 - val_matthews_correlation: 0.6272
#
# Epoch 00012: val_matthews_correlation did not improve from 0.65024
# Epoch 13/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0859 - matthews_correlation: 0.7271 - val_loss: 0.1118 - val_matthews_correlation: 0.5912
#
# Epoch 00013: val_matthews_correlation did not improve from 0.65024
# Epoch 14/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0841 - matthews_correlation: 0.7246 - val_loss: 0.1132 - val_matthews_correlation: 0.6014
#
# Epoch 00014: val_matthews_correlation did not improve from 0.65024
# Epoch 15/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0826 - matthews_correlation: 0.7221 - val_loss: 0.1179 - val_matthews_correlation: 0.6559
#
# Epoch 00015: val_matthews_correlation improved from 0.65024 to 0.65586, saving model to weights_2.h5
# Epoch 16/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0835 - matthews_correlation: 0.7092 - val_loss: 0.1137 - val_matthews_correlation: 0.6274
#
# Epoch 00016: val_matthews_correlation did not improve from 0.65586
# Epoch 17/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0954 - matthews_correlation: 0.5977 - val_loss: 0.1118 - val_matthews_correlation: 0.6473
#
# Epoch 00017: val_matthews_correlation did not improve from 0.65586
# Epoch 18/50
# 2323/2323 [==============================] - 25s 11ms/step - loss: 0.0837 - matthews_correlation: 0.6965 - val_loss: 0.1088 - val_matthews_correlation: 0.6279
#
# Epoch 00018: val_matthews_correlation did not improve from 0.65586
# Epoch 19/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0819 - matthews_correlation: 0.7271 - val_loss: 0.1091 - val_matthews_correlation: 0.6297
#
# Epoch 00019: val_matthews_correlation did not improve from 0.65586
# Epoch 20/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0786 - matthews_correlation: 0.7340 - val_loss: 0.1094 - val_matthews_correlation: 0.5870
#
# Epoch 00020: val_matthews_correlation did not improve from 0.65586
# Epoch 21/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0790 - matthews_correlation: 0.6975 - val_loss: 0.1141 - val_matthews_correlation: 0.5780
#
# Epoch 00021: val_matthews_correlation did not improve from 0.65586
# Epoch 22/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0755 - matthews_correlation: 0.7370 - val_loss: 0.1138 - val_matthews_correlation: 0.5315
#
# Epoch 00022: val_matthews_correlation did not improve from 0.65586
# Epoch 23/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0783 - matthews_correlation: 0.7573 - val_loss: 0.1215 - val_matthews_correlation: 0.6596
#
# Epoch 00023: val_matthews_correlation improved from 0.65586 to 0.65960, saving model to weights_2.h5
# Epoch 24/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0794 - matthews_correlation: 0.7288 - val_loss: 0.1157 - val_matthews_correlation: 0.5754
#
# Epoch 00024: val_matthews_correlation did not improve from 0.65960
# Epoch 25/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0774 - matthews_correlation: 0.7145 - val_loss: 0.1169 - val_matthews_correlation: 0.5526
#
# Epoch 00025: val_matthews_correlation did not improve from 0.65960
# Epoch 26/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0876 - matthews_correlation: 0.6353 - val_loss: 0.1150 - val_matthews_correlation: 0.5233
#
# Epoch 00026: val_matthews_correlation did not improve from 0.65960
# Epoch 27/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0792 - matthews_correlation: 0.7132 - val_loss: 0.1086 - val_matthews_correlation: 0.6334
#
# Epoch 00027: val_matthews_correlation did not improve from 0.65960
# Epoch 28/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0749 - matthews_correlation: 0.7751 - val_loss: 0.1059 - val_matthews_correlation: 0.5694
#
# Epoch 00028: val_matthews_correlation did not improve from 0.65960
# Epoch 29/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0750 - matthews_correlation: 0.7302 - val_loss: 0.1103 - val_matthews_correlation: 0.6196
#
# Epoch 00029: val_matthews_correlation did not improve from 0.65960
# Epoch 30/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0731 - matthews_correlation: 0.7287 - val_loss: 0.1155 - val_matthews_correlation: 0.6241
#
# Epoch 00030: val_matthews_correlation did not improve from 0.65960
# Epoch 31/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0751 - matthews_correlation: 0.7202 - val_loss: 0.1100 - val_matthews_correlation: 0.6001
#
# Epoch 00031: val_matthews_correlation did not improve from 0.65960
# Epoch 32/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0781 - matthews_correlation: 0.6846 - val_loss: 0.1146 - val_matthews_correlation: 0.4980
#
# Epoch 00032: val_matthews_correlation did not improve from 0.65960
# Epoch 33/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.0811 - matthews_correlation: 0.7027 - val_loss: 0.1090 - val_matthews_correlation: 0.6330
#
# Epoch 00033: val_matthews_correlation did not improve from 0.65960
# Epoch 34/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0716 - matthews_correlation: 0.7637 - val_loss: 0.1061 - val_matthews_correlation: 0.6423
#
# Epoch 00034: val_matthews_correlation did not improve from 0.65960
# Epoch 35/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0691 - matthews_correlation: 0.7494 - val_loss: 0.1051 - val_matthews_correlation: 0.5981
#
# Epoch 00035: val_matthews_correlation did not improve from 0.65960
# Epoch 36/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0714 - matthews_correlation: 0.7327 - val_loss: 0.1123 - val_matthews_correlation: 0.5725
#
# Epoch 00036: val_matthews_correlation did not improve from 0.65960
# Epoch 37/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0710 - matthews_correlation: 0.8007 - val_loss: 0.1181 - val_matthews_correlation: 0.6143
#
# Epoch 00037: val_matthews_correlation did not improve from 0.65960
# Epoch 38/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0711 - matthews_correlation: 0.7229 - val_loss: 0.1077 - val_matthews_correlation: 0.6565
#
# Epoch 00038: val_matthews_correlation did not improve from 0.65960
# Epoch 39/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0656 - matthews_correlation: 0.7745 - val_loss: 0.1077 - val_matthews_correlation: 0.6176
#
# Epoch 00039: val_matthews_correlation did not improve from 0.65960
# Epoch 40/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0624 - matthews_correlation: 0.7806 - val_loss: 0.1101 - val_matthews_correlation: 0.5577
#
# Epoch 00040: val_matthews_correlation did not improve from 0.65960
# Epoch 41/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0649 - matthews_correlation: 0.7307 - val_loss: 0.1274 - val_matthews_correlation: 0.5314
#
# Epoch 00041: val_matthews_correlation did not improve from 0.65960
# Epoch 42/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0702 - matthews_correlation: 0.7513 - val_loss: 0.1176 - val_matthews_correlation: 0.6663
#
# Epoch 00042: val_matthews_correlation improved from 0.65960 to 0.66631, saving model to weights_2.h5
# Epoch 43/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0712 - matthews_correlation: 0.7796 - val_loss: 0.1066 - val_matthews_correlation: 0.6238
#
# Epoch 00043: val_matthews_correlation did not improve from 0.66631
# Epoch 44/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.0672 - matthews_correlation: 0.7518 - val_loss: 0.1084 - val_matthews_correlation: 0.6210
#
# Epoch 00044: val_matthews_correlation did not improve from 0.66631
# Epoch 45/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0677 - matthews_correlation: 0.7501 - val_loss: 0.1201 - val_matthews_correlation: 0.5808
#
# Epoch 00045: val_matthews_correlation did not improve from 0.66631
# Epoch 46/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0687 - matthews_correlation: 0.7588 - val_loss: 0.1054 - val_matthews_correlation: 0.6210
#
# Epoch 00046: val_matthews_correlation did not improve from 0.66631
# Epoch 47/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0634 - matthews_correlation: 0.7830 - val_loss: 0.1203 - val_matthews_correlation: 0.6576
#
# Epoch 00047: val_matthews_correlation did not improve from 0.66631
# Epoch 48/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0600 - matthews_correlation: 0.7924 - val_loss: 0.1278 - val_matthews_correlation: 0.6870
#
# Epoch 00048: val_matthews_correlation improved from 0.66631 to 0.68698, saving model to weights_2.h5
# Epoch 49/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0687 - matthews_correlation: 0.7622 - val_loss: 0.1108 - val_matthews_correlation: 0.6762
#
# Epoch 00049: val_matthews_correlation did not improve from 0.68698
# Epoch 50/50
# 2323/2323 [==============================] - 23s 10ms/step - loss: 0.0694 - matthews_correlation: 0.7262 - val_loss: 0.1307 - val_matthews_correlation: 0.5785
#
# Epoch 00050: val_matthews_correlation did not improve from 0.68698
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 28s 12ms/step - loss: 0.3769 - matthews_correlation: 0.0000e+00 - val_loss: 0.2323 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.2249 - matthews_correlation: 0.0000e+00 - val_loss: 0.2044 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1717 - matthews_correlation: 0.2635 - val_loss: 0.1611 - val_matthews_correlation: 0.2902
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.29020, saving model to weights_3.h5
# Epoch 4/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1301 - matthews_correlation: 0.5280 - val_loss: 0.1174 - val_matthews_correlation: 0.4398
#
# Epoch 00004: val_matthews_correlation improved from 0.29020 to 0.43982, saving model to weights_3.h5
# Epoch 5/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1174 - matthews_correlation: 0.6064 - val_loss: 0.1126 - val_matthews_correlation: 0.5963
#
# Epoch 00005: val_matthews_correlation improved from 0.43982 to 0.59635, saving model to weights_3.h5
# Epoch 6/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1081 - matthews_correlation: 0.6057 - val_loss: 0.1120 - val_matthews_correlation: 0.6063
#
# Epoch 00006: val_matthews_correlation improved from 0.59635 to 0.60625, saving model to weights_3.h5
# Epoch 7/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.1066 - matthews_correlation: 0.6094 - val_loss: 0.1083 - val_matthews_correlation: 0.6340
#
# Epoch 00007: val_matthews_correlation improved from 0.60625 to 0.63404, saving model to weights_3.h5
# Epoch 8/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0995 - matthews_correlation: 0.6724 - val_loss: 0.1051 - val_matthews_correlation: 0.6467
#
# Epoch 00008: val_matthews_correlation improved from 0.63404 to 0.64673, saving model to weights_3.h5
# Epoch 9/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1037 - matthews_correlation: 0.6109 - val_loss: 0.1075 - val_matthews_correlation: 0.5327
#
# Epoch 00009: val_matthews_correlation did not improve from 0.64673
# Epoch 10/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0994 - matthews_correlation: 0.6888 - val_loss: 0.1041 - val_matthews_correlation: 0.6753
#
# Epoch 00010: val_matthews_correlation improved from 0.64673 to 0.67531, saving model to weights_3.h5
# Epoch 11/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1000 - matthews_correlation: 0.6882 - val_loss: 0.1008 - val_matthews_correlation: 0.6712
#
# Epoch 00011: val_matthews_correlation did not improve from 0.67531
# Epoch 12/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0941 - matthews_correlation: 0.6726 - val_loss: 0.0997 - val_matthews_correlation: 0.6712
#
# Epoch 00012: val_matthews_correlation did not improve from 0.67531
# Epoch 13/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0927 - matthews_correlation: 0.6829 - val_loss: 0.0987 - val_matthews_correlation: 0.5858
#
# Epoch 00013: val_matthews_correlation did not improve from 0.67531
# Epoch 14/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0908 - matthews_correlation: 0.6965 - val_loss: 0.0981 - val_matthews_correlation: 0.6369
#
# Epoch 00014: val_matthews_correlation did not improve from 0.67531
# Epoch 15/50
# 2324/2324 [==============================] - 22s 10ms/step - loss: 0.0919 - matthews_correlation: 0.6934 - val_loss: 0.0974 - val_matthews_correlation: 0.6537
# Epoch 00015: val_matthews_correlation did not improve from 0.67531
# Epoch 16/50
# 2324/2324 [==============================] - 22s 10ms/step - loss: 0.0943 - matthews_correlation: 0.7000 - val_loss: 0.1179 - val_matthews_correlation: 0.5013
#
# Epoch 00016: val_matthews_correlation did not improve from 0.67531
# Epoch 17/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0933 - matthews_correlation: 0.6911 - val_loss: 0.1052 - val_matthews_correlation: 0.5412
#
# Epoch 00017: val_matthews_correlation did not improve from 0.67531
# Epoch 18/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0893 - matthews_correlation: 0.6962 - val_loss: 0.1007 - val_matthews_correlation: 0.5783
#
# Epoch 00018: val_matthews_correlation did not improve from 0.67531
# Epoch 19/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0852 - matthews_correlation: 0.7133 - val_loss: 0.0974 - val_matthews_correlation: 0.6645
#
# Epoch 00019: val_matthews_correlation did not improve from 0.67531
# Epoch 20/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0843 - matthews_correlation: 0.7080 - val_loss: 0.0989 - val_matthews_correlation: 0.6684
#
# Epoch 00020: val_matthews_correlation did not improve from 0.67531
# Epoch 21/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0838 - matthews_correlation: 0.6930 - val_loss: 0.1011 - val_matthews_correlation: 0.6576
#
# Epoch 00021: val_matthews_correlation did not improve from 0.67531
# Epoch 22/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0873 - matthews_correlation: 0.6742 - val_loss: 0.0981 - val_matthews_correlation: 0.6085
#
# Epoch 00022: val_matthews_correlation did not improve from 0.67531
# Epoch 23/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0956 - matthews_correlation: 0.6583 - val_loss: 0.0993 - val_matthews_correlation: 0.6549
#
# Epoch 00023: val_matthews_correlation did not improve from 0.67531
# Epoch 24/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0850 - matthews_correlation: 0.7173 - val_loss: 0.0977 - val_matthews_correlation: 0.6712
#
# Epoch 00024: val_matthews_correlation did not improve from 0.67531
# Epoch 25/50
# 2324/2324 [==============================] - 25s 11ms/step - loss: 0.0832 - matthews_correlation: 0.7312 - val_loss: 0.1031 - val_matthews_correlation: 0.5986
#
# Epoch 00025: val_matthews_correlation did not improve from 0.67531
# Epoch 26/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0837 - matthews_correlation: 0.7560 - val_loss: 0.0990 - val_matthews_correlation: 0.6731
#
# Epoch 00026: val_matthews_correlation did not improve from 0.67531
# Epoch 27/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0843 - matthews_correlation: 0.6697 - val_loss: 0.0987 - val_matthews_correlation: 0.6399
#
# Epoch 00027: val_matthews_correlation did not improve from 0.67531
# Epoch 28/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0814 - matthews_correlation: 0.7158 - val_loss: 0.0962 - val_matthews_correlation: 0.6774
#
# Epoch 00028: val_matthews_correlation improved from 0.67531 to 0.67737, saving model to weights_3.h5
# Epoch 29/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0773 - matthews_correlation: 0.7557 - val_loss: 0.0957 - val_matthews_correlation: 0.6636
#
# Epoch 00029: val_matthews_correlation did not improve from 0.67737
# Epoch 30/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0769 - matthews_correlation: 0.7452 - val_loss: 0.0980 - val_matthews_correlation: 0.5718
#
# Epoch 00030: val_matthews_correlation did not improve from 0.67737
# Epoch 31/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0797 - matthews_correlation: 0.6677 - val_loss: 0.1056 - val_matthews_correlation: 0.6521
#
# Epoch 00031: val_matthews_correlation did not improve from 0.67737
# Epoch 32/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0794 - matthews_correlation: 0.7235 - val_loss: 0.1073 - val_matthews_correlation: 0.6351
#
# Epoch 00032: val_matthews_correlation did not improve from 0.67737
# Epoch 33/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0795 - matthews_correlation: 0.7055 - val_loss: 0.1039 - val_matthews_correlation: 0.6415
#
# Epoch 00033: val_matthews_correlation did not improve from 0.67737
# Epoch 34/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0742 - matthews_correlation: 0.7351 - val_loss: 0.0980 - val_matthews_correlation: 0.6886
#
# Epoch 00034: val_matthews_correlation improved from 0.67737 to 0.68865, saving model to weights_3.h5
# Epoch 35/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0771 - matthews_correlation: 0.7255 - val_loss: 0.0936 - val_matthews_correlation: 0.6331
#
# Epoch 00035: val_matthews_correlation did not improve from 0.68865
# Epoch 36/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0895 - matthews_correlation: 0.7248 - val_loss: 0.0966 - val_matthews_correlation: 0.5692
#
# Epoch 00036: val_matthews_correlation did not improve from 0.68865
# Epoch 37/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0774 - matthews_correlation: 0.7503 - val_loss: 0.0922 - val_matthews_correlation: 0.5965
#
# Epoch 00037: val_matthews_correlation did not improve from 0.68865
# Epoch 38/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0718 - matthews_correlation: 0.7554 - val_loss: 0.0927 - val_matthews_correlation: 0.6487
#
# Epoch 00038: val_matthews_correlation did not improve from 0.68865
# Epoch 39/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0716 - matthews_correlation: 0.6941 - val_loss: 0.0954 - val_matthews_correlation: 0.6780
#
# Epoch 00039: val_matthews_correlation did not improve from 0.68865
# Epoch 40/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0717 - matthews_correlation: 0.7617 - val_loss: 0.0897 - val_matthews_correlation: 0.6409
#
# Epoch 00040: val_matthews_correlation did not improve from 0.68865
# Epoch 41/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0710 - matthews_correlation: 0.7638 - val_loss: 0.0954 - val_matthews_correlation: 0.6192
#
# Epoch 00041: val_matthews_correlation did not improve from 0.68865
# Epoch 42/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0701 - matthews_correlation: 0.7355 - val_loss: 0.0959 - val_matthews_correlation: 0.6509
#
# Epoch 00042: val_matthews_correlation did not improve from 0.68865
# Epoch 43/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0709 - matthews_correlation: 0.6964 - val_loss: 0.0981 - val_matthews_correlation: 0.6488
#
# Epoch 00043: val_matthews_correlation did not improve from 0.68865
# Epoch 44/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0683 - matthews_correlation: 0.7698 - val_loss: 0.0898 - val_matthews_correlation: 0.7245
#
# Epoch 00044: val_matthews_correlation improved from 0.68865 to 0.72451, saving model to weights_3.h5
# Epoch 45/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0673 - matthews_correlation: 0.7589 - val_loss: 0.0903 - val_matthews_correlation: 0.6345
#
# Epoch 00045: val_matthews_correlation did not improve from 0.72451
# Epoch 46/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0632 - matthews_correlation: 0.7481 - val_loss: 0.0936 - val_matthews_correlation: 0.6590
#
# Epoch 00046: val_matthews_correlation did not improve from 0.72451
# Epoch 47/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0623 - matthews_correlation: 0.7752 - val_loss: 0.0890 - val_matthews_correlation: 0.6589
#
# Epoch 00047: val_matthews_correlation did not improve from 0.72451
# Epoch 48/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0599 - matthews_correlation: 0.7974 - val_loss: 0.0933 - val_matthews_correlation: 0.6638
#
# Epoch 00048: val_matthews_correlation did not improve from 0.72451
# Epoch 49/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0647 - matthews_correlation: 0.7660 - val_loss: 0.0902 - val_matthews_correlation: 0.6703
# Epoch 00049: val_matthews_correlation did not improve from 0.72451
# Epoch 50/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0674 - matthews_correlation: 0.7511 - val_loss: 0.0893 - val_matthews_correlation: 0.6924
#
# Epoch 00050: val_matthews_correlation did not improve from 0.72451
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 27s 12ms/step - loss: 0.3712 - matthews_correlation: 0.0000e+00 - val_loss: 0.2307 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.2279 - matthews_correlation: 0.0000e+00 - val_loss: 0.2065 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1768 - matthews_correlation: 0.1949 - val_loss: 0.1185 - val_matthews_correlation: 0.4517
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.45170, saving model to weights_4.h5
# Epoch 4/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.1216 - matthews_correlation: 0.4756 - val_loss: 0.1092 - val_matthews_correlation: 0.5604
#
# Epoch 00004: val_matthews_correlation improved from 0.45170 to 0.56036, saving model to weights_4.h5
# Epoch 5/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1107 - matthews_correlation: 0.5391 - val_loss: 0.1314 - val_matthews_correlation: 0.5989
#
# Epoch 00005: val_matthews_correlation improved from 0.56036 to 0.59895, saving model to weights_4.h5
# Epoch 6/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1071 - matthews_correlation: 0.6354 - val_loss: 0.1151 - val_matthews_correlation: 0.2861
#
# Epoch 00006: val_matthews_correlation did not improve from 0.59895
# Epoch 7/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0971 - matthews_correlation: 0.5836 - val_loss: 0.0970 - val_matthews_correlation: 0.6602
#
# Epoch 00007: val_matthews_correlation improved from 0.59895 to 0.66018, saving model to weights_4.h5
# Epoch 8/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1253 - matthews_correlation: 0.5117 - val_loss: 0.1380 - val_matthews_correlation: 0.3500
#
# Epoch 00008: val_matthews_correlation did not improve from 0.66018
# Epoch 9/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1467 - matthews_correlation: 0.2284 - val_loss: 0.1259 - val_matthews_correlation: 0.4769
#
# Epoch 00009: val_matthews_correlation did not improve from 0.66018
# Epoch 10/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1204 - matthews_correlation: 0.4998 - val_loss: 0.1128 - val_matthews_correlation: 0.5134
#
# Epoch 00010: val_matthews_correlation did not improve from 0.66018
# Epoch 11/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.1135 - matthews_correlation: 0.5709 - val_loss: 0.1057 - val_matthews_correlation: 0.6545
#
# Epoch 00011: val_matthews_correlation did not improve from 0.66018
# Epoch 12/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0959 - matthews_correlation: 0.6423 - val_loss: 0.0959 - val_matthews_correlation: 0.6843
#
# Epoch 00012: val_matthews_correlation improved from 0.66018 to 0.68425, saving model to weights_4.h5
# Epoch 13/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0931 - matthews_correlation: 0.6556 - val_loss: 0.0943 - val_matthews_correlation: 0.6868
#
# Epoch 00013: val_matthews_correlation improved from 0.68425 to 0.68681, saving model to weights_4.h5
# Epoch 14/50
# 2324/2324 [==============================] - 22s 10ms/step - loss: 0.0975 - matthews_correlation: 0.6549 - val_loss: 0.0960 - val_matthews_correlation: 0.6275
#
# Epoch 00014: val_matthews_correlation did not improve from 0.68681
# Epoch 15/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0961 - matthews_correlation: 0.6654 - val_loss: 0.0955 - val_matthews_correlation: 0.6894
#
# Epoch 00015: val_matthews_correlation improved from 0.68681 to 0.68939, saving model to weights_4.h5
# Epoch 16/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0908 - matthews_correlation: 0.6508 - val_loss: 0.1069 - val_matthews_correlation: 0.3865
#
# Epoch 00016: val_matthews_correlation did not improve from 0.68939
# Epoch 17/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0885 - matthews_correlation: 0.6541 - val_loss: 0.0958 - val_matthews_correlation: 0.6411
#
# Epoch 00017: val_matthews_correlation did not improve from 0.68939
# Epoch 18/50
# 2324/2324 [==============================] - 22s 10ms/step - loss: 0.0829 - matthews_correlation: 0.7111 - val_loss: 0.0999 - val_matthews_correlation: 0.4398
#
# Epoch 00018: val_matthews_correlation did not improve from 0.68939
# Epoch 19/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0824 - matthews_correlation: 0.6952 - val_loss: 0.0991 - val_matthews_correlation: 0.4489
#
# Epoch 00019: val_matthews_correlation did not improve from 0.68939
# Epoch 20/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0788 - matthews_correlation: 0.7079 - val_loss: 0.1298 - val_matthews_correlation: 0.4199
#
# Epoch 00020: val_matthews_correlation did not improve from 0.68939
# Epoch 21/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0961 - matthews_correlation: 0.6412 - val_loss: 0.1119 - val_matthews_correlation: 0.5840
#
# Epoch 00021: val_matthews_correlation did not improve from 0.68939
# Epoch 22/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0880 - matthews_correlation: 0.6769 - val_loss: 0.1088 - val_matthews_correlation: 0.5493
#
# Epoch 00022: val_matthews_correlation did not improve from 0.68939
# Epoch 23/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0856 - matthews_correlation: 0.6836 - val_loss: 0.1048 - val_matthews_correlation: 0.6503
#
# Epoch 00023: val_matthews_correlation did not improve from 0.68939
# Epoch 24/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0820 - matthews_correlation: 0.7215 - val_loss: 0.1028 - val_matthews_correlation: 0.6737
#
# Epoch 00024: val_matthews_correlation did not improve from 0.68939
# Epoch 25/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0770 - matthews_correlation: 0.7327 - val_loss: 0.1105 - val_matthews_correlation: 0.5662
#
# Epoch 00025: val_matthews_correlation did not improve from 0.68939
# Epoch 26/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0979 - matthews_correlation: 0.6274 - val_loss: 0.0981 - val_matthews_correlation: 0.5927
#
# Epoch 00026: val_matthews_correlation did not improve from 0.68939
# Epoch 27/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0883 - matthews_correlation: 0.6321 - val_loss: 0.1022 - val_matthews_correlation: 0.4953
#
# Epoch 00027: val_matthews_correlation did not improve from 0.68939
# Epoch 28/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0812 - matthews_correlation: 0.6931 - val_loss: 0.1100 - val_matthews_correlation: 0.5319
#
# Epoch 00028: val_matthews_correlation did not improve from 0.68939
# Epoch 29/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0798 - matthews_correlation: 0.6975 - val_loss: 0.0942 - val_matthews_correlation: 0.6017
#
# Epoch 00029: val_matthews_correlation did not improve from 0.68939
# Epoch 30/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0774 - matthews_correlation: 0.7182 - val_loss: 0.0997 - val_matthews_correlation: 0.5941
#
# Epoch 00030: val_matthews_correlation did not improve from 0.68939
# Epoch 31/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0779 - matthews_correlation: 0.7131 - val_loss: 0.1028 - val_matthews_correlation: 0.5429
#
# Epoch 00031: val_matthews_correlation did not improve from 0.68939
# Epoch 32/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0726 - matthews_correlation: 0.7008 - val_loss: 0.0953 - val_matthews_correlation: 0.6578
# Epoch 00032: val_matthews_correlation did not improve from 0.68939
# Epoch 33/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0831 - matthews_correlation: 0.7350 - val_loss: 0.1074 - val_matthews_correlation: 0.5566
#
# Epoch 00033: val_matthews_correlation did not improve from 0.68939
# Epoch 34/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0757 - matthews_correlation: 0.7605 - val_loss: 0.1132 - val_matthews_correlation: 0.5683
#
# Epoch 00034: val_matthews_correlation did not improve from 0.68939
# Epoch 35/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0764 - matthews_correlation: 0.7199 - val_loss: 0.1053 - val_matthews_correlation: 0.6448
#
# Epoch 00035: val_matthews_correlation did not improve from 0.68939
# Epoch 36/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0792 - matthews_correlation: 0.7366 - val_loss: 0.1057 - val_matthews_correlation: 0.6071
#
# Epoch 00036: val_matthews_correlation did not improve from 0.68939
# Epoch 37/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0786 - matthews_correlation: 0.7187 - val_loss: 0.1010 - val_matthews_correlation: 0.5402
#
# Epoch 00037: val_matthews_correlation did not improve from 0.68939
# Epoch 38/50
# 2324/2324 [==============================] - 22s 10ms/step - loss: 0.0722 - matthews_correlation: 0.7290 - val_loss: 0.1114 - val_matthews_correlation: 0.6007
#
# Epoch 00038: val_matthews_correlation did not improve from 0.68939
# Epoch 39/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0718 - matthews_correlation: 0.7226 - val_loss: 0.0967 - val_matthews_correlation: 0.5700
#
# Epoch 00039: val_matthews_correlation did not improve from 0.68939
# Epoch 40/50
# 2324/2324 [==============================] - 22s 10ms/step - loss: 0.0705 - matthews_correlation: 0.6943 - val_loss: 0.1037 - val_matthews_correlation: 0.6537
#
# Epoch 00040: val_matthews_correlation did not improve from 0.68939
# Epoch 41/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0749 - matthews_correlation: 0.7106 - val_loss: 0.1024 - val_matthews_correlation: 0.6141
#
# Epoch 00041: val_matthews_correlation did not improve from 0.68939
# Epoch 42/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0721 - matthews_correlation: 0.7671 - val_loss: 0.1076 - val_matthews_correlation: 0.4609
#
# Epoch 00042: val_matthews_correlation did not improve from 0.68939
# Epoch 43/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0868 - matthews_correlation: 0.7139 - val_loss: 0.1309 - val_matthews_correlation: 0.4968
#
# Epoch 00043: val_matthews_correlation did not improve from 0.68939
# Epoch 44/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0834 - matthews_correlation: 0.7052 - val_loss: 0.1076 - val_matthews_correlation: 0.6068
#
# Epoch 00044: val_matthews_correlation did not improve from 0.68939
# Epoch 45/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0708 - matthews_correlation: 0.7600 - val_loss: 0.1107 - val_matthews_correlation: 0.5682
#
# Epoch 00045: val_matthews_correlation did not improve from 0.68939
# Epoch 46/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0833 - matthews_correlation: 0.6972 - val_loss: 0.1361 - val_matthews_correlation: 0.4987
#
# Epoch 00046: val_matthews_correlation did not improve from 0.68939
# Epoch 47/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0842 - matthews_correlation: 0.6973 - val_loss: 0.1311 - val_matthews_correlation: 0.3716
#
# Epoch 00047: val_matthews_correlation did not improve from 0.68939
# Epoch 48/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0765 - matthews_correlation: 0.6940 - val_loss: 0.1076 - val_matthews_correlation: 0.5202
#
# Epoch 00048: val_matthews_correlation did not improve from 0.68939
# Epoch 49/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.0733 - matthews_correlation: 0.7731 - val_loss: 0.1068 - val_matthews_correlation: 0.6368
#
# Epoch 00049: val_matthews_correlation did not improve from 0.68939
# Epoch 50/50
# 2324/2324 [==============================] - 24s 10ms/step - loss: 0.0698 - matthews_correlation: 0.7372 - val_loss: 0.1027 - val_matthews_correlation: 0.5772
#
# Epoch 00050: val_matthews_correlation did not improve from 0.68939
# ((2904,), (2904,))

# %%
np.save('./tmp/y_val_tmp_6.npy', y_val)
np.save('./tmp/preds_val_tmp_6.npy', preds_val)

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    
    #y_pred = K.cast(y_pred, np.float)
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = np.round(np.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)

    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        #score = matthews_correlation(y_true, (y_proba > threshold).astype(int))
        #score = K.eval(matthews_correlation(y_true, (y_proba > threshold).astype(int)))
        #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        score = matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 9416.94it/s]

# %%
best_threshold
# Out:
# 0.48

# %%
matthews_correlation(y_val[:582], preds_val[:582])
# Out:
# 0.8154950512574061

# %%
matthews_correlation(y_val, preds_val)
# Out:
# 0.7437214286793025

# %%
threshold_search(y_val[:582], preds_val[:582])['threshold']
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 14573.68it/s]
# 0.5

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')
df_test = meta_test.set_index(['id_measurement', 'phase'])
# Out:
# CPU times: user 14.9 ms, sys: 1.88 ms, total: 16.7 ms
# Wall time: 45.5 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data_test(start, end):
    # load a piece of data from file
    praq_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start+8712, end+8712)]).to_pandas()
    X = []

    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_test.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id = df_test.loc[id_measurement].loc[phase][0]
            # but just append the target one time, to not triplicate it
            
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_test[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    return X

# %%
def process_subtest(arg_tuple):
    start, end, idx = arg_tuple
    X = prep_data_test(start, end)
    return idx, X

# %%
all_chunks = []

num_cores = 16 
#def load_all():
total_size = len(meta_test)
chunk_size = np.ceil(total_size/num_cores)
#train_size = len(df_train)

for i in range(16):
    if i != 15:
        start_idx = int(i * chunk_size)
        end_idx = int(start_idx + chunk_size)
        #chunk = (start_idx+train_size, end_idx+train_size, i)
        chunk = (start_idx, end_idx, i)
        all_chunks.append(chunk)
    else:
        start_idx = int(i * chunk_size)
        end_idx = int(total_size)
        #chunk = (start_idx+train_size, end_idx+train_size, i)
        chunk = (start_idx, end_idx, i)
        all_chunks.append(chunk)

# %%
pool = Pool()
results_1 = pool.map(process_subtest, all_chunks[0:8])    
results_1 = sorted(results_1, key=lambda tup: tup[0])
# Out:
# 100%|██████████| 424/424 [16:24<00:00,  2.07s/it]
# 100%|██████████| 424/424 [16:25<00:00,  2.31s/it]
# 100%|██████████| 424/424 [18:04<00:00,  1.25s/it]
# 100%|██████████| 424/424 [18:14<00:00,  1.14s/it]
# 100%|██████████| 424/424 [18:18<00:00,  3.11s/it]
# 100%|██████████| 424/424 [18:29<00:00,  1.23it/s]
# 100%|██████████| 424/424 [18:35<00:00,  1.35it/s]
# 100%|██████████| 424/424 [19:02<00:00,  1.22s/it]
# 100%|██████████| 424/424 [15:51<00:00,  3.53s/it]
# 100%|██████████| 424/424 [17:05<00:00,  5.07s/it]
#  88%|████████▊ | 374/424 [17:08<02:02,  2.46s/it]
# 100%|██████████| 419/419 [17:08<00:00,  2.13s/it]
# 100%|██████████| 424/424 [17:21<00:00,  1.72s/it]
# 100%|██████████| 424/424 [17:59<00:00,  1.21it/s]
# 100%|██████████| 424/424 [18:02<00:00,  1.16s/it]
# 100%|██████████| 424/424 [18:24<00:00,  1.33s/it]

# %%
results_2 = pool.map(process_subtest, all_chunks[8:16])    
results_2 = sorted(results_2, key=lambda tup: tup[0])

# %%
results = results_1 + results_2
X_test = np.concatenate([item[1] for item in results], axis=0)

# %%
np.save("X_test_4.npy",X_test)

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %% [markdown]
# splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
#
# for idx, (train_idx, val_idx) in enumerate(splits):
#     K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
#     print("Beginning fold {}".format(idx+1))
#     # use the indexes to extract the folds in the train and validation data
#     train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
#     # instantiate the model for this fold
#     model = model_lstm(train_X.shape)

# %%
X_test[np.isnan(X_test)] = 0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 17s 2ms/step
# 6779/6779 [==============================] - 17s 2ms/step
# 6779/6779 [==============================] - 17s 2ms/step
# 6779/6779 [==============================] - 17s 2ms/step
# 6779/6779 [==============================] - 17s 2ms/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('../output/submission_21.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
lstm_preds = np.squeeze(np.mean(preds_test, axis=0))
np.save("./lstm_preds.npy", lstm_preds)

# %%
np.sum(preds_test[preds_test==1])
# Out:
# 933

# %%
submission['target'].value_counts()
# Out:
# 0    19404
# 1      933
# Name: target, dtype: int64

# %%
model.load_weights('weights_0.h5')
pred = model.predict(X_test, batch_size=300, verbose=1)
pred_3 = []
for pred_scalar in pred:
    for i in range(3):
        pred_3.append(pred_scalar)
# Out:
# 6779/6779 [==============================] - 17s 2ms/step

# %%
pred_3>0.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-5823f4244eaa> in <module>()
# ----> 1 pred_3>0.5
#
# TypeError: '>' not supported between instances of 'list' and 'float'

# %%
preds_3 = (np.squeeze(pred_3) > 0.5).astype(np.int)

# %%
np.sum(preds_3[preds_3==1])
# Out:
# 1209

# %%
submission['target'] = preds_3
submission.to_csv('../output/submission_22.csv', index=False)

# %%
submission['target'].value_counts()
# Out:
# 0    19128
# 1     1209
# Name: target, dtype: int64
