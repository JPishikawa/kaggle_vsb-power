# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
# Out:
# /home/cwademo123/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    
    y_pred = K.cast(y_pred, np.float)
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        # now, we just add all the features to new_ts and convert it to np.array
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
# 100%|██████████| 1452/1452 [06:40<00:00,  3.62it/s]
# 100%|██████████| 1452/1452 [06:08<00:00,  3.78it/s]

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
# Out:
# (2904, 160, 57) (2904,)

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(LSTM(128, return_sequences=True))(inp)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64, activation="relu")(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 27s 12ms/step - loss: 0.3637 - matthews_correlation: -0.0104 - val_loss: 0.2639 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.2331 - matthews_correlation: 0.0000e+00 - val_loss: 0.2219 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.2119 - matthews_correlation: 0.0000e+00 - val_loss: 0.2156 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.2080 - matthews_correlation: 0.0000e+00 - val_loss: 0.2068 - val_matthews_correlation: 0.1930
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.19302, saving model to weights_0.h5
# Epoch 5/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1944 - matthews_correlation: 0.2061 - val_loss: 0.1915 - val_matthews_correlation: 0.1923
#
# Epoch 00005: val_matthews_correlation did not improve from 0.19302
# Epoch 6/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1782 - matthews_correlation: 0.2750 - val_loss: 0.1756 - val_matthews_correlation: 0.2638
#
# Epoch 00006: val_matthews_correlation improved from 0.19302 to 0.26381, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1716 - matthews_correlation: 0.0234 - val_loss: 0.1668 - val_matthews_correlation: 0.2192
#
# Epoch 00007: val_matthews_correlation did not improve from 0.26381
# Epoch 8/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1493 - matthews_correlation: 0.3743 - val_loss: 0.1201 - val_matthews_correlation: 0.6526
#
# Epoch 00008: val_matthews_correlation improved from 0.26381 to 0.65264, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 22s 10ms/step - loss: 0.1449 - matthews_correlation: 0.3888 - val_loss: 0.1328 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.65264
# Epoch 10/50
# 2322/2322 [==============================] - 22s 10ms/step - loss: 0.1220 - matthews_correlation: 0.4403 - val_loss: 0.1018 - val_matthews_correlation: 0.6804
#
# Epoch 00010: val_matthews_correlation improved from 0.65264 to 0.68036, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1169 - matthews_correlation: 0.5860 - val_loss: 0.1406 - val_matthews_correlation: 0.6639
#
# Epoch 00011: val_matthews_correlation did not improve from 0.68036
# Epoch 12/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1229 - matthews_correlation: 0.5688 - val_loss: 0.0909 - val_matthews_correlation: 0.7020
#
# Epoch 00012: val_matthews_correlation improved from 0.68036 to 0.70197, saving model to weights_0.h5
# Epoch 13/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1139 - matthews_correlation: 0.5976 - val_loss: 0.0913 - val_matthews_correlation: 0.7330
#
# Epoch 00013: val_matthews_correlation improved from 0.70197 to 0.73303, saving model to weights_0.h5
# Epoch 14/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1128 - matthews_correlation: 0.6254 - val_loss: 0.1126 - val_matthews_correlation: 0.7418
#
# Epoch 00014: val_matthews_correlation improved from 0.73303 to 0.74177, saving model to weights_0.h5
# Epoch 15/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1074 - matthews_correlation: 0.5862 - val_loss: 0.0868 - val_matthews_correlation: 0.7367
#
# Epoch 00015: val_matthews_correlation did not improve from 0.74177
# Epoch 16/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1112 - matthews_correlation: 0.5288 - val_loss: 0.1221 - val_matthews_correlation: 0.6703
#
# Epoch 00016: val_matthews_correlation did not improve from 0.74177
# Epoch 17/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1102 - matthews_correlation: 0.5607 - val_loss: 0.0910 - val_matthews_correlation: 0.7297
#
# Epoch 00017: val_matthews_correlation did not improve from 0.74177
# Epoch 18/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1084 - matthews_correlation: 0.6256 - val_loss: 0.0890 - val_matthews_correlation: 0.7184
#
# Epoch 00018: val_matthews_correlation did not improve from 0.74177
# Epoch 19/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1014 - matthews_correlation: 0.6541 - val_loss: 0.1110 - val_matthews_correlation: 0.7104
#
# Epoch 00019: val_matthews_correlation did not improve from 0.74177
# Epoch 20/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1143 - matthews_correlation: 0.5692 - val_loss: 0.0978 - val_matthews_correlation: 0.7381
#
# Epoch 00020: val_matthews_correlation did not improve from 0.74177
# Epoch 21/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1085 - matthews_correlation: 0.5332 - val_loss: 0.0884 - val_matthews_correlation: 0.6877
#
# Epoch 00021: val_matthews_correlation did not improve from 0.74177
# Epoch 22/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1046 - matthews_correlation: 0.5962 - val_loss: 0.0912 - val_matthews_correlation: 0.7157
#
# Epoch 00022: val_matthews_correlation did not improve from 0.74177
# Epoch 23/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0959 - matthews_correlation: 0.6683 - val_loss: 0.0797 - val_matthews_correlation: 0.7133
#
# Epoch 00023: val_matthews_correlation did not improve from 0.74177
# Epoch 24/50
# 2322/2322 [==============================] - 24s 11ms/step - loss: 0.0955 - matthews_correlation: 0.6749 - val_loss: 0.0873 - val_matthews_correlation: 0.7543
#
# Epoch 00024: val_matthews_correlation improved from 0.74177 to 0.75427, saving model to weights_0.h5
# Epoch 25/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1007 - matthews_correlation: 0.6208 - val_loss: 0.0904 - val_matthews_correlation: 0.7338
#
# Epoch 00025: val_matthews_correlation did not improve from 0.75427
# Epoch 26/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0962 - matthews_correlation: 0.6296 - val_loss: 0.0945 - val_matthews_correlation: 0.7297
#
# Epoch 00026: val_matthews_correlation did not improve from 0.75427
# Epoch 27/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0967 - matthews_correlation: 0.6928 - val_loss: 0.0808 - val_matthews_correlation: 0.7468
#
# Epoch 00027: val_matthews_correlation did not improve from 0.75427
# Epoch 28/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0942 - matthews_correlation: 0.6314 - val_loss: 0.0868 - val_matthews_correlation: 0.7304
#
# Epoch 00028: val_matthews_correlation did not improve from 0.75427
# Epoch 29/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0995 - matthews_correlation: 0.6489 - val_loss: 0.0936 - val_matthews_correlation: 0.7101
#
# Epoch 00029: val_matthews_correlation did not improve from 0.75427
# Epoch 30/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1107 - matthews_correlation: 0.6029 - val_loss: 0.1060 - val_matthews_correlation: 0.5043
#
# Epoch 00030: val_matthews_correlation did not improve from 0.75427
# Epoch 31/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1097 - matthews_correlation: 0.5771 - val_loss: 0.0815 - val_matthews_correlation: 0.7350
#
# Epoch 00031: val_matthews_correlation did not improve from 0.75427
# Epoch 32/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0927 - matthews_correlation: 0.6275 - val_loss: 0.0764 - val_matthews_correlation: 0.7673
#
# Epoch 00032: val_matthews_correlation improved from 0.75427 to 0.76731, saving model to weights_0.h5
# Epoch 33/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0933 - matthews_correlation: 0.6738 - val_loss: 0.0872 - val_matthews_correlation: 0.6522
# Epoch 00033: val_matthews_correlation did not improve from 0.76731
# Epoch 34/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0927 - matthews_correlation: 0.6353 - val_loss: 0.0774 - val_matthews_correlation: 0.7320
#
# Epoch 00034: val_matthews_correlation did not improve from 0.76731
# Epoch 35/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0862 - matthews_correlation: 0.7149 - val_loss: 0.0846 - val_matthews_correlation: 0.7058
#
# Epoch 00035: val_matthews_correlation did not improve from 0.76731
# Epoch 36/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0921 - matthews_correlation: 0.7307 - val_loss: 0.0836 - val_matthews_correlation: 0.7406
#
# Epoch 00036: val_matthews_correlation did not improve from 0.76731
# Epoch 37/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1058 - matthews_correlation: 0.6268 - val_loss: 0.0811 - val_matthews_correlation: 0.7036
#
# Epoch 00037: val_matthews_correlation did not improve from 0.76731
# Epoch 38/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0923 - matthews_correlation: 0.6541 - val_loss: 0.0828 - val_matthews_correlation: 0.7299
#
# Epoch 00038: val_matthews_correlation did not improve from 0.76731
# Epoch 39/50
# 2322/2322 [==============================] - 24s 10ms/step - loss: 0.0876 - matthews_correlation: 0.7109 - val_loss: 0.0760 - val_matthews_correlation: 0.7320
#
# Epoch 00039: val_matthews_correlation did not improve from 0.76731
# Epoch 40/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0840 - matthews_correlation: 0.6969 - val_loss: 0.0771 - val_matthews_correlation: 0.7244
#
# Epoch 00040: val_matthews_correlation did not improve from 0.76731
# Epoch 41/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0931 - matthews_correlation: 0.6335 - val_loss: 0.0942 - val_matthews_correlation: 0.7489
#
# Epoch 00041: val_matthews_correlation did not improve from 0.76731
# Epoch 42/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0938 - matthews_correlation: 0.6883 - val_loss: 0.0802 - val_matthews_correlation: 0.7936
#
# Epoch 00042: val_matthews_correlation improved from 0.76731 to 0.79357, saving model to weights_0.h5
# Epoch 43/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0921 - matthews_correlation: 0.6620 - val_loss: 0.0823 - val_matthews_correlation: 0.7694
#
# Epoch 00043: val_matthews_correlation did not improve from 0.79357
# Epoch 44/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0914 - matthews_correlation: 0.6856 - val_loss: 0.0808 - val_matthews_correlation: 0.7050
#
# Epoch 00044: val_matthews_correlation did not improve from 0.79357
# Epoch 45/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0889 - matthews_correlation: 0.6794 - val_loss: 0.0790 - val_matthews_correlation: 0.7103
#
# Epoch 00045: val_matthews_correlation did not improve from 0.79357
# Epoch 46/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0884 - matthews_correlation: 0.6705 - val_loss: 0.0823 - val_matthews_correlation: 0.7165
#
# Epoch 00046: val_matthews_correlation did not improve from 0.79357
# Epoch 47/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0868 - matthews_correlation: 0.6848 - val_loss: 0.0830 - val_matthews_correlation: 0.6325
#
# Epoch 00047: val_matthews_correlation did not improve from 0.79357
# Epoch 48/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0863 - matthews_correlation: 0.6576 - val_loss: 0.0792 - val_matthews_correlation: 0.7209
#
# Epoch 00048: val_matthews_correlation did not improve from 0.79357
# Epoch 49/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0892 - matthews_correlation: 0.6952 - val_loss: 0.1171 - val_matthews_correlation: 0.6569
#
# Epoch 00049: val_matthews_correlation did not improve from 0.79357
# Epoch 50/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0945 - matthews_correlation: 0.6399 - val_loss: 0.0921 - val_matthews_correlation: 0.7060
#
# Epoch 00050: val_matthews_correlation did not improve from 0.79357
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 25s 11ms/step - loss: 0.3882 - matthews_correlation: -0.0018 - val_loss: 0.2356 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2305 - matthews_correlation: 0.0000e+00 - val_loss: 0.2299 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.2248 - matthews_correlation: 0.0000e+00 - val_loss: 0.2256 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2107 - matthews_correlation: 0.0000e+00 - val_loss: 0.2380 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2069 - matthews_correlation: 0.0985 - val_loss: 0.2183 - val_matthews_correlation: 0.0716
#
# Epoch 00005: val_matthews_correlation improved from 0.00000 to 0.07157, saving model to weights_1.h5
# Epoch 6/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1961 - matthews_correlation: 0.2611 - val_loss: 0.1981 - val_matthews_correlation: 0.0716
#
# Epoch 00006: val_matthews_correlation did not improve from 0.07157
# Epoch 7/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1931 - matthews_correlation: 0.1874 - val_loss: 0.2010 - val_matthews_correlation: 0.0496
#
# Epoch 00007: val_matthews_correlation did not improve from 0.07157
# Epoch 8/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1925 - matthews_correlation: 0.2160 - val_loss: 0.1913 - val_matthews_correlation: 0.1045
#
# Epoch 00008: val_matthews_correlation improved from 0.07157 to 0.10453, saving model to weights_1.h5
# Epoch 9/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1844 - matthews_correlation: 0.3390 - val_loss: 0.1927 - val_matthews_correlation: 0.1034
#
# Epoch 00009: val_matthews_correlation did not improve from 0.10453
# Epoch 10/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1817 - matthews_correlation: 0.1288 - val_loss: 0.1846 - val_matthews_correlation: 0.2008
#
# Epoch 00010: val_matthews_correlation improved from 0.10453 to 0.20083, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1830 - matthews_correlation: 0.3205 - val_loss: 0.1825 - val_matthews_correlation: 0.1121
#
# Epoch 00011: val_matthews_correlation did not improve from 0.20083
# Epoch 12/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1847 - matthews_correlation: 0.4272 - val_loss: 0.1784 - val_matthews_correlation: 0.2072
#
# Epoch 00012: val_matthews_correlation improved from 0.20083 to 0.20718, saving model to weights_1.h5
# Epoch 13/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1404 - matthews_correlation: 0.4865 - val_loss: 0.1702 - val_matthews_correlation: 0.4197
#
# Epoch 00013: val_matthews_correlation improved from 0.20718 to 0.41974, saving model to weights_1.h5
# Epoch 14/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1475 - matthews_correlation: 0.4983 - val_loss: 0.1468 - val_matthews_correlation: 0.2974
#
# Epoch 00014: val_matthews_correlation did not improve from 0.41974
# Epoch 15/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1202 - matthews_correlation: 0.5714 - val_loss: 0.1182 - val_matthews_correlation: 0.6114
#
# Epoch 00015: val_matthews_correlation improved from 0.41974 to 0.61138, saving model to weights_1.h5
# Epoch 16/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1194 - matthews_correlation: 0.6067 - val_loss: 0.1213 - val_matthews_correlation: 0.6658
# Epoch 00016: val_matthews_correlation improved from 0.61138 to 0.66585, saving model to weights_1.h5
# Epoch 17/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1109 - matthews_correlation: 0.6355 - val_loss: 0.1110 - val_matthews_correlation: 0.6140
#
# Epoch 00017: val_matthews_correlation did not improve from 0.66585
# Epoch 18/50
# 2323/2323 [==============================] - 22s 10ms/step - loss: 0.1024 - matthews_correlation: 0.6532 - val_loss: 0.1157 - val_matthews_correlation: 0.6598
#
# Epoch 00018: val_matthews_correlation did not improve from 0.66585
# Epoch 19/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1201 - matthews_correlation: 0.5738 - val_loss: 0.1194 - val_matthews_correlation: 0.6564
#
# Epoch 00019: val_matthews_correlation did not improve from 0.66585
# Epoch 20/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1086 - matthews_correlation: 0.6344 - val_loss: 0.1142 - val_matthews_correlation: 0.5795
#
# Epoch 00020: val_matthews_correlation did not improve from 0.66585
# Epoch 21/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1114 - matthews_correlation: 0.6011 - val_loss: 0.1331 - val_matthews_correlation: 0.6278
#
# Epoch 00021: val_matthews_correlation did not improve from 0.66585
# Epoch 22/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1110 - matthews_correlation: 0.5511 - val_loss: 0.1080 - val_matthews_correlation: 0.6348
#
# Epoch 00022: val_matthews_correlation did not improve from 0.66585
# Epoch 23/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1039 - matthews_correlation: 0.6630 - val_loss: 0.1059 - val_matthews_correlation: 0.6732
#
# Epoch 00023: val_matthews_correlation improved from 0.66585 to 0.67323, saving model to weights_1.h5
# Epoch 24/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0960 - matthews_correlation: 0.6733 - val_loss: 0.1029 - val_matthews_correlation: 0.6796
#
# Epoch 00024: val_matthews_correlation improved from 0.67323 to 0.67964, saving model to weights_1.h5
# Epoch 25/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0926 - matthews_correlation: 0.6444 - val_loss: 0.1031 - val_matthews_correlation: 0.6538
#
# Epoch 00025: val_matthews_correlation did not improve from 0.67964
# Epoch 26/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0951 - matthews_correlation: 0.6314 - val_loss: 0.1083 - val_matthews_correlation: 0.6303
#
# Epoch 00026: val_matthews_correlation did not improve from 0.67964
# Epoch 27/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0962 - matthews_correlation: 0.7024 - val_loss: 0.1031 - val_matthews_correlation: 0.6752
#
# Epoch 00027: val_matthews_correlation did not improve from 0.67964
# Epoch 28/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1012 - matthews_correlation: 0.6715 - val_loss: 0.1069 - val_matthews_correlation: 0.6815
#
# Epoch 00028: val_matthews_correlation improved from 0.67964 to 0.68147, saving model to weights_1.h5
# Epoch 29/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0905 - matthews_correlation: 0.6807 - val_loss: 0.0940 - val_matthews_correlation: 0.7178
#
# Epoch 00029: val_matthews_correlation improved from 0.68147 to 0.71785, saving model to weights_1.h5
# Epoch 30/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0936 - matthews_correlation: 0.6715 - val_loss: 0.1111 - val_matthews_correlation: 0.7058
#
# Epoch 00030: val_matthews_correlation did not improve from 0.71785
# Epoch 31/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0968 - matthews_correlation: 0.6753 - val_loss: 0.1006 - val_matthews_correlation: 0.6667
#
# Epoch 00031: val_matthews_correlation did not improve from 0.71785
# Epoch 32/50
# 2323/2323 [==============================] - 22s 9ms/step - loss: 0.0957 - matthews_correlation: 0.6799 - val_loss: 0.0905 - val_matthews_correlation: 0.6799
#
# Epoch 00032: val_matthews_correlation did not improve from 0.71785
# Epoch 33/50
# 2323/2323 [==============================] - 22s 9ms/step - loss: 0.0902 - matthews_correlation: 0.6762 - val_loss: 0.1024 - val_matthews_correlation: 0.7025
#
# Epoch 00033: val_matthews_correlation did not improve from 0.71785
# Epoch 34/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0902 - matthews_correlation: 0.6996 - val_loss: 0.0980 - val_matthews_correlation: 0.6656
#
# Epoch 00034: val_matthews_correlation did not improve from 0.71785
# Epoch 35/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0910 - matthews_correlation: 0.6970 - val_loss: 0.0935 - val_matthews_correlation: 0.6600
#
# Epoch 00035: val_matthews_correlation did not improve from 0.71785
# Epoch 36/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0923 - matthews_correlation: 0.6948 - val_loss: 0.1047 - val_matthews_correlation: 0.6209
#
# Epoch 00036: val_matthews_correlation did not improve from 0.71785
# Epoch 37/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0858 - matthews_correlation: 0.6964 - val_loss: 0.1011 - val_matthews_correlation: 0.6741
#
# Epoch 00037: val_matthews_correlation did not improve from 0.71785
# Epoch 38/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0871 - matthews_correlation: 0.6815 - val_loss: 0.1093 - val_matthews_correlation: 0.6859
#
# Epoch 00038: val_matthews_correlation did not improve from 0.71785
# Epoch 39/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0914 - matthews_correlation: 0.6743 - val_loss: 0.1021 - val_matthews_correlation: 0.6478
#
# Epoch 00039: val_matthews_correlation did not improve from 0.71785
# Epoch 40/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0902 - matthews_correlation: 0.6419 - val_loss: 0.0971 - val_matthews_correlation: 0.6384
#
# Epoch 00040: val_matthews_correlation did not improve from 0.71785
# Epoch 41/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0878 - matthews_correlation: 0.6715 - val_loss: 0.0904 - val_matthews_correlation: 0.6832
#
# Epoch 00041: val_matthews_correlation did not improve from 0.71785
# Epoch 42/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0836 - matthews_correlation: 0.7152 - val_loss: 0.1379 - val_matthews_correlation: 0.6620
#
# Epoch 00042: val_matthews_correlation did not improve from 0.71785
# Epoch 43/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1023 - matthews_correlation: 0.5580 - val_loss: 0.1240 - val_matthews_correlation: 0.6003
#
# Epoch 00043: val_matthews_correlation did not improve from 0.71785
# Epoch 44/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0971 - matthews_correlation: 0.6471 - val_loss: 0.0950 - val_matthews_correlation: 0.6828
#
# Epoch 00044: val_matthews_correlation did not improve from 0.71785
# Epoch 45/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0874 - matthews_correlation: 0.6996 - val_loss: 0.0989 - val_matthews_correlation: 0.7132
#
# Epoch 00045: val_matthews_correlation did not improve from 0.71785
# Epoch 46/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0993 - matthews_correlation: 0.6339 - val_loss: 0.1033 - val_matthews_correlation: 0.5796
#
# Epoch 00046: val_matthews_correlation did not improve from 0.71785
# Epoch 47/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0923 - matthews_correlation: 0.6435 - val_loss: 0.0962 - val_matthews_correlation: 0.7116
#
# Epoch 00047: val_matthews_correlation did not improve from 0.71785
# Epoch 48/50
# 2323/2323 [==============================] - 22s 9ms/step - loss: 0.0913 - matthews_correlation: 0.6838 - val_loss: 0.0980 - val_matthews_correlation: 0.6086
#
# Epoch 00048: val_matthews_correlation did not improve from 0.71785
# Epoch 49/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0861 - matthews_correlation: 0.7386 - val_loss: 0.1011 - val_matthews_correlation: 0.7226
#
# Epoch 00049: val_matthews_correlation improved from 0.71785 to 0.72255, saving model to weights_1.h5
# Epoch 50/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0898 - matthews_correlation: 0.7046 - val_loss: 0.0917 - val_matthews_correlation: 0.7379
#
# Epoch 00050: val_matthews_correlation improved from 0.72255 to 0.73791, saving model to weights_1.h5
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 25s 11ms/step - loss: 0.3761 - matthews_correlation: 0.0000e+00 - val_loss: 0.2486 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2308 - matthews_correlation: 0.0000e+00 - val_loss: 0.2216 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2160 - matthews_correlation: 0.0000e+00 - val_loss: 0.2148 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2092 - matthews_correlation: 0.0619 - val_loss: 0.2094 - val_matthews_correlation: 0.1397
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.13970, saving model to weights_2.h5
# Epoch 5/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.2113 - matthews_correlation: 0.0956 - val_loss: 0.1991 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.13970
# Epoch 6/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.2001 - matthews_correlation: 0.1174 - val_loss: 0.1886 - val_matthews_correlation: 0.1369
#
# Epoch 00006: val_matthews_correlation did not improve from 0.13970
# Epoch 7/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1861 - matthews_correlation: 0.2430 - val_loss: 0.1696 - val_matthews_correlation: 0.3496
#
# Epoch 00007: val_matthews_correlation improved from 0.13970 to 0.34964, saving model to weights_2.h5
# Epoch 8/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1615 - matthews_correlation: 0.3383 - val_loss: 0.1305 - val_matthews_correlation: 0.4330
#
# Epoch 00008: val_matthews_correlation improved from 0.34964 to 0.43295, saving model to weights_2.h5
# Epoch 9/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1458 - matthews_correlation: 0.2599 - val_loss: 0.1517 - val_matthews_correlation: 0.4031
#
# Epoch 00009: val_matthews_correlation did not improve from 0.43295
# Epoch 10/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1216 - matthews_correlation: 0.5550 - val_loss: 0.1382 - val_matthews_correlation: 0.4505
#
# Epoch 00010: val_matthews_correlation improved from 0.43295 to 0.45050, saving model to weights_2.h5
# Epoch 11/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1146 - matthews_correlation: 0.5476 - val_loss: 0.1177 - val_matthews_correlation: 0.5236
#
# Epoch 00011: val_matthews_correlation improved from 0.45050 to 0.52364, saving model to weights_2.h5
# Epoch 12/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1050 - matthews_correlation: 0.6264 - val_loss: 0.1299 - val_matthews_correlation: 0.3718
#
# Epoch 00012: val_matthews_correlation did not improve from 0.52364
# Epoch 13/50
# 2323/2323 [==============================] - 22s 9ms/step - loss: 0.1072 - matthews_correlation: 0.6185 - val_loss: 0.1352 - val_matthews_correlation: 0.2629
#
# Epoch 00013: val_matthews_correlation did not improve from 0.52364
# Epoch 14/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0991 - matthews_correlation: 0.6241 - val_loss: 0.1173 - val_matthews_correlation: 0.5821
#
# Epoch 00014: val_matthews_correlation improved from 0.52364 to 0.58213, saving model to weights_2.h5
# Epoch 15/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0973 - matthews_correlation: 0.6885 - val_loss: 0.1172 - val_matthews_correlation: 0.6376
#
# Epoch 00015: val_matthews_correlation improved from 0.58213 to 0.63762, saving model to weights_2.h5
# Epoch 16/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1023 - matthews_correlation: 0.6936 - val_loss: 0.1496 - val_matthews_correlation: 0.2441
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63762
# Epoch 17/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0943 - matthews_correlation: 0.6870 - val_loss: 0.1240 - val_matthews_correlation: 0.5379
#
# Epoch 00017: val_matthews_correlation did not improve from 0.63762
# Epoch 18/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1026 - matthews_correlation: 0.6485 - val_loss: 0.1150 - val_matthews_correlation: 0.5874
#
# Epoch 00018: val_matthews_correlation did not improve from 0.63762
# Epoch 19/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1049 - matthews_correlation: 0.6411 - val_loss: 0.1208 - val_matthews_correlation: 0.6044
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63762
# Epoch 20/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0959 - matthews_correlation: 0.6695 - val_loss: 0.1140 - val_matthews_correlation: 0.5935
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63762
# Epoch 21/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0942 - matthews_correlation: 0.6928 - val_loss: 0.1507 - val_matthews_correlation: 0.2995
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63762
# Epoch 22/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0972 - matthews_correlation: 0.6402 - val_loss: 0.1308 - val_matthews_correlation: 0.3467
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63762
# Epoch 23/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0982 - matthews_correlation: 0.6480 - val_loss: 0.1123 - val_matthews_correlation: 0.6489
#
# Epoch 00023: val_matthews_correlation improved from 0.63762 to 0.64895, saving model to weights_2.h5
# Epoch 24/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0895 - matthews_correlation: 0.6902 - val_loss: 0.1182 - val_matthews_correlation: 0.5551
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64895
# Epoch 25/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0879 - matthews_correlation: 0.7020 - val_loss: 0.1099 - val_matthews_correlation: 0.6712
#
# Epoch 00025: val_matthews_correlation improved from 0.64895 to 0.67117, saving model to weights_2.h5
# Epoch 26/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0887 - matthews_correlation: 0.7102 - val_loss: 0.1168 - val_matthews_correlation: 0.6474
#
# Epoch 00026: val_matthews_correlation did not improve from 0.67117
# Epoch 27/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0894 - matthews_correlation: 0.7295 - val_loss: 0.1251 - val_matthews_correlation: 0.4697
#
# Epoch 00027: val_matthews_correlation did not improve from 0.67117
# Epoch 28/50
# 2323/2323 [==============================] - 22s 9ms/step - loss: 0.0861 - matthews_correlation: 0.7429 - val_loss: 0.1303 - val_matthews_correlation: 0.4961
#
# Epoch 00028: val_matthews_correlation did not improve from 0.67117
# Epoch 29/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0911 - matthews_correlation: 0.7054 - val_loss: 0.1171 - val_matthews_correlation: 0.5914
#
# Epoch 00029: val_matthews_correlation did not improve from 0.67117
# Epoch 30/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0886 - matthews_correlation: 0.7210 - val_loss: 0.1141 - val_matthews_correlation: 0.5898
#
# Epoch 00030: val_matthews_correlation did not improve from 0.67117
# Epoch 31/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0906 - matthews_correlation: 0.7271 - val_loss: 0.1091 - val_matthews_correlation: 0.6334
#
# Epoch 00031: val_matthews_correlation did not improve from 0.67117
# Epoch 32/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0845 - matthews_correlation: 0.7063 - val_loss: 0.1153 - val_matthews_correlation: 0.5641
# Epoch 00032: val_matthews_correlation did not improve from 0.67117
# Epoch 33/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0816 - matthews_correlation: 0.7487 - val_loss: 0.1174 - val_matthews_correlation: 0.6055
#
# Epoch 00033: val_matthews_correlation did not improve from 0.67117
# Epoch 34/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0816 - matthews_correlation: 0.7273 - val_loss: 0.1373 - val_matthews_correlation: 0.5470
#
# Epoch 00034: val_matthews_correlation did not improve from 0.67117
# Epoch 35/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0881 - matthews_correlation: 0.6553 - val_loss: 0.1224 - val_matthews_correlation: 0.5296
#
# Epoch 00035: val_matthews_correlation did not improve from 0.67117
# Epoch 36/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0861 - matthews_correlation: 0.6875 - val_loss: 0.1214 - val_matthews_correlation: 0.5423
#
# Epoch 00036: val_matthews_correlation did not improve from 0.67117
# Epoch 37/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0907 - matthews_correlation: 0.6902 - val_loss: 0.1080 - val_matthews_correlation: 0.6629
#
# Epoch 00037: val_matthews_correlation did not improve from 0.67117
# Epoch 38/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0864 - matthews_correlation: 0.7626 - val_loss: 0.1086 - val_matthews_correlation: 0.6399
#
# Epoch 00038: val_matthews_correlation did not improve from 0.67117
# Epoch 39/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0821 - matthews_correlation: 0.6960 - val_loss: 0.1218 - val_matthews_correlation: 0.6142
#
# Epoch 00039: val_matthews_correlation did not improve from 0.67117
# Epoch 40/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0783 - matthews_correlation: 0.7397 - val_loss: 0.1149 - val_matthews_correlation: 0.6244
#
# Epoch 00040: val_matthews_correlation did not improve from 0.67117
# Epoch 41/50
# 2323/2323 [==============================] - 22s 9ms/step - loss: 0.0760 - matthews_correlation: 0.7485 - val_loss: 0.1253 - val_matthews_correlation: 0.5758
#
# Epoch 00041: val_matthews_correlation did not improve from 0.67117
# Epoch 42/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0762 - matthews_correlation: 0.7470 - val_loss: 0.1192 - val_matthews_correlation: 0.5758
#
# Epoch 00042: val_matthews_correlation did not improve from 0.67117
# Epoch 43/50
# 2323/2323 [==============================] - 22s 9ms/step - loss: 0.0810 - matthews_correlation: 0.6851 - val_loss: 0.1183 - val_matthews_correlation: 0.6045
#
# Epoch 00043: val_matthews_correlation did not improve from 0.67117
# Epoch 44/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0787 - matthews_correlation: 0.7476 - val_loss: 0.1260 - val_matthews_correlation: 0.5641
#
# Epoch 00044: val_matthews_correlation did not improve from 0.67117
# Epoch 45/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1034 - matthews_correlation: 0.6454 - val_loss: 0.1235 - val_matthews_correlation: 0.6663
#
# Epoch 00045: val_matthews_correlation did not improve from 0.67117
# Epoch 46/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0924 - matthews_correlation: 0.7166 - val_loss: 0.1173 - val_matthews_correlation: 0.5384
#
# Epoch 00046: val_matthews_correlation did not improve from 0.67117
# Epoch 47/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0851 - matthews_correlation: 0.7333 - val_loss: 0.1222 - val_matthews_correlation: 0.5885
#
# Epoch 00047: val_matthews_correlation did not improve from 0.67117
# Epoch 48/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0796 - matthews_correlation: 0.7271 - val_loss: 0.1171 - val_matthews_correlation: 0.5588
#
# Epoch 00048: val_matthews_correlation did not improve from 0.67117
# Epoch 49/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0779 - matthews_correlation: 0.7344 - val_loss: 0.1248 - val_matthews_correlation: 0.5408
#
# Epoch 00049: val_matthews_correlation did not improve from 0.67117
# Epoch 50/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0777 - matthews_correlation: 0.7569 - val_loss: 0.1147 - val_matthews_correlation: 0.6192
#
# Epoch 00050: val_matthews_correlation did not improve from 0.67117
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 25s 11ms/step - loss: 0.3930 - matthews_correlation: 0.0000e+00 - val_loss: 0.2349 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2327 - matthews_correlation: 0.0000e+00 - val_loss: 0.2274 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2262 - matthews_correlation: 0.0000e+00 - val_loss: 0.2172 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2178 - matthews_correlation: 0.0000e+00 - val_loss: 0.2073 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2154 - matthews_correlation: 0.0000e+00 - val_loss: 0.2025 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2024 - matthews_correlation: 0.0595 - val_loss: 0.1795 - val_matthews_correlation: 0.0986
#
# Epoch 00006: val_matthews_correlation improved from 0.00000 to 0.09859, saving model to weights_3.h5
# Epoch 7/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.1884 - matthews_correlation: 0.0211 - val_loss: 0.1686 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.09859
# Epoch 8/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1768 - matthews_correlation: 0.1453 - val_loss: 0.1615 - val_matthews_correlation: 0.0725
#
# Epoch 00008: val_matthews_correlation did not improve from 0.09859
# Epoch 9/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1469 - matthews_correlation: 0.2462 - val_loss: 0.1097 - val_matthews_correlation: 0.6246
#
# Epoch 00009: val_matthews_correlation improved from 0.09859 to 0.62456, saving model to weights_3.h5
# Epoch 10/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1215 - matthews_correlation: 0.5970 - val_loss: 0.1299 - val_matthews_correlation: 0.4996
#
# Epoch 00010: val_matthews_correlation did not improve from 0.62456
# Epoch 11/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1267 - matthews_correlation: 0.6275 - val_loss: 0.1130 - val_matthews_correlation: 0.5453
#
# Epoch 00011: val_matthews_correlation did not improve from 0.62456
# Epoch 12/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1077 - matthews_correlation: 0.6119 - val_loss: 0.1074 - val_matthews_correlation: 0.6041
#
# Epoch 00012: val_matthews_correlation did not improve from 0.62456
# Epoch 13/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1012 - matthews_correlation: 0.6841 - val_loss: 0.1209 - val_matthews_correlation: 0.4909
#
# Epoch 00013: val_matthews_correlation did not improve from 0.62456
# Epoch 14/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1074 - matthews_correlation: 0.6164 - val_loss: 0.1389 - val_matthews_correlation: 0.4415
#
# Epoch 00014: val_matthews_correlation did not improve from 0.62456
# Epoch 15/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1068 - matthews_correlation: 0.6659 - val_loss: 0.1115 - val_matthews_correlation: 0.4969
#
# Epoch 00015: val_matthews_correlation did not improve from 0.62456
# Epoch 16/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0978 - matthews_correlation: 0.6658 - val_loss: 0.1162 - val_matthews_correlation: 0.4969
#
# Epoch 00016: val_matthews_correlation did not improve from 0.62456
# Epoch 17/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0990 - matthews_correlation: 0.6616 - val_loss: 0.1158 - val_matthews_correlation: 0.4969
#
# Epoch 00017: val_matthews_correlation did not improve from 0.62456
# Epoch 18/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0955 - matthews_correlation: 0.6527 - val_loss: 0.1087 - val_matthews_correlation: 0.5200
#
# Epoch 00018: val_matthews_correlation did not improve from 0.62456
# Epoch 19/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0987 - matthews_correlation: 0.6598 - val_loss: 0.1155 - val_matthews_correlation: 0.6540
#
# Epoch 00019: val_matthews_correlation improved from 0.62456 to 0.65397, saving model to weights_3.h5
# Epoch 20/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0999 - matthews_correlation: 0.6036 - val_loss: 0.1409 - val_matthews_correlation: 0.5100
#
# Epoch 00020: val_matthews_correlation did not improve from 0.65397
# Epoch 21/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0965 - matthews_correlation: 0.6941 - val_loss: 0.1095 - val_matthews_correlation: 0.4956
#
# Epoch 00021: val_matthews_correlation did not improve from 0.65397
# Epoch 22/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0957 - matthews_correlation: 0.6943 - val_loss: 0.1056 - val_matthews_correlation: 0.5788
#
# Epoch 00022: val_matthews_correlation did not improve from 0.65397
# Epoch 23/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0939 - matthews_correlation: 0.6782 - val_loss: 0.1153 - val_matthews_correlation: 0.4956
#
# Epoch 00023: val_matthews_correlation did not improve from 0.65397
# Epoch 24/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0933 - matthews_correlation: 0.6724 - val_loss: 0.1052 - val_matthews_correlation: 0.5317
#
# Epoch 00024: val_matthews_correlation did not improve from 0.65397
# Epoch 25/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0954 - matthews_correlation: 0.6907 - val_loss: 0.1094 - val_matthews_correlation: 0.6132
#
# Epoch 00025: val_matthews_correlation did not improve from 0.65397
# Epoch 26/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0923 - matthews_correlation: 0.6792 - val_loss: 0.1037 - val_matthews_correlation: 0.5118
#
# Epoch 00026: val_matthews_correlation did not improve from 0.65397
# Epoch 27/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0945 - matthews_correlation: 0.7063 - val_loss: 0.1017 - val_matthews_correlation: 0.6879
#
# Epoch 00027: val_matthews_correlation improved from 0.65397 to 0.68789, saving model to weights_3.h5
# Epoch 28/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0901 - matthews_correlation: 0.7173 - val_loss: 0.1017 - val_matthews_correlation: 0.5310
#
# Epoch 00028: val_matthews_correlation did not improve from 0.68789
# Epoch 29/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0887 - matthews_correlation: 0.6883 - val_loss: 0.1083 - val_matthews_correlation: 0.4768
#
# Epoch 00029: val_matthews_correlation did not improve from 0.68789
# Epoch 30/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0884 - matthews_correlation: 0.6704 - val_loss: 0.0989 - val_matthews_correlation: 0.5021
#
# Epoch 00030: val_matthews_correlation did not improve from 0.68789
# Epoch 31/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0871 - matthews_correlation: 0.6850 - val_loss: 0.1062 - val_matthews_correlation: 0.5106
#
# Epoch 00031: val_matthews_correlation did not improve from 0.68789
# Epoch 32/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0893 - matthews_correlation: 0.6753 - val_loss: 0.0999 - val_matthews_correlation: 0.6384
#
# Epoch 00032: val_matthews_correlation did not improve from 0.68789
# Epoch 33/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0889 - matthews_correlation: 0.6799 - val_loss: 0.1002 - val_matthews_correlation: 0.5327
#
# Epoch 00033: val_matthews_correlation did not improve from 0.68789
# Epoch 34/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0869 - matthews_correlation: 0.6822 - val_loss: 0.1022 - val_matthews_correlation: 0.5160
#
# Epoch 00034: val_matthews_correlation did not improve from 0.68789
# Epoch 35/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.0943 - matthews_correlation: 0.6681 - val_loss: 0.1010 - val_matthews_correlation: 0.4959
#
# Epoch 00035: val_matthews_correlation did not improve from 0.68789
# Epoch 36/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0908 - matthews_correlation: 0.6447 - val_loss: 0.1047 - val_matthews_correlation: 0.4575
#
# Epoch 00036: val_matthews_correlation did not improve from 0.68789
# Epoch 37/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.0949 - matthews_correlation: 0.5989 - val_loss: 0.1055 - val_matthews_correlation: 0.5126
#
# Epoch 00037: val_matthews_correlation did not improve from 0.68789
# Epoch 38/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0901 - matthews_correlation: 0.6797 - val_loss: 0.0941 - val_matthews_correlation: 0.6825
#
# Epoch 00038: val_matthews_correlation did not improve from 0.68789
# Epoch 39/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0858 - matthews_correlation: 0.6796 - val_loss: 0.1021 - val_matthews_correlation: 0.5477
#
# Epoch 00039: val_matthews_correlation did not improve from 0.68789
# Epoch 40/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0825 - matthews_correlation: 0.7001 - val_loss: 0.1069 - val_matthews_correlation: 0.5083
#
# Epoch 00040: val_matthews_correlation did not improve from 0.68789
# Epoch 41/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0835 - matthews_correlation: 0.7167 - val_loss: 0.1029 - val_matthews_correlation: 0.5317
#
# Epoch 00041: val_matthews_correlation did not improve from 0.68789
# Epoch 42/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0800 - matthews_correlation: 0.7151 - val_loss: 0.0990 - val_matthews_correlation: 0.5441
#
# Epoch 00042: val_matthews_correlation did not improve from 0.68789
# Epoch 43/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0812 - matthews_correlation: 0.6889 - val_loss: 0.0968 - val_matthews_correlation: 0.5334
#
# Epoch 00043: val_matthews_correlation did not improve from 0.68789
# Epoch 44/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0763 - matthews_correlation: 0.7040 - val_loss: 0.1058 - val_matthews_correlation: 0.5477
#
# Epoch 00044: val_matthews_correlation did not improve from 0.68789
# Epoch 45/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0771 - matthews_correlation: 0.7535 - val_loss: 0.0994 - val_matthews_correlation: 0.5874
#
# Epoch 00045: val_matthews_correlation did not improve from 0.68789
# Epoch 46/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0809 - matthews_correlation: 0.7275 - val_loss: 0.1021 - val_matthews_correlation: 0.6192
#
# Epoch 00046: val_matthews_correlation did not improve from 0.68789
# Epoch 47/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0816 - matthews_correlation: 0.7032 - val_loss: 0.1197 - val_matthews_correlation: 0.4927
#
# Epoch 00047: val_matthews_correlation did not improve from 0.68789
# Epoch 48/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0823 - matthews_correlation: 0.6922 - val_loss: 0.1039 - val_matthews_correlation: 0.6480
#
# Epoch 00048: val_matthews_correlation did not improve from 0.68789
# Epoch 49/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0769 - matthews_correlation: 0.7427 - val_loss: 0.0942 - val_matthews_correlation: 0.5317
#
# Epoch 00049: val_matthews_correlation did not improve from 0.68789
# Epoch 50/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.0743 - matthews_correlation: 0.7497 - val_loss: 0.0974 - val_matthews_correlation: 0.6252
#
# Epoch 00050: val_matthews_correlation did not improve from 0.68789
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 25s 11ms/step - loss: 0.3651 - matthews_correlation: 0.0067 - val_loss: 0.2315 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.2287 - matthews_correlation: 0.0000e+00 - val_loss: 0.2172 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2172 - matthews_correlation: 0.0000e+00 - val_loss: 0.1981 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2086 - matthews_correlation: -0.0014 - val_loss: 0.1866 - val_matthews_correlation: 0.0955
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.09551, saving model to weights_4.h5
# Epoch 5/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1887 - matthews_correlation: 0.2140 - val_loss: 0.2175 - val_matthews_correlation: 0.2471
#
# Epoch 00005: val_matthews_correlation improved from 0.09551 to 0.24706, saving model to weights_4.h5
# Epoch 6/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2053 - matthews_correlation: 0.0089 - val_loss: 0.1908 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.24706
# Epoch 7/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1854 - matthews_correlation: 0.1271 - val_loss: 0.1734 - val_matthews_correlation: 0.3947
#
# Epoch 00007: val_matthews_correlation improved from 0.24706 to 0.39473, saving model to weights_4.h5
# Epoch 8/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1740 - matthews_correlation: 0.1381 - val_loss: 0.1966 - val_matthews_correlation: 0.4126
#
# Epoch 00008: val_matthews_correlation improved from 0.39473 to 0.41259, saving model to weights_4.h5
# Epoch 9/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1560 - matthews_correlation: 0.1691 - val_loss: 0.1490 - val_matthews_correlation: 0.5301
#
# Epoch 00009: val_matthews_correlation improved from 0.41259 to 0.53006, saving model to weights_4.h5
# Epoch 10/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1310 - matthews_correlation: 0.4837 - val_loss: 0.1801 - val_matthews_correlation: 0.1579
#
# Epoch 00010: val_matthews_correlation did not improve from 0.53006
# Epoch 11/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1262 - matthews_correlation: 0.5583 - val_loss: 0.1269 - val_matthews_correlation: 0.4872
#
# Epoch 00011: val_matthews_correlation did not improve from 0.53006
# Epoch 12/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1199 - matthews_correlation: 0.4681 - val_loss: 0.1253 - val_matthews_correlation: 0.5763
#
# Epoch 00012: val_matthews_correlation improved from 0.53006 to 0.57631, saving model to weights_4.h5
# Epoch 13/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1105 - matthews_correlation: 0.5958 - val_loss: 0.1556 - val_matthews_correlation: 0.5299
#
# Epoch 00013: val_matthews_correlation did not improve from 0.57631
# Epoch 14/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1161 - matthews_correlation: 0.5731 - val_loss: 0.1146 - val_matthews_correlation: 0.5717
#
# Epoch 00014: val_matthews_correlation did not improve from 0.57631
# Epoch 15/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1002 - matthews_correlation: 0.6062 - val_loss: 0.1311 - val_matthews_correlation: 0.5563
#
# Epoch 00015: val_matthews_correlation did not improve from 0.57631
# Epoch 16/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1066 - matthews_correlation: 0.6206 - val_loss: 0.1144 - val_matthews_correlation: 0.6141
#
# Epoch 00016: val_matthews_correlation improved from 0.57631 to 0.61413, saving model to weights_4.h5
# Epoch 17/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.0976 - matthews_correlation: 0.6638 - val_loss: 0.1157 - val_matthews_correlation: 0.4127
#
# Epoch 00017: val_matthews_correlation did not improve from 0.61413
# Epoch 18/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0956 - matthews_correlation: 0.6403 - val_loss: 0.1228 - val_matthews_correlation: 0.4532
#
# Epoch 00018: val_matthews_correlation did not improve from 0.61413
# Epoch 19/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0964 - matthews_correlation: 0.6703 - val_loss: 0.1121 - val_matthews_correlation: 0.5996
#
# Epoch 00019: val_matthews_correlation did not improve from 0.61413
# Epoch 20/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0952 - matthews_correlation: 0.6851 - val_loss: 0.1160 - val_matthews_correlation: 0.4225
#
# Epoch 00020: val_matthews_correlation did not improve from 0.61413
# Epoch 21/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0987 - matthews_correlation: 0.6359 - val_loss: 0.1430 - val_matthews_correlation: 0.4544
#
# Epoch 00021: val_matthews_correlation did not improve from 0.61413
# Epoch 22/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0956 - matthews_correlation: 0.6827 - val_loss: 0.1188 - val_matthews_correlation: 0.3989
#
# Epoch 00022: val_matthews_correlation did not improve from 0.61413
# Epoch 23/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0895 - matthews_correlation: 0.6497 - val_loss: 0.1096 - val_matthews_correlation: 0.4636
#
# Epoch 00023: val_matthews_correlation did not improve from 0.61413
# Epoch 24/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0953 - matthews_correlation: 0.6761 - val_loss: 0.1071 - val_matthews_correlation: 0.6120
#
# Epoch 00024: val_matthews_correlation did not improve from 0.61413
# Epoch 25/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0945 - matthews_correlation: 0.6915 - val_loss: 0.1101 - val_matthews_correlation: 0.4654
#
# Epoch 00025: val_matthews_correlation did not improve from 0.61413
# Epoch 26/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0904 - matthews_correlation: 0.6558 - val_loss: 0.1135 - val_matthews_correlation: 0.6453
#
# Epoch 00026: val_matthews_correlation improved from 0.61413 to 0.64526, saving model to weights_4.h5
# Epoch 27/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0881 - matthews_correlation: 0.7282 - val_loss: 0.1216 - val_matthews_correlation: 0.3989
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64526
# Epoch 28/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0885 - matthews_correlation: 0.6815 - val_loss: 0.1173 - val_matthews_correlation: 0.5671
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64526
# Epoch 29/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0870 - matthews_correlation: 0.6820 - val_loss: 0.1108 - val_matthews_correlation: 0.6058
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64526
# Epoch 30/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0914 - matthews_correlation: 0.6677 - val_loss: 0.1185 - val_matthews_correlation: 0.4449
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64526
# Epoch 31/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0850 - matthews_correlation: 0.7301 - val_loss: 0.1202 - val_matthews_correlation: 0.4249
#
# Epoch 00031: val_matthews_correlation did not improve from 0.64526
# Epoch 32/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.0953 - matthews_correlation: 0.5885 - val_loss: 0.1097 - val_matthews_correlation: 0.6269
#
# Epoch 00032: val_matthews_correlation did not improve from 0.64526
# Epoch 33/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0899 - matthews_correlation: 0.6859 - val_loss: 0.1123 - val_matthews_correlation: 0.5337
#
# Epoch 00033: val_matthews_correlation did not improve from 0.64526
# Epoch 34/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0936 - matthews_correlation: 0.6824 - val_loss: 0.1397 - val_matthews_correlation: 0.3666
#
# Epoch 00034: val_matthews_correlation did not improve from 0.64526
# Epoch 35/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0945 - matthews_correlation: 0.6540 - val_loss: 0.1160 - val_matthews_correlation: 0.6004
#
# Epoch 00035: val_matthews_correlation did not improve from 0.64526
# Epoch 36/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0909 - matthews_correlation: 0.7038 - val_loss: 0.1128 - val_matthews_correlation: 0.6289
#
# Epoch 00036: val_matthews_correlation did not improve from 0.64526
# Epoch 37/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0889 - matthews_correlation: 0.6197 - val_loss: 0.1126 - val_matthews_correlation: 0.4840
#
# Epoch 00037: val_matthews_correlation did not improve from 0.64526
# Epoch 38/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.1088 - matthews_correlation: 0.6861 - val_loss: 0.1193 - val_matthews_correlation: 0.4264
#
# Epoch 00038: val_matthews_correlation did not improve from 0.64526
# Epoch 39/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0986 - matthews_correlation: 0.5873 - val_loss: 0.1092 - val_matthews_correlation: 0.6179
#
# Epoch 00039: val_matthews_correlation did not improve from 0.64526
# Epoch 40/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0962 - matthews_correlation: 0.6062 - val_loss: 0.1159 - val_matthews_correlation: 0.3607
#
# Epoch 00040: val_matthews_correlation did not improve from 0.64526
# Epoch 41/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0956 - matthews_correlation: 0.6706 - val_loss: 0.1137 - val_matthews_correlation: 0.5165
#
# Epoch 00041: val_matthews_correlation did not improve from 0.64526
# Epoch 42/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0896 - matthews_correlation: 0.6631 - val_loss: 0.1067 - val_matthews_correlation: 0.4707
#
# Epoch 00042: val_matthews_correlation did not improve from 0.64526
# Epoch 43/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0838 - matthews_correlation: 0.7104 - val_loss: 0.1131 - val_matthews_correlation: 0.5850
#
# Epoch 00043: val_matthews_correlation did not improve from 0.64526
# Epoch 44/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0904 - matthews_correlation: 0.6969 - val_loss: 0.1096 - val_matthews_correlation: 0.5957
#
# Epoch 00044: val_matthews_correlation did not improve from 0.64526
# Epoch 45/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0842 - matthews_correlation: 0.7376 - val_loss: 0.1085 - val_matthews_correlation: 0.5364
#
# Epoch 00045: val_matthews_correlation did not improve from 0.64526
# Epoch 46/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0794 - matthews_correlation: 0.7203 - val_loss: 0.1181 - val_matthews_correlation: 0.5845
#
# Epoch 00046: val_matthews_correlation did not improve from 0.64526
# Epoch 47/50
# 2324/2324 [==============================] - 22s 9ms/step - loss: 0.0851 - matthews_correlation: 0.7169 - val_loss: 0.1212 - val_matthews_correlation: 0.6043
#
# Epoch 00047: val_matthews_correlation did not improve from 0.64526
# Epoch 48/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0924 - matthews_correlation: 0.6775 - val_loss: 0.1190 - val_matthews_correlation: 0.4393
#
# Epoch 00048: val_matthews_correlation did not improve from 0.64526
# Epoch 49/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0799 - matthews_correlation: 0.7002 - val_loss: 0.1121 - val_matthews_correlation: 0.6155
#
# Epoch 00049: val_matthews_correlation did not improve from 0.64526
# Epoch 50/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0772 - matthews_correlation: 0.7366 - val_loss: 0.1262 - val_matthews_correlation: 0.4293
#
# Epoch 00050: val_matthews_correlation did not improve from 0.64526
# ((2904,), (2904,))

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        score = matthews_correlation(y_true, (y_proba > threshold).astype(int))
        #score = K.eval(matthews_correlation(y_true, (y_proba > threshold).astype(int)))
        #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
y_val = K.cast(y_val, np.float32)
preds_val = K.cast(preds_val, np.float32)

# %%
y_val = K.eval(y_val)
preds_val = K.eval(preds_val)

# %%
np.save('./y_val_tmp.npy', y_val)
np.save('./preds_val_tmp.npy', preds_val)

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-bbeab1d2bbef> in <module>()
# ----> 1 best_threshold = threshold_search(y_val, preds_val)['threshold']
#
# <ipython-input-35-c43605b06ac6> in threshold_search(y_true, y_proba)
#       6     best_score = 0
#       7     for threshold in tqdm([i * 0.01 for i in range(100)]):
# ----> 8         score = matthews_correlation(y_true, (y_proba > threshold).astype(int))
#       9         #score = K.eval(matthews_correlation(y_true, (y_proba > threshold).astype(int)))
#      10         #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
#
# <ipython-input-3-a35a1e4a083b> in matthews_correlation(y_true, y_pred)
#       5     of binary classification problems.
#       6     '''
# ----> 7     y_pred_pos = K.round(K.clip(y_pred, 0, 1))
#       8     y_pred_neg = 1 - y_pred_pos
#       9
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in clip(x, min_value, max_value)
#    1599     if max_value is None:
#    1600         max_value = np.inf
# -> 1601     min_value = _to_tensor(min_value, x.dtype.base_dtype)
#    1602     max_value = _to_tensor(max_value, x.dtype.base_dtype)
#    1603     return tf.clip_by_value(x, min_value, max_value)
#
# AttributeError: 'numpy.dtype' object has no attribute 'base_dtype'

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()

# %%
# %%time
# First we daclarete a series of parameters to initiate the loading of the main data
# it is too large, it is impossible to load in one time, so we are doing it in dividing in 10 parts
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape

# %%
submission['target'] = preds_test
submission.to_csv('submission_14.csv', index=False)
submission.head()
