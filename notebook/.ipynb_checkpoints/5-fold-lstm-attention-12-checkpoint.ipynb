# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from scipy.signal import chirp, find_peaks, peak_widths
import pywt

from multiprocessing import Pool
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import warnings

warnings.filterwarnings('ignore')

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
def maddest(d, axis=None):
    """
    Mean Absolute Deviation
    """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

# %%
def denoise_signal( x, wavelet='db4', level=1):
    """
    1. Adapted from waveletSmooth function found here:
    http://connor-johnson.com/2016/01/24/using-pywavelets-to-remove-high-frequency-noise/
    2. Threshold equation and using hard mode in threshold as mentioned
    in section '3.2 denoising based on optimized singular values' from paper by Tomas Vantuch:
    http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    """
    
    # Decompose to get the wavelet coefficients
    coeff = pywt.wavedec( x, wavelet, mode="per", level=level)
    
    # Calculate sigma for threshold as defined in http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    # As noted by @harshit92 MAD referred to in the paper is Mean Absolute Deviation not Median Absolute Deviation
    sigma = (1/0.6745) * maddest( coeff[-level] )

    # Calculte the univeral threshold
    uthresh = sigma * np.sqrt( 2*np.log( len( x ) ) )
    coeff[1:] = ( pywt.threshold( i, value=uthresh, mode='hard' ) for i in coeff[1:] )
    
    # Reconstruct the signal using the thresholded coefficients
    return pywt.waverec( coeff[1:], wavelet, mode='per' )

# %%
def remove_corona(x_dn, maxDistance=10, maxHeightRatio=0.25, maxTicksRemoval=500):
    index = pd.Series(x_dn).loc[np.abs(x_dn)>0].index
    corona_idx = []
    for idx in index:
        for i in range(1,maxDistance+1):
            if idx+i < pd.Series(x_dn).shape[0]:
                if x_dn[idx+i]/(x_dn[idx]+1e-04)<-maxHeightRatio:
                    x_dn[idx:idx+maxTicksRemoval] = 0
                    corona_idx.append(idx)
    return x_dn, corona_idx

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    #ts_wave = denoise_signal(ts_std, wavelet='haar', level=1)
    #ts_rm, corona_idx = remove_corona(ts_wave)
    
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        #ts_rm_range = ts_rm[int(i/2):int(i/2) + int(bucket_size/2)]
        #ts_rm_range = pd.Series(ts_rm_range)
        
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        
        numpeaks = np.sum(ts_range!=0)/len(ts_range)
        #numpospeaks = ts_rm_range[ts_rm_range>0].count()
        numpospeaks = np.sum(ts_range>0)/len(ts_range)
        #numnegpeaks = ts_rm_range[ts_rm_range<0].count()
        numnegpeaks = np.sum(ts_range<0)/len(ts_range)
        #numpeaks = ts_rm_range[ts_rm_range!=0].count()
        #numpeaks = np.sum(ts_rm_range!=0)/len(ts_rm_range)
        #numpospeaks = ts_rm_range[ts_rm_range>0].count()
        #numpospeaks = np.sum(ts_rm_range>0)/len(ts_rm_range)
        #numnegpeaks = ts_rm_range[ts_rm_range<0].count()
        #numnegpeaks = np.sum(ts_rm_range<0)/len(ts_rm_range)

        #meanamp = np.mean(ts_rm_range)
        #meanamppos = np.mean(ts_rm_range[ts_rm_range>0])
        #meanampneg = np.mean(ts_rm_range[ts_rm_range<0])

        #maxamp = np.max(ts_rm_range)
        #minamp = np.min(ts_rm_range)
        
        #peaks, _ = find_peaks(ts_rm_range)
        #results_full = peak_widths(ts_rm_range, peaks, rel_height=1)
        
        #if len(results_full[0])==0:
         #   maxwidth = 0
         #   minwidth = 0
        #else:
         #   maxwidth = np.max(results_full[0])/len(ts_rm_range)
         #   minwidth = np.min(results_full[0])/len(ts_rm_range)
        
        
        
        feat_array = np.asarray([mean, std, std_top, std_bot, max_range])
        feat_array_2 = np.asarray([numpeaks, numpospeaks, numnegpeaks
        #                           , meanamp, meanamppos, meanampneg,
        #                         maxamp, minamp, maxwidth, minwidth
                                  ])
        
        new_ts.append(np.concatenate([feat_array, feat_array_2
                                      , percentil_calc, relative_percentile]))
        
    #scaler = MinMaxScaler(feature_range=(-1, 1))
    #scaler = StandardScaler()
    #new_ts = np.asarray(new_ts)
    #new_ts[np.isnan(new_ts)] = 0
    
    #new_ts = scaler.fit_transform(new_ts)
        
    return new_ts

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts_sum(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    #ts_wave = denoise_signal(ts_std, wavelet='haar', level=1)
    #ts_rm, corona_idx = remove_corona(ts_wave)
    
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        #ts_rm_range = ts_rm[int(i/2):int(i/2) + int(bucket_size/2)]
        #ts_rm_range = pd.Series(ts_rm_range)
        
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        
        #numpeaks = ts_rm_range[ts_rm_range!=0].count()
        
        numpeaks = np.sum(ts_range!=0)/len(ts_range)
        #numpospeaks = ts_rm_range[ts_rm_range>0].count()
        numpospeaks = np.sum(ts_range>0)/len(ts_range)
        #numnegpeaks = ts_rm_range[ts_rm_range<0].count()
        numnegpeaks = np.sum(ts_range<0)/len(ts_range)

        #meanamp = np.mean(ts_rm_range)
        #meanamppos = np.mean(ts_range[ts_range>0])
        #meanampneg = np.mean(ts_range[ts_range<0])

        #maxamp = np.max(ts_rm_range)
        #minamp = np.min(ts_rm_range)
        
        #peaks, _ = find_peaks(ts_range)
        #results_full = peak_widths(ts_range, peaks, rel_height=1)
        
        #if len(results_full[0])==0:
        #    maxwidth = 0
        #    minwidth = 0
        #else:
        #    maxwidth = np.max(results_full[0])/len(ts_range)
        #    minwidth = np.min(results_full[0])/len(ts_range)
        
        
        
        feat_array = np.asarray([mean, std, std_top, std_bot, max_range])
        feat_array_2 = np.asarray([numpeaks, numpospeaks, numnegpeaks
                                   #, meanamppos, meanampneg,
                                 #maxwidth, minwidth
                                  ])
        
        new_ts.append(np.concatenate([feat_array, feat_array_2, percentil_calc, relative_percentile]))
        
    #scaler = MinMaxScaler(feature_range=(-1, 1))
    #scaler = StandardScaler()
    #new_ts = np.asarray(new_ts)
    #new_ts[np.isnan(new_ts)] = 0
    
    #new_ts = scaler.fit_transform(new_ts)
        
    return new_ts

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
                ts_sum = praq_train[str(signal_id)] + praq_train[str(signal_id+1)] + praq_train[str(signal_id+2)]
                X_signal.append(transform_ts_sum(ts_sum))
                
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(3, 6)]).to_pandas()

# %%
np.max(praq_train['3']+praq_train['4']+praq_train['5'])
# Out:
# 71

# %%
np.min(praq_train['3']+praq_train['4']+praq_train['5'])
# Out:
# -70

# %%
def process_subtrain(arg_tuple):
    start, end, idx = arg_tuple
    X, y = prep_data(start, end)
    return idx, X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
#X = []
#y = []
all_chunks = []

num_cores = 8 
#def load_all():
total_size = len(df_train)
chunk_size = total_size/num_cores

for i in range(8):
    start_idx = int(i * chunk_size)
    end_idx = int(start_idx + chunk_size)
    chunk = (start_idx, end_idx, i)
    all_chunks.append(chunk)

pool = Pool()
results = pool.map(process_subtrain, all_chunks)    
results = sorted(results, key=lambda tup: tup[0])

X = np.concatenate([item[1] for item in results], axis=0)
y = np.concatenate([item[2] for item in results], axis=0)

#load_all()

#X = np.asarray(X)
#y = np.asarray(y)
# Out:
# 100%|██████████| 363/363 [08:44<00:00,  1.48s/it]
# 100%|██████████| 363/363 [08:44<00:00,  1.48s/it]
# 100%|██████████| 363/363 [08:45<00:00,  1.50s/it]
# 100%|██████████| 363/363 [08:47<00:00,  1.45s/it]
# 100%|██████████| 363/363 [08:46<00:00,  1.41s/it]
# 100%|██████████| 363/363 [08:46<00:00,  1.40s/it]
# 100%|██████████| 363/363 [08:46<00:00,  1.36s/it]
# 100%|██████████| 363/363 [08:46<00:00,  1.32s/it]

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# Out:
# (2904, 160, 88) (2904,)

# %%
#X = X.reshape(2904, 160, 26)

# %%
print(np.max(X), np.min(X))
# Out:
# 2.0 -1.4914572549019534

# %%
X[np.isnan(X)] = 0

# %%
# save data into file, a numpy specific format
np.save("X_6.npy",X)
np.save("y_6.npy",y)

# %%
X = np.load("./X_6.npy")
y = np.load("./y_6.npy")

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(LSTM(128, return_sequences=True))(inp)
    print(x.shape)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    print(x.shape)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    print(x.shape)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64)(x)
    print(x.shape)
    
    x = LeakyReLU(alpha=0.1)(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 26s 11ms/step - loss: 0.2968 - matthews_correlation: 0.0038 - val_loss: 0.2345 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.2219 - matthews_correlation: 0.0000e+00 - val_loss: 0.2232 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.2087 - matthews_correlation: 0.1000 - val_loss: 0.2004 - val_matthews_correlation: 0.1923
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.19231, saving model to weights_0.h5
# Epoch 4/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.1951 - matthews_correlation: 0.2707 - val_loss: 0.1942 - val_matthews_correlation: 0.1923
#
# Epoch 00004: val_matthews_correlation did not improve from 0.19231
# Epoch 5/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1759 - matthews_correlation: 0.1369 - val_loss: 0.1421 - val_matthews_correlation: 0.3566
#
# Epoch 00005: val_matthews_correlation improved from 0.19231 to 0.35661, saving model to weights_0.h5
# Epoch 6/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1301 - matthews_correlation: 0.4676 - val_loss: 0.0984 - val_matthews_correlation: 0.7394
#
# Epoch 00006: val_matthews_correlation improved from 0.35661 to 0.73944, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1316 - matthews_correlation: 0.4922 - val_loss: 0.1616 - val_matthews_correlation: 0.6976
#
# Epoch 00007: val_matthews_correlation did not improve from 0.73944
# Epoch 8/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1264 - matthews_correlation: 0.5348 - val_loss: 0.1030 - val_matthews_correlation: 0.5348
#
# Epoch 00008: val_matthews_correlation did not improve from 0.73944
# Epoch 9/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1225 - matthews_correlation: 0.5983 - val_loss: 0.0899 - val_matthews_correlation: 0.6985
#
# Epoch 00009: val_matthews_correlation did not improve from 0.73944
# Epoch 10/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1087 - matthews_correlation: 0.6229 - val_loss: 0.0893 - val_matthews_correlation: 0.6586
#
# Epoch 00010: val_matthews_correlation did not improve from 0.73944
# Epoch 11/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1040 - matthews_correlation: 0.5659 - val_loss: 0.0975 - val_matthews_correlation: 0.6738
#
# Epoch 00011: val_matthews_correlation did not improve from 0.73944
# Epoch 12/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1058 - matthews_correlation: 0.6299 - val_loss: 0.0865 - val_matthews_correlation: 0.6188
#
# Epoch 00012: val_matthews_correlation did not improve from 0.73944
# Epoch 13/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1151 - matthews_correlation: 0.3693 - val_loss: 0.0916 - val_matthews_correlation: 0.5488
#
# Epoch 00013: val_matthews_correlation did not improve from 0.73944
# Epoch 14/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1110 - matthews_correlation: 0.5465 - val_loss: 0.0932 - val_matthews_correlation: 0.4593
#
# Epoch 00014: val_matthews_correlation did not improve from 0.73944
# Epoch 15/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1078 - matthews_correlation: 0.5898 - val_loss: 0.0861 - val_matthews_correlation: 0.6674
#
# Epoch 00015: val_matthews_correlation did not improve from 0.73944
# Epoch 16/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1023 - matthews_correlation: 0.5468 - val_loss: 0.0816 - val_matthews_correlation: 0.7091
#
# Epoch 00016: val_matthews_correlation did not improve from 0.73944
# Epoch 17/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0961 - matthews_correlation: 0.6581 - val_loss: 0.0832 - val_matthews_correlation: 0.6368
#
# Epoch 00017: val_matthews_correlation did not improve from 0.73944
# Epoch 18/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1001 - matthews_correlation: 0.5717 - val_loss: 0.0927 - val_matthews_correlation: 0.6139
#
# Epoch 00018: val_matthews_correlation did not improve from 0.73944
# Epoch 19/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0993 - matthews_correlation: 0.5992 - val_loss: 0.1064 - val_matthews_correlation: 0.6870
#
# Epoch 00019: val_matthews_correlation did not improve from 0.73944
# Epoch 20/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1055 - matthews_correlation: 0.6253 - val_loss: 0.0916 - val_matthews_correlation: 0.7323
#
# Epoch 00020: val_matthews_correlation did not improve from 0.73944
# Epoch 21/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0954 - matthews_correlation: 0.6589 - val_loss: 0.0809 - val_matthews_correlation: 0.7136
#
# Epoch 00021: val_matthews_correlation did not improve from 0.73944
# Epoch 22/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0956 - matthews_correlation: 0.6630 - val_loss: 0.0802 - val_matthews_correlation: 0.7507
#
# Epoch 00022: val_matthews_correlation improved from 0.73944 to 0.75069, saving model to weights_0.h5
# Epoch 23/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0895 - matthews_correlation: 0.6608 - val_loss: 0.0996 - val_matthews_correlation: 0.6984
#
# Epoch 00023: val_matthews_correlation did not improve from 0.75069
# Epoch 24/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0894 - matthews_correlation: 0.7001 - val_loss: 0.0796 - val_matthews_correlation: 0.7398
#
# Epoch 00024: val_matthews_correlation did not improve from 0.75069
# Epoch 25/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0853 - matthews_correlation: 0.6878 - val_loss: 0.0943 - val_matthews_correlation: 0.7651
#
# Epoch 00025: val_matthews_correlation improved from 0.75069 to 0.76506, saving model to weights_0.h5
# Epoch 26/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.1138 - matthews_correlation: 0.5066 - val_loss: 0.0861 - val_matthews_correlation: 0.7119
#
# Epoch 00026: val_matthews_correlation did not improve from 0.76506
# Epoch 27/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0943 - matthews_correlation: 0.6265 - val_loss: 0.0895 - val_matthews_correlation: 0.6932
#
# Epoch 00027: val_matthews_correlation did not improve from 0.76506
# Epoch 28/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0918 - matthews_correlation: 0.6605 - val_loss: 0.0977 - val_matthews_correlation: 0.6500
#
# Epoch 00028: val_matthews_correlation did not improve from 0.76506
# Epoch 29/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0939 - matthews_correlation: 0.6616 - val_loss: 0.0991 - val_matthews_correlation: 0.7138
#
# Epoch 00029: val_matthews_correlation did not improve from 0.76506
# Epoch 30/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0863 - matthews_correlation: 0.6728 - val_loss: 0.0933 - val_matthews_correlation: 0.7338
#
# Epoch 00030: val_matthews_correlation did not improve from 0.76506
# Epoch 31/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0868 - matthews_correlation: 0.6948 - val_loss: 0.1088 - val_matthews_correlation: 0.7322
#
# Epoch 00031: val_matthews_correlation did not improve from 0.76506
# Epoch 32/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0987 - matthews_correlation: 0.6244 - val_loss: 0.0923 - val_matthews_correlation: 0.6293
#
# Epoch 00032: val_matthews_correlation did not improve from 0.76506
# Epoch 33/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0906 - matthews_correlation: 0.6191 - val_loss: 0.0797 - val_matthews_correlation: 0.7610
#
# Epoch 00033: val_matthews_correlation did not improve from 0.76506
# Epoch 34/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0960 - matthews_correlation: 0.6105 - val_loss: 0.0816 - val_matthews_correlation: 0.6885
#
# Epoch 00034: val_matthews_correlation did not improve from 0.76506
# Epoch 35/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0945 - matthews_correlation: 0.5789 - val_loss: 0.0810 - val_matthews_correlation: 0.7409
#
# Epoch 00035: val_matthews_correlation did not improve from 0.76506
# Epoch 36/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0910 - matthews_correlation: 0.6153 - val_loss: 0.0891 - val_matthews_correlation: 0.7087
#
# Epoch 00036: val_matthews_correlation did not improve from 0.76506
# Epoch 37/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0831 - matthews_correlation: 0.7081 - val_loss: 0.1329 - val_matthews_correlation: 0.6643
#
# Epoch 00037: val_matthews_correlation did not improve from 0.76506
# Epoch 38/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0818 - matthews_correlation: 0.6592 - val_loss: 0.0860 - val_matthews_correlation: 0.7693
#
# Epoch 00038: val_matthews_correlation improved from 0.76506 to 0.76931, saving model to weights_0.h5
# Epoch 39/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0850 - matthews_correlation: 0.6464 - val_loss: 0.1075 - val_matthews_correlation: 0.6861
#
# Epoch 00039: val_matthews_correlation did not improve from 0.76931
# Epoch 40/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0842 - matthews_correlation: 0.7074 - val_loss: 0.1138 - val_matthews_correlation: 0.7041
#
# Epoch 00040: val_matthews_correlation did not improve from 0.76931
# Epoch 41/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0877 - matthews_correlation: 0.6853 - val_loss: 0.0775 - val_matthews_correlation: 0.7928
#
# Epoch 00041: val_matthews_correlation improved from 0.76931 to 0.79277, saving model to weights_0.h5
# Epoch 42/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0835 - matthews_correlation: 0.6867 - val_loss: 0.0839 - val_matthews_correlation: 0.6731
#
# Epoch 00042: val_matthews_correlation did not improve from 0.79277
# Epoch 43/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0789 - matthews_correlation: 0.7208 - val_loss: 0.0780 - val_matthews_correlation: 0.7646
#
# Epoch 00043: val_matthews_correlation did not improve from 0.79277
# Epoch 44/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0780 - matthews_correlation: 0.6823 - val_loss: 0.0932 - val_matthews_correlation: 0.6663
#
# Epoch 00044: val_matthews_correlation did not improve from 0.79277
# Epoch 45/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0882 - matthews_correlation: 0.6503 - val_loss: 0.0782 - val_matthews_correlation: 0.7313
#
# Epoch 00045: val_matthews_correlation did not improve from 0.79277
# Epoch 46/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0783 - matthews_correlation: 0.7262 - val_loss: 0.0851 - val_matthews_correlation: 0.6497
#
# Epoch 00046: val_matthews_correlation did not improve from 0.79277
# Epoch 47/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0807 - matthews_correlation: 0.6732 - val_loss: 0.0808 - val_matthews_correlation: 0.7104
#
# Epoch 00047: val_matthews_correlation did not improve from 0.79277
# Epoch 48/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0785 - matthews_correlation: 0.7466 - val_loss: 0.0932 - val_matthews_correlation: 0.6188
#
# Epoch 00048: val_matthews_correlation did not improve from 0.79277
# Epoch 49/50
# 2322/2322 [==============================] - 20s 9ms/step - loss: 0.0752 - matthews_correlation: 0.7020 - val_loss: 0.0847 - val_matthews_correlation: 0.6312
#
# Epoch 00049: val_matthews_correlation did not improve from 0.79277
# Epoch 50/50
# 2322/2322 [==============================] - 21s 9ms/step - loss: 0.0753 - matthews_correlation: 0.7053 - val_loss: 0.0787 - val_matthews_correlation: 0.7582
#
# Epoch 00050: val_matthews_correlation did not improve from 0.79277
# Beginning fold 2
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.3131 - matthews_correlation: 0.0000e+00 - val_loss: 0.2351 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.2270 - matthews_correlation: 0.0000e+00 - val_loss: 0.2247 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.2045 - matthews_correlation: 0.1857 - val_loss: 0.2138 - val_matthews_correlation: 0.1045
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.10453, saving model to weights_1.h5
# Epoch 4/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1892 - matthews_correlation: 0.2539 - val_loss: 0.1958 - val_matthews_correlation: 0.1045
#
# Epoch 00004: val_matthews_correlation did not improve from 0.10453
# Epoch 5/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1673 - matthews_correlation: 0.2699 - val_loss: 0.1809 - val_matthews_correlation: 0.3787
#
# Epoch 00005: val_matthews_correlation improved from 0.10453 to 0.37873, saving model to weights_1.h5
# Epoch 6/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1552 - matthews_correlation: 0.3518 - val_loss: 0.1541 - val_matthews_correlation: 0.4739
#
# Epoch 00006: val_matthews_correlation improved from 0.37873 to 0.47391, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1279 - matthews_correlation: 0.5616 - val_loss: 0.1176 - val_matthews_correlation: 0.5714
#
# Epoch 00007: val_matthews_correlation improved from 0.47391 to 0.57142, saving model to weights_1.h5
# Epoch 8/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1771 - matthews_correlation: 0.3399 - val_loss: 0.1418 - val_matthews_correlation: 0.1188
#
# Epoch 00008: val_matthews_correlation did not improve from 0.57142
# Epoch 9/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1209 - matthews_correlation: 0.4825 - val_loss: 0.1365 - val_matthews_correlation: 0.5417
#
# Epoch 00009: val_matthews_correlation did not improve from 0.57142
# Epoch 10/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1187 - matthews_correlation: 0.6202 - val_loss: 0.1161 - val_matthews_correlation: 0.6185
#
# Epoch 00010: val_matthews_correlation improved from 0.57142 to 0.61852, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1145 - matthews_correlation: 0.6150 - val_loss: 0.1147 - val_matthews_correlation: 0.5944
#
# Epoch 00011: val_matthews_correlation did not improve from 0.61852
# Epoch 12/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1102 - matthews_correlation: 0.6580 - val_loss: 0.1157 - val_matthews_correlation: 0.6118
#
# Epoch 00012: val_matthews_correlation did not improve from 0.61852
# Epoch 13/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1055 - matthews_correlation: 0.6359 - val_loss: 0.1042 - val_matthews_correlation: 0.6185
#
# Epoch 00013: val_matthews_correlation did not improve from 0.61852
# Epoch 14/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1040 - matthews_correlation: 0.6678 - val_loss: 0.1068 - val_matthews_correlation: 0.6388
#
# Epoch 00014: val_matthews_correlation improved from 0.61852 to 0.63881, saving model to weights_1.h5
# Epoch 15/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.1037 - matthews_correlation: 0.6860 - val_loss: 0.1121 - val_matthews_correlation: 0.5845
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63881
# Epoch 16/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0987 - matthews_correlation: 0.6729 - val_loss: 0.1058 - val_matthews_correlation: 0.6147
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63881
# Epoch 17/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0937 - matthews_correlation: 0.6504 - val_loss: 0.1079 - val_matthews_correlation: 0.6485
#
# Epoch 00017: val_matthews_correlation improved from 0.63881 to 0.64855, saving model to weights_1.h5
# Epoch 18/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0930 - matthews_correlation: 0.6723 - val_loss: 0.1056 - val_matthews_correlation: 0.6314
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64855
# Epoch 19/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0924 - matthews_correlation: 0.6934 - val_loss: 0.0985 - val_matthews_correlation: 0.6426
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64855
# Epoch 20/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0940 - matthews_correlation: 0.6606 - val_loss: 0.0938 - val_matthews_correlation: 0.6916
#
# Epoch 00020: val_matthews_correlation improved from 0.64855 to 0.69162, saving model to weights_1.h5
# Epoch 21/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1001 - matthews_correlation: 0.6795 - val_loss: 0.1083 - val_matthews_correlation: 0.6645
#
# Epoch 00021: val_matthews_correlation did not improve from 0.69162
# Epoch 22/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0965 - matthews_correlation: 0.6307 - val_loss: 0.1115 - val_matthews_correlation: 0.6370
#
# Epoch 00022: val_matthews_correlation did not improve from 0.69162
# Epoch 23/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0954 - matthews_correlation: 0.6385 - val_loss: 0.0940 - val_matthews_correlation: 0.7088
#
# Epoch 00023: val_matthews_correlation improved from 0.69162 to 0.70877, saving model to weights_1.h5
# Epoch 24/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1022 - matthews_correlation: 0.6410 - val_loss: 0.0979 - val_matthews_correlation: 0.6246
#
# Epoch 00024: val_matthews_correlation did not improve from 0.70877
# Epoch 25/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0880 - matthews_correlation: 0.6507 - val_loss: 0.1104 - val_matthews_correlation: 0.6198
#
# Epoch 00025: val_matthews_correlation did not improve from 0.70877
# Epoch 26/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0855 - matthews_correlation: 0.7088 - val_loss: 0.1037 - val_matthews_correlation: 0.6528
#
# Epoch 00026: val_matthews_correlation did not improve from 0.70877
# Epoch 27/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0898 - matthews_correlation: 0.6475 - val_loss: 0.1098 - val_matthews_correlation: 0.5515
#
# Epoch 00027: val_matthews_correlation did not improve from 0.70877
# Epoch 28/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0908 - matthews_correlation: 0.6452 - val_loss: 0.0931 - val_matthews_correlation: 0.6731
#
# Epoch 00028: val_matthews_correlation did not improve from 0.70877
# Epoch 29/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0856 - matthews_correlation: 0.6855 - val_loss: 0.0893 - val_matthews_correlation: 0.7146
#
# Epoch 00029: val_matthews_correlation improved from 0.70877 to 0.71463, saving model to weights_1.h5
# Epoch 30/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0849 - matthews_correlation: 0.6560 - val_loss: 0.1086 - val_matthews_correlation: 0.6229
#
# Epoch 00030: val_matthews_correlation did not improve from 0.71463
# Epoch 31/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0844 - matthews_correlation: 0.6919 - val_loss: 0.0952 - val_matthews_correlation: 0.6906
#
# Epoch 00031: val_matthews_correlation did not improve from 0.71463
# Epoch 32/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0792 - matthews_correlation: 0.7001 - val_loss: 0.0980 - val_matthews_correlation: 0.6978
#
# Epoch 00032: val_matthews_correlation did not improve from 0.71463
# Epoch 33/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0776 - matthews_correlation: 0.7021 - val_loss: 0.1052 - val_matthews_correlation: 0.6763
#
# Epoch 00033: val_matthews_correlation did not improve from 0.71463
# Epoch 34/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0795 - matthews_correlation: 0.7122 - val_loss: 0.1035 - val_matthews_correlation: 0.6206
#
# Epoch 00034: val_matthews_correlation did not improve from 0.71463
# Epoch 35/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0773 - matthews_correlation: 0.6959 - val_loss: 0.0969 - val_matthews_correlation: 0.7085
#
# Epoch 00035: val_matthews_correlation did not improve from 0.71463
# Epoch 36/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0865 - matthews_correlation: 0.6611 - val_loss: 0.0961 - val_matthews_correlation: 0.6748
#
# Epoch 00036: val_matthews_correlation did not improve from 0.71463
# Epoch 37/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0757 - matthews_correlation: 0.6917 - val_loss: 0.0884 - val_matthews_correlation: 0.6968
#
# Epoch 00037: val_matthews_correlation did not improve from 0.71463
# Epoch 38/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0742 - matthews_correlation: 0.6414 - val_loss: 0.1110 - val_matthews_correlation: 0.6754
#
# Epoch 00038: val_matthews_correlation did not improve from 0.71463
# Epoch 39/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0744 - matthews_correlation: 0.7553 - val_loss: 0.0912 - val_matthews_correlation: 0.7488
#
# Epoch 00039: val_matthews_correlation improved from 0.71463 to 0.74882, saving model to weights_1.h5
# Epoch 40/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0700 - matthews_correlation: 0.7528 - val_loss: 0.0998 - val_matthews_correlation: 0.7206
#
# Epoch 00040: val_matthews_correlation did not improve from 0.74882
# Epoch 41/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0727 - matthews_correlation: 0.6856 - val_loss: 0.1081 - val_matthews_correlation: 0.7555
#
# Epoch 00041: val_matthews_correlation improved from 0.74882 to 0.75548, saving model to weights_1.h5
# Epoch 42/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0723 - matthews_correlation: 0.7152 - val_loss: 0.1042 - val_matthews_correlation: 0.6837
#
# Epoch 00042: val_matthews_correlation did not improve from 0.75548
# Epoch 43/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0724 - matthews_correlation: 0.7837 - val_loss: 0.0988 - val_matthews_correlation: 0.6382
#
# Epoch 00043: val_matthews_correlation did not improve from 0.75548
# Epoch 44/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0727 - matthews_correlation: 0.7342 - val_loss: 0.0960 - val_matthews_correlation: 0.6468
#
# Epoch 00044: val_matthews_correlation did not improve from 0.75548
# Epoch 45/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0773 - matthews_correlation: 0.7151 - val_loss: 0.2126 - val_matthews_correlation: 0.6211
#
# Epoch 00045: val_matthews_correlation did not improve from 0.75548
# Epoch 46/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0900 - matthews_correlation: 0.6855 - val_loss: 0.0854 - val_matthews_correlation: 0.7657
#
# Epoch 00046: val_matthews_correlation improved from 0.75548 to 0.76571, saving model to weights_1.h5
# Epoch 47/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0923 - matthews_correlation: 0.6027 - val_loss: 0.0989 - val_matthews_correlation: 0.6544
#
# Epoch 00047: val_matthews_correlation did not improve from 0.76571
# Epoch 48/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0847 - matthews_correlation: 0.6724 - val_loss: 0.0936 - val_matthews_correlation: 0.6531
#
# Epoch 00048: val_matthews_correlation did not improve from 0.76571
# Epoch 49/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0851 - matthews_correlation: 0.6692 - val_loss: 0.0931 - val_matthews_correlation: 0.6972
#
# Epoch 00049: val_matthews_correlation did not improve from 0.76571
# Epoch 50/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0791 - matthews_correlation: 0.7447 - val_loss: 0.0880 - val_matthews_correlation: 0.7531
# Epoch 00050: val_matthews_correlation did not improve from 0.76571
# Beginning fold 3
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 24s 10ms/step - loss: 0.2867 - matthews_correlation: -0.0013 - val_loss: 0.2279 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.2230 - matthews_correlation: 0.0000e+00 - val_loss: 0.2011 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.2101 - matthews_correlation: 0.0558 - val_loss: 0.1942 - val_matthews_correlation: 0.0242
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.02415, saving model to weights_2.h5
# Epoch 4/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1955 - matthews_correlation: 0.2286 - val_loss: 0.1707 - val_matthews_correlation: 0.3466
#
# Epoch 00004: val_matthews_correlation improved from 0.02415 to 0.34657, saving model to weights_2.h5
# Epoch 5/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1782 - matthews_correlation: 0.3052 - val_loss: 0.1668 - val_matthews_correlation: 0.2472
#
# Epoch 00005: val_matthews_correlation did not improve from 0.34657
# Epoch 6/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1507 - matthews_correlation: 0.4240 - val_loss: 0.1555 - val_matthews_correlation: 0.3946
#
# Epoch 00006: val_matthews_correlation improved from 0.34657 to 0.39464, saving model to weights_2.h5
# Epoch 7/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1327 - matthews_correlation: 0.4100 - val_loss: 0.1126 - val_matthews_correlation: 0.6746
#
# Epoch 00007: val_matthews_correlation improved from 0.39464 to 0.67459, saving model to weights_2.h5
# Epoch 8/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1275 - matthews_correlation: 0.5968 - val_loss: 0.1279 - val_matthews_correlation: 0.4449
#
# Epoch 00008: val_matthews_correlation did not improve from 0.67459
# Epoch 9/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1166 - matthews_correlation: 0.6158 - val_loss: 0.1107 - val_matthews_correlation: 0.6753
#
# Epoch 00009: val_matthews_correlation improved from 0.67459 to 0.67533, saving model to weights_2.h5
# Epoch 10/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1061 - matthews_correlation: 0.6074 - val_loss: 0.1040 - val_matthews_correlation: 0.5800
#
# Epoch 00010: val_matthews_correlation did not improve from 0.67533
# Epoch 11/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0978 - matthews_correlation: 0.6681 - val_loss: 0.1142 - val_matthews_correlation: 0.6143
#
# Epoch 00011: val_matthews_correlation did not improve from 0.67533
# Epoch 12/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1044 - matthews_correlation: 0.6034 - val_loss: 0.1111 - val_matthews_correlation: 0.5297
#
# Epoch 00012: val_matthews_correlation did not improve from 0.67533
# Epoch 13/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1066 - matthews_correlation: 0.5692 - val_loss: 0.1443 - val_matthews_correlation: 0.6439
#
# Epoch 00013: val_matthews_correlation did not improve from 0.67533
# Epoch 14/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1151 - matthews_correlation: 0.6147 - val_loss: 0.1073 - val_matthews_correlation: 0.6362
#
# Epoch 00014: val_matthews_correlation did not improve from 0.67533
# Epoch 15/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0995 - matthews_correlation: 0.6553 - val_loss: 0.1060 - val_matthews_correlation: 0.5690
#
# Epoch 00015: val_matthews_correlation did not improve from 0.67533
# Epoch 16/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1016 - matthews_correlation: 0.6206 - val_loss: 0.1050 - val_matthews_correlation: 0.6327
#
# Epoch 00016: val_matthews_correlation did not improve from 0.67533
# Epoch 17/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0909 - matthews_correlation: 0.6527 - val_loss: 0.1039 - val_matthews_correlation: 0.6492
#
# Epoch 00017: val_matthews_correlation did not improve from 0.67533
# Epoch 18/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0892 - matthews_correlation: 0.7074 - val_loss: 0.1029 - val_matthews_correlation: 0.6378
#
# Epoch 00018: val_matthews_correlation did not improve from 0.67533
# Epoch 19/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0860 - matthews_correlation: 0.7082 - val_loss: 0.1181 - val_matthews_correlation: 0.5735
#
# Epoch 00019: val_matthews_correlation did not improve from 0.67533
# Epoch 20/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.1061 - matthews_correlation: 0.6305 - val_loss: 0.1062 - val_matthews_correlation: 0.6371
#
# Epoch 00020: val_matthews_correlation did not improve from 0.67533
# Epoch 21/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0861 - matthews_correlation: 0.7136 - val_loss: 0.1023 - val_matthews_correlation: 0.6332
#
# Epoch 00021: val_matthews_correlation did not improve from 0.67533
# Epoch 22/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0823 - matthews_correlation: 0.7267 - val_loss: 0.0993 - val_matthews_correlation: 0.6295
#
# Epoch 00022: val_matthews_correlation did not improve from 0.67533
# Epoch 23/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0848 - matthews_correlation: 0.6960 - val_loss: 0.1008 - val_matthews_correlation: 0.5687
#
# Epoch 00023: val_matthews_correlation did not improve from 0.67533
# Epoch 24/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0812 - matthews_correlation: 0.7131 - val_loss: 0.1047 - val_matthews_correlation: 0.6766
#
# Epoch 00024: val_matthews_correlation improved from 0.67533 to 0.67658, saving model to weights_2.h5
# Epoch 25/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0872 - matthews_correlation: 0.6851 - val_loss: 0.1094 - val_matthews_correlation: 0.5569
#
# Epoch 00025: val_matthews_correlation did not improve from 0.67658
# Epoch 26/50
# 2323/2323 [==============================] - 21s 9ms/step - loss: 0.0876 - matthews_correlation: 0.7220 - val_loss: 0.1020 - val_matthews_correlation: 0.6125
#
# Epoch 00026: val_matthews_correlation did not improve from 0.67658
# Epoch 27/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0830 - matthews_correlation: 0.7042 - val_loss: 0.0983 - val_matthews_correlation: 0.6977
#
# Epoch 00027: val_matthews_correlation improved from 0.67658 to 0.69773, saving model to weights_2.h5
# Epoch 28/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0840 - matthews_correlation: 0.7111 - val_loss: 0.0995 - val_matthews_correlation: 0.6361
#
# Epoch 00028: val_matthews_correlation did not improve from 0.69773
# Epoch 29/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0771 - matthews_correlation: 0.7499 - val_loss: 0.1010 - val_matthews_correlation: 0.6193
#
# Epoch 00029: val_matthews_correlation did not improve from 0.69773
# Epoch 30/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0819 - matthews_correlation: 0.7329 - val_loss: 0.1026 - val_matthews_correlation: 0.6845
#
# Epoch 00030: val_matthews_correlation did not improve from 0.69773
# Epoch 31/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0819 - matthews_correlation: 0.7543 - val_loss: 0.0997 - val_matthews_correlation: 0.6839
#
# Epoch 00031: val_matthews_correlation did not improve from 0.69773
# Epoch 32/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0765 - matthews_correlation: 0.7006 - val_loss: 0.0996 - val_matthews_correlation: 0.6078
#
# Epoch 00032: val_matthews_correlation did not improve from 0.69773
# Epoch 33/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0812 - matthews_correlation: 0.7544 - val_loss: 0.1022 - val_matthews_correlation: 0.5659
# Epoch 00033: val_matthews_correlation did not improve from 0.69773
# Epoch 34/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0833 - matthews_correlation: 0.7063 - val_loss: 0.1137 - val_matthews_correlation: 0.6602
#
# Epoch 00034: val_matthews_correlation did not improve from 0.69773
# Epoch 35/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0808 - matthews_correlation: 0.7382 - val_loss: 0.1025 - val_matthews_correlation: 0.6295
#
# Epoch 00035: val_matthews_correlation did not improve from 0.69773
# Epoch 36/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0786 - matthews_correlation: 0.6944 - val_loss: 0.0998 - val_matthews_correlation: 0.6389
#
# Epoch 00036: val_matthews_correlation did not improve from 0.69773
# Epoch 37/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0772 - matthews_correlation: 0.7560 - val_loss: 0.0984 - val_matthews_correlation: 0.6337
#
# Epoch 00037: val_matthews_correlation did not improve from 0.69773
# Epoch 38/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0713 - matthews_correlation: 0.7232 - val_loss: 0.1018 - val_matthews_correlation: 0.6310
#
# Epoch 00038: val_matthews_correlation did not improve from 0.69773
# Epoch 39/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0851 - matthews_correlation: 0.7072 - val_loss: 0.1001 - val_matthews_correlation: 0.6977
#
# Epoch 00039: val_matthews_correlation did not improve from 0.69773
# Epoch 40/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0724 - matthews_correlation: 0.7684 - val_loss: 0.0998 - val_matthews_correlation: 0.6783
#
# Epoch 00040: val_matthews_correlation did not improve from 0.69773
# Epoch 41/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0764 - matthews_correlation: 0.7062 - val_loss: 0.1123 - val_matthews_correlation: 0.5220
#
# Epoch 00041: val_matthews_correlation did not improve from 0.69773
# Epoch 42/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0779 - matthews_correlation: 0.7387 - val_loss: 0.1009 - val_matthews_correlation: 0.6179
#
# Epoch 00042: val_matthews_correlation did not improve from 0.69773
# Epoch 43/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0706 - matthews_correlation: 0.7584 - val_loss: 0.1072 - val_matthews_correlation: 0.6166
#
# Epoch 00043: val_matthews_correlation did not improve from 0.69773
# Epoch 44/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0703 - matthews_correlation: 0.7687 - val_loss: 0.1019 - val_matthews_correlation: 0.6697
#
# Epoch 00044: val_matthews_correlation did not improve from 0.69773
# Epoch 45/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0698 - matthews_correlation: 0.7519 - val_loss: 0.1078 - val_matthews_correlation: 0.6408
#
# Epoch 00045: val_matthews_correlation did not improve from 0.69773
# Epoch 46/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0740 - matthews_correlation: 0.7120 - val_loss: 0.1021 - val_matthews_correlation: 0.6305
#
# Epoch 00046: val_matthews_correlation did not improve from 0.69773
# Epoch 47/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0678 - matthews_correlation: 0.7188 - val_loss: 0.0998 - val_matthews_correlation: 0.6092
#
# Epoch 00047: val_matthews_correlation did not improve from 0.69773
# Epoch 48/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0660 - matthews_correlation: 0.7857 - val_loss: 0.0950 - val_matthews_correlation: 0.6671
#
# Epoch 00048: val_matthews_correlation did not improve from 0.69773
# Epoch 49/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0717 - matthews_correlation: 0.7646 - val_loss: 0.0967 - val_matthews_correlation: 0.6924
#
# Epoch 00049: val_matthews_correlation did not improve from 0.69773
# Epoch 50/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.0705 - matthews_correlation: 0.7474 - val_loss: 0.1024 - val_matthews_correlation: 0.6332
#
# Epoch 00050: val_matthews_correlation did not improve from 0.69773
# Beginning fold 4
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.2997 - matthews_correlation: 0.0000e+00 - val_loss: 0.2263 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2285 - matthews_correlation: 0.0000e+00 - val_loss: 0.2217 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2227 - matthews_correlation: 0.0000e+00 - val_loss: 0.2133 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2161 - matthews_correlation: 0.0139 - val_loss: 0.2150 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2081 - matthews_correlation: 0.2076 - val_loss: 0.1835 - val_matthews_correlation: 0.2741
#
# Epoch 00005: val_matthews_correlation improved from 0.00000 to 0.27415, saving model to weights_3.h5
# Epoch 6/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1909 - matthews_correlation: 0.0410 - val_loss: 0.2039 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.27415
# Epoch 7/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2007 - matthews_correlation: 0.1496 - val_loss: 0.1801 - val_matthews_correlation: 0.2741
#
# Epoch 00007: val_matthews_correlation did not improve from 0.27415
# Epoch 8/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1693 - matthews_correlation: 0.3263 - val_loss: 0.1350 - val_matthews_correlation: 0.3546
#
# Epoch 00008: val_matthews_correlation improved from 0.27415 to 0.35461, saving model to weights_3.h5
# Epoch 9/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1235 - matthews_correlation: 0.5793 - val_loss: 0.1168 - val_matthews_correlation: 0.5880
#
# Epoch 00009: val_matthews_correlation improved from 0.35461 to 0.58802, saving model to weights_3.h5
# Epoch 10/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1209 - matthews_correlation: 0.5417 - val_loss: 0.1256 - val_matthews_correlation: 0.3631
#
# Epoch 00010: val_matthews_correlation did not improve from 0.58802
# Epoch 11/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1153 - matthews_correlation: 0.5497 - val_loss: 0.1240 - val_matthews_correlation: 0.4320
#
# Epoch 00011: val_matthews_correlation did not improve from 0.58802
# Epoch 12/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1130 - matthews_correlation: 0.5823 - val_loss: 0.1134 - val_matthews_correlation: 0.5988
#
# Epoch 00012: val_matthews_correlation improved from 0.58802 to 0.59884, saving model to weights_3.h5
# Epoch 13/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1040 - matthews_correlation: 0.6441 - val_loss: 0.1102 - val_matthews_correlation: 0.5988
#
# Epoch 00013: val_matthews_correlation did not improve from 0.59884
# Epoch 14/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0986 - matthews_correlation: 0.5877 - val_loss: 0.1123 - val_matthews_correlation: 0.4431
#
# Epoch 00014: val_matthews_correlation did not improve from 0.59884
# Epoch 15/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0955 - matthews_correlation: 0.6196 - val_loss: 0.1109 - val_matthews_correlation: 0.4416
#
# Epoch 00015: val_matthews_correlation did not improve from 0.59884
# Epoch 16/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0985 - matthews_correlation: 0.5894 - val_loss: 0.1116 - val_matthews_correlation: 0.6478
#
# Epoch 00016: val_matthews_correlation improved from 0.59884 to 0.64776, saving model to weights_3.h5
# Epoch 17/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0985 - matthews_correlation: 0.6523 - val_loss: 0.1088 - val_matthews_correlation: 0.4706
#
# Epoch 00017: val_matthews_correlation did not improve from 0.64776
# Epoch 18/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1022 - matthews_correlation: 0.6318 - val_loss: 0.1173 - val_matthews_correlation: 0.4504
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64776
# Epoch 19/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0973 - matthews_correlation: 0.5881 - val_loss: 0.1094 - val_matthews_correlation: 0.4326
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64776
# Epoch 20/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0929 - matthews_correlation: 0.6748 - val_loss: 0.1131 - val_matthews_correlation: 0.5695
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64776
# Epoch 21/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0907 - matthews_correlation: 0.6965 - val_loss: 0.1214 - val_matthews_correlation: 0.4520
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64776
# Epoch 22/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0893 - matthews_correlation: 0.6889 - val_loss: 0.1047 - val_matthews_correlation: 0.4713
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64776
# Epoch 23/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0875 - matthews_correlation: 0.7325 - val_loss: 0.0997 - val_matthews_correlation: 0.4685
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64776
# Epoch 24/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0874 - matthews_correlation: 0.6726 - val_loss: 0.1273 - val_matthews_correlation: 0.4388
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64776
# Epoch 25/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0936 - matthews_correlation: 0.6600 - val_loss: 0.1020 - val_matthews_correlation: 0.5164
#
# Epoch 00025: val_matthews_correlation did not improve from 0.64776
# Epoch 26/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0862 - matthews_correlation: 0.6902 - val_loss: 0.1109 - val_matthews_correlation: 0.4811
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64776
# Epoch 27/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0882 - matthews_correlation: 0.6520 - val_loss: 0.1201 - val_matthews_correlation: 0.4811
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64776
# Epoch 28/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0793 - matthews_correlation: 0.7227 - val_loss: 0.1032 - val_matthews_correlation: 0.5227
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64776
# Epoch 29/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0803 - matthews_correlation: 0.7106 - val_loss: 0.1152 - val_matthews_correlation: 0.6887
#
# Epoch 00029: val_matthews_correlation improved from 0.64776 to 0.68871, saving model to weights_3.h5
# Epoch 30/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0885 - matthews_correlation: 0.6478 - val_loss: 0.1000 - val_matthews_correlation: 0.5203
#
# Epoch 00030: val_matthews_correlation did not improve from 0.68871
# Epoch 31/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0804 - matthews_correlation: 0.7196 - val_loss: 0.1089 - val_matthews_correlation: 0.4713
#
# Epoch 00031: val_matthews_correlation did not improve from 0.68871
# Epoch 32/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0765 - matthews_correlation: 0.6983 - val_loss: 0.1084 - val_matthews_correlation: 0.4889
#
# Epoch 00032: val_matthews_correlation did not improve from 0.68871
# Epoch 33/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0758 - matthews_correlation: 0.7281 - val_loss: 0.1070 - val_matthews_correlation: 0.5715
#
# Epoch 00033: val_matthews_correlation did not improve from 0.68871
# Epoch 34/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0741 - matthews_correlation: 0.7660 - val_loss: 0.1070 - val_matthews_correlation: 0.5150
#
# Epoch 00034: val_matthews_correlation did not improve from 0.68871
# Epoch 35/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0823 - matthews_correlation: 0.6750 - val_loss: 0.1057 - val_matthews_correlation: 0.4662
#
# Epoch 00035: val_matthews_correlation did not improve from 0.68871
# Epoch 36/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0818 - matthews_correlation: 0.7129 - val_loss: 0.1072 - val_matthews_correlation: 0.5167
#
# Epoch 00036: val_matthews_correlation did not improve from 0.68871
# Epoch 37/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0795 - matthews_correlation: 0.7366 - val_loss: 0.1077 - val_matthews_correlation: 0.5317
#
# Epoch 00037: val_matthews_correlation did not improve from 0.68871
# Epoch 38/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0778 - matthews_correlation: 0.7306 - val_loss: 0.1105 - val_matthews_correlation: 0.5019
#
# Epoch 00038: val_matthews_correlation did not improve from 0.68871
# Epoch 39/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0734 - matthews_correlation: 0.7497 - val_loss: 0.1035 - val_matthews_correlation: 0.5126
#
# Epoch 00039: val_matthews_correlation did not improve from 0.68871
# Epoch 40/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0685 - matthews_correlation: 0.7464 - val_loss: 0.1311 - val_matthews_correlation: 0.5100
#
# Epoch 00040: val_matthews_correlation did not improve from 0.68871
# Epoch 41/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0788 - matthews_correlation: 0.7405 - val_loss: 0.1806 - val_matthews_correlation: 0.5533
#
# Epoch 00041: val_matthews_correlation did not improve from 0.68871
# Epoch 42/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1035 - matthews_correlation: 0.5328 - val_loss: 0.1040 - val_matthews_correlation: 0.4463
#
# Epoch 00042: val_matthews_correlation did not improve from 0.68871
# Epoch 43/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0851 - matthews_correlation: 0.7086 - val_loss: 0.0886 - val_matthews_correlation: 0.6926
#
# Epoch 00043: val_matthews_correlation improved from 0.68871 to 0.69261, saving model to weights_3.h5
# Epoch 44/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0863 - matthews_correlation: 0.7233 - val_loss: 0.0990 - val_matthews_correlation: 0.5702
#
# Epoch 00044: val_matthews_correlation did not improve from 0.69261
# Epoch 45/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0796 - matthews_correlation: 0.7044 - val_loss: 0.1095 - val_matthews_correlation: 0.5356
#
# Epoch 00045: val_matthews_correlation did not improve from 0.69261
# Epoch 46/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0919 - matthews_correlation: 0.6663 - val_loss: 0.1051 - val_matthews_correlation: 0.5317
#
# Epoch 00046: val_matthews_correlation did not improve from 0.69261
# Epoch 47/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0708 - matthews_correlation: 0.7705 - val_loss: 0.0993 - val_matthews_correlation: 0.5795
#
# Epoch 00047: val_matthews_correlation did not improve from 0.69261
# Epoch 48/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0690 - matthews_correlation: 0.7344 - val_loss: 0.1031 - val_matthews_correlation: 0.5053
#
# Epoch 00048: val_matthews_correlation did not improve from 0.69261
# Epoch 49/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0652 - matthews_correlation: 0.7525 - val_loss: 0.1283 - val_matthews_correlation: 0.5483
#
# Epoch 00049: val_matthews_correlation did not improve from 0.69261
# Epoch 50/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0670 - matthews_correlation: 0.7740 - val_loss: 0.1056 - val_matthews_correlation: 0.5013
#
# Epoch 00050: val_matthews_correlation did not improve from 0.69261
# Beginning fold 5
# (?, ?, 256)
# (?, ?, 128)
# (?, 128)
# (?, 64)
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 23s 10ms/step - loss: 0.2791 - matthews_correlation: 0.0000e+00 - val_loss: 0.2293 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.2272 - matthews_correlation: 0.0000e+00 - val_loss: 0.2044 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.2117 - matthews_correlation: 0.1165 - val_loss: 0.1851 - val_matthews_correlation: 0.3887
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.38873, saving model to weights_4.h5
# Epoch 4/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1838 - matthews_correlation: 0.1976 - val_loss: 0.1665 - val_matthews_correlation: 0.3887
#
# Epoch 00004: val_matthews_correlation did not improve from 0.38873
# Epoch 5/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1620 - matthews_correlation: 0.1515 - val_loss: 0.1396 - val_matthews_correlation: 0.3952
#
# Epoch 00005: val_matthews_correlation improved from 0.38873 to 0.39520, saving model to weights_4.h5
# Epoch 6/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1241 - matthews_correlation: 0.4972 - val_loss: 0.1379 - val_matthews_correlation: 0.5313
#
# Epoch 00006: val_matthews_correlation improved from 0.39520 to 0.53130, saving model to weights_4.h5
# Epoch 7/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1199 - matthews_correlation: 0.5396 - val_loss: 0.1300 - val_matthews_correlation: 0.5016
#
# Epoch 00007: val_matthews_correlation did not improve from 0.53130
# Epoch 8/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1060 - matthews_correlation: 0.5415 - val_loss: 0.1366 - val_matthews_correlation: 0.3571
#
# Epoch 00008: val_matthews_correlation did not improve from 0.53130
# Epoch 9/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1041 - matthews_correlation: 0.6399 - val_loss: 0.1232 - val_matthews_correlation: 0.5818
#
# Epoch 00009: val_matthews_correlation improved from 0.53130 to 0.58182, saving model to weights_4.h5
# Epoch 10/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0957 - matthews_correlation: 0.6403 - val_loss: 0.1281 - val_matthews_correlation: 0.3862
#
# Epoch 00010: val_matthews_correlation did not improve from 0.58182
# Epoch 11/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1010 - matthews_correlation: 0.6256 - val_loss: 0.1262 - val_matthews_correlation: 0.3064
#
# Epoch 00011: val_matthews_correlation did not improve from 0.58182
# Epoch 12/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0985 - matthews_correlation: 0.6470 - val_loss: 0.1150 - val_matthews_correlation: 0.6142
#
# Epoch 00012: val_matthews_correlation improved from 0.58182 to 0.61424, saving model to weights_4.h5
# Epoch 13/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0965 - matthews_correlation: 0.6739 - val_loss: 0.1189 - val_matthews_correlation: 0.4217
#
# Epoch 00013: val_matthews_correlation did not improve from 0.61424
# Epoch 14/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0962 - matthews_correlation: 0.6691 - val_loss: 0.1135 - val_matthews_correlation: 0.6062
#
# Epoch 00014: val_matthews_correlation did not improve from 0.61424
# Epoch 15/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0936 - matthews_correlation: 0.6337 - val_loss: 0.1191 - val_matthews_correlation: 0.4352
#
# Epoch 00015: val_matthews_correlation did not improve from 0.61424
# Epoch 16/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0921 - matthews_correlation: 0.6845 - val_loss: 0.1190 - val_matthews_correlation: 0.6204
#
# Epoch 00016: val_matthews_correlation improved from 0.61424 to 0.62041, saving model to weights_4.h5
# Epoch 17/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0899 - matthews_correlation: 0.6821 - val_loss: 0.1100 - val_matthews_correlation: 0.5404
#
# Epoch 00017: val_matthews_correlation did not improve from 0.62041
# Epoch 18/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0873 - matthews_correlation: 0.6735 - val_loss: 0.1104 - val_matthews_correlation: 0.5758
#
# Epoch 00018: val_matthews_correlation did not improve from 0.62041
# Epoch 19/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0993 - matthews_correlation: 0.6308 - val_loss: 0.1052 - val_matthews_correlation: 0.6447
#
# Epoch 00019: val_matthews_correlation improved from 0.62041 to 0.64473, saving model to weights_4.h5
# Epoch 20/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0873 - matthews_correlation: 0.6781 - val_loss: 0.1175 - val_matthews_correlation: 0.6423
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64473
# Epoch 21/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0861 - matthews_correlation: 0.7067 - val_loss: 0.1112 - val_matthews_correlation: 0.6207
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64473
# Epoch 22/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0895 - matthews_correlation: 0.6819 - val_loss: 0.1358 - val_matthews_correlation: 0.3986
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64473
# Epoch 23/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0910 - matthews_correlation: 0.6385 - val_loss: 0.1115 - val_matthews_correlation: 0.6294
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64473
# Epoch 24/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0832 - matthews_correlation: 0.7101 - val_loss: 0.1067 - val_matthews_correlation: 0.5978
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64473
# Epoch 25/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0814 - matthews_correlation: 0.7494 - val_loss: 0.1063 - val_matthews_correlation: 0.6046
#
# Epoch 00025: val_matthews_correlation did not improve from 0.64473
# Epoch 26/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0785 - matthews_correlation: 0.6751 - val_loss: 0.1092 - val_matthews_correlation: 0.6128
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64473
# Epoch 27/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0793 - matthews_correlation: 0.7344 - val_loss: 0.1109 - val_matthews_correlation: 0.5490
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64473
# Epoch 28/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0938 - matthews_correlation: 0.6899 - val_loss: 0.1047 - val_matthews_correlation: 0.5859
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64473
# Epoch 29/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.1021 - matthews_correlation: 0.5383 - val_loss: 0.1165 - val_matthews_correlation: 0.4241
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64473
# Epoch 30/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0871 - matthews_correlation: 0.6248 - val_loss: 0.1307 - val_matthews_correlation: 0.6062
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64473
# Epoch 31/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0915 - matthews_correlation: 0.6678 - val_loss: 0.1153 - val_matthews_correlation: 0.6183
#
# Epoch 00031: val_matthews_correlation did not improve from 0.64473
# Epoch 32/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0845 - matthews_correlation: 0.6828 - val_loss: 0.1107 - val_matthews_correlation: 0.5933
#
# Epoch 00032: val_matthews_correlation did not improve from 0.64473
# Epoch 33/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0826 - matthews_correlation: 0.7127 - val_loss: 0.1164 - val_matthews_correlation: 0.6247
#
# Epoch 00033: val_matthews_correlation did not improve from 0.64473
# Epoch 34/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0801 - matthews_correlation: 0.7459 - val_loss: 0.1175 - val_matthews_correlation: 0.6275
#
# Epoch 00034: val_matthews_correlation did not improve from 0.64473
# Epoch 35/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0776 - matthews_correlation: 0.7301 - val_loss: 0.1138 - val_matthews_correlation: 0.5861
#
# Epoch 00035: val_matthews_correlation did not improve from 0.64473
# Epoch 36/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0743 - matthews_correlation: 0.7483 - val_loss: 0.1105 - val_matthews_correlation: 0.6735
#
# Epoch 00036: val_matthews_correlation improved from 0.64473 to 0.67350, saving model to weights_4.h5
# Epoch 37/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0775 - matthews_correlation: 0.7168 - val_loss: 0.1181 - val_matthews_correlation: 0.6133
#
# Epoch 00037: val_matthews_correlation did not improve from 0.67350
# Epoch 38/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0813 - matthews_correlation: 0.7364 - val_loss: 0.1170 - val_matthews_correlation: 0.6055
#
# Epoch 00038: val_matthews_correlation did not improve from 0.67350
# Epoch 39/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0899 - matthews_correlation: 0.7041 - val_loss: 0.1136 - val_matthews_correlation: 0.6430
#
# Epoch 00039: val_matthews_correlation did not improve from 0.67350
# Epoch 40/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0828 - matthews_correlation: 0.6833 - val_loss: 0.1164 - val_matthews_correlation: 0.5757
#
# Epoch 00040: val_matthews_correlation did not improve from 0.67350
# Epoch 41/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0820 - matthews_correlation: 0.7021 - val_loss: 0.1105 - val_matthews_correlation: 0.6144
#
# Epoch 00041: val_matthews_correlation did not improve from 0.67350
# Epoch 42/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0807 - matthews_correlation: 0.6817 - val_loss: 0.1301 - val_matthews_correlation: 0.5779
#
# Epoch 00042: val_matthews_correlation did not improve from 0.67350
# Epoch 43/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0850 - matthews_correlation: 0.7015 - val_loss: 0.1133 - val_matthews_correlation: 0.6005
#
# Epoch 00043: val_matthews_correlation did not improve from 0.67350
# Epoch 44/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0884 - matthews_correlation: 0.6366 - val_loss: 0.1144 - val_matthews_correlation: 0.5434
#
# Epoch 00044: val_matthews_correlation did not improve from 0.67350
# Epoch 45/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0849 - matthews_correlation: 0.6900 - val_loss: 0.1218 - val_matthews_correlation: 0.6033
#
# Epoch 00045: val_matthews_correlation did not improve from 0.67350
# Epoch 46/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0801 - matthews_correlation: 0.7510 - val_loss: 0.1219 - val_matthews_correlation: 0.5986
#
# Epoch 00046: val_matthews_correlation did not improve from 0.67350
# Epoch 47/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0733 - matthews_correlation: 0.7527 - val_loss: 0.1162 - val_matthews_correlation: 0.6207
#
# Epoch 00047: val_matthews_correlation did not improve from 0.67350
# Epoch 48/50
# 2324/2324 [==============================] - 21s 9ms/step - loss: 0.0722 - matthews_correlation: 0.7481 - val_loss: 0.1299 - val_matthews_correlation: 0.5781
#
# Epoch 00048: val_matthews_correlation did not improve from 0.67350
# Epoch 49/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0918 - matthews_correlation: 0.6482 - val_loss: 0.1220 - val_matthews_correlation: 0.6124
#
# Epoch 00049: val_matthews_correlation did not improve from 0.67350
# Epoch 50/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.0816 - matthews_correlation: 0.7400 - val_loss: 0.1216 - val_matthews_correlation: 0.5677
#
# Epoch 00050: val_matthews_correlation did not improve from 0.67350
# ((2904,), (2904,))

# %%
np.save('./tmp/y_val_tmp_8.npy', y_val)
np.save('./tmp/preds_val_tmp_8.npy', preds_val)

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    
    #y_pred = K.cast(y_pred, np.float)
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = np.round(np.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)

    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        #score = matthews_correlation(y_true, (y_proba > threshold).astype(int))
        #score = K.eval(matthews_correlation(y_true, (y_proba > threshold).astype(int)))
        #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        score = matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 11068.52it/s]

# %%
best_threshold
# Out:
# 0.52

# %%
matthews_correlation(y_val[582:582+581], preds_val[582:582+581])

# %%
matthews_correlation(y_val, preds_val)
# Out:
# 0.7272947519285593

# %%
threshold_search(y_val[:582], preds_val[:582])['threshold']
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 15442.95it/s]
# 0.28

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')
df_test = meta_test.set_index(['id_measurement', 'phase'])
# Out:
# CPU times: user 11.6 ms, sys: 325 µs, total: 11.9 ms
# Wall time: 35 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data_test(start, end):
    # load a piece of data from file
    praq_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start+8712, end+8712)]).to_pandas()
    X = []

    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_test.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id = df_test.loc[id_measurement].loc[phase][0]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                ts_sum = praq_test[str(signal_id)] + praq_test[str(signal_id+1)] + praq_test[str(signal_id+2)]
                X_signal.append(transform_ts_sum(ts_sum))
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_test[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    return X

# %%
def process_subtest(arg_tuple):
    start, end, idx = arg_tuple
    X = prep_data_test(start, end)
    return idx, X

# %%
all_chunks = []

num_cores = 16 
#def load_all():
total_size = len(meta_test)
chunk_size = np.ceil(total_size/num_cores)
#train_size = len(df_train)

for i in range(16):
    if i != 15:
        start_idx = int(i * chunk_size)
        end_idx = int(start_idx + chunk_size)
        #chunk = (start_idx+train_size, end_idx+train_size, i)
        chunk = (start_idx, end_idx, i)
        all_chunks.append(chunk)
    else:
        start_idx = int(i * chunk_size)
        end_idx = int(total_size)
        #chunk = (start_idx+train_size, end_idx+train_size, i)
        chunk = (start_idx, end_idx, i)
        all_chunks.append(chunk)

# %%
pool = Pool()
results_1 = pool.map(process_subtest, all_chunks[0:8])    
results_1 = sorted(results_1, key=lambda tup: tup[0])
# Out:
# 100%|██████████| 424/424 [10:15<00:00,  1.44s/it]
# 100%|██████████| 424/424 [10:16<00:00,  1.46s/it]
# 100%|██████████| 424/424 [10:16<00:00,  1.40s/it]
# 100%|██████████| 424/424 [10:16<00:00,  1.44s/it]
# 100%|██████████| 424/424 [10:16<00:00,  1.44s/it]
# 100%|██████████| 424/424 [10:17<00:00,  1.43s/it]
# 100%|██████████| 424/424 [10:17<00:00,  1.40s/it]
# 100%|██████████| 424/424 [10:17<00:00,  1.38s/it]
#   8%|▊         | 34/424 [00:49<09:28,  1.46s/it]

# %%
results_2 = pool.map(process_subtest, all_chunks[8:16])    
results_2 = sorted(results_2, key=lambda tup: tup[0])

# %%
results = results_1 + results_2
X_test = np.concatenate([item[1] for item in results], axis=0)

# %%
np.save("X_test_6.npy",X_test)

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %% [markdown]
# splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
#
# for idx, (train_idx, val_idx) in enumerate(splits):
#     K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
#     print("Beginning fold {}".format(idx+1))
#     # use the indexes to extract the folds in the train and validation data
#     train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
#     # instantiate the model for this fold
#     model = model_lstm(train_X.shape)

# %%
X_test[np.isnan(X_test)] = 0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 17s 2ms/step
# 6779/6779 [==============================] - 17s 2ms/step
# 6779/6779 [==============================] - 17s 2ms/step
# 6779/6779 [==============================] - 17s 2ms/step
# 6779/6779 [==============================] - 17s 2ms/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('../output/submission_24.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
lstm_preds = np.squeeze(np.mean(preds_test, axis=0))
np.save("./lstm_preds.npy", lstm_preds)

# %%
np.sum(preds_test[preds_test==1])
# Out:
# 651

# %%
submission['target'].value_counts()
# Out:
# 0    19404
# 1      933
# Name: target, dtype: int64

# %%
model.load_weights('weights_0.h5')
pred = model.predict(X_test, batch_size=300, verbose=1)
pred_3 = []
for pred_scalar in pred:
    for i in range(3):
        pred_3.append(pred_scalar)
# Out:
# 6779/6779 [==============================] - 17s 2ms/step

# %%
pred_3>0.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-5823f4244eaa> in <module>()
# ----> 1 pred_3>0.5
#
# TypeError: '>' not supported between instances of 'list' and 'float'

# %%
preds_3 = (np.squeeze(pred_3) > 0.5).astype(np.int)

# %%
np.sum(preds_3[preds_3==1])
# Out:
# 1209

# %%
submission['target'] = preds_3
submission.to_csv('../output/submission_22.csv', index=False)

# %%
submission['target'].value_counts()
# Out:
# 0    19128
# 1     1209
# Name: target, dtype: int64
