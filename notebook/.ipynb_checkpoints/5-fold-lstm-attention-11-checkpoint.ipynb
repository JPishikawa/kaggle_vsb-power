# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
# Out:
# /home/cwademo123/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        # now, we just add all the features to new_ts and convert it to np.array
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
# Out:
# (2904, 160, 57) (2904,)

# %%
X = np.load("./X.npy")
y = np.load("./y.npy")

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    

    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    
    x = Bidirectional(LSTM(128, return_sequences=True), merge_mode='ave')(inp)
    #x = Bidirectional(Attention(input_shape[1]))(inp)
    
    #print(x.shape)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(LSTM(64, return_sequences=True), merge_mode='concat')(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    #print(x.shape)
    
    #print(x.shape)
    
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64)(x)
    
    x = LeakyReLU(alpha=0.05)(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 19s 8ms/step - loss: 0.4258 - matthews_correlation: 0.0000e+00 - val_loss: 0.2354 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.2333 - matthews_correlation: 0.0000e+00 - val_loss: 0.2312 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 16s 7ms/step - loss: 0.2263 - matthews_correlation: 0.0000e+00 - val_loss: 0.2256 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.2195 - matthews_correlation: 0.0436 - val_loss: 0.2246 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.2189 - matthews_correlation: 0.0000e+00 - val_loss: 0.2184 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.2122 - matthews_correlation: 0.0574 - val_loss: 0.2151 - val_matthews_correlation: 0.1923
#
# Epoch 00006: val_matthews_correlation improved from 0.00000 to 0.19231, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.2097 - matthews_correlation: 0.1526 - val_loss: 0.2138 - val_matthews_correlation: 0.1662
#
# Epoch 00007: val_matthews_correlation did not improve from 0.19231
# Epoch 8/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.2003 - matthews_correlation: 0.2549 - val_loss: 0.2101 - val_matthews_correlation: 0.2353
#
# Epoch 00008: val_matthews_correlation improved from 0.19231 to 0.23530, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1939 - matthews_correlation: 0.1300 - val_loss: 0.2048 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.23530
# Epoch 10/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1817 - matthews_correlation: 0.2865 - val_loss: 0.1513 - val_matthews_correlation: 0.2930
#
# Epoch 00010: val_matthews_correlation improved from 0.23530 to 0.29297, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.2031 - matthews_correlation: 0.2455 - val_loss: 0.1865 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00011: val_matthews_correlation did not improve from 0.29297
# Epoch 12/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1613 - matthews_correlation: 0.2893 - val_loss: 0.1216 - val_matthews_correlation: 0.5057
#
# Epoch 00012: val_matthews_correlation improved from 0.29297 to 0.50566, saving model to weights_0.h5
# Epoch 13/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1223 - matthews_correlation: 0.5663 - val_loss: 0.1276 - val_matthews_correlation: 0.6835
#
# Epoch 00013: val_matthews_correlation improved from 0.50566 to 0.68349, saving model to weights_0.h5
# Epoch 14/50
# 2322/2322 [==============================] - 16s 7ms/step - loss: 0.1200 - matthews_correlation: 0.5754 - val_loss: 0.1685 - val_matthews_correlation: 0.5818
#
# Epoch 00014: val_matthews_correlation did not improve from 0.68349
# Epoch 15/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1616 - matthews_correlation: 0.4437 - val_loss: 0.0987 - val_matthews_correlation: 0.5933
#
# Epoch 00015: val_matthews_correlation did not improve from 0.68349
# Epoch 16/50
# 2322/2322 [==============================] - 16s 7ms/step - loss: 0.1194 - matthews_correlation: 0.5913 - val_loss: 0.0964 - val_matthews_correlation: 0.5985
#
# Epoch 00016: val_matthews_correlation did not improve from 0.68349
# Epoch 17/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1184 - matthews_correlation: 0.5146 - val_loss: 0.0867 - val_matthews_correlation: 0.6744
#
# Epoch 00017: val_matthews_correlation did not improve from 0.68349
# Epoch 18/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1078 - matthews_correlation: 0.6533 - val_loss: 0.0794 - val_matthews_correlation: 0.7760
#
# Epoch 00018: val_matthews_correlation improved from 0.68349 to 0.77604, saving model to weights_0.h5
# Epoch 19/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1129 - matthews_correlation: 0.5940 - val_loss: 0.0925 - val_matthews_correlation: 0.6320
#
# Epoch 00019: val_matthews_correlation did not improve from 0.77604
# Epoch 20/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1032 - matthews_correlation: 0.6404 - val_loss: 0.0786 - val_matthews_correlation: 0.7661
#
# Epoch 00020: val_matthews_correlation did not improve from 0.77604
# Epoch 21/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1003 - matthews_correlation: 0.6819 - val_loss: 0.0866 - val_matthews_correlation: 0.6939
#
# Epoch 00021: val_matthews_correlation did not improve from 0.77604
# Epoch 22/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0995 - matthews_correlation: 0.6919 - val_loss: 0.0782 - val_matthews_correlation: 0.6964
#
# Epoch 00022: val_matthews_correlation did not improve from 0.77604
# Epoch 23/50
# 2322/2322 [==============================] - 16s 7ms/step - loss: 0.1006 - matthews_correlation: 0.6492 - val_loss: 0.0812 - val_matthews_correlation: 0.7582
#
# Epoch 00023: val_matthews_correlation did not improve from 0.77604
# Epoch 24/50
# 2322/2322 [==============================] - 16s 7ms/step - loss: 0.1108 - matthews_correlation: 0.6085 - val_loss: 0.1025 - val_matthews_correlation: 0.7431
#
# Epoch 00024: val_matthews_correlation did not improve from 0.77604
# Epoch 25/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1231 - matthews_correlation: 0.5868 - val_loss: 0.1065 - val_matthews_correlation: 0.6457
#
# Epoch 00025: val_matthews_correlation did not improve from 0.77604
# Epoch 26/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1101 - matthews_correlation: 0.6295 - val_loss: 0.0778 - val_matthews_correlation: 0.7585
#
# Epoch 00026: val_matthews_correlation did not improve from 0.77604
# Epoch 27/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1021 - matthews_correlation: 0.6492 - val_loss: 0.0764 - val_matthews_correlation: 0.7807
#
# Epoch 00027: val_matthews_correlation improved from 0.77604 to 0.78070, saving model to weights_0.h5
# Epoch 28/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0996 - matthews_correlation: 0.6979 - val_loss: 0.0965 - val_matthews_correlation: 0.5675
#
# Epoch 00028: val_matthews_correlation did not improve from 0.78070
# Epoch 29/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1141 - matthews_correlation: 0.6321 - val_loss: 0.0808 - val_matthews_correlation: 0.7719
#
# Epoch 00029: val_matthews_correlation did not improve from 0.78070
# Epoch 30/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1008 - matthews_correlation: 0.6454 - val_loss: 0.0799 - val_matthews_correlation: 0.7482
#
# Epoch 00030: val_matthews_correlation did not improve from 0.78070
# Epoch 31/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0975 - matthews_correlation: 0.6986 - val_loss: 0.0771 - val_matthews_correlation: 0.7940
#
# Epoch 00031: val_matthews_correlation improved from 0.78070 to 0.79405, saving model to weights_0.h5
# Epoch 32/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0993 - matthews_correlation: 0.6597 - val_loss: 0.0805 - val_matthews_correlation: 0.7091
#
# Epoch 00032: val_matthews_correlation did not improve from 0.79405
# Epoch 33/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1019 - matthews_correlation: 0.6603 - val_loss: 0.0906 - val_matthews_correlation: 0.7769
#
# Epoch 00033: val_matthews_correlation did not improve from 0.79405
# Epoch 34/50
# 2322/2322 [==============================] - 16s 7ms/step - loss: 0.1031 - matthews_correlation: 0.7114 - val_loss: 0.0940 - val_matthews_correlation: 0.7900
#
# Epoch 00034: val_matthews_correlation did not improve from 0.79405
# Epoch 35/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0973 - matthews_correlation: 0.7088 - val_loss: 0.0761 - val_matthews_correlation: 0.7786
#
# Epoch 00035: val_matthews_correlation did not improve from 0.79405
# Epoch 36/50
# 2322/2322 [==============================] - 16s 7ms/step - loss: 0.0953 - matthews_correlation: 0.6920 - val_loss: 0.0747 - val_matthews_correlation: 0.8074
#
# Epoch 00036: val_matthews_correlation improved from 0.79405 to 0.80739, saving model to weights_0.h5
# Epoch 37/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.1020 - matthews_correlation: 0.6161 - val_loss: 0.0848 - val_matthews_correlation: 0.6168
#
# Epoch 00037: val_matthews_correlation did not improve from 0.80739
# Epoch 38/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0987 - matthews_correlation: 0.6475 - val_loss: 0.0752 - val_matthews_correlation: 0.7792
#
# Epoch 00038: val_matthews_correlation did not improve from 0.80739
# Epoch 39/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0982 - matthews_correlation: 0.6872 - val_loss: 0.0776 - val_matthews_correlation: 0.8131
#
# Epoch 00039: val_matthews_correlation improved from 0.80739 to 0.81315, saving model to weights_0.h5
# Epoch 40/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0921 - matthews_correlation: 0.6989 - val_loss: 0.0880 - val_matthews_correlation: 0.7706
#
# Epoch 00040: val_matthews_correlation did not improve from 0.81315
# Epoch 41/50
# 2322/2322 [==============================] - 16s 7ms/step - loss: 0.0961 - matthews_correlation: 0.7069 - val_loss: 0.0852 - val_matthews_correlation: 0.8031
#
# Epoch 00041: val_matthews_correlation did not improve from 0.81315
# Epoch 42/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0924 - matthews_correlation: 0.6933 - val_loss: 0.0753 - val_matthews_correlation: 0.7499
#
# Epoch 00042: val_matthews_correlation did not improve from 0.81315
# Epoch 43/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0932 - matthews_correlation: 0.7220 - val_loss: 0.0741 - val_matthews_correlation: 0.7939
#
# Epoch 00043: val_matthews_correlation did not improve from 0.81315
# Epoch 44/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0924 - matthews_correlation: 0.6928 - val_loss: 0.0781 - val_matthews_correlation: 0.7457
#
# Epoch 00044: val_matthews_correlation did not improve from 0.81315
# Epoch 45/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0954 - matthews_correlation: 0.6488 - val_loss: 0.0722 - val_matthews_correlation: 0.8017
#
# Epoch 00045: val_matthews_correlation did not improve from 0.81315
# Epoch 46/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0904 - matthews_correlation: 0.6989 - val_loss: 0.0717 - val_matthews_correlation: 0.8150
#
# Epoch 00046: val_matthews_correlation improved from 0.81315 to 0.81504, saving model to weights_0.h5
# Epoch 47/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0905 - matthews_correlation: 0.7094 - val_loss: 0.0837 - val_matthews_correlation: 0.7987
#
# Epoch 00047: val_matthews_correlation did not improve from 0.81504
# Epoch 48/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0967 - matthews_correlation: 0.6856 - val_loss: 0.0786 - val_matthews_correlation: 0.7584
#
# Epoch 00048: val_matthews_correlation did not improve from 0.81504
# Epoch 49/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0885 - matthews_correlation: 0.6736 - val_loss: 0.0792 - val_matthews_correlation: 0.7314
#
# Epoch 00049: val_matthews_correlation did not improve from 0.81504
# Epoch 50/50
# 2322/2322 [==============================] - 15s 7ms/step - loss: 0.0884 - matthews_correlation: 0.7174 - val_loss: 0.0788 - val_matthews_correlation: 0.7727
#
# Epoch 00050: val_matthews_correlation did not improve from 0.81504
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 19s 8ms/step - loss: 0.3992 - matthews_correlation: 0.0040 - val_loss: 0.2350 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2357 - matthews_correlation: 0.0000e+00 - val_loss: 0.2337 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2285 - matthews_correlation: 0.0000e+00 - val_loss: 0.2321 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2221 - matthews_correlation: 0.0000e+00 - val_loss: 0.2348 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2120 - matthews_correlation: 9.0424e-04 - val_loss: 0.2348 - val_matthews_correlation: 0.0187
#
# Epoch 00005: val_matthews_correlation improved from 0.00000 to 0.01869, saving model to weights_1.h5
# Epoch 6/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2059 - matthews_correlation: 0.1619 - val_loss: 0.2227 - val_matthews_correlation: 0.1045
#
# Epoch 00006: val_matthews_correlation improved from 0.01869 to 0.10453, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2058 - matthews_correlation: 0.2021 - val_loss: 0.2122 - val_matthews_correlation: 0.1045
#
# Epoch 00007: val_matthews_correlation did not improve from 0.10453
# Epoch 8/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1847 - matthews_correlation: 0.2955 - val_loss: 0.1847 - val_matthews_correlation: 0.1148
#
# Epoch 00008: val_matthews_correlation improved from 0.10453 to 0.11483, saving model to weights_1.h5
# Epoch 9/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1477 - matthews_correlation: 0.3711 - val_loss: 0.1347 - val_matthews_correlation: 0.5195
#
# Epoch 00009: val_matthews_correlation improved from 0.11483 to 0.51947, saving model to weights_1.h5
# Epoch 10/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1308 - matthews_correlation: 0.5647 - val_loss: 0.1249 - val_matthews_correlation: 0.5589
#
# Epoch 00010: val_matthews_correlation improved from 0.51947 to 0.55888, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1192 - matthews_correlation: 0.6141 - val_loss: 0.1148 - val_matthews_correlation: 0.5254
#
# Epoch 00011: val_matthews_correlation did not improve from 0.55888
# Epoch 12/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1091 - matthews_correlation: 0.6658 - val_loss: 0.1436 - val_matthews_correlation: 0.6353
#
# Epoch 00012: val_matthews_correlation improved from 0.55888 to 0.63526, saving model to weights_1.h5
# Epoch 13/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1138 - matthews_correlation: 0.6695 - val_loss: 0.1094 - val_matthews_correlation: 0.5790
#
# Epoch 00013: val_matthews_correlation did not improve from 0.63526
# Epoch 14/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1063 - matthews_correlation: 0.6744 - val_loss: 0.1077 - val_matthews_correlation: 0.6197
#
# Epoch 00014: val_matthews_correlation did not improve from 0.63526
# Epoch 15/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1056 - matthews_correlation: 0.6257 - val_loss: 0.1148 - val_matthews_correlation: 0.5715
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63526
# Epoch 16/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1101 - matthews_correlation: 0.6527 - val_loss: 0.1109 - val_matthews_correlation: 0.6533
# Epoch 00016: val_matthews_correlation improved from 0.63526 to 0.65330, saving model to weights_1.h5
# Epoch 17/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1068 - matthews_correlation: 0.6681 - val_loss: 0.1165 - val_matthews_correlation: 0.6665
#
# Epoch 00017: val_matthews_correlation improved from 0.65330 to 0.66655, saving model to weights_1.h5
# Epoch 18/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1084 - matthews_correlation: 0.6328 - val_loss: 0.1057 - val_matthews_correlation: 0.6282
#
# Epoch 00018: val_matthews_correlation did not improve from 0.66655
# Epoch 19/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1053 - matthews_correlation: 0.6648 - val_loss: 0.1264 - val_matthews_correlation: 0.5849
#
# Epoch 00019: val_matthews_correlation did not improve from 0.66655
# Epoch 20/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1039 - matthews_correlation: 0.6810 - val_loss: 0.1057 - val_matthews_correlation: 0.6470
#
# Epoch 00020: val_matthews_correlation did not improve from 0.66655
# Epoch 21/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0973 - matthews_correlation: 0.6897 - val_loss: 0.1126 - val_matthews_correlation: 0.6592
#
# Epoch 00021: val_matthews_correlation did not improve from 0.66655
# Epoch 22/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0946 - matthews_correlation: 0.6758 - val_loss: 0.1085 - val_matthews_correlation: 0.6303
#
# Epoch 00022: val_matthews_correlation did not improve from 0.66655
# Epoch 23/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1041 - matthews_correlation: 0.6434 - val_loss: 0.1111 - val_matthews_correlation: 0.5677
#
# Epoch 00023: val_matthews_correlation did not improve from 0.66655
# Epoch 24/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0999 - matthews_correlation: 0.5954 - val_loss: 0.0977 - val_matthews_correlation: 0.7139
#
# Epoch 00024: val_matthews_correlation improved from 0.66655 to 0.71391, saving model to weights_1.h5
# Epoch 25/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0948 - matthews_correlation: 0.6904 - val_loss: 0.0996 - val_matthews_correlation: 0.6197
#
# Epoch 00025: val_matthews_correlation did not improve from 0.71391
# Epoch 26/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0976 - matthews_correlation: 0.6803 - val_loss: 0.1198 - val_matthews_correlation: 0.6095
#
# Epoch 00026: val_matthews_correlation did not improve from 0.71391
# Epoch 27/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0969 - matthews_correlation: 0.6693 - val_loss: 0.1111 - val_matthews_correlation: 0.7165
#
# Epoch 00027: val_matthews_correlation improved from 0.71391 to 0.71653, saving model to weights_1.h5
# Epoch 28/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0962 - matthews_correlation: 0.6762 - val_loss: 0.1104 - val_matthews_correlation: 0.6345
#
# Epoch 00028: val_matthews_correlation did not improve from 0.71653
# Epoch 29/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0938 - matthews_correlation: 0.6645 - val_loss: 0.1034 - val_matthews_correlation: 0.6405
#
# Epoch 00029: val_matthews_correlation did not improve from 0.71653
# Epoch 30/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1055 - matthews_correlation: 0.6097 - val_loss: 0.1022 - val_matthews_correlation: 0.7011
#
# Epoch 00030: val_matthews_correlation did not improve from 0.71653
# Epoch 31/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0935 - matthews_correlation: 0.6339 - val_loss: 0.1043 - val_matthews_correlation: 0.6470
#
# Epoch 00031: val_matthews_correlation did not improve from 0.71653
# Epoch 32/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0950 - matthews_correlation: 0.6910 - val_loss: 0.1080 - val_matthews_correlation: 0.5856
#
# Epoch 00032: val_matthews_correlation did not improve from 0.71653
# Epoch 33/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1022 - matthews_correlation: 0.6659 - val_loss: 0.1042 - val_matthews_correlation: 0.6019
#
# Epoch 00033: val_matthews_correlation did not improve from 0.71653
# Epoch 34/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0967 - matthews_correlation: 0.6955 - val_loss: 0.1002 - val_matthews_correlation: 0.6662
#
# Epoch 00034: val_matthews_correlation did not improve from 0.71653
# Epoch 35/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0902 - matthews_correlation: 0.6877 - val_loss: 0.1014 - val_matthews_correlation: 0.6392
#
# Epoch 00035: val_matthews_correlation did not improve from 0.71653
# Epoch 36/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0887 - matthews_correlation: 0.6963 - val_loss: 0.1008 - val_matthews_correlation: 0.6513
#
# Epoch 00036: val_matthews_correlation did not improve from 0.71653
# Epoch 37/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0856 - matthews_correlation: 0.7218 - val_loss: 0.1247 - val_matthews_correlation: 0.5858
#
# Epoch 00037: val_matthews_correlation did not improve from 0.71653
# Epoch 38/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0968 - matthews_correlation: 0.6893 - val_loss: 0.1063 - val_matthews_correlation: 0.6732
#
# Epoch 00038: val_matthews_correlation did not improve from 0.71653
# Epoch 39/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0880 - matthews_correlation: 0.7069 - val_loss: 0.1016 - val_matthews_correlation: 0.6649
#
# Epoch 00039: val_matthews_correlation did not improve from 0.71653
# Epoch 40/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0832 - matthews_correlation: 0.7099 - val_loss: 0.1262 - val_matthews_correlation: 0.6347
#
# Epoch 00040: val_matthews_correlation did not improve from 0.71653
# Epoch 41/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0822 - matthews_correlation: 0.7244 - val_loss: 0.0996 - val_matthews_correlation: 0.6559
#
# Epoch 00041: val_matthews_correlation did not improve from 0.71653
# Epoch 42/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0820 - matthews_correlation: 0.7057 - val_loss: 0.0975 - val_matthews_correlation: 0.6875
#
# Epoch 00042: val_matthews_correlation did not improve from 0.71653
# Epoch 43/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0897 - matthews_correlation: 0.6849 - val_loss: 0.1105 - val_matthews_correlation: 0.5507
#
# Epoch 00043: val_matthews_correlation did not improve from 0.71653
# Epoch 44/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0926 - matthews_correlation: 0.6437 - val_loss: 0.0993 - val_matthews_correlation: 0.6622
#
# Epoch 00044: val_matthews_correlation did not improve from 0.71653
# Epoch 45/50
# 2323/2323 [==============================] - 17s 7ms/step - loss: 0.0835 - matthews_correlation: 0.7007 - val_loss: 0.1109 - val_matthews_correlation: 0.6416
#
# Epoch 00045: val_matthews_correlation did not improve from 0.71653
# Epoch 46/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0802 - matthews_correlation: 0.7295 - val_loss: 0.1070 - val_matthews_correlation: 0.6844
#
# Epoch 00046: val_matthews_correlation did not improve from 0.71653
# Epoch 47/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0810 - matthews_correlation: 0.7200 - val_loss: 0.1070 - val_matthews_correlation: 0.6314
#
# Epoch 00047: val_matthews_correlation did not improve from 0.71653
# Epoch 48/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0859 - matthews_correlation: 0.6807 - val_loss: 0.1080 - val_matthews_correlation: 0.6401
#
# Epoch 00048: val_matthews_correlation did not improve from 0.71653
# Epoch 49/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0829 - matthews_correlation: 0.6563 - val_loss: 0.1018 - val_matthews_correlation: 0.6416
#
# Epoch 00049: val_matthews_correlation did not improve from 0.71653
# Epoch 50/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0826 - matthews_correlation: 0.6931 - val_loss: 0.1077 - val_matthews_correlation: 0.6466
# Epoch 00050: val_matthews_correlation did not improve from 0.71653
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 20s 9ms/step - loss: 0.4336 - matthews_correlation: 0.0000e+00 - val_loss: 0.2348 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2327 - matthews_correlation: 0.0000e+00 - val_loss: 0.2334 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2315 - matthews_correlation: 0.0000e+00 - val_loss: 0.2324 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2301 - matthews_correlation: 0.0000e+00 - val_loss: 0.2300 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2284 - matthews_correlation: 0.0000e+00 - val_loss: 0.2279 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2250 - matthews_correlation: 0.0000e+00 - val_loss: 0.2192 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2148 - matthews_correlation: 0.0000e+00 - val_loss: 0.2056 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.00000
# Epoch 8/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.2000 - matthews_correlation: 0.0877 - val_loss: 0.1891 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00008: val_matthews_correlation did not improve from 0.00000
# Epoch 9/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1902 - matthews_correlation: 0.0000e+00 - val_loss: 0.1645 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.00000
# Epoch 10/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1677 - matthews_correlation: 0.0203 - val_loss: 0.1598 - val_matthews_correlation: 0.2135
#
# Epoch 00010: val_matthews_correlation improved from 0.00000 to 0.21351, saving model to weights_2.h5
# Epoch 11/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1284 - matthews_correlation: 0.4592 - val_loss: 0.3941 - val_matthews_correlation: 0.3261
#
# Epoch 00011: val_matthews_correlation improved from 0.21351 to 0.32614, saving model to weights_2.h5
# Epoch 12/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1806 - matthews_correlation: 0.1606 - val_loss: 0.1301 - val_matthews_correlation: 0.2754
#
# Epoch 00012: val_matthews_correlation did not improve from 0.32614
# Epoch 13/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1233 - matthews_correlation: 0.5899 - val_loss: 0.1163 - val_matthews_correlation: 0.6237
#
# Epoch 00013: val_matthews_correlation improved from 0.32614 to 0.62369, saving model to weights_2.h5
# Epoch 14/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1097 - matthews_correlation: 0.6080 - val_loss: 0.1143 - val_matthews_correlation: 0.6007
#
# Epoch 00014: val_matthews_correlation did not improve from 0.62369
# Epoch 15/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1154 - matthews_correlation: 0.6169 - val_loss: 0.1299 - val_matthews_correlation: 0.4685
#
# Epoch 00015: val_matthews_correlation did not improve from 0.62369
# Epoch 16/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1056 - matthews_correlation: 0.6274 - val_loss: 0.1170 - val_matthews_correlation: 0.5227
#
# Epoch 00016: val_matthews_correlation did not improve from 0.62369
# Epoch 17/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0990 - matthews_correlation: 0.6554 - val_loss: 0.1154 - val_matthews_correlation: 0.6403
#
# Epoch 00017: val_matthews_correlation improved from 0.62369 to 0.64034, saving model to weights_2.h5
# Epoch 18/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0967 - matthews_correlation: 0.6416 - val_loss: 0.1324 - val_matthews_correlation: 0.5792
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64034
# Epoch 19/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1056 - matthews_correlation: 0.5679 - val_loss: 0.1254 - val_matthews_correlation: 0.5895
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64034
# Epoch 20/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0991 - matthews_correlation: 0.6549 - val_loss: 0.1250 - val_matthews_correlation: 0.4203
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64034
# Epoch 21/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0960 - matthews_correlation: 0.6912 - val_loss: 0.1318 - val_matthews_correlation: 0.4367
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64034
# Epoch 22/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0977 - matthews_correlation: 0.5702 - val_loss: 0.1268 - val_matthews_correlation: 0.4340
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64034
# Epoch 23/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1037 - matthews_correlation: 0.6263 - val_loss: 0.1162 - val_matthews_correlation: 0.6256
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64034
# Epoch 24/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1007 - matthews_correlation: 0.6909 - val_loss: 0.1186 - val_matthews_correlation: 0.5698
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64034
# Epoch 25/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0919 - matthews_correlation: 0.6655 - val_loss: 0.1187 - val_matthews_correlation: 0.5494
#
# Epoch 00025: val_matthews_correlation did not improve from 0.64034
# Epoch 26/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1025 - matthews_correlation: 0.6689 - val_loss: 0.1147 - val_matthews_correlation: 0.4686
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64034
# Epoch 27/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0966 - matthews_correlation: 0.6812 - val_loss: 0.1254 - val_matthews_correlation: 0.5312
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64034
# Epoch 28/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1005 - matthews_correlation: 0.6729 - val_loss: 0.1276 - val_matthews_correlation: 0.5197
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64034
# Epoch 29/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0892 - matthews_correlation: 0.6833 - val_loss: 0.1222 - val_matthews_correlation: 0.5792
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64034
# Epoch 30/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0918 - matthews_correlation: 0.6936 - val_loss: 0.1325 - val_matthews_correlation: 0.4766
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64034
# Epoch 31/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1001 - matthews_correlation: 0.6674 - val_loss: 0.1113 - val_matthews_correlation: 0.5400
#
# Epoch 00031: val_matthews_correlation did not improve from 0.64034
# Epoch 32/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.1185 - matthews_correlation: 0.6919 - val_loss: 0.1269 - val_matthews_correlation: 0.3637
#
# Epoch 00032: val_matthews_correlation did not improve from 0.64034
# Epoch 33/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0956 - matthews_correlation: 0.6785 - val_loss: 0.1151 - val_matthews_correlation: 0.6572
#
# Epoch 00033: val_matthews_correlation improved from 0.64034 to 0.65719, saving model to weights_2.h5
# Epoch 34/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0917 - matthews_correlation: 0.6984 - val_loss: 0.1188 - val_matthews_correlation: 0.5400
#
# Epoch 00034: val_matthews_correlation did not improve from 0.65719
# Epoch 35/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0901 - matthews_correlation: 0.6931 - val_loss: 0.1204 - val_matthews_correlation: 0.6154
#
# Epoch 00035: val_matthews_correlation did not improve from 0.65719
# Epoch 36/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0911 - matthews_correlation: 0.7039 - val_loss: 0.1212 - val_matthews_correlation: 0.5990
#
# Epoch 00036: val_matthews_correlation did not improve from 0.65719
# Epoch 37/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0917 - matthews_correlation: 0.7164 - val_loss: 0.1217 - val_matthews_correlation: 0.5846
#
# Epoch 00037: val_matthews_correlation did not improve from 0.65719
# Epoch 38/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0887 - matthews_correlation: 0.7001 - val_loss: 0.1232 - val_matthews_correlation: 0.6233
#
# Epoch 00038: val_matthews_correlation did not improve from 0.65719
# Epoch 39/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0842 - matthews_correlation: 0.7079 - val_loss: 0.1264 - val_matthews_correlation: 0.5682
#
# Epoch 00039: val_matthews_correlation did not improve from 0.65719
# Epoch 40/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0812 - matthews_correlation: 0.7480 - val_loss: 0.1249 - val_matthews_correlation: 0.6153
#
# Epoch 00040: val_matthews_correlation did not improve from 0.65719
# Epoch 41/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0812 - matthews_correlation: 0.7560 - val_loss: 0.1277 - val_matthews_correlation: 0.5969
#
# Epoch 00041: val_matthews_correlation did not improve from 0.65719
# Epoch 42/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0907 - matthews_correlation: 0.6608 - val_loss: 0.1290 - val_matthews_correlation: 0.5845
#
# Epoch 00042: val_matthews_correlation did not improve from 0.65719
# Epoch 43/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0860 - matthews_correlation: 0.7149 - val_loss: 0.1237 - val_matthews_correlation: 0.5464
#
# Epoch 00043: val_matthews_correlation did not improve from 0.65719
# Epoch 44/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0831 - matthews_correlation: 0.7346 - val_loss: 0.1305 - val_matthews_correlation: 0.6040
#
# Epoch 00044: val_matthews_correlation did not improve from 0.65719
# Epoch 45/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0809 - matthews_correlation: 0.7121 - val_loss: 0.1324 - val_matthews_correlation: 0.5678
#
# Epoch 00045: val_matthews_correlation did not improve from 0.65719
# Epoch 46/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0866 - matthews_correlation: 0.7443 - val_loss: 0.1351 - val_matthews_correlation: 0.5471
#
# Epoch 00046: val_matthews_correlation did not improve from 0.65719
# Epoch 47/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0908 - matthews_correlation: 0.6523 - val_loss: 0.1284 - val_matthews_correlation: 0.5316
#
# Epoch 00047: val_matthews_correlation did not improve from 0.65719
# Epoch 48/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0899 - matthews_correlation: 0.7142 - val_loss: 0.1308 - val_matthews_correlation: 0.5400
#
# Epoch 00048: val_matthews_correlation did not improve from 0.65719
# Epoch 49/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0892 - matthews_correlation: 0.6950 - val_loss: 0.1255 - val_matthews_correlation: 0.5758
#
# Epoch 00049: val_matthews_correlation did not improve from 0.65719
# Epoch 50/50
# 2323/2323 [==============================] - 16s 7ms/step - loss: 0.0791 - matthews_correlation: 0.7519 - val_loss: 0.1269 - val_matthews_correlation: 0.5678
#
# Epoch 00050: val_matthews_correlation did not improve from 0.65719
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.4137 - matthews_correlation: -0.0121 - val_loss: 0.2311 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2435 - matthews_correlation: 0.0000e+00 - val_loss: 0.2287 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2330 - matthews_correlation: 0.0000e+00 - val_loss: 0.2270 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2305 - matthews_correlation: 0.0000e+00 - val_loss: 0.2248 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2275 - matthews_correlation: 0.0000e+00 - val_loss: 0.2191 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2167 - matthews_correlation: 0.0000e+00 - val_loss: 0.2039 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2037 - matthews_correlation: 0.1019 - val_loss: 0.1974 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.00000
# Epoch 8/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2000 - matthews_correlation: 0.1784 - val_loss: 0.1892 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00008: val_matthews_correlation did not improve from 0.00000
# Epoch 9/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1812 - matthews_correlation: 0.0407 - val_loss: 0.1636 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.00000
# Epoch 10/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1728 - matthews_correlation: 0.0980 - val_loss: 0.1474 - val_matthews_correlation: 0.2741
#
# Epoch 00010: val_matthews_correlation improved from 0.00000 to 0.27415, saving model to weights_3.h5
# Epoch 11/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1620 - matthews_correlation: 0.1482 - val_loss: 0.1502 - val_matthews_correlation: 0.3004
#
# Epoch 00011: val_matthews_correlation improved from 0.27415 to 0.30036, saving model to weights_3.h5
# Epoch 12/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1551 - matthews_correlation: 0.2911 - val_loss: 0.1595 - val_matthews_correlation: 0.3276
#
# Epoch 00012: val_matthews_correlation improved from 0.30036 to 0.32760, saving model to weights_3.h5
# Epoch 13/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1342 - matthews_correlation: 0.5301 - val_loss: 0.1559 - val_matthews_correlation: 0.5755
#
# Epoch 00013: val_matthews_correlation improved from 0.32760 to 0.57552, saving model to weights_3.h5
# Epoch 14/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1162 - matthews_correlation: 0.5132 - val_loss: 0.1151 - val_matthews_correlation: 0.5523
#
# Epoch 00014: val_matthews_correlation did not improve from 0.57552
# Epoch 15/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1087 - matthews_correlation: 0.6570 - val_loss: 0.1127 - val_matthews_correlation: 0.4717
#
# Epoch 00015: val_matthews_correlation did not improve from 0.57552
# Epoch 16/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0995 - matthews_correlation: 0.6671 - val_loss: 0.1061 - val_matthews_correlation: 0.6396
#
# Epoch 00016: val_matthews_correlation improved from 0.57552 to 0.63962, saving model to weights_3.h5
# Epoch 17/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1024 - matthews_correlation: 0.6661 - val_loss: 0.1228 - val_matthews_correlation: 0.4894
#
# Epoch 00017: val_matthews_correlation did not improve from 0.63962
# Epoch 18/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1020 - matthews_correlation: 0.6329 - val_loss: 0.1258 - val_matthews_correlation: 0.4414
#
# Epoch 00018: val_matthews_correlation did not improve from 0.63962
# Epoch 19/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1011 - matthews_correlation: 0.6486 - val_loss: 0.1261 - val_matthews_correlation: 0.4540
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63962
# Epoch 20/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0947 - matthews_correlation: 0.6723 - val_loss: 0.1184 - val_matthews_correlation: 0.4713
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63962
# Epoch 21/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0988 - matthews_correlation: 0.6329 - val_loss: 0.1072 - val_matthews_correlation: 0.5953
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63962
# Epoch 22/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0945 - matthews_correlation: 0.6801 - val_loss: 0.1165 - val_matthews_correlation: 0.5041
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63962
# Epoch 23/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0896 - matthews_correlation: 0.6422 - val_loss: 0.1110 - val_matthews_correlation: 0.6152
#
# Epoch 00023: val_matthews_correlation did not improve from 0.63962
# Epoch 24/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0879 - matthews_correlation: 0.7127 - val_loss: 0.1089 - val_matthews_correlation: 0.5532
#
# Epoch 00024: val_matthews_correlation did not improve from 0.63962
# Epoch 25/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0920 - matthews_correlation: 0.6817 - val_loss: 0.1156 - val_matthews_correlation: 0.5652
#
# Epoch 00025: val_matthews_correlation did not improve from 0.63962
# Epoch 26/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0919 - matthews_correlation: 0.7096 - val_loss: 0.1101 - val_matthews_correlation: 0.7086
#
# Epoch 00026: val_matthews_correlation improved from 0.63962 to 0.70856, saving model to weights_3.h5
# Epoch 27/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1042 - matthews_correlation: 0.6306 - val_loss: 0.1106 - val_matthews_correlation: 0.6533
#
# Epoch 00027: val_matthews_correlation did not improve from 0.70856
# Epoch 28/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0988 - matthews_correlation: 0.6442 - val_loss: 0.1046 - val_matthews_correlation: 0.5834
#
# Epoch 00028: val_matthews_correlation did not improve from 0.70856
# Epoch 29/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0925 - matthews_correlation: 0.6602 - val_loss: 0.1057 - val_matthews_correlation: 0.6419
#
# Epoch 00029: val_matthews_correlation did not improve from 0.70856
# Epoch 30/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0903 - matthews_correlation: 0.6737 - val_loss: 0.1087 - val_matthews_correlation: 0.5320
#
# Epoch 00030: val_matthews_correlation did not improve from 0.70856
# Epoch 31/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0851 - matthews_correlation: 0.6800 - val_loss: 0.1033 - val_matthews_correlation: 0.7178
#
# Epoch 00031: val_matthews_correlation improved from 0.70856 to 0.71780, saving model to weights_3.h5
# Epoch 32/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0876 - matthews_correlation: 0.7192 - val_loss: 0.1029 - val_matthews_correlation: 0.6926
#
# Epoch 00032: val_matthews_correlation did not improve from 0.71780
# Epoch 33/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0826 - matthews_correlation: 0.7211 - val_loss: 0.1089 - val_matthews_correlation: 0.6995
#
# Epoch 00033: val_matthews_correlation did not improve from 0.71780
# Epoch 34/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0855 - matthews_correlation: 0.6797 - val_loss: 0.1088 - val_matthews_correlation: 0.5183
#
# Epoch 00034: val_matthews_correlation did not improve from 0.71780
# Epoch 35/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0892 - matthews_correlation: 0.7058 - val_loss: 0.1080 - val_matthews_correlation: 0.5608
#
# Epoch 00035: val_matthews_correlation did not improve from 0.71780
# Epoch 36/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0839 - matthews_correlation: 0.7096 - val_loss: 0.1027 - val_matthews_correlation: 0.6977
#
# Epoch 00036: val_matthews_correlation did not improve from 0.71780
# Epoch 37/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0846 - matthews_correlation: 0.7025 - val_loss: 0.1218 - val_matthews_correlation: 0.6982
#
# Epoch 00037: val_matthews_correlation did not improve from 0.71780
# Epoch 38/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0852 - matthews_correlation: 0.7084 - val_loss: 0.1107 - val_matthews_correlation: 0.6854
#
# Epoch 00038: val_matthews_correlation did not improve from 0.71780
# Epoch 39/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0883 - matthews_correlation: 0.6758 - val_loss: 0.1071 - val_matthews_correlation: 0.6062
#
# Epoch 00039: val_matthews_correlation did not improve from 0.71780
# Epoch 40/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0810 - matthews_correlation: 0.7228 - val_loss: 0.1174 - val_matthews_correlation: 0.5047
#
# Epoch 00040: val_matthews_correlation did not improve from 0.71780
# Epoch 41/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0846 - matthews_correlation: 0.6741 - val_loss: 0.1053 - val_matthews_correlation: 0.5764
#
# Epoch 00041: val_matthews_correlation did not improve from 0.71780
# Epoch 42/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0781 - matthews_correlation: 0.7395 - val_loss: 0.1105 - val_matthews_correlation: 0.6881
#
# Epoch 00042: val_matthews_correlation did not improve from 0.71780
# Epoch 43/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0811 - matthews_correlation: 0.7152 - val_loss: 0.1152 - val_matthews_correlation: 0.6070
#
# Epoch 00043: val_matthews_correlation did not improve from 0.71780
# Epoch 44/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0754 - matthews_correlation: 0.7124 - val_loss: 0.1247 - val_matthews_correlation: 0.5653
#
# Epoch 00044: val_matthews_correlation did not improve from 0.71780
# Epoch 45/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0778 - matthews_correlation: 0.7062 - val_loss: 0.1223 - val_matthews_correlation: 0.6744
#
# Epoch 00045: val_matthews_correlation did not improve from 0.71780
# Epoch 46/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0854 - matthews_correlation: 0.7110 - val_loss: 0.1119 - val_matthews_correlation: 0.6043
#
# Epoch 00046: val_matthews_correlation did not improve from 0.71780
# Epoch 47/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0819 - matthews_correlation: 0.7358 - val_loss: 0.1085 - val_matthews_correlation: 0.6342
#
# Epoch 00047: val_matthews_correlation did not improve from 0.71780
# Epoch 48/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0772 - matthews_correlation: 0.7473 - val_loss: 0.1086 - val_matthews_correlation: 0.6274
#
# Epoch 00048: val_matthews_correlation did not improve from 0.71780
# Epoch 49/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0750 - matthews_correlation: 0.7580 - val_loss: 0.1106 - val_matthews_correlation: 0.6109
#
# Epoch 00049: val_matthews_correlation did not improve from 0.71780
# Epoch 50/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0730 - matthews_correlation: 0.7566 - val_loss: 0.1464 - val_matthews_correlation: 0.4476
#
# Epoch 00050: val_matthews_correlation did not improve from 0.71780
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 20s 9ms/step - loss: 0.4089 - matthews_correlation: -0.0046 - val_loss: 0.2296 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2334 - matthews_correlation: 0.0000e+00 - val_loss: 0.2272 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2304 - matthews_correlation: 0.0000e+00 - val_loss: 0.2257 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2303 - matthews_correlation: 0.0000e+00 - val_loss: 0.2204 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2251 - matthews_correlation: 0.0000e+00 - val_loss: 0.2101 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2128 - matthews_correlation: 0.0000e+00 - val_loss: 0.2008 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.2059 - matthews_correlation: 0.0000e+00 - val_loss: 0.1844 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.00000
# Epoch 8/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1833 - matthews_correlation: 0.0000e+00 - val_loss: 0.1735 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00008: val_matthews_correlation did not improve from 0.00000
# Epoch 9/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1654 - matthews_correlation: 0.0000e+00 - val_loss: 0.2165 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.00000
# Epoch 10/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1573 - matthews_correlation: -0.0011 - val_loss: 0.1597 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00010: val_matthews_correlation did not improve from 0.00000
# Epoch 11/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1303 - matthews_correlation: 0.3033 - val_loss: 0.1316 - val_matthews_correlation: 0.5274
#
# Epoch 00011: val_matthews_correlation improved from 0.00000 to 0.52745, saving model to weights_4.h5
# Epoch 12/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1183 - matthews_correlation: 0.5751 - val_loss: 0.1223 - val_matthews_correlation: 0.5439
#
# Epoch 00012: val_matthews_correlation improved from 0.52745 to 0.54392, saving model to weights_4.h5
# Epoch 13/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1170 - matthews_correlation: 0.5625 - val_loss: 0.1500 - val_matthews_correlation: 0.6018
#
# Epoch 00013: val_matthews_correlation improved from 0.54392 to 0.60181, saving model to weights_4.h5
# Epoch 14/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1244 - matthews_correlation: 0.5402 - val_loss: 0.1236 - val_matthews_correlation: 0.6009
#
# Epoch 00014: val_matthews_correlation did not improve from 0.60181
# Epoch 15/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1056 - matthews_correlation: 0.6049 - val_loss: 0.1261 - val_matthews_correlation: 0.6233
#
# Epoch 00015: val_matthews_correlation improved from 0.60181 to 0.62327, saving model to weights_4.h5
# Epoch 16/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1076 - matthews_correlation: 0.6341 - val_loss: 0.1132 - val_matthews_correlation: 0.6455
#
# Epoch 00016: val_matthews_correlation improved from 0.62327 to 0.64547, saving model to weights_4.h5
# Epoch 17/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1039 - matthews_correlation: 0.6607 - val_loss: 0.1147 - val_matthews_correlation: 0.6428
#
# Epoch 00017: val_matthews_correlation did not improve from 0.64547
# Epoch 18/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1027 - matthews_correlation: 0.6285 - val_loss: 0.1152 - val_matthews_correlation: 0.6479
#
# Epoch 00018: val_matthews_correlation improved from 0.64547 to 0.64787, saving model to weights_4.h5
# Epoch 19/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0976 - matthews_correlation: 0.6888 - val_loss: 0.1121 - val_matthews_correlation: 0.4429
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64787
# Epoch 20/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1019 - matthews_correlation: 0.6506 - val_loss: 0.1397 - val_matthews_correlation: 0.2027
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64787
# Epoch 21/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.1007 - matthews_correlation: 0.5898 - val_loss: 0.1096 - val_matthews_correlation: 0.5707
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64787
# Epoch 22/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0923 - matthews_correlation: 0.6984 - val_loss: 0.1088 - val_matthews_correlation: 0.4556
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64787
# Epoch 23/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0947 - matthews_correlation: 0.6413 - val_loss: 0.1303 - val_matthews_correlation: 0.3908
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64787
# Epoch 24/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0951 - matthews_correlation: 0.6195 - val_loss: 0.1216 - val_matthews_correlation: 0.5996
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64787
# Epoch 25/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0903 - matthews_correlation: 0.6424 - val_loss: 0.1493 - val_matthews_correlation: 0.3895
#
# Epoch 00025: val_matthews_correlation did not improve from 0.64787
# Epoch 26/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0914 - matthews_correlation: 0.6699 - val_loss: 0.1118 - val_matthews_correlation: 0.5589
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64787
# Epoch 27/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0907 - matthews_correlation: 0.7019 - val_loss: 0.1084 - val_matthews_correlation: 0.4545
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64787
# Epoch 28/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0887 - matthews_correlation: 0.6817 - val_loss: 0.1117 - val_matthews_correlation: 0.5466
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64787
# Epoch 29/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0887 - matthews_correlation: 0.6787 - val_loss: 0.1144 - val_matthews_correlation: 0.4082
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64787
# Epoch 30/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0847 - matthews_correlation: 0.6844 - val_loss: 0.1161 - val_matthews_correlation: 0.4125
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64787
# Epoch 31/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0872 - matthews_correlation: 0.7048 - val_loss: 0.1109 - val_matthews_correlation: 0.5589
#
# Epoch 00031: val_matthews_correlation did not improve from 0.64787
# Epoch 32/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0853 - matthews_correlation: 0.6584 - val_loss: 0.1187 - val_matthews_correlation: 0.4104
#
# Epoch 00032: val_matthews_correlation did not improve from 0.64787
# Epoch 33/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0847 - matthews_correlation: 0.6715 - val_loss: 0.1162 - val_matthews_correlation: 0.3842
#
# Epoch 00033: val_matthews_correlation did not improve from 0.64787
# Epoch 34/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0854 - matthews_correlation: 0.7132 - val_loss: 0.1123 - val_matthews_correlation: 0.5178
#
# Epoch 00034: val_matthews_correlation did not improve from 0.64787
# Epoch 35/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0794 - matthews_correlation: 0.7563 - val_loss: 0.1097 - val_matthews_correlation: 0.4403
#
# Epoch 00035: val_matthews_correlation did not improve from 0.64787
# Epoch 36/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0839 - matthews_correlation: 0.6939 - val_loss: 0.1319 - val_matthews_correlation: 0.3813
#
# Epoch 00036: val_matthews_correlation did not improve from 0.64787
# Epoch 37/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0848 - matthews_correlation: 0.6919 - val_loss: 0.1221 - val_matthews_correlation: 0.3819
#
# Epoch 00037: val_matthews_correlation did not improve from 0.64787
# Epoch 38/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0832 - matthews_correlation: 0.6595 - val_loss: 0.1201 - val_matthews_correlation: 0.3882
#
# Epoch 00038: val_matthews_correlation did not improve from 0.64787
# Epoch 39/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0777 - matthews_correlation: 0.7362 - val_loss: 0.1161 - val_matthews_correlation: 0.4698
#
# Epoch 00039: val_matthews_correlation did not improve from 0.64787
# Epoch 40/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0784 - matthews_correlation: 0.6915 - val_loss: 0.1185 - val_matthews_correlation: 0.4061
#
# Epoch 00040: val_matthews_correlation did not improve from 0.64787
# Epoch 41/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0750 - matthews_correlation: 0.7687 - val_loss: 0.1121 - val_matthews_correlation: 0.5807
#
# Epoch 00041: val_matthews_correlation did not improve from 0.64787
# Epoch 42/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0844 - matthews_correlation: 0.6777 - val_loss: 0.1127 - val_matthews_correlation: 0.4160
#
# Epoch 00042: val_matthews_correlation did not improve from 0.64787
# Epoch 43/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0779 - matthews_correlation: 0.7296 - val_loss: 0.1161 - val_matthews_correlation: 0.5118
#
# Epoch 00043: val_matthews_correlation did not improve from 0.64787
# Epoch 44/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0770 - matthews_correlation: 0.7492 - val_loss: 0.1239 - val_matthews_correlation: 0.5495
#
# Epoch 00044: val_matthews_correlation did not improve from 0.64787
# Epoch 45/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0839 - matthews_correlation: 0.7011 - val_loss: 0.1104 - val_matthews_correlation: 0.5458
#
# Epoch 00045: val_matthews_correlation did not improve from 0.64787
# Epoch 46/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0761 - matthews_correlation: 0.7415 - val_loss: 0.1127 - val_matthews_correlation: 0.5761
#
# Epoch 00046: val_matthews_correlation did not improve from 0.64787
# Epoch 47/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0786 - matthews_correlation: 0.6756 - val_loss: 0.1494 - val_matthews_correlation: 0.4516
#
# Epoch 00047: val_matthews_correlation did not improve from 0.64787
# Epoch 48/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0787 - matthews_correlation: 0.7012 - val_loss: 0.1129 - val_matthews_correlation: 0.5157
#
# Epoch 00048: val_matthews_correlation did not improve from 0.64787
# Epoch 49/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0775 - matthews_correlation: 0.7343 - val_loss: 0.1122 - val_matthews_correlation: 0.5535
#
# Epoch 00049: val_matthews_correlation did not improve from 0.64787
# Epoch 50/50
# 2324/2324 [==============================] - 16s 7ms/step - loss: 0.0810 - matthews_correlation: 0.7378 - val_loss: 0.1175 - val_matthews_correlation: 0.5572
#
# Epoch 00050: val_matthews_correlation did not improve from 0.64787
# ((2904,), (2904,))

# %%
np.save('./tmp/y_val_tmp_3.npy', y_val)
np.save('./tmp/preds_val_tmp_3.npy', preds_val)

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    
    #y_pred = K.cast(y_pred, np.float)
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = np.round(np.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)

    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
matthews_correlation(y_val, preds_val)
# Out:
# 0.7142421405775691

# %%
y_val = np.load('./tmp/y_val_tmp_2.npy')
preds_val = np.load('./tmp/preds_val_tmp_2.npy')

# %%
matthews_correlation(y_val, preds_val)
# Out:
# 0.7232583042907601

# %%
y_val = np.load('./y_val_tmp.npy')
preds_val = np.load('./preds_val_tmp.npy')

# %%
matthews_correlation(y_val, preds_val)
# Out:
# 0.7098417026109459

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        #score = matthews_correlation(y_true, (y_proba > threshold).astype(int))
        #score = K.eval(matthews_correlation(y_true, (y_proba > threshold).astype(int)))
        #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        score = matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 10583.93it/s]

# %%
best_threshold
# Out:
# 0.5

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')
# Out:
# CPU times: user 5.7 ms, sys: 4.31 ms, total: 10 ms
# Wall time: 33.3 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# %%time
# First we daclarete a series of parameters to initiate the loading of the main data
# it is too large, it is impossible to load in one time, so we are doing it in dividing in 10 parts
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [03:01<00:00, 11.34it/s]
# 100%|██████████| 2033/2033 [03:08<00:00, 10.76it/s]
# 100%|██████████| 2033/2033 [03:08<00:00, 10.63it/s]
# 100%|██████████| 2033/2033 [03:07<00:00, 10.82it/s]
# 100%|██████████| 2033/2033 [03:03<00:00, 10.98it/s]
# 100%|██████████| 2033/2033 [03:03<00:00, 10.83it/s]
# 100%|██████████| 2033/2033 [03:04<00:00, 11.22it/s]
# 100%|██████████| 2033/2033 [03:03<00:00, 11.19it/s]
# 100%|██████████| 2033/2033 [03:04<00:00, 10.99it/s]
# 100%|██████████| 2033/2033 [03:04<00:00,  7.64it/s]
# 100%|██████████| 7/7 [00:00<00:00, 10.23it/s]
# CPU times: user 34min 45s, sys: 1min 52s, total: 36min 38s
# Wall time: 32min 22s

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
X_test_input = np.load('./X_test.npy')

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
# Out:
# Beginning fold 1
# Beginning fold 2
# Beginning fold 3
# Beginning fold 4
# Beginning fold 5

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 13s 2ms/step
# 6779/6779 [==============================] - 13s 2ms/step
# 6779/6779 [==============================] - 13s 2ms/step
# 6779/6779 [==============================] - 13s 2ms/step
# 6779/6779 [==============================] - 13s 2ms/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('../output/submission_17.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
lstm_preds = np.squeeze(np.mean(preds_test, axis=0))
np.save("./lstm_preds.npy", lstm_preds)
