# %%
import pandas as pd
import numpy as np
import random as rnd
import os
import datetime
import pickle

from scipy import stats
from scipy.special import boxcox1p

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm_notebook

from itertools import product

import gc

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone

import xgboost as xgb
import lightgbm as lgb

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,r2_score

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 200)

import warnings
warnings.filterwarnings('ignore')

# %%
from numba import jit

# %%
@jit
def mcc(tp, tn, fp, fn):
    sup = tp * tn - fp * fn
    inf = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    if inf==0:
        return 0
    else:
        return sup / np.sqrt(inf)

# %%
def eval_mcc(y_true, y_prob, show=False):
    idx = np.argsort(y_prob)
    y_true_sort = y_true[idx]
    n = y_true.shape[0]
    nump = 1.0 * np.sum(y_true) # number of positive
    numn = n - nump # number of negative
    tp = nump
    tn = 0.0
    fp = numn
    fn = 0.0
    best_mcc = 0.0
    best_id = -1
    prev_proba = -1
    best_proba = -1
    mccs = np.zeros(n)
    for i in range(n):
        # all items with idx < i are predicted negative while others are predicted positive
        # only evaluate mcc when probability changes
        proba = y_prob[idx[i]]
        if proba != prev_proba:
            prev_proba = proba
            new_mcc = mcc(tp, tn, fp, fn)
            if new_mcc >= best_mcc:
                best_mcc = new_mcc
                best_id = i
                best_proba = proba
        mccs[i] = new_mcc
        if y_true_sort[i] == 1:
            tp -= 1.0
            fn += 1.0
        else:
            fp -= 1.0
            tn += 1.0
    if show:
        y_pred = (y_prob >= best_proba).astype(int)
        score = matthews_corrcoef(y_true, y_pred)
        print(score, best_mcc)
        plt.plot(mccs)
        return best_proba, best_mcc, y_pred
    else:
        return best_mcc

# %%
def mcc_eval(y_prob, dtrain):
    y_true = dtrain.get_label()
    best_mcc = eval_mcc(y_true, y_prob)
    is_higher_better = True
    return 'MCC', best_mcc, is_higher_better

# %%
meta_train = pd.read_csv('../input/metadata_train.csv')
meta_test = pd.read_csv('../input/metadata_test.csv')

# %%
numpeaks = np.load('../features/numpeaks.npy')
numpospeaks = np.load('../features/numpospeaks.npy')
numnegpeaks = np.load('../features/numnegpeaks.npy')

maxpeakwidth = np.load('../features/maxpeakwidth.npy')
minpeakwidth = np.load('../features/minpeakwidth.npy')
meanpeakwidth = np.load('../features/meanpeakwidth.npy')
maxamp = np.load('../features/maxamp.npy')
minamp = np.load('../features/minamp.npy')
meanamp = np.load('../features/meanamp.npy')

stdampall = np.load('../features/stdampall.npy')
stdposall = np.load('../features/stdposall.npy')
stdwidthall = np.load('../features/stdwidthall.npy')

stdampq2 = np.load('../features/stdampq2.npy')
stdposq2 = np.load('../features/stdposq2.npy')
stdwidthq2 = np.load('../features/stdwidthq2.npy')
stdampq3 = np.load('../features/stdampq3.npy')
stdposq3 = np.load('../features/stdposq3.npy')
stdwidthq3 = np.load('../features/stdwidthq3.npy')
stdampq4 = np.load('../features/stdampq4.npy')
stdposq4 = np.load('../features/stdposq4.npy')
stdwidthq4 = np.load('../features/stdwidthq4.npy')

# %%
stdampall_ad = np.load('../features/stdampall_ad.npy')
stdampq2_ad = np.load('../features/stdampq2_ad.npy')
stdampq3_ad = np.load('../features/stdampq3_ad.npy')
stdampq4_ad = np.load('../features/stdampq4_ad.npy')

meanampall_ad = np.load('../features/meanampall_ad.npy')
meanampq2_ad = np.load('../features/meanampq2_ad.npy')
meanampq3_ad = np.load('../features/meanampq3_ad.npy')
meanampq4_ad = np.load('../features/meanampq4_ad.npy')

meanamppos = np.load('../features/meanamppos.npy')
meanampneg = np.load('../features/meanampneg.npy')

# %%
numpeaks_id = np.load('../features/numpeaks_id.npy')
numpospeaks_id = np.load('../features/numpospeaks_id.npy')
numnegpeaks_id = np.load('../features/numnegpeaks_id .npy')

maxamp_id = np.load('../features/maxamp_id.npy')
minamp_id = np.load('../features/minamp_id.npy')
meanamp_id = np.load('../features/meanamp_id.npy')

meanamppos_id = np.load('../features/meanamppos_id.npy')
meanampneg_id = np.load('../features/meanampneg_id.npy')

# %%
train_features = pd.DataFrame({'NumPeaks':numpeaks, 'NumPosPeaks':numpospeaks, 'NumNegPeaks':numnegpeaks, 'MaxWidth':maxpeakwidth,
                         'MinWidth':minpeakwidth, 'MeanWidth':meanpeakwidth, 'MaxAmp':maxamp, 'MinAmp':minamp, 'MeanAmp':meanamp,
                        'StdAmpAll':stdampall, 'StdPosAll':stdposall, 'StdWidthAll':stdwidthall, 'StdAmpQ2':stdampq2, 'StdPosQ2':stdposq2,
                         'StdWidthQ2':stdwidthq2, 'StdAmpQ3':stdampq3, 'StdPosQ3':stdposq3, 'StdWidthQ3':stdwidthq3,
                        'StdAmpQ4':stdampq4, 'StdPosQ4':stdposq4, 'StdWidthQ4':stdwidthq4, 
                        'StdAmpAll_AD':stdampall_ad, 'StdAmpQ2_AD': stdampq2_ad, 'StdAmpQ3_AD': stdampq3_ad, 'StdAmpQ4_AD': stdampq4_ad,
                        'MeanAmpAll_AD':meanampall_ad, 'MeanAmpQ2_AD': meanampq2_ad,
                        'MeanAmpQ3_AD': meanampq3_ad, 'MeanAmpQ4_AD': meanampq4_ad,
                        'MeanAmpPos':meanamppos, 'MeanAmpNeg':meanampneg,
                        'NumPeaks_ID':numpeaks_id, 'NumPosPeaks_ID':numpospeaks_id, 'NumNegPeaks_ID':numnegpeaks_id,
                        'MaxAmp_ID':maxamp_id, 'MinAmp_ID':minamp_id, 'MeanAmp_ID':meanamp_id,
                        'MeanAmpPos_ID':meanamppos_id, 'MeanAmpNeg_ID':meanampneg_id})

# %%
train = pd.concat([meta_train, train_features], axis=1)

# %%
train.head()
# Out:
#    signal_id  id_measurement  phase  target  NumPeaks  NumPosPeaks  \
# 0          0               0      0       0       105           48
# 1          1               0      1       0        23           14
# 2          2               0      2       0       121           67
# 3          3               1      0       1       217           99
# 4          4               1      1       1       141           68
#
#    NumNegPeaks  MaxWidth  MinWidth     MeanWidth     MaxAmp     MinAmp  \
# 0           57     41741         1   3676.451923  46.676929 -21.931899
# 1            9     69734         1  10977.954545  13.454715 -12.666357
# 2           54     58988         1   3175.458333  26.176798 -30.415865
# 3          118     44999         1   1820.212963  91.147620 -38.193195
# 4           73     37017         1   2803.257143  14.246623  -9.247347
#
#     MeanAmp  StdAmpAll      StdPosAll   StdWidthAll   StdAmpQ2      StdPosQ2  \
# 0 -0.000125  11.866878   77424.493902   7099.857490  11.214203  25011.751218
# 1  0.000094   8.663170   76017.661321  16116.212440   9.545417   8608.000000
# 2  0.000112  11.285462   74713.050192   7570.433485  14.920124  24129.371090
# 3  0.000239  11.473998  131660.062871   4198.542517   5.535926  25928.722290
# 4 -0.000065   4.289404  126355.390058   5433.900865   4.720264  21722.232143
#
#      StdWidthQ2   StdAmpQ3      StdPosQ3   StdWidthQ3   StdAmpQ4  \
# 0   6165.933632  12.479814  22686.469829  2801.657114   8.081718
# 1      0.000000   8.286657  19963.709475  6986.037612   5.719954
# 2   7265.204158  11.041417  20894.197560  1152.704984  11.427326
# 3  12482.994099   5.538974  22936.531117  3615.659712   5.086507
# 4   7837.139326   3.000449  25632.115546  9773.675906   3.425179
#
#        StdPosQ4   StdWidthQ4  StdAmpAll_AD  StdAmpQ2_AD  StdAmpQ3_AD  \
# 0  22092.125444  8984.882428     44.891664     0.670594    85.296720
# 1  15027.735166  9284.827461     30.568193    35.273220    43.143698
# 2  21303.210731  5779.776683     30.570660    43.144629    35.274377
# 3  34060.095196  2594.629391     87.000132    60.780813    70.004487
# 4  29998.890319  4142.901139     84.430994    60.780715    65.567084
#
#    StdAmpQ4_AD  MeanAmpAll_AD  MeanAmpQ2_AD  MeanAmpQ3_AD  MeanAmpQ4_AD  \
# 0    24.976989       4.062346      0.000151     14.999402      1.249880
# 1    24.977523       1.875258      2.500917      3.750465      1.249668
# 2    24.978110       1.875325      3.750685      2.500106      1.250578
# 3    43.144785      15.624495      7.500015      9.998660      3.750652
# 4    24.979410      14.686710      7.499892      8.748330      1.249292
#
#    MeanAmpPos  MeanAmpNeg  NumPeaks_ID  NumPosPeaks_ID  NumNegPeaks_ID  \
# 0   11.181670  -10.294509        198.0           101.0            97.0
# 1    8.331531   -8.799846        198.0           101.0            97.0
# 2    9.514662  -10.973763        198.0           101.0            97.0
# 3    8.910585   -6.666027        478.0           220.0           258.0
# 4    3.898276   -3.984866        478.0           220.0           258.0
#
#    MaxAmp_ID  MinAmp_ID  MeanAmp_ID  MeanAmpPos_ID  MeanAmpNeg_ID
# 0  46.676929 -27.570240    0.000081       9.362523      -9.415874
# 1  46.676929 -27.570240    0.000081       9.362523      -9.415874
# 2  46.676929 -27.570240    0.000081       9.362523      -9.415874
# 3  91.147620 -38.193195   -0.000027       6.438788      -5.532838
# 4  91.147620 -38.193195   -0.000027       6.438788      -5.532838

# %%
signal_id = train['signal_id'].values
del train['signal_id']

# %%
target = train['target'].values
del train['target']

# %%
from sklearn.metrics import matthews_corrcoef

# %%
kf = KFold(n_splits=4, random_state=123, shuffle=False)

# %%
skf = StratifiedKFold(n_splits=4, random_state=123, shuffle=False)

# %%
clf = []
val_mcc = []
val_pred = pd.DataFrame([])
proba = []
lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'None',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'binary', 
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }


for train_idx, val_idx in kf.split(train, target):
    X_tr, y_tr = train.iloc[train_idx, :], target[train_idx]
    X_val, y_val = train.iloc[val_idx, :], target[val_idx]
 
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30, feval=mcc_eval)
    pred_lgb = model_lgb.predict(X_val)
    
    best_proba, best_mcc, y_pred = eval_mcc(y_val, pred_lgb, show=True)
    val_mcc.append(best_mcc)
    proba.append(best_proba)
    
    pred_lgb = pd.DataFrame(pred_lgb, index=val_idx)
    val_pred = pd.concat([val_pred, pred_lgb], axis=1)
    
    clf.append(model_lgb)
# Out:
# [1]	valid_0's MCC: 0.591946
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's MCC: 0.63397
# [3]	valid_0's MCC: 0.645179
# [4]	valid_0's MCC: 0.650919
# [5]	valid_0's MCC: 0.642271
# [6]	valid_0's MCC: 0.637717
# [7]	valid_0's MCC: 0.64782
# [8]	valid_0's MCC: 0.649816
# [9]	valid_0's MCC: 0.643278
# [10]	valid_0's MCC: 0.643278
# [11]	valid_0's MCC: 0.643873
# [12]	valid_0's MCC: 0.636896
# [13]	valid_0's MCC: 0.637617
# [14]	valid_0's MCC: 0.635577
# [15]	valid_0's MCC: 0.647611
# [16]	valid_0's MCC: 0.649854
# [17]	valid_0's MCC: 0.649854
# [18]	valid_0's MCC: 0.64937
# [19]	valid_0's MCC: 0.654041
# [20]	valid_0's MCC: 0.65418
# [21]	valid_0's MCC: 0.65418
# [22]	valid_0's MCC: 0.65418
# [23]	valid_0's MCC: 0.658884
# [24]	valid_0's MCC: 0.661154
# [25]	valid_0's MCC: 0.654359
# [26]	valid_0's MCC: 0.658884
# [27]	valid_0's MCC: 0.65418
# [28]	valid_0's MCC: 0.652104
# [29]	valid_0's MCC: 0.654952
# [30]	valid_0's MCC: 0.651704
# [31]	valid_0's MCC: 0.652391
# [32]	valid_0's MCC: 0.649616
# [33]	valid_0's MCC: 0.651896
# [34]	valid_0's MCC: 0.64937
# [35]	valid_0's MCC: 0.644646
# [36]	valid_0's MCC: 0.651896
# [37]	valid_0's MCC: 0.644644
# [38]	valid_0's MCC: 0.647039
# [39]	valid_0's MCC: 0.647039
# [40]	valid_0's MCC: 0.645762
# [41]	valid_0's MCC: 0.647153
# [42]	valid_0's MCC: 0.647153
# [43]	valid_0's MCC: 0.647153
# [44]	valid_0's MCC: 0.644712
# [45]	valid_0's MCC: 0.647024
# [46]	valid_0's MCC: 0.647114
# [47]	valid_0's MCC: 0.649616
# [48]	valid_0's MCC: 0.651711
# [49]	valid_0's MCC: 0.654041
# [50]	valid_0's MCC: 0.661154
# [51]	valid_0's MCC: 0.658884
# [52]	valid_0's MCC: 0.65639
# [53]	valid_0's MCC: 0.661154
# [54]	valid_0's MCC: 0.654359
# Early stopping, best iteration is:
# [24]	valid_0's MCC: 0.661154
# 0.6611536170189366 0.6611536170189366
# [1]	valid_0's MCC: 0.650822
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's MCC: 0.65703
# [3]	valid_0's MCC: 0.65547
# [4]	valid_0's MCC: 0.667157
# [5]	valid_0's MCC: 0.671268
# [6]	valid_0's MCC: 0.668877
# [7]	valid_0's MCC: 0.677951
# [8]	valid_0's MCC: 0.673885
# [9]	valid_0's MCC: 0.680264
# [10]	valid_0's MCC: 0.678791
# [11]	valid_0's MCC: 0.675693
# [12]	valid_0's MCC: 0.673559
# [13]	valid_0's MCC: 0.675693
# [14]	valid_0's MCC: 0.675641
# [15]	valid_0's MCC: 0.670995
# [16]	valid_0's MCC: 0.666349
# [17]	valid_0's MCC: 0.659822
# [18]	valid_0's MCC: 0.662026
# [19]	valid_0's MCC: 0.664247
# [20]	valid_0's MCC: 0.664013
# [21]	valid_0's MCC: 0.660151
# [22]	valid_0's MCC: 0.6596
# [23]	valid_0's MCC: 0.661076
# [24]	valid_0's MCC: 0.660151
# [25]	valid_0's MCC: 0.656228
# [26]	valid_0's MCC: 0.658393
# [27]	valid_0's MCC: 0.661857
# [28]	valid_0's MCC: 0.659406
# [29]	valid_0's MCC: 0.6571
# [30]	valid_0's MCC: 0.65794
# [31]	valid_0's MCC: 0.660151
# [32]	valid_0's MCC: 0.662751
# [33]	valid_0's MCC: 0.662751
# [34]	valid_0's MCC: 0.660151
# [35]	valid_0's MCC: 0.657174
# [36]	valid_0's MCC: 0.655323
# [37]	valid_0's MCC: 0.662563
# [38]	valid_0's MCC: 0.659262
# [39]	valid_0's MCC: 0.658157
# Early stopping, best iteration is:
# [9]	valid_0's MCC: 0.680264
# 0.6802638225152792 0.6802638225152792
# [1]	valid_0's MCC: 0.588218
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's MCC: 0.608808
# [3]	valid_0's MCC: 0.645869
# [4]	valid_0's MCC: 0.623806
# [5]	valid_0's MCC: 0.628384
# [6]	valid_0's MCC: 0.641109
# [7]	valid_0's MCC: 0.64776
# [8]	valid_0's MCC: 0.643733
# [9]	valid_0's MCC: 0.654009
# [10]	valid_0's MCC: 0.640842
# [11]	valid_0's MCC: 0.64724
# [12]	valid_0's MCC: 0.641424
# [13]	valid_0's MCC: 0.643994
# [14]	valid_0's MCC: 0.649761
# [15]	valid_0's MCC: 0.647041
# [16]	valid_0's MCC: 0.648736
# [17]	valid_0's MCC: 0.640065
# [18]	valid_0's MCC: 0.639378
# [19]	valid_0's MCC: 0.6345
# [20]	valid_0's MCC: 0.634269
# [21]	valid_0's MCC: 0.635942
# [22]	valid_0's MCC: 0.639317
# [23]	valid_0's MCC: 0.644743
# [24]	valid_0's MCC: 0.640208
# [25]	valid_0's MCC: 0.647041
# [26]	valid_0's MCC: 0.647041
# [27]	valid_0's MCC: 0.644743
# [28]	valid_0's MCC: 0.644289
# [29]	valid_0's MCC: 0.64772
# [30]	valid_0's MCC: 0.6356
# [31]	valid_0's MCC: 0.63847
# [32]	valid_0's MCC: 0.641906
# [33]	valid_0's MCC: 0.641906
# [34]	valid_0's MCC: 0.636215
# [35]	valid_0's MCC: 0.643356
# [36]	valid_0's MCC: 0.633092
# [37]	valid_0's MCC: 0.631736
# [38]	valid_0's MCC: 0.636056
# [39]	valid_0's MCC: 0.63508
# Early stopping, best iteration is:
# [9]	valid_0's MCC: 0.654009
# 0.6540091855191316 0.6540091855191316
# [1]	valid_0's MCC: 0.585945
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's MCC: 0.596217
# [3]	valid_0's MCC: 0.604515
# [4]	valid_0's MCC: 0.615765
# [5]	valid_0's MCC: 0.613385
# [6]	valid_0's MCC: 0.611603
# [7]	valid_0's MCC: 0.620292
# [8]	valid_0's MCC: 0.614932
# [9]	valid_0's MCC: 0.632573
# [10]	valid_0's MCC: 0.637617
# [11]	valid_0's MCC: 0.637617
# [12]	valid_0's MCC: 0.623193
# [13]	valid_0's MCC: 0.623206
# [14]	valid_0's MCC: 0.629937
# [15]	valid_0's MCC: 0.629433
# [16]	valid_0's MCC: 0.638487
# [17]	valid_0's MCC: 0.636183
# [18]	valid_0's MCC: 0.622627
# [19]	valid_0's MCC: 0.614932
# [20]	valid_0's MCC: 0.617428
# [21]	valid_0's MCC: 0.617785
# [22]	valid_0's MCC: 0.62113
# [23]	valid_0's MCC: 0.62113
# [24]	valid_0's MCC: 0.625016
# [25]	valid_0's MCC: 0.625016
# [26]	valid_0's MCC: 0.627141
# [27]	valid_0's MCC: 0.62274
# [28]	valid_0's MCC: 0.620329
# [29]	valid_0's MCC: 0.627023
# [30]	valid_0's MCC: 0.62398
# [31]	valid_0's MCC: 0.614017
# [32]	valid_0's MCC: 0.614017
# [33]	valid_0's MCC: 0.625589
# [34]	valid_0's MCC: 0.625589
# [35]	valid_0's MCC: 0.622861
# [36]	valid_0's MCC: 0.622861
# [37]	valid_0's MCC: 0.620947
# [38]	valid_0's MCC: 0.617475
# [39]	valid_0's MCC: 0.622861
# [40]	valid_0's MCC: 0.628348
# [41]	valid_0's MCC: 0.640322
# [42]	valid_0's MCC: 0.639821
# [43]	valid_0's MCC: 0.645776
# [44]	valid_0's MCC: 0.645776
# [45]	valid_0's MCC: 0.652453
# [46]	valid_0's MCC: 0.652453
# [47]	valid_0's MCC: 0.652453
# [48]	valid_0's MCC: 0.645538
# [49]	valid_0's MCC: 0.648579
# [50]	valid_0's MCC: 0.648766
# [51]	valid_0's MCC: 0.66157
# [52]	valid_0's MCC: 0.654991
# [53]	valid_0's MCC: 0.658709
# [54]	valid_0's MCC: 0.649567
# [55]	valid_0's MCC: 0.653024
# [56]	valid_0's MCC: 0.653024
# [57]	valid_0's MCC: 0.652453
# [58]	valid_0's MCC: 0.649567
# [59]	valid_0's MCC: 0.649567
# [60]	valid_0's MCC: 0.645538
# [61]	valid_0's MCC: 0.642422
# [62]	valid_0's MCC: 0.645538
# [63]	valid_0's MCC: 0.640992
# [64]	valid_0's MCC: 0.639821
# [65]	valid_0's MCC: 0.637424
# [66]	valid_0's MCC: 0.637424
# [67]	valid_0's MCC: 0.637424
# [68]	valid_0's MCC: 0.633908
# [69]	valid_0's MCC: 0.643233
# [70]	valid_0's MCC: 0.643233
# [71]	valid_0's MCC: 0.633443
# [72]	valid_0's MCC: 0.63097
# [73]	valid_0's MCC: 0.639475
# [74]	valid_0's MCC: 0.639475
# [75]	valid_0's MCC: 0.642794
# [76]	valid_0's MCC: 0.643233
# [77]	valid_0's MCC: 0.646157
# [78]	valid_0's MCC: 0.643835
# [79]	valid_0's MCC: 0.642794
# [80]	valid_0's MCC: 0.643835
# [81]	valid_0's MCC: 0.643835
# Early stopping, best iteration is:
# [51]	valid_0's MCC: 0.66157
# 0.6615704222717651 0.6615704222717651

# %%
proba
# Out:
# [0.25444568970246445,
#  0.21272104273302125,
#  0.33056543233236546,
#  0.35742549139162166]

# %%
val_mcc
# Out:
# [0.6611536170189366,
#  0.6802638225152792,
#  0.6540091855191316,
#  0.6615704222717651]

# %%
np.mean(val_mcc)
# Out:
# 0.6642492618312781

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(target, (np.sum(val_pred, axis=1)>np.mean(proba)).astype(int))
# Out:
# array([[7986,  201],
#        [ 170,  355]])

# %%
best_proba, best_mcc, y_pred = eval_mcc(target, np.sum(val_pred, axis=1), show=True)
# Out:
# 0.6409611225905376 0.6409611225905376

# %%
feature_imp = np.zeros(train.shape[1])
for model in clf:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp/4, index=train.columns).sort_values(by=0, ascending=False)
# Out:
#                           0
# NumNegPeaks_ID  4794.769107
# MeanAmpNeg_ID   1553.467728
# MinAmp_ID        785.545135
# NumPosPeaks_ID   742.403401
# MeanAmpPos_ID    727.445287
# MaxAmp_ID        320.713815
# NumPeaks_ID      270.777929
# MeanAmp_ID       228.963528
# MeanAmpAll_AD    208.782245
# id_measurement   169.319849
# NumNegPeaks      154.781474
# StdAmpAll_AD     122.730525
# NumPosPeaks      115.478486
# StdAmpQ2          93.200115
# StdAmpQ2_AD       83.836037
# StdWidthQ2        78.938200
# StdPosQ2          73.036472
# StdWidthQ3        71.424083
# StdWidthQ4        64.578054
# NumPeaks          54.265613
# MeanAmpQ2_AD      53.049565
# StdAmpQ3          51.887679
# MeanAmpQ4_AD      50.204605
# StdAmpQ4_AD       44.710657
# MinAmp            35.069905
# StdAmpQ4          34.275728
# StdAmpQ3_AD       32.814398
# MaxWidth          28.698902
# StdPosAll         28.634045
# StdPosQ4          26.519710
# MeanAmpNeg        25.472495
# MeanAmpQ3_AD      24.025465
# StdPosQ3          23.498898
# MaxAmp            17.513613
# MeanWidth         16.329427
# StdWidthAll       15.517625
# MeanAmpPos         7.463112
# MeanAmp            6.174082
# StdAmpAll          2.501650
# MinWidth           0.811005
# phase              0.000000

# %%
feature_imp = []
for model in clf:
    feature_imp.append(model.feature_importance(importance_type='gain'))

pd.DataFrame(feature_imp, columns=train.columns).T.sort_values(by=0, ascending=False)
# Out:
#                           0            1            2            3
# NumNegPeaks_ID  5103.614702  4279.206081  4313.958845  5482.296800
# MeanAmpNeg_ID   1818.331578  1491.984712  1200.266795  1703.287825
# MinAmp_ID        951.040191   649.337694   702.749199   839.053455
# NumPosPeaks_ID   682.607888   274.558397   359.285502  1653.161818
# MeanAmpPos_ID    518.216208   837.842502   881.949786   671.772650
# MeanAmpAll_AD    316.362493   198.913204    67.915499   251.937786
# MeanAmp_ID       315.186631    91.857801   167.642570   341.167108
# NumPeaks_ID      308.049067   407.007298   151.274500   216.780850
# MaxAmp_ID        211.275262   127.034039   533.261098   411.284861
# StdAmpQ2_AD      166.752160    21.579800    40.396500   106.615690
# NumPeaks         160.646052     6.589180     0.000000    49.827219
# id_measurement   155.514691   126.407628    56.089500   339.267579
# StdAmpAll_AD     122.925870    95.968652    25.072800   246.954779
# NumNegPeaks      100.723928   161.783997   346.110500    10.507470
# StdAmpQ2         100.490379    34.799999    34.729900   202.780182
# NumPosPeaks       98.723638     0.000000     0.000000   363.190305
# MeanAmpQ2_AD      94.125521    25.810600    31.192599    61.069541
# MinAmp            77.520860     9.428780     0.000000    53.329979
# StdWidthQ2        59.669751    73.691131    38.672900   143.719020
# StdWidthQ3        58.739633    15.856700    74.225101   136.874900
# MaxWidth          44.336660     6.395700     0.000000    64.063250
# StdPosQ3          44.191601     0.000000     0.000000    49.803990
# MeanAmpNeg        40.083599    24.260799    31.879040     5.666540
# StdPosQ2          39.067820    88.752399    16.174801   148.150869
# StdAmpQ4          37.717090    23.203800    27.931001    48.251020
# StdPosQ4          37.120180     9.307840    18.167900    41.482920
# StdAmpQ3          26.805091    39.837898    92.344999    48.562729
# StdPosAll         26.067121     0.000000     0.000000    88.469060
# MeanAmpPos        25.694580     0.000000     0.000000     4.157870
# MeanAmpQ3_AD      22.530510    10.861200    11.056300    51.653850
# StdWidthAll       19.798070     0.000000    19.288300    22.984130
# StdWidthQ4        17.688860    98.191629    80.496199    61.935529
# MeanAmpQ4_AD      17.301140    27.543600    37.017800   118.955880
# StdAmpQ3_AD       15.684440     0.000000    40.743500    74.829652
# MaxAmp            11.707510    16.750299     0.000000    41.596641
# MeanAmp           10.898100     8.403040     0.000000     5.395190
# MeanWidth         10.237800     0.000000    12.465600    42.614310
# StdAmpQ4_AD        7.826740     0.000000   119.532698    51.483190
# MinWidth           0.000000     0.000000     0.000000     3.244020
# StdAmpAll          0.000000     0.000000    10.006600     0.000000
# phase              0.000000     0.000000     0.000000     0.000000

# %%
best_proba
# Out:
# 0.33056543233236546

# %%
numpeaks = np.load('../features/numpeaks_test.npy')
numpospeaks = np.load('../features/numpospeaks_test.npy')
numnegpeaks = np.load('../features/numnegpeaks_test.npy')

maxpeakwidth = np.load('../features/maxpeakwidth_test.npy')
minpeakwidth = np.load('../features/minpeakwidth_test.npy')
meanpeakwidth = np.load('../features/meanpeakwidth_test.npy')
maxamp = np.load('../features/maxamp_test.npy')
minamp = np.load('../features/minamp_test.npy')
meanamp = np.load('../features/meanamp_test.npy')

stdampall = np.load('../features/stdampall_test.npy')
stdposall = np.load('../features/stdposall_test.npy')
stdwidthall = np.load('../features/stdwidthall_test.npy')

stdampq2 = np.load('../features/stdampq2_test.npy')
stdposq2 = np.load('../features/stdposq2_test.npy')
stdwidthq2 = np.load('../features/stdwidthq2_test.npy')
stdampq3 = np.load('../features/stdampq3_test.npy')
stdposq3 = np.load('../features/stdposq3_test.npy')
stdwidthq3 = np.load('../features/stdwidthq3_test.npy')
stdampq4 = np.load('../features/stdampq4_test.npy')
stdposq4 = np.load('../features/stdposq4_test.npy')
stdwidthq4 = np.load('../features/stdwidthq4_test.npy')

# %%
stdampall_ad = np.load('../features/stdampall_ad_test.npy')
stdampq2_ad = np.load('../features/stdampq2_ad_test.npy')
stdampq3_ad = np.load('../features/stdampq3_ad_test.npy')
stdampq4_ad = np.load('../features/stdampq4_ad_test.npy')

meanampall_ad = np.load('../features/meanampall_ad_test.npy')
meanampq2_ad = np.load('../features/meanampq2_ad_test.npy')
meanampq3_ad = np.load('../features/meanampq3_ad_test.npy')
meanampq4_ad = np.load('../features/meanampq4_ad_test.npy')

meanamppos = np.load('../features/meanamppos_test.npy')
meanampneg = np.load('../features/meanampneg_test.npy')

# %%
numpeaks_id = np.load('../features/numpeaks_id_test.npy')
numpospeaks_id = np.load('../features/numpospeaks_id_test.npy')
numnegpeaks_id = np.load('../features/numnegpeaks_id_test.npy')

maxamp_id = np.load('../features/maxamp_id_test.npy')
minamp_id = np.load('../features/minamp_id_test.npy')
meanamp_id = np.load('../features/meanamp_id_test.npy')

meanamppos_id = np.load('../features/meanamppos_id_test.npy')
meanampneg_id = np.load('../features/meanampneg_id_test.npy')

# %%
test_features = pd.DataFrame({'NumPeaks':numpeaks, 'NumPosPeaks':numpospeaks, 'NumNegPeaks':numnegpeaks, 'MaxWidth':maxpeakwidth,
                         'MinWidth':minpeakwidth, 'MeanWidth':meanpeakwidth, 'MaxAmp':maxamp, 'MinAmp':minamp, 'MeanAmp':meanamp,
                        'StdAmpAll':stdampall, 'StdPosAll':stdposall, 'StdWidthAll':stdwidthall, 'StdAmpQ2':stdampq2, 'StdPosQ2':stdposq2,
                         'StdWidthQ2':stdwidthq2, 'StdAmpQ3':stdampq3, 'StdPosQ3':stdposq3, 'StdWidthQ3':stdwidthq3,
                        'StdAmpQ4':stdampq4, 'StdPosQ4':stdposq4, 'StdWidthQ4':stdwidthq4, 
                        'StdAmpAll_AD':stdampall_ad, 'StdAmpQ2_AD': stdampq2_ad, 'StdAmpQ3_AD': stdampq3_ad, 'StdAmpQ4_AD': stdampq4_ad,
                        'MeanAmpAll_AD':meanampall_ad, 'MeanAmpQ2_AD': meanampq2_ad,
                        'MeanAmpQ3_AD': meanampq3_ad, 'MeanAmpQ4_AD': meanampq4_ad,
                        'MeanAmpPos':meanamppos, 'MeanAmpNeg':meanampneg,
                        'NumPeaks_ID':numpeaks_id[0:20000], 'NumPosPeaks_ID':numpospeaks_id[0:20000], 'NumNegPeaks_ID':numnegpeaks_id[0:20000],
                        'MaxAmp_ID':maxamp_id[0:20000], 'MinAmp_ID':minamp_id[0:20000], 'MeanAmp_ID':meanamp_id[0:20000],
                        'MeanAmpPos_ID':meanamppos_id[0:20000], 'MeanAmpNeg_ID':meanampneg_id[0:20000]})

# %%
test = pd.concat([meta_test, test_features], axis=1)

# %%
test_id = test['signal_id'].values
del test['signal_id']

# %%
preds = clf[1].predict(test)

# %%
submission = pd.DataFrame({'signal_id':test_id,'target':(preds>proba[1]).astype(int)})

# %%
submission.to_csv('../output/submission_13.csv', index=False)

# %%
np.max(preds)
# Out:
# 0.7359073152454013

# %%
pd.Series((preds>proba[1]).astype(int)).value_counts()
# Out:
# 0    19426
# 1      911
# dtype: int64

# %%
proba[1]
# Out:
# 0.21272104273302125
